# %%
mes = '01'

# %%
#manipulação de dados
import pandas as pd
import numpy as np

#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)
import warnings #Warning inuteis
from pandas.errors import SettingWithCopyWarning
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import unidecode #arrumar strings

import re #regex
import os

import pyautogui

# %%
#definindo quantidade de linhas e colunas visiveis
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#######################-FUNÇÕES
def count_freq(data_frame, coluna):
    freq = df[coluna].value_counts()
    perc = df[coluna].value_counts(normalize = True)*100
    tabela = pd.DataFrame({"Freq":freq, "Perc":perc})
    return display(tabela)

def salvando_nome_arquivo(nome_arquivo, dataframe):
    if os.path.exists(nome_arquivo): #O nome_arquivo existe
        df1 = pd.read_excel(nome_arquivo)
        len_antigo = len(dataframe)
        
        dataframe = pd.concat([df1, dataframe]).reset_index(drop=True)
        dataframe = dataframe.drop_duplicates(subset=['chat'])
        
        print(len(df1), " += ", len_antigo, "=>", len(dataframe))
        
        dataframe.to_excel(nome_arquivo, index=False)
    
    else: #O nome_arquivo não existe
        dataframe.to_excel(nome_arquivo, index=False)
        print(len(dataframe)) 
        
def tabela_cont(linha, coluna):
    a = df.groupby([linha, coluna]).size().unstack()
    for i in a.columns:
        a[i].fillna(0, inplace = True)
        a[i] = a[i].apply(lambda x: int(x))
    return a
    print('='*100)

def tabela_cont_percent(linha, coluna, opcao):
    result = tabela_cont(linha, coluna)
    if opcao == 'Linha':
        return round(result.div(result.sum(axis=1), axis=0) * 100, 2)
    elif opcao == 'Coluna':
        return round(result.div(result.sum(), axis=1) * 100, 2)
    else:
        return 'Opção invalida'

# %%
#abrindo navegador
browser = webdriver.Firefox()

# %%
browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()

# %% [markdown]
# # Capturando setores:

# %%
#click criar novo plantão
def criar_plantao():
    browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr[1]/td[4]/button').click()
    
criar_plantao()

# %%
inicio = time.time() #iniciando o cronometro

#Setor
browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()

setor_html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML')
soup = BeautifulSoup(setor_html, 'html.parser')

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.8010754585266113

# %%
inicio = time.time() #iniciando o cronometro

lista_unidade = []
lista_unidade_count = []
lista_plt = []
lista_plt_count = []

count_unidade = 1

for i in soup.find_all(class_="select2-results-dept-0 select2-result select2-result-unselectable select2-result-with-children"):
    #print('\n', i.find(class_='select2-result-label').get_text(), '====== \n')
    count_plt = 1
    for t in i.find_all(class_='select2-results-dept-1 select2-result select2-result-selectable'): 
        #print(t.get_text())
        lista_plt.append(t.get_text())
        lista_plt_count.append(count_plt)
        count_plt += 1
            
        lista_unidade.append(i.find(class_='select2-result-label').get_text())
        lista_unidade_count.append(count_unidade)
    count_unidade += 1

scrap_unidades = pd.DataFrame({'unidade':lista_unidade, 'momento':lista_plt,
                               'unidade_count':lista_unidade_count, 'plt_count':lista_plt_count})

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: x.replace('  ',' '))

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))
scrap_unidades['unidade'] = scrap_unidades['unidade'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.020888805389404297

# %%
#scrap_unidades.to_excel("setores.xlsx", index=False)
scrap_unidades.sample(20)
# Out:
#                 unidade                             momento  unidade_count  \
# 181               VILLA    SEMANA - TARDE - COBERTURA EXTRA             12
# 2         ADMINISTRACAO             PERIODO DE DESCANSO - 2              1
# 78                ITAIM        SEMANA - NOTURNO - DISTANCIA              6
# 71                ITAIM                        SEMANA - 6HS              6
# 142              OSASCO  SEMANA - MANHA - AV.PRE ANESTESICA             10
# 51             AVICCENA                       FDS - PLANTAO              4
# 43               ANALIA        SEMANA - TARDE - C.CIRURGICO              3
# 38               ANALIA  SEMANA - MANHA - AV.PRE ANESTESICA              3
# 56             AVICCENA        SEMANA - NOTURNO - DISTANCIA              4
# 86            JABAQUARA                            FDS - D2              7
# 59   H.GABRIEL DO ANJOS            FDS - C.CIRURGICO ROTINA              5
# 37               ANALIA                        SEMANA - 6HS              3
# 175               VILLA  SEMANA - MANHA - AV.PRE ANESTESICA             12
# 99          MATERNIDADE                           FDS - 6HS              8
# 40               ANALIA        SEMANA - MANHA - C.CIRURGICO              3
# 89            JABAQUARA                        SEMANA - 6HS              7
# 46               ANALIA          SEMANA - NOTURNO - PLANTAO              3
# 138              OSASCO                            FDS - D2             10
# 106         MATERNIDADE    SEMANA - MANHA - COBERTURA EXTRA              8
# 149              OSASCO          SEMANA - NOTURNO - PLANTAO             10
#
#      plt_count
# 181         16
# 2            3
# 78          17
# 71          10
# 142          9
# 51           4
# 43          16
# 38          11
# 56           9
# 86           6
# 59           1
# 37          10
# 175         10
# 99           1
# 40          13
# 89           9
# 46          19
# 138          5
# 106          8
# 149         16

# %%
scrap_unidades[scrap_unidades['unidade'] == 'SANTA ISABEL']
# Out:
#           unidade                             momento  unidade_count  \
# 151  SANTA ISABEL                           FDS - 6HS             11
# 152  SANTA ISABEL     FDS - MANHA - AV.PRE ANESTESICA             11
# 153  SANTA ISABEL           FDS - MANHA - C.CIRURGICO             11
# 154  SANTA ISABEL                            FDS - D1             11
# 155  SANTA ISABEL                       FDS - PLANTAO             11
# 156  SANTA ISABEL                         FDS - SAIDA             11
# 157  SANTA ISABEL                        SEMANA - 6HS             11
# 158  SANTA ISABEL  SEMANA - MANHA - AV.PRE ANESTESICA             11
# 159  SANTA ISABEL        SEMANA - MANHA - C.CIRURGICO             11
# 160  SANTA ISABEL    SEMANA - MANHA - COBERTURA EXTRA             11
# 161  SANTA ISABEL        SEMANA - TARDE - C.CIRURGICO             11
# 162  SANTA ISABEL    SEMANA - TARDE - COBERTURA EXTRA             11
# 163  SANTA ISABEL        SEMANA - NOTURNO - DISTANCIA             11
# 164  SANTA ISABEL          SEMANA - NOTURNO - PLANTAO             11
# 165  SANTA ISABEL            SEMANA - NOTURNO - SAIDA             11
#
#      plt_count
# 151          1
# 152          2
# 153          3
# 154          4
# 155          5
# 156          6
# 157          7
# 158          8
# 159          9
# 160         10
# 161         11
# 162         12
# 163         13
# 164         14
# 165         15

# %% [markdown]
# # TESTANDO SETORES

# %%
# df_gabs
# df_continuar

df_backup = pd.read_excel('continuar.xlsx')
df_backup = df_backup.sort_values(['nome', 'data', 'periodo2'], ascending=[True, True, False]).reset_index(drop=True)
#df = df.sort_values(['nome', 'data']).reset_index(drop=True)

df_backup = df_backup.drop('Unnamed: 0.1', axis=1)
df_backup = df_backup.drop('Unnamed: 0', axis=1)

df_ok = df_backup[df_backup['controle'] == "OK"].reset_index(drop=True)
print('df_ok:', len(df_ok))
df_backup = df_backup[df_backup['controle'] != "OK"].reset_index(drop=True)
print('df_prob:', len(df_backup))

df = df_backup.copy()
print(len(df))
df.head()
# Out:
# df_ok: 347
# df_prob: 966
# 966
#                                                 chat         dia  \
# 0  [17/01/2024 22:57:57] Amanda Kiyoko Souza Koss...  17/01/2024
# 1  [18/01/2024 18:38:01] Ana Jung Docko: 18/01 An...  18/01/2024
# 2  [19/01/2024 18:53:54] Ana Jung Docko: 19/01 An...  19/01/2024
# 3  [02/01/2024 08:55:15] André Augusto Bellini: 0...  02/01/2024
# 4  [04/01/2024 14:57:44] André Augusto Bellini: 0...  04/01/2024
#
#                           nome  \
# 0  AMANDA KIYOKO SOUZA KOSSAKA
# 1               ANA JUNG DOCKO
# 2               ANA JUNG DOCKO
# 3        ANDRE AUGUSTO BELLINI
# 4        ANDRE AUGUSTO BELLINI
#
#                                             mensagem controle        data  \
# 0               17/01 MORUMBI  -  Amanda saída 22:40     PROB  17/01/2024
# 1                       18/01 Analia Ana saída 18:35     PROB  18/01/2024
# 2                       19/01 Analia Ana saída 18:40     PROB  19/01/2024
# 3  02/01 Osasco  -  Bellini entrada 09:00   (   a...     PROB  02/01/2024
# 4            04/01 JABAQUARA  -  Bellini saída 14:50     PROB  04/01/2024
#
#      unidade extra     tipo ENTRADA  SAIDA DURAÇÃO        PERIODO  periodo2  \
# 0    MORUMBI   NaN    SAIDA   19:00  23:00   04:00  noturno saida         4
# 1     ANALIA   NaN    SAIDA   19:00  19:00   06:00  noturno saida         4
# 2     ANALIA   NaN    SAIDA   19:00  19:00   06:00  noturno saida         4
# 3     OSASCO   NaN  ENTRADA   09:00  13:00   04:00          manha         2
# 4  JABAQUARA   NaN    SAIDA   13:00  15:00   02:00          tarde         3
#
#                           setor sem_ou_fds unidade2 setor_inicio  hora
# 0      SEMANA - NOTURNO - SAIDA     semana  MORUMBI          NaN   NaN
# 1      SEMANA - NOTURNO - SAIDA     semana   ANALIA          NaN   NaN
# 2      SEMANA - NOTURNO - SAIDA     semana   ANALIA          NaN   NaN
# 3  SEMANA - MANHA - C.CIRURGICO     semana   OSASCO          NaN   NaN
# 4  SEMANA - TARDE - C.CIRURGICO     semana     JABA          NaN   NaN

# %%
df['setor'][(df['setor'] == 'FDS - C.CIRURGICO ROTINA') & (df['unidade'] == 'SANTA ISABEL')] = 'FDS - MANHA - C.CIRURGICO'

# %%
for X in range(0, len(df)):
    if len(scrap_unidades.loc[(scrap_unidades.unidade == df['unidade'][X]) & 
                                 (scrap_unidades.momento == df['setor'][X])]) < 1:
        print(X)
        print(df['unidade'][X], '-', df['setor'][X])
        #print('index', ind)
        #print(scrap_unidades['unidade'][ind], '-', scrap_unidades['momento'][ind])
        #print('codigos:', unidade, setorzin)
        

print("="*20, "TUDO OK", "="*20)
# Out:
# ==================== TUDO OK ====================

# %%
print(df['unidade'][X])
print(df['setor'][X])
# Out:
# MORUMBI
# FDS - 6HS

# %% [markdown]
# # =========================================================

# %% [markdown]
# # FUNÇÕES

# %%
def reset_selecao():
    posicao_antiga = pyautogui.position()
    pyautogui.click(x=214, y=251)
    pyautogui.moveTo(posicao_antiga)
    
reset_selecao()

# %%
def setor(unidade, setor):
    #print('base:', unidade, '-', setor)
    browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()
    ind = scrap_unidades.loc[(scrap_unidades.unidade == unidade) & 
                             (scrap_unidades.momento == setor)].index.values[0]
    unidade_sel = scrap_unidades['unidade_count'][ind]
    setor_sel = scrap_unidades['plt_count'][ind]
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade_sel)+']/ul/li['+str(setor_sel)+']/div').click()
    
setor("SANTA ISABEL", "SEMANA - TARDE - C.CIRURGICO")

def nome(nome_profissional):
    #listar todos
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
    
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
    sleep(1)
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionalA"]/a/span[1]').click()
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(nome_profissional)
    #Dando enter
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(Keys.RETURN)
    
nome('OTTO MITTERMAYER')

def hora(inicio, duracao):
    #Inicio do plantão
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').send_keys(inicio)
    sleep(1)
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').send_keys(duracao)
    
hora('13:30', '05:00')
    
def data(data_selecionada):
    browser.find_element("xpath", '/html/body/div[5]/div/div[2]/div[2]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').clear()
    sleep(1)
    browser.find_element("xpath", '/html/body/div[5]/div/div[2]/div[2]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').send_keys(data_selecionada)
    sleep(1)
    
data("10/01/2024")
reset_selecao()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[27], line 10
#       7     setor_sel = scrap_unidades['plt_count'][ind]
#       8     browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade_sel)+']/ul/li['+str(setor_sel)+']/div').click()
# ---> 10 setor("SANTA ISABEL", "SEMANA - TARDE - C.CIRURGICO")
#      12 def nome(nome_profissional):
#      13     #listar todos
#      14     browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
#
# Cell In[27], line 3, in setor(unidade, setor)
#       1 def setor(unidade, setor):
#       2     #print('base:', unidade, '-', setor)
# ----> 3     browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()
#       4     ind = scrap_unidades.loc[(scrap_unidades.unidade == unidade) &
#       5                              (scrap_unidades.momento == setor)].index.values[0]
#       6     unidade_sel = scrap_unidades['unidade_count'][ind]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: Element <span class="select2-chosen"> could not be scrolled into view
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:191:5
# ElementNotInteractableError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:351:5
# webdriverClickElement@chrome://remote/content/marionette/interaction.sys.mjs:166:11
# interaction.clickElement@chrome://remote/content/marionette/interaction.sys.mjs:135:11
# clickElement@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:204:29
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:84:31

# %%
def pontuacao(pontos):
    browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(pontos) #Pontos

pontuacao("666")
'''
//*[@id="select2-drop"]/ul/li[3]/div
1 - Normal
2 - DESLOCAMENTO
3 - VOLUNTÁRIO
4 - COBERTURA
'''
def tipo_do_registro(duracao, sem_ou_fds, tipo_registro):
    if tipo_registro == 'extra':
        print('EXTRA')
        sleep(1)
        reset_selecao()
        
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        #browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(1)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[3]/div').click()
        if int(duracao[:2]) >= 5 and sem_ou_fds == "semana":
            pontuacao(200)
            pontuacao(200)
            print('duração >= 5 => 200 pontos')
        else:
            pass
    elif tipo_registro == 'DESLOCADO':
        print('DESLOCADO')
        sleep(1)
        reset_selecao()
        
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        #browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(1)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()
        if int(duracao[:2]) >= 5 and sem_ou_fds == "semana":
            pontuacao(100)
            pontuacao(100)
            print('duração >5 -> 100 pontos')
        else:
            pass
        sleep(1)
    else:
        if int(duracao[:2]) >= 5 and sem_ou_fds == "semana":
            pontuacao(100)
            pontuacao(100)
            print('duração >5 -> 100 pontos')
        else:
            pass
        sleep(1)

#tipo_do_registro("05:00", "semana", "extra")
#tipo_do_registro(df['DURAÇÃO'][h], df['sem_ou_fds'][h], df['extra'][h])
        
def salvar_plantao():
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    
#salvar_plantao()

def fechar():
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button').click()

fechar()

# %%
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

# %%
#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# # =========================================================

# %% [markdown]
# # =======================================================================

# %% [markdown]
# # =======================================================================

# %%
######### ######### FUNÇÃO DE CAPTURA ######### ######### 
#capturando registros
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

def funcao():
    lista_tabela = []
    for i in range(1, 6): #passando por cada semana[1 a 5]
    ##print('semana:', i, "=="*20)
        for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
            reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
            content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
            content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra

            dia = content[0] #dia do registro
            del(content[0]) #deletando o dia, ja que foi coletado
            del(content[-1]) #deletando resido do wepscraping

            if len(content) != 0: #ignorando dias em branco (sem registro) ¹
                #print('dia:', t)

                ##print('dia:', dia)
                #print(content)

                count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
                lista_control = []
                for y in content: #passando um for sobre cada item da lista
                    if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                        #print('================unidade:', y)
                        unidade = y
                    elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                        count_hora += 1
                        if count_hora == 1: #capturando entrada
                            #print('hora entrada:', y)
                            lista_control.append(y)
                        elif count_hora == 2: #capturando saida
                            #print('hora saida:', y)
                            lista_control.append(y)
                            ##print('lista teste', lista_control)
                            lista_tabela.append(lista_control)
                            lista_control = []
                            count_hora = 0
                    else: #capturando dia, unidade, e periodo
                        #print('.')
                        #print('periodo:', y)
                        lista_control.append(dia)
                        lista_control.append(unidade)
                        lista_control.append(y)
                        lista_control.append(i)
                        lista_control.append(t) #dia semanal

                ##print('='*20)    

            else:
                continue #ignorando dias em branco (sem registro) ²
    
    tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Dia Semana','Entrada','Saida'])
    
    #limpeza da tabela
    #########3
    tabela['Dia'] = tabela['Dia'].apply(lambda x: int(x))

    #recolhendo os dias do mes passado que ainda aparecem na primeira semana
    dias_mes_passado = list(tabela[(tabela['Dia'] > 20) & (tabela['Semana'] == 1)].index) 
    tabela.drop(dias_mes_passado, axis=0, inplace=True) #excluindo
    tabela.reset_index(drop=True, inplace=True) #resetando index

    #Inserindo a ordem dos registros
    tabela['ordem'] = ''

    for i in tabela['Dia'].unique():
        for t in range(0, len(tabela[tabela['Dia'] == i].index)):
            tabela['ordem'][tabela[tabela['Dia'] == i].index[t]] = t+1

    #Inserindo coluna de data        
    tabela['data'] = tabela['Dia'].apply(lambda x: str(x))

    for i in range(len(tabela)):
        if len(tabela['data'][i]) == 1:
            tabela['data'][i] = "0" + tabela['data'][i]

        tabela['data'][i] = tabela['data'][i] + "/" + mes + "/2024" 

    tabela = tabela.query("Unidade != 'ADMINISTRACAO'")
    tabela = tabela[~((tabela['Semana'] >= 5) & (tabela['Dia'] < 10))]
    tabela.reset_index(drop=True, inplace=True) #resetando index
    
    tabela['PERIODO'] = np.nan
    for i in range(0, len(tabela)):
        if int(tabela['Entrada'][i][:2]) <= 6:
            tabela['PERIODO'][i] = '6h'
        elif int(tabela['Entrada'][i][:2]) >= 7 and int(tabela['Entrada'][i][:2]) <= 12:
            tabela['PERIODO'][i] = 'manha'
        elif int(tabela['Entrada'][i][:2]) >= 13 and int(tabela['Entrada'][i][:2]) <= 18:
            tabela['PERIODO'][i] = 'tarde'
        else:
            tabela['PERIODO'][i] = 'noturno saida'

    tabela['periodo'] = np.nan
    tabela['periodo'][tabela['PERIODO'] == '6h'] = 1
    tabela['periodo'][tabela['PERIODO'] == 'manha'] = 2
    tabela['periodo'][tabela['PERIODO'] == 'tarde'] = 3
    tabela['periodo'][tabela['PERIODO'] == 'noturno saida'] = 4
    
    return tabela
    
tabela = funcao()
tabela
# Out:
#     Dia Unidade                       Periodo  Semana  Dia Semana Entrada  \
# 0     2   ITAIM  SEMANA - TARDE - C.CIRURGICO       2           1   13:00
# 1     3   ITAIM                  SEMANA - 6HS       2           2   06:00
# 2     3   ITAIM  SEMANA - MANHA - C.CIRURGICO       2           2   07:00
# 3     9   ITAIM  SEMANA - TARDE - C.CIRURGICO       3           1   13:00
# 4     9   ITAIM      SEMANA - NOTURNO - SAIDA       3           1   19:00
# 5    10   ITAIM                  SEMANA - 6HS       3           2   05:00
# 6    10   ITAIM  SEMANA - MANHA - C.CIRURGICO       3           2   07:00
# 7    10   ITAIM  SEMANA - TARDE - C.CIRURGICO       3           2   13:00
# 8    11   ITAIM                  SEMANA - 6HS       3           3   06:00
# 9    11   ITAIM      SEMANA - NOTURNO - SAIDA       3           3   19:00
# 10   14   ITAIM                     FDS - 6HS       3           6   05:00
# 11   14   ITAIM      FDS - C.CIRURGICO ROTINA       3           6   07:00
# 12   14   ITAIM                   FDS - SAIDA       3           6   13:00
# 13   15   ITAIM      SEMANA - NOTURNO - SAIDA       3           7   19:00
# 14   16   ITAIM                  SEMANA - 6HS       4           1   06:00
# 15   16   ITAIM  SEMANA - MANHA - C.CIRURGICO       4           1   07:00
# 16   16   ITAIM      SEMANA - NOTURNO - SAIDA       4           1   19:00
# 17   17   ITAIM                  SEMANA - 6HS       4           2   05:00
# 18   17   ITAIM  SEMANA - MANHA - C.CIRURGICO       4           2   07:00
# 19   17   ITAIM  SEMANA - TARDE - C.CIRURGICO       4           2   13:00
# 20   17   ITAIM      SEMANA - NOTURNO - SAIDA       4           2   19:00
# 21   18   ITAIM      SEMANA - NOTURNO - SAIDA       4           3   19:00
# 22   19   ITAIM                  SEMANA - 6HS       4           4   06:00
# 23   19   ITAIM  SEMANA - MANHA - C.CIRURGICO       4           4   07:00
# 24   19   ITAIM      SEMANA - NOTURNO - SAIDA       4           4   19:00
# 25   23   ITAIM  SEMANA - TARDE - C.CIRURGICO       5           1   13:00
# 26   24   ITAIM  SEMANA - MANHA - C.CIRURGICO       5           2   07:00
# 27   24   ITAIM  SEMANA - TARDE - C.CIRURGICO       5           2   13:00
# 28   24   ITAIM      SEMANA - NOTURNO - SAIDA       5           2   19:00
# 29   25   ITAIM                  SEMANA - 6HS       5           3   06:00
# 30   25   ITAIM  SEMANA - MANHA - C.CIRURGICO       5           3   07:00
# 31   25   ITAIM  SEMANA - TARDE - C.CIRURGICO       5           3   13:00
# 32   26   ITAIM  SEMANA - MANHA - C.CIRURGICO       5           4   07:00
# 33   26   ITAIM  SEMANA - TARDE - C.CIRURGICO       5           4   13:00
# 34   26   ITAIM      SEMANA - NOTURNO - SAIDA       5           4   19:00
# 35   27   ITAIM                  SEMANA - 6HS       5           5   06:00
# 36   27   ITAIM  SEMANA - MANHA - C.CIRURGICO       5           5   07:00
# 37   27   ITAIM  SEMANA - TARDE - C.CIRURGICO       5           5   13:00
# 38   28   ITAIM                     FDS - 6HS       5           6   06:00
# 39   28   ITAIM      FDS - C.CIRURGICO ROTINA       5           6   07:00
# 40   28   ITAIM                   FDS - SAIDA       5           6   13:00
#
#     Saida ordem        data        PERIODO  periodo
# 0   19:00     1  02/01/2024          tarde      3.0
# 1   07:00     1  03/01/2024             6h      1.0
# 2   10:30     2  03/01/2024          manha      2.0
# 3   19:00     1  09/01/2024          tarde      3.0
# 4   19:30     2  09/01/2024  noturno saida      4.0
# 5   07:00     1  10/01/2024             6h      1.0
# 6   13:00     2  10/01/2024          manha      2.0
# 7   18:30     3  10/01/2024          tarde      3.0
# 8   07:00     3  11/01/2024             6h      1.0
# 9   20:00     4  11/01/2024  noturno saida      4.0
# 10  07:00     1  14/01/2024             6h      1.0
# 11  13:00     2  14/01/2024          manha      2.0
# 12  15:00     3  14/01/2024          tarde      3.0
# 13  21:00     1  15/01/2024  noturno saida      4.0
# 14  07:00     2  16/01/2024             6h      1.0
# 15  10:30     3  16/01/2024          manha      2.0
# 16  20:00     4  16/01/2024  noturno saida      4.0
# 17  07:00     3  17/01/2024             6h      1.0
# 18  13:00     4  17/01/2024          manha      2.0
# 19  17:00     5  17/01/2024          tarde      3.0
# 20  21:00     6  17/01/2024  noturno saida      4.0
# 21  21:00     3  18/01/2024  noturno saida      4.0
# 22  07:00     3  19/01/2024             6h      1.0
# 23  11:30     4  19/01/2024          manha      2.0
# 24  01:00     5  19/01/2024  noturno saida      4.0
# 25  19:00     1  23/01/2024          tarde      3.0
# 26  13:00     1  24/01/2024          manha      2.0
# 27  19:00     2  24/01/2024          tarde      3.0
# 28  23:30     3  24/01/2024  noturno saida      4.0
# 29  07:00     1  25/01/2024             6h      1.0
# 30  13:00     2  25/01/2024          manha      2.0
# 31  13:30     3  25/01/2024          tarde      3.0
# 32  13:00     1  26/01/2024          manha      2.0
# 33  19:00     2  26/01/2024          tarde      3.0
# 34  20:00     3  26/01/2024  noturno saida      4.0
# 35  07:00     1  27/01/2024             6h      1.0
# 36  13:00     2  27/01/2024          manha      2.0
# 37  15:30     3  27/01/2024          tarde      3.0
# 38  07:00     1  28/01/2024             6h      1.0
# 39  13:00     2  28/01/2024          manha      2.0
# 40  13:30     3  28/01/2024          tarde      3.0

# %%
def atualizando_plantao():
    #browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[2]/button[5]').click()
    browser.find_element("xpath", '/html/body/div[4]/div/div[1]/div[2]/button[5]').click()
atualizando_plantao()

# %%
def apagando_registro():
    #Apagando
    browser.find_element("xpath", '/html/body/div[4]/div/div[1]/div[2]/button[1]').click()
    #Clicando em continuar
    sleep(0.5)
    browser.find_element("xpath", '/html/body/div[4]/div/div[1]/div[3]/button[2]').click()
apagando_registro()

# %%
count = 421

# %%
#Para cada profissional na lista
df = df_backup[count:]

for i in df['nome'].unique():
    print("nome:", i)
    df_nome = df[df['nome'] == i]
    df_nome.reset_index(drop=True, inplace=True)
    
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    #browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/div/div[1]/div[3]/professionals/div/a/span[2]/b').click()
    sleep(2)
    
    browser.find_element("xpath", '/html/body/div[8]/div/input').send_keys(i)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()
    
    #esperando carregamento do site
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))

    tabela = funcao()    
    sleep(2)
    
    #Para cada registro na lista_nome
    for t in range(len(df_nome)):
        print(df_nome['mensagem'][t])
        sleep(3)
        
        dia_sel = tabela[(tabela['data'] == df_nome['data'][t]) & 
                         (tabela['Entrada'] == df_nome['ENTRADA'][t]) &
                         (tabela['Saida'] == df_nome['SAIDA'][t]) &
                         (tabela['Unidade'] == df_nome['unidade'][t]) & 
                         (tabela['Periodo'] == df_nome['setor'][t])]
        
        dia_sel.reset_index(drop=True, inplace=True)
        
        if len(dia_sel) == 0:
            print(count, "-> PROB")
            df_backup['controle'][count] = "PROB"
        else:
            sleep(1)
            #abrindo/selecionando periodo conforme localização
            xpath_localizacao = '//*[@id="shift-monthly"]/div[2]/table/tbody/tr['+str(dia_sel['Semana'][0])+']/td['+str(dia_sel['Dia Semana'][0])+']/ul['+str(dia_sel['ordem'][0])+']/li'
            browser.find_element("xpath", xpath_localizacao).click()
            
            #Esperar componentes carregarem
            WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]')))
            
            apagando_registro()
            
            WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]')))
            #salvar plantão
            print(count, "-> OK")
            df_backup['controle'][count] = "OK"
            sleep(4.5)
            
        count += 1 
        if count % 25 == 0:
            print('='*80)
            print(df_backup['controle'].value_counts())
            print('='*80)
    print("\n")
    
print("="*50, 'TERMINOU', "="*50)
print('Total  ', len(df_backup))
print(df_backup['controle'].value_counts())
# Out:
# nome: VANESSA PACIULLO MAROSSI
# 08/01 Anália  -  Vanessa entrada 06:00
# 887 -> PROB
# 10/01 Villa  -  Vanessa saída 12:45
# 888 -> OK
# 10/01 Villa  -  Vanessa entrada 06:00
# 889 -> OK
# 12/01 Anália  -  Vanessa saída 21:10
# 890 -> OK
# 15/01 Anália  -  Vanessa saída 19:15
# 891 -> OK
# 15/01 Anália  -  Vanessa entrada 05:30
# 892 -> OK
# 17/01 ANÁLIA  -  Vanessa saída 14:50
# 893 -> OK
# 17/01 Anália  -  Vanessa entrada 05:00
# 894 -> OK
# 19/01 Anália  -  Vanessa saída 20:30
# 895 -> OK
# 19/01 Anália  -  Vanessa entrada 06:00
# 896 -> OK
# 22/01 Anália  -  Vanessa entrada 05:30
# 897 -> OK
#
#
# nome: VICTOR AUGUSTO DE SOUZA MORAES
# 06/01 ANÁLIA  -  Augusto saída 11:10
# 898 -> OK
# 06/01 ANÁLIA  -  Augusto entrada 06:00
# 899 -> OK
# ================================================================================
# controle
# NORM    479
# OK      450
# PROB     37
# Name: count, dtype: int64
# ================================================================================
# 19/01 Anália  -  Victor Augusto saída 22:20
# 900 -> OK
#
#
# nome: VICTOR SAPOUNTZAKIS RIBEIRO
# 03/01 Villa Sapountzakis saída 16:20
# 901 -> OK
# 03/01 Villa  -  Sapountzakis entrada 6:00
# 902 -> OK
# 05/01 Itaim Sapountzakis entrada 06:05
# 903 -> OK
# 06/01 Jabaquara  -  saída 18:35
# 904 -> PROB
# 08/01 Osasco  -  Sapountzakis saída 19:22
# 905 -> OK
# 11/01 Jabaquara Sapountzakis saída 22:10
# 906 -> OK
# 12/01 Villa Sapountzakis entrada 05:15
# 907 -> OK
# 15/01 Itaim Sapountzakis saída 12:42   (  pós - plantão  )
# 908 -> OK
# 18/01 Jabaquara  -  Sapountzakis saída 22:50
# 909 -> OK
#
#
# nome: VITOR LUIZ ASSUNCAO MARTINS
# 02/01 Itaim Assunção saída 09:50   (  pós - plantão, deslocado Morumbi  )
# 910 -> OK
# 04/01 Itaim Assunção saída 21:45
# 911 -> OK
# 06/01 Analia Assunção saída 12:45
# 912 -> OK
# 09/01 Osasco Assunção saída 19:15   (  deslocado VNS  )
# 913 -> OK
# 09/01 Osasco Assunção entrada 06:00   (  deslocado  VNS  )
# 914 -> OK
# 13/01 Osasco Assunção entrada 07:00   (  EXTRA  )
# 915 -> OK
# 16/01 Villa  -  Assunção saída 22:00
# 916 -> OK
# 18/01 Analia Assunção saída 22:40
# 917 -> OK
# 18/01 Analia  -  Assunção entrada 06:00
# 918 -> OK
# 19/01 Osasco  -  Assunção saída 14:00   (  EXTRA  )
# 919 -> OK
# 19/01 Osasco  -  Assunção entrada 07:00   (  EXTRA  )
# 920 -> OK
#
#
# nome: VITOR MACIEL DE SOUSA PINTO
# 03/01 Anália  -  Maciel saída 15:45
# 921 -> OK
# 09/01 Anália  -  Maciel saída 13:15
# 922 -> OK
# 12/01 Anália  -  Maciel entrada 06:00
# 923 -> OK
# 18/01 Anália  -  Maciel entrada 06:00
# 924 -> OK
# ================================================================================
# controle
# OK      474
# NORM    454
# PROB     38
# Name: count, dtype: int64
# ================================================================================
# 19/01 Anália Maciel entrada 06:00
# 925 -> OK
#
#
# nome: VITOR OLIVEIRA ANDRE
# 05/01 Jabaquara Vitor saída 11:09
# 926 -> OK
# 08/01 Jabaquara Vitor entrada 06:00
# 927 -> OK
# 10/01 Itaim Vitor entrada 06:00
# 928 -> OK
# 12/01 Jabaquara Vitor saída 18:46
# 929 -> PROB
# 16/01 Itaim Vitor entrada 05:20
# 930 -> OK
# 19/01 Jabaquara Vitor entrada 06:00
# 931 -> OK
# 22/01 Jabaquara Vitor entrada 06:00
# 932 -> OK
#
#
# nome: VIVIAN CRISTINE DOS ANJOS E SILVA
# 03/01 Anália Vívian entrada 06:00
# 933 -> OK
# 06/01 Villa Vivian saida 09:50
# 934 -> OK
# 06/01 Villa Vivian entrada 06:00
# 935 -> OK
# 08/01 Anália Vívian saída 17:00
# 936 -> OK
# 09/01 Villa Vivian entrada 06:00
# 937 -> OK
# 16/01 Villa Vivian entrada 05:40
# 938 -> OK
# 19/01 Anália Vivian saida 19:15
# 939 -> OK
# 19/01 Anália Vivian entrada 05:20
# 940 -> OK
# 20/01 Villa Vivian saida 17:55
# 941 -> OK
#
#
# nome: VIVIANNA BOVERIO GALZERANI
# 12/01 Itaim Vivianna saída 20:40
# 942 -> OK
# 16/01 Jabaquara Vivianna saída 20:40
# 943 -> OK
# 17/01 Osasco Vivianna entrada 05:45   (  deslocada VNS  )
# 944 -> OK
# 19/01 Itaim Vivianna saída 20:40
# 945 -> OK
# 19/01 Itaim Vivianna entrada 06:10
# 946 -> OK
# 20/01 Morumbi Vivianna entrada 04:30   (  deslocada Osasco  )
# 947 -> OK
#
#
# nome: WANGLES PIGNATON DE PAULA
# 08/01 ANÁLIA  -  Wangles saída 17:35   (  deslocado VILLA  )
# 948 -> OK
# 15/01 ANÁLIA  -  Wangles saída 19:10   (  troca de unidade com Marcela Leite  )
# 949 -> OK
# ================================================================================
# controle
# OK      498
# NORM    429
# PROB     39
# Name: count, dtype: int64
# ================================================================================
# 15/01 ANÁLIA  -  Wangles entrada 5:45
# 950 -> OK
# 17/01 ANÁLIA  -  Wangles saída 22:15
# 951 -> OK
#
#
# nome: YOKO HAYASHI
# 04/01 Itaim Yoko entrada 6:00
# 952 -> OK
# 11/01 Itaim Yoko entrada 5:30
# 953 -> OK
# 15/01 Jabaquara Yoko saída 19:35
# 954 -> OK
# 18/01 Itaim Yoko entrada 5:00
# 955 -> OK
#
#
# nome: YURI ANDERSON PACHECO DE LIMA
# 02/01 Itaim  -  Yuri saída 17:40
# 956 -> OK
# 03/01 Itaim  -  Yuri saída 19:20
# 957 -> OK
# 06/01 Jabaquara  -  Yuri saída 19:40
# 958 -> OK
# 08/01 Morumbi  -  Yuri entrada 05:30
# 959 -> OK
# 09/01 Itaim  -  Yuri saída 21:30
# 960 -> OK
# 13/01 Morumbi  -  Yuri entrada 05:30
# 961 -> OK
# 17/01 Osasco  -  Yuri entrada 05:30   (  deslocado Itaim  )
# 962 -> OK
# 18/01 Jabaquara  -  Yuri entrada 05:20   (  deslocado VNS  )
# 963 -> OK
# 19/01 Itaim  -  Yuri saída 19:00   (  deslocado VNS  )
# 964 -> PROB
# 20/01 Morumbi  -  Yuri entrada 05:30
# 965 -> OK
#
#
# ================================================== TERMINOU ==================================================
# Total   966
# controle
# OK      513
# NORM    413
# PROB     40
# Name: count, dtype: int64

# %%
df_backup['controle'].loc[1:8]

# %%
print(df_backup['controle'].value_counts())

# %%
print('De:', count)
df_backup['controle'][count] = "OK"
#df_backup['controle'][count] = "PROB"
count += 1
print('Para:', count)
# Out:
# De: 428
# Para: 429

# %%
df_backup.to_excel("continuar.xlsx")

# %%
browser.quit()
