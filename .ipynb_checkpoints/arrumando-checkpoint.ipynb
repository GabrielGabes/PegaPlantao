# %%
mes = "01"

#manipulação de dados
import pandas as pd
import numpy as np

#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

browser = webdriver.Firefox()

# %%
browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()

# %%
#CAPTURANDO NOME DE TODOS PROFISSIONAIS ========================================================
browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a').click() #barra de nome

html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML') #
soup_nome = BeautifulSoup(html, 'html.parser')
#soup_nome

NOMES = []
for i in soup_nome.find_all(class_ ="select2-results-dept-0 select2-result select2-result-selectable"):
    #print(i.get_text())
    NOMES.append(i.get_text())
#del(NOME[0])

NOMES
# Out:
# ['ALBERTO DE AZEVEDO ALVES MOREIRA',
#  'ALESSANDRE LUIZ BRAGA JUNIOR',
#  'ALEXANDRE BERNARDINO',
#  'ALEXSANDER TAKASHI HAMADA',
#  'ALICE DIAS POLVERINI',
#  'ALINE FRANCHINI GOULART LIMA',
#  'ÁLVARO LÁZARO RÁO REGONATO',
#  'AMANDA KIYOKO SOUZA KOSSAKA',
#  'ANA JUNG DOCKO',
#  'ANDRÉ DA COSTA AGUIAR VENTURA',
#  'ANDRÉ LUIS XAVIER FRANCO',
#  'ANDRÉ MORTARI PLÁ GIL',
#  'ANDREIA LOUREIRO MORI',
#  'ANNA BEATRIZ ARANHA TREVISAN',
#  'ANNA BEATRIZ LIMA DO VALLE ASTUR',
#  'ANTONIO ALVARO DIAS LIMA DA CUNHA NETO',
#  'ARTHUR OLIVEIRA FACCHINI',
#  'AVELINO JOSÉ DA SILVA FREITAS JÚNIOR',
#  'BEATRIZ ANTIPOU DOS SANTOS',
#  'BIANCA PRISCILA BUNIOTTI',
#  'BRUCE YE MAN CHOW',
#  'BRUNA DAIBERT DANESIN',
#  'BRUNO FERRAZ DE CAMPOS BARONE',
#  'BRUNO STORNIOLI TAGUCHI LEMOS',
#  'CAIO TULIO DUARTE',
#  'CAMILA CHIARANTANO HARRISON',
#  'CARLOS AUGUSTO TREVISAN',
#  'CARLOS EDUARDO CORRÊA GRILO',
#  'CARLOS EDUARDO GONDIM OLIVEIRA',
#  'CAROLINE FIRMINO LEMES DA SILVA',
#  'CLAUDIO MUELLER KAKUDA',
#  'DANIEL MASUZAKI WONG',
#  'DANIEL RODRIGUES DE OLIVEIRA',
#  'DANIELLEN LINS LOURENÇO',
#  'DÉBORA ALVES AUDE',
#  'DÉBORA PHILIPPI BRESSANE',
#  'DENIO LOPES DE ALMEIDA',
#  'DIEGO DA CUNHA TOMAZ',
#  'DIOGO CANDEO RODRIGUES CORDEIRO',
#  'DIOGO HENRIQUE PEREIRA MATTOS',
#  'EDUARDO ARBACHE BEZERRA',
#  'EDUARDO DALA ROSA SOARES',
#  'ELAINE IMAEDA DE MOURA',
#  'EMERSON DOMINGOS DA COSTA',
#  'ERICK OLIVEIRA LIMA GOMES',
#  'ESTANRLEY BARCELOS PINTO',
#  'EVERTON SIDNEY DA CONCEIÇÃO CARVALHO',
#  'FABIANA BARBOSA BASTOS',
#  'FABIANA SOARES GAMA',
#  'FÁBIO ANTÔNIO DE SOUZA OLIVEIRA',
#  'FÁBIO YUJI SUGUITA',
#  'FELIPE COELHO DE SOUZA',
#  'FELIPE DE OLIVEIRA NUNES',
#  'FERNANDA TELES RIBEIRO',
#  'FERNANDO AKIRA KOGA',
#  'FERNANDO NARDY BELLICIERI',
#  'FERNANDO RIBEIRO SÁ',
#  'FILIPE LUGON MOULIN LIMA',
#  'FILIPE MAEDA HASHI ABDALLA MARTINS',
#  'FLÁVIO HIDEKI OSHIKA',
#  'FRANCISCO ANTONIO ALVES BONATTO',
#  'FRANCISCO JOSÉ LUCENA BEZERRA',
#  'GABRIEL DE AGUIAR SANTANA',
#  'GABRIEL GONDIM FONSECA',
#  'GABRIELA RODRIGUES MACHADO BORJA',
#  'GABRIELA SOARES PIASSI',
#  'GABRIELLA GADELHA SARMENTO',
#  'GRETEL OLIVEIRA NICOLAU',
#  'GUILHERME DE ALMEIDA COSTA',
#  'GUILHERME SILVEIRA LOPES',
#  'GUSTAVO MARQUES DA SILVA',
#  'HEDICLEBER PESTANA SEVERINO',
#  'HELENA ARAUJO DAMASCENO',
#  'HENRI ROGER WATANABE OLIVEIRA',
#  'IVÃ BARBOSA SOARES',
#  'IZABELLA GONTIJO CUNHA',
#  'JÉSSICA LÍDIA DE SOUZA',
#  'JOÃO THEODORO DE MEDEIROS NETO',
#  'JOSÉ CARLOS TUNA SCARPA',
#  'JOSÉ MARCOS VIEIRA DA SILVA',
#  'JULIANA AKEMI FUNABASHI',
#  'JULIANA HUSSEIN GRILO',
#  'JULIANO MOISÉS TOBAL',
#  'KAIÊ FERNANDES',
#  'KAREN PEIXOTO RICCI',
#  'KAREN YUMI MIYASHIRO',
#  'LAIS RIBEIRO TEIXEIRA',
#  'LARISSA MAYUMI ONO',
#  'LEANDRO EDUARDO FRANÇA',
#  'LEANDRO KENDI KANADA',
#  'LEANDRO OLIVEIRA MARTINS CÔRTES',
#  'LEOPOLDO MUNIZ DA SILVA',
#  'LETÍCIA FERNANDES BORGES',
#  'LÍVIA SCHENKEL THURLER TRAIRI',
#  'LUANA MARIS RODRIGUES DE SOUZA',
#  'LUCCAS VARELA GODOY',
#  'LUCIANA VENTURINI',
#  'LUCIANO ANGELO RICHETTI',
#  'LUDMYLLA GOMES NEVES',
#  'LUIZ ALBERTO CEPÊDA',
#  'LUIZ AUGUSTO XAVIER BRANDÃO',
#  'LUIZ GUILHERME THOMAZ ZACHARIAS',
#  'MAIELY MARCOLIN',
#  'MAÍRA LEITE BASILE',
#  'MANOEL DE SOUZA NETO',
#  'MARCELA APARECIDA CORREA MARTINS',
#  'MARCELA LEITE ROSIGNOLI',
#  'MARCELLA PELLICCIOTTI DE SOUZA',
#  'MARCELO DOS ANJOS REIS',
#  'MARCELO FELIPE DE SOUZA BUTO',
#  'MARCELO MAIA DA SILVEIRA',
#  'MÁRCIO IGHOR AZEVEDO SILVA DE MENDONÇA MELÂNIA',
#  'MARCOS ROGÉRIO PEREIRA MACHADO FILHO',
#  'MARIA CAROLINA CELIA SILVEIRA',
#  'MARIA CECÍLIA DOMINGUES DA SILVA SOARES',
#  'MARIANA DARDENGO BORGES',
#  'MARIANA GASPARELLI DE SOUZA',
#  'MARIANA OLIVEIRA DE TOLEDO',
#  'MARINA BORGES CURRALO',
#  'MARINA PONTES MOURA NASCIMENTO E SILVA',
#  'MATHEUS ACQUESTA GAUBEUR',
#  'MATHEUS DE ALENCAR ARRAES',
#  'MATHEUS VIANA LEMO',
#  'MAURÍCIO FARIA TETTI',
#  'MAXVILANO LIMA DE MACEDO',
#  'MILTON OLAIO NETO',
#  'MIRELA FARIAS FIGUEIRÔA',
#  'MÔNICA ROBLES GONÇALVES',
#  'NARA YAMANE DOS SANTOS',
#  'NATAN SOARES SILVEIRA',
#  'NATHÁLIA FANUCCI OLIVEIRA DI JORGE',
#  'NELIANE GUEDES PRETTI',
#  'NORIVAL SCANDELAI JÚNIOR',
#  'ORLANDO DOMINGUES DE ARAÚJO PONTES',
#  'Otto Mittermayer',
#  'PALOMA KIYOMI TAGUCHI LEMOS',
#  'PAOLA RODRIGUES OSHIRO',
#  'PATRICK ALEXANDER SUER SCHUES',
#  'PAULA ANGÉLICA PINHA NEVES',
#  'PAULA LOPES AGAPITO DE FREITAS',
#  'PEDRO AUGUSTO TAVARES DALL AGLIO',
#  'PEDRO HENRIQUE MILHOMENS DA MOTA',
#  'PEDRO PAULO SILVA FARAH',
#  'PEDRO TIAGO BONFITTO',
#  'PEDRO ULYSSES VIEIRA DE MATOS',
#  'RAFAEL SOUZA FAVA NERSESSIAN',
#  'RAFAEL TADEU MARQUES',
#  'RENAN ZORZI ABBAS',
#  'RENATA PINHEIRO MODOLO',
#  'RENATA TOGEIRO BASTOS GODOY DE FARIA',
#  'RENATA TORRES BUENO',
#  'RENATO DOS SANTOS BOREGA',
#  'RICARDO BARBOSA VIANA FILHO',
#  'RICARDO GIRALDELLI CARVALHO LIMA',
#  'RICARDO IVO DE LIMA',
#  'RICARDO KAWAURA',
#  'ROBERTO VOTTO MELKAN',
#  'RODRIGO ACHUI HAGA',
#  'RODRIGO ANDRADE CARMELLO',
#  'RODRIGO ANTONIO REY GONZALEZ',
#  'RODRIGO DE CARVALHO SILVA',
#  'RODRIGO GIOVANELLI CONSTANTINO',
#  'RODRIGO MIYASHIRO NUNES DOS SANTOS',
#  'ROGÉRIO SIDNEY THON',
#  'ROMULO SPOLIDORIO',
#  'RONALD FIGUEIREDO GOMES',
#  'SABRINA DE SOUZA RAMOS',
#  'SAULLO QUEIROZ SILVEIRA',
#  'SÉRGIO ZAMITH',
#  'SHEILA ITIROCO MONTE',
#  'SIDNEY ORLANDO DE SOUZA',
#  'SILVIA ALINE DOS SANTOS ANDRADE',
#  'STEFANY HÉLLEN SOUSA MARTINS',
#  'THAIS CHAVES PINHEIRO',
#  'THAIS MIRANDA RAMOS',
#  'THALES LUVISOTTO NEDER',
#  'THASSIO CUNHA DE SANTANA',
#  'THAYS FILIZZOLA BORGES',
#  'THIAGO BARRETO MARQUES DA SILVA',
#  'THIAGO FRANCISCO MARTINS',
#  'THIAGO SILVA PINTO',
#  'TURÍBIO RODRIGUES FREIRE NETO',
#  'VANESSA PACIULLO MAROSSI',
#  'VICTOR SAPOUNTZAKIS RIBEIRO',
#  'VITOR MACIEL DE SOUSA PINTO',
#  'VITOR OLIVEIRA ANDRÉ',
#  'VIVIAN CRISTINE DOS ANJOS E SILVA',
#  'VIVIANNA BOVÉRIO GALZERANI',
#  'WANGLES PIGNATON DE PAULA',
#  'YOKO HAYASHI',
#  'YURI ANDERSON PACHECO DE LIMA',
#  'YURI LUCAS DE SOUZA']

# %%
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

lista_tabela = []

for i in range(1, 6): #passando por cada semana[1 a 5]
    ##print('semana:', i, "=="*20)
    for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
        reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
        content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
        content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra

        dia = content[0] #dia do registro
        del(content[0]) #deletando o dia, ja que foi coletado
        del(content[-1]) #deletando resido do wepscraping

        if len(content) != 0: #ignorando dias em branco (sem registro) ¹
            #print('dia:', t)

            ##print('dia:', dia)
            #print(content)

            count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
            lista_control = []
            for y in content: #passando um for sobre cada item da lista
                if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                    #print('================unidade:', y)
                    unidade = y
                elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                    count_hora += 1
                    if count_hora == 1: #capturando entrada
                        #print('hora entrada:', y)
                        lista_control.append(y)
                    elif count_hora == 2: #capturando saida
                        #print('hora saida:', y)
                        lista_control.append(y)
                        #print('lista teste', lista_control)
                        lista_tabela.append(lista_control)
                        lista_control = []
                        count_hora = 0
                else: #capturando dia, unidade, e periodo
                    #print('.')
                    #print('periodo:', y)
                    lista_control.append(dia)
                    lista_control.append(unidade)
                    lista_control.append(y)
                    lista_control.append(i)
                    lista_control.append(t) #dia semanal

            ##print('='*20)    

        else:
            continue #ignorando dias em branco (sem registro) ²

tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Dia Semana','Entrada','Saida'])
tabela
# Out:
#    Dia        Unidade                       Periodo  Semana  Dia Semana  \
# 0   02  ADMINISTRACAO                ADMINISTRATIVO       1           2
# 1   03          ITAIM  SEMANA - MANHA - C.CIRURGICO       1           3
# 2   03          ITAIM  SEMANA - TARDE - C.CIRURGICO       1           3
# 3   03          ITAIM  SEMANA - NOTURNO - DISTANCIA       1           3
# 4   04          ITAIM  SEMANA - MANHA - C.CIRURGICO       1           4
# 5   05          ITAIM  SEMANA - MANHA - C.CIRURGICO       1           5
# 6   05          ITAIM  SEMANA - TARDE - C.CIRURGICO       1           5
# 7   06          ITAIM                  SEMANA - 6HS       1           6
# 8   06          ITAIM  SEMANA - MANHA - C.CIRURGICO       1           6
# 9   06          ITAIM  SEMANA - TARDE - C.CIRURGICO       1           6
# 10  09  ADMINISTRACAO                ADMINISTRATIVO       2           2
# 11  10          ITAIM  SEMANA - MANHA - C.CIRURGICO       2           3
# 12  10          ITAIM  SEMANA - TARDE - C.CIRURGICO       2           3
# 13  10          ITAIM  SEMANA - NOTURNO - DISTANCIA       2           3
# 14  11          ITAIM  SEMANA - MANHA - C.CIRURGICO       2           4
# 15  11          ITAIM  SEMANA - TARDE - C.CIRURGICO       2           4
# 16  12          ITAIM                  SEMANA - 6HS       2           5
# 17  12          ITAIM  SEMANA - MANHA - C.CIRURGICO       2           5
# 18  12          ITAIM  SEMANA - TARDE - C.CIRURGICO       2           5
# 19  13          ITAIM                  SEMANA - 6HS       2           6
# 20  13          ITAIM  SEMANA - MANHA - C.CIRURGICO       2           6
# 21  13          ITAIM  SEMANA - TARDE - C.CIRURGICO       2           6
# 22  13          ITAIM      SEMANA - NOTURNO - SAIDA       2           6
# 23  14          ITAIM      FDS - C.CIRURGICO ROTINA       2           7
# 24  14          ITAIM                   FDS - SAIDA       2           7
# 25  16  ADMINISTRACAO                ADMINISTRATIVO       3           2
# 26  16       AVICCENA                   FDS - SAIDA       3           2
# 27  17          ITAIM  SEMANA - MANHA - C.CIRURGICO       3           3
# 28  17          ITAIM  SEMANA - TARDE - C.CIRURGICO       3           3
# 29  17          ITAIM  SEMANA - NOTURNO - DISTANCIA       3           3
# 30  18          ITAIM  SEMANA - MANHA - C.CIRURGICO       3           4
# 31  19          ITAIM  SEMANA - MANHA - C.CIRURGICO       3           5
# 32  19          ITAIM  SEMANA - TARDE - C.CIRURGICO       3           5
# 33  19          ITAIM      SEMANA - NOTURNO - SAIDA       3           5
# 34  30  ADMINISTRACAO                ADMINISTRATIVO       5           2
# 35  31          ITAIM  SEMANA - MANHA - C.CIRURGICO       5           3
# 36  31          ITAIM  SEMANA - TARDE - C.CIRURGICO       5           3
# 37  31          ITAIM  SEMANA - NOTURNO - DISTANCIA       5           3
# 38  01          ITAIM  SEMANA - MANHA - C.CIRURGICO       5           4
# 39  02          ITAIM  SEMANA - MANHA - C.CIRURGICO       5           5
# 40  02          ITAIM  SEMANA - TARDE - C.CIRURGICO       5           5
# 41  03          ITAIM  SEMANA - MANHA - C.CIRURGICO       5           6
# 42  03          ITAIM  SEMANA - TARDE - C.CIRURGICO       5           6
#
#    Entrada  Saida
# 0    07:00  13:00
# 1    07:00  13:00
# 2    13:00  19:00
# 3    19:00  06:00
# 4    07:00  13:00
# 5    07:00  13:00
# 6    13:00  16:00
# 7    06:00  07:00
# 8    07:00  13:00
# 9    13:00  19:00
# 10   07:00  13:00
# 11   07:00  13:00
# 12   13:00  19:00
# 13   19:00  06:00
# 14   07:00  13:00
# 15   13:00  13:30
# 16   06:00  07:00
# 17   07:00  13:00
# 18   13:00  17:00
# 19   05:00  07:00
# 20   07:00  13:00
# 21   13:00  19:00
# 22   19:00  20:30
# 23   07:00  13:00
# 24   13:00  14:00
# 25   07:00  13:00
# 26   19:00  01:00
# 27   07:00  13:00
# 28   13:00  19:00
# 29   19:00  06:00
# 30   07:00  13:00
# 31   07:00  13:00
# 32   13:00  19:00
# 33   19:00  22:30
# 34   07:00  13:00
# 35   07:00  13:00
# 36   13:00  19:00
# 37   19:00  06:00
# 38   07:00  13:00
# 39   07:00  13:00
# 40   13:00  19:00
# 41   07:00  13:00
# 42   13:00  19:00

# %%
browser.quit()
