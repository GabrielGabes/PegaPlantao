# %%
#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)

import re

import pandas as pd

import time #biblioteca para calcular o tempo de geração do codigo

# %%
browser = webdriver.Firefox()

# %%
browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
#Layout Mensal
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()
sleep(1)

#CAPTURANDO NOME DE TODOS PROFISSIONAIS ========================================================
browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a').click() #barra de nome

html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML') #
soup_nome = BeautifulSoup(html, 'html.parser')
#soup_nome

NOMES = []
for i in soup_nome.find_all(class_ ="select2-results-dept-0 select2-result select2-result-selectable"):
    #print(i.get_text())
    NOMES.append(i.get_text())
#del(NOME[0])

NOMES
# Out:
# ['ALBERTO DE AZEVEDO ALVES MOREIRA',
#  'ALESSANDRE LUIZ BRAGA JUNIOR',
#  'ALEXANDRE BERNARDINO',
#  'ALEXSANDER TAKASHI HAMADA',
#  'ALICE DIAS POLVERINI',
#  'ALINE FRANCHINI GOULART LIMA',
#  'ÁLVARO LÁZARO RÁO REGONATO',
#  'AMANDA KIYOKO SOUZA KOSSAKA',
#  'ANA GABRIELA GEWEHR VALE SALMEN',
#  'ANA JUNG DOCKO',
#  'ANDRÉ DA COSTA AGUIAR VENTURA',
#  'ANDRÉ LUIS XAVIER FRANCO',
#  'ANDRÉ MORTARI PLÁ GIL',
#  'ANDREIA LOUREIRO MORI',
#  'ANNA BEATRIZ ARANHA TREVISAN',
#  'ANNA BEATRIZ LIMA DO VALLE ASTUR',
#  'ANTONIO ALVARO DIAS LIMA DA CUNHA NETO',
#  'ARTHUR OLIVEIRA FACCHINI',
#  'AVELINO JOSÉ DA SILVA FREITAS JÚNIOR',
#  'BEATRIZ ANTIPOU DOS SANTOS',
#  'BIANCA PRISCILA BUNIOTTI',
#  'BRUCE YE MAN CHOW',
#  'BRUNA DAIBERT DANESIN',
#  'BRUNO FERRAZ DE CAMPOS BARONE',
#  'BRUNO STORNIOLI TAGUCHI LEMOS',
#  'CAIO TULIO DUARTE',
#  'CAMILA CHIARANTANO HARRISON',
#  'CARLOS AUGUSTO TREVISAN',
#  'CARLOS EDUARDO CORRÊA GRILO',
#  'CARLOS EDUARDO GONDIM OLIVEIRA',
#  'CAROLINE FIRMINO LEMES DA SILVA',
#  'CLAUDIO MUELLER KAKUDA',
#  'DANIEL MASUZAKI WONG',
#  'DANIEL RODRIGUES DE OLIVEIRA',
#  'DANIELLEN LINS LOURENÇO',
#  'DÉBORA ALVES AUDE',
#  'DÉBORA PHILIPPI BRESSANE',
#  'DENIO LOPES DE ALMEIDA',
#  'DIEGO DA CUNHA TOMAZ',
#  'DIOGO CANDEO RODRIGUES CORDEIRO',
#  'DIOGO HENRIQUE PEREIRA MATTOS',
#  'EDUARDO ARBACHE BEZERRA',
#  'EDUARDO DALA ROSA SOARES',
#  'ELAINE IMAEDA DE MOURA',
#  'EMERSON DOMINGOS DA COSTA',
#  'ERICK OLIVEIRA LIMA GOMES',
#  'ESTANRLEY BARCELOS PINTO',
#  'EVERTON SIDNEY DA CONCEIÇÃO CARVALHO',
#  'FABIANA BARBOSA BASTOS',
#  'FABIANA SOARES GAMA',
#  'FÁBIO ANTÔNIO DE SOUZA OLIVEIRA',
#  'FÁBIO YUJI SUGUITA',
#  'FELIPE COELHO DE SOUZA',
#  'FELIPE DE OLIVEIRA NUNES',
#  'FERNANDA TELES RIBEIRO',
#  'FERNANDO AKIRA KOGA',
#  'FERNANDO NARDY BELLICIERI',
#  'FERNANDO RIBEIRO SÁ',
#  'FILIPE LUGON MOULIN LIMA',
#  'FILIPE MAEDA HASHI ABDALLA MARTINS',
#  'FLÁVIO HIDEKI OSHIKA',
#  'FRANCISCO ANTONIO ALVES BONATTO',
#  'FRANCISCO JOSÉ LUCENA BEZERRA',
#  'GABRIEL DE AGUIAR SANTANA',
#  'GABRIEL GONDIM FONSECA',
#  'GABRIELA RODRIGUES MACHADO BORJA',
#  'GABRIELA SOARES PIASSI',
#  'GABRIELLA GADELHA SARMENTO',
#  'GRETEL OLIVEIRA NICOLAU',
#  'GUILHERME DE ALMEIDA COSTA',
#  'GUILHERME SILVEIRA LOPES',
#  'GUSTAVO MARQUES DA SILVA',
#  'HEDICLEBER PESTANA SEVERINO',
#  'HELENA ARAUJO DAMASCENO',
#  'HENRI ROGER WATANABE OLIVEIRA',
#  'IVÃ BARBOSA SOARES',
#  'IZABELLA GONTIJO CUNHA',
#  'JÉSSICA LÍDIA DE SOUZA',
#  'JOÃO THEODORO DE MEDEIROS NETO',
#  'JOSÉ CARLOS TUNA SCARPA',
#  'JOSÉ MARCOS VIEIRA DA SILVA',
#  'JULIANA AKEMI FUNABASHI',
#  'JULIANA HUSSEIN GRILO',
#  'JULIANO MOISÉS TOBAL',
#  'KAIÊ FERNANDES',
#  'KAREN PEIXOTO RICCI',
#  'KAREN YUMI MIYASHIRO',
#  'KAWAN RAMIS RODRIGUES',
#  'LAIS RIBEIRO TEIXEIRA',
#  'LARISSA MAYUMI ONO',
#  'LEANDRO EDUARDO FRANÇA',
#  'LEANDRO KENDI KANADA',
#  'LEANDRO OLIVEIRA MARTINS CÔRTES',
#  'LEOPOLDO MUNIZ DA SILVA',
#  'LETÍCIA FERNANDES BORGES',
#  'LÍVIA SCHENKEL THURLER TRAIRI',
#  'LUANA MARIS RODRIGUES DE SOUZA',
#  'LUCCAS VARELA GODOY',
#  'LUCIANA VENTURINI',
#  'LUCIANO ANGELO RICHETTI',
#  'LUDMYLLA GOMES NEVES',
#  'LUIZ ALBERTO CEPÊDA',
#  'LUIZ AUGUSTO XAVIER BRANDÃO',
#  'LUIZ GUILHERME THOMAZ ZACHARIAS',
#  'MAIELY MARCOLIN',
#  'MAÍRA LEITE BASILE',
#  'MANOEL DE SOUZA NETO',
#  'MARCELA APARECIDA CORREA MARTINS',
#  'MARCELA LEITE ROSIGNOLI',
#  'MARCELLA PELLICCIOTTI DE SOUZA',
#  'MARCELO DOS ANJOS REIS',
#  'MARCELO FELIPE DE SOUZA BUTO',
#  'MARCELO MAIA DA SILVEIRA',
#  'MÁRCIO IGHOR AZEVEDO SILVA DE MENDONÇA MELÂNIA',
#  'MARCOS ROGÉRIO PEREIRA MACHADO FILHO',
#  'MARIA CAROLINA CELIA SILVEIRA',
#  'MARIA CECÍLIA DOMINGUES DA SILVA SOARES',
#  'MARIANA DARDENGO BORGES',
#  'MARIANA GASPARELLI DE SOUZA',
#  'MARIANA OLIVEIRA DE TOLEDO',
#  'MARINA BORGES CURRALO',
#  'MARINA PONTES MOURA NASCIMENTO E SILVA',
#  'MATHEUS ACQUESTA GAUBEUR',
#  'MATHEUS DE ALENCAR ARRAES',
#  'MATHEUS VIANA LEMO',
#  'MAURÍCIO FARIA TETTI',
#  'MAXVILANO LIMA DE MACEDO',
#  'MILTON OLAIO NETO',
#  'MIRELA FARIAS FIGUEIRÔA',
#  'MÔNICA ROBLES GONÇALVES',
#  'NARA YAMANE DOS SANTOS',
#  'NATAN SOARES SILVEIRA',
#  'NATHÁLIA FANUCCI OLIVEIRA DI JORGE',
#  'NELIANE GUEDES PRETTI',
#  'NORIVAL SCANDELAI JÚNIOR',
#  'ORLANDO DOMINGUES DE ARAÚJO PONTES',
#  'Otto Mittermayer',
#  'PALOMA KIYOMI TAGUCHI LEMOS',
#  'PAOLA RODRIGUES OSHIRO',
#  'PATRICK ALEXANDER SUER SCHUES',
#  'PAULA ANGÉLICA PINHA NEVES',
#  'PAULA LOPES AGAPITO DE FREITAS',
#  'PEDRO AUGUSTO TAVARES DALL AGLIO',
#  'PEDRO HENRIQUE MILHOMENS DA MOTA',
#  'PEDRO PAULO SILVA FARAH',
#  'PEDRO TIAGO BONFITTO',
#  'PEDRO ULYSSES VIEIRA DE MATOS',
#  'RAFAEL SOUZA FAVA NERSESSIAN',
#  'RAFAEL TADEU MARQUES',
#  'RENAN ZORZI ABBAS',
#  'RENATA PINHEIRO MODOLO',
#  'RENATA TOGEIRO BASTOS GODOY DE FARIA',
#  'RENATA TORRES BUENO',
#  'RENATO DOS SANTOS BOREGA',
#  'RICARDO BARBOSA VIANA FILHO',
#  'RICARDO GIRALDELLI CARVALHO LIMA',
#  'RICARDO IVO DE LIMA',
#  'RICARDO KAWAURA',
#  'ROBERTO VOTTO MELKAN',
#  'RODRIGO ACHUI HAGA',
#  'RODRIGO ANDRADE CARMELLO',
#  'RODRIGO ANTONIO REY GONZALEZ',
#  'RODRIGO DE CARVALHO SILVA',
#  'RODRIGO GIOVANELLI CONSTANTINO',
#  'RODRIGO MIYASHIRO NUNES DOS SANTOS',
#  'ROGÉRIO SIDNEY THON',
#  'ROMULO SPOLIDORIO',
#  'RONALD FIGUEIREDO GOMES',
#  'SABRINA DE SOUZA RAMOS',
#  'SAULLO QUEIROZ SILVEIRA',
#  'SÉRGIO ZAMITH',
#  'SHEILA ITIROCO MONTE',
#  'SIDNEY ORLANDO DE SOUZA',
#  'SILVIA ALINE DOS SANTOS ANDRADE',
#  'STEFANY HÉLLEN SOUSA MARTINS',
#  'THAIS CHAVES PINHEIRO',
#  'THAIS MIRANDA RAMOS',
#  'THALES LUVISOTTO NEDER',
#  'THASSIO CUNHA DE SANTANA',
#  'THAYS FILIZZOLA BORGES',
#  'THIAGO BARRETO MARQUES DA SILVA',
#  'THIAGO FRANCISCO MARTINS',
#  'THIAGO SILVA PINTO',
#  'TURÍBIO RODRIGUES FREIRE NETO',
#  'VANESSA PACIULLO MAROSSI',
#  'VICTOR SAPOUNTZAKIS RIBEIRO',
#  'VITOR MACIEL DE SOUSA PINTO',
#  'VITOR OLIVEIRA ANDRÉ',
#  'VIVIAN CRISTINE DOS ANJOS E SILVA',
#  'VIVIANNA BOVÉRIO GALZERANI',
#  'WANGLES PIGNATON DE PAULA',
#  'YOKO HAYASHI',
#  'YURI ANDERSON PACHECO DE LIMA',
#  'YURI LUCAS DE SOUZA']

# %%
df = pd.DataFrame(NOMES)
df.head()
df.to_excel("NOMES.xlsx", index=False)

# %% [markdown]
# # TESTES:

# %%
print("oi")

# %%
#capturando parte onde fica os registros
setor_html = browser.find_element_by_xpath('//*[@id="shift-monthly"]/div[2]/table/tbody').get_attribute('outerHTML')
soup = BeautifulSoup(setor_html, 'html.parser')
soup

# %%
count = 0 
for i in soup.find_all(class_="another-month"):
    count += 1
    print('\n', count, ":")
    print(i.find(class_="sector-title"))

# %% [markdown]
# # save

# %%
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

lista_tabela = []

for i in range(1, 6): #passando por cada semana[1 a 5]
    print('semana:', i, "=="*20)
    for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
        reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
        content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
        content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra
        
        dia = content[0] #dia do registro
        del(content[0]) #deletando o dia, ja que foi coletado
        del(content[-1]) #deletando resido do wepscraping
        
        if len(content) != 0: #ignorando dias em branco (sem registro) ¹
            #print('dia:', t)
            
            print('dia:', dia)
            print(content)
            
            count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
            lista_control = []
            for y in content: #passando um for sobre cada item da lista
                if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                    #print('================unidade:', y)
                    unidade = y
                elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                    count_hora += 1
                    if count_hora == 1: #capturando entrada
                        #print('hora entrada:', y)
                        lista_control.append(y)
                    elif count_hora == 2: #capturando entrada
                        #print('hora saida:', y)
                        lista_control.append(y)
                        print('lista teste', lista_control)
                        lista_tabela.append(lista_control)
                        lista_control = []
                        count_hora = 0
                else: #capturando dia, unidade, e periodo
                    #print('.')
                    #print('periodo:', y)
                    lista_control.append(dia)
                    lista_control.append(unidade)
                    lista_control.append(y)
                    lista_control.append(i)
     
            print('='*20)    
            
        else:
            continue #ignorando dias em branco (sem registro) ²
            
tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Entrada','Saida',])
tabela

# %%
tabela.head(1)

# %%
browser.find_element_by_xpath('//*[@id="filter-container"]/month-picker/div/button[1]/span').click()

# %%
count = 0 
for NOME in NOMES:
    print(count, NOME)
    count += 1

# %%
dias_fds = ['07','08','14','15','21','22','28','29']

unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

for NOME in range(0, len(NOMES)):
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    sleep(2)
    browser.find_element("xpath", '/html/body/div[6]/div/input').send_keys(NOMES[NOME])
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()

    inicio = time.time() #iniciando o cronometro
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))
    fim = time.time() #encerrando cronometro
    print('carregou - 1', round(fim - inicio, 2))
    
    lista_tabela = []

    for i in range(1, 6): #passando por cada semana[1 a 5]
        ##print('semana:', i, "=="*20)
        for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
            reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
            content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
            content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra

            dia = content[0] #dia do registro
            del(content[0]) #deletando o dia, ja que foi coletado
            del(content[-1]) #deletando resido do wepscraping

            if len(content) != 0: #ignorando dias em branco (sem registro) ¹
                #print('dia:', t)

                ##print('dia:', dia)
                #print(content)

                count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
                lista_control = []
                for y in content: #passando um for sobre cada item da lista
                    if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                        #print('================unidade:', y)
                        unidade = y
                    elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                        count_hora += 1
                        if count_hora == 1: #capturando entrada
                            #print('hora entrada:', y)
                            lista_control.append(y)
                        elif count_hora == 2: #capturando entrada
                            #print('hora saida:', y)
                            lista_control.append(y)
                            ##print('lista teste', lista_control)
                            lista_tabela.append(lista_control)
                            lista_control = []
                            count_hora = 0
                    else: #capturando dia, unidade, e periodo
                        #print('.')
                        #print('periodo:', y)
                        lista_control.append(dia)
                        lista_control.append(unidade)
                        lista_control.append(y)
                        lista_control.append(i)

                ##print('='*20)    

            else:
                continue #ignorando dias em branco (sem registro) ²

    tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Entrada','Saida',])
    ##tabela

    print(NOMES[NOME], "="*50)

    for semana in tabela['Semana'].unique(): 
        tabela_semana = tabela[tabela['Semana'] == semana] # _isolar semana_
        #print('SEMANA', semana, '='*50)

        for dia in tabela_semana['Dia'].unique(): #verifique cada dia
            #print('DIA', dia, '='*40)
            tab_dia = tabela_semana[tabela_semana['Dia'] == str(dia)] #tabela dia XX # _isolar dia_
            tab_dia.reset_index(drop=True, inplace=True) #resetando index

            #ENCONTRANDO REGISTRO UNICOS, QUE NÃO SEJAM FINAL DE SEMANA COM PERIODOS MAIOR QUE 6H
            if len(tab_dia) == 1: #se contem apenas um registro
                if dia in dias_fds and int(tab_dia['Saida'][0][:2]) - int(tab_dia['Entrada'][0][:2]) <= 6:
                    continue #pule 
                elif (int(tab_dia['Dia'][0]) <= 25 and semana == 1) or (int(tab_dia['Dia'][0]) == 1 and semana == 5):
                    continue #pule 
                else: #se não for final de semana
                    print(dia, '- valor unico:', '[', 
                          tab_dia['Entrada'][0][:2],'...',tab_dia['Saida'][0][:2],
                          '-',tab_dia['Unidade'][0],'-',tab_dia['Periodo'][0],']') #indique
                    #print(int(tab_dia['Saida'][0][:2]), int(tab_dia['Entrada'][0][:2]))

            #ENCONTRANDO DIAS QUE NÃO BATEM OS HORARIOS DE ENTRADA E SAIDA DOS TURNOS
            for t in range(len(tab_dia)): #para cada registro da tabela
                if t != 0: #em excessão do primeiro
                    if tab_dia['Entrada'][t] != tab_dia['Saida'][t-1]: 
                        #verifique se a hora do inicio do plantão é igual a fim do plantão anterior
                        print(dia, '- erro entre os horarios:', 
                              '[', tab_dia['Entrada'][t], '...',tab_dia['Saida'][t-1],']') #se for, indique                        

            #ENCONTRANDO DIAS COM MAIS DE UMA UNIDADE REGISTRADA
            unidades_presentes = tab_dia['Unidade'].unique()
            if len(unidades_presentes) != 1:
                print(dia, '- unidade diferentes:', unidades_presentes)

            #ENCONTRANDO FINAIS DE SEMANA REGISTRADO COMO SEMANA
            if dia in dias_fds:
                for registro in range(len(tab_dia)):
                    if 'FDS' not in tab_dia['Periodo'][registro]:
                        if (int(tab_dia['Dia'][registro]) == 31 and semana == 1) or (int(tab_dia['Dia'][registro]) <= 3 and semana == 5):
                            continue
                        else:
                            print(tab_dia['Dia'][registro], "- fim de semana errado:",
                                  '[', tab_dia['Periodo'][registro], ']')
                        
            if dia not in dias_fds:
                for registro in range(len(tab_dia)):
                    if 'SEMANA' not in tab_dia['Periodo'][registro]:
                        if (int(tab_dia['Dia'][registro]) == 31 and semana == 1) or (int(tab_dia['Dia'][registro]) <= 3 and semana == 5):
                            continue
                        else:
                            print(tab_dia['Dia'][registro], '- dia da semana errado:',
                                  '[', tab_dia['Periodo'][registro], ']')
                    
            for j in range(len(tab_dia)):
                if tab_dia['Periodo'][j] == 'FDS - PLANTAO':
                    if int(tab_dia['Entrada'][j][0:2]) < 18:
                        print(tab_dia['Dia'][j], '- [FDS - PLANTÃO] registrado a tarde -'
                              '[', tab_dia['Entrada'][j], '...',tab_dia['Saida'][j],']')
                if tab_dia['Periodo'][j] == 'FDS - SAIDA':
                    if int(tab_dia['Entrada'][j][0:2]) > 18:
                        print(tab_dia['Dia'][j], '- [FDS - SAIDA] registrado a noite -'
                              '[', tab_dia['Entrada'][j], '...',tab_dia['Saida'][j],']')
                        
    print('\n')
# Out:
# carregou - 1 0.03
# ALBERTO DE AZEVEDO ALVES MOREIRA ==================================================
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 26 - erro entre os horarios: [ 07:00 ... 01:00 ]
# 26 - dia da semana errado: [ ADMINISTRATIVO ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 12 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# ALESSANDRE LUIZ BRAGA JUNIOR ==================================================
#
#
# carregou - 1 0.04
# ALEXANDRE BERNARDINO ==================================================
# 15 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - PRIMEIRO (R) ]
# 04 - dia da semana errado: [ FDS - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.05
# ALEXSANDER TAKASHI HAMADA ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# ALICE DIAS POLVERINI ==================================================
#
#
# carregou - 1 0.03
# ALINE FRANCHINI GOULART LIMA ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# ÁLVARO LÁZARO RÁO REGONATO ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 30 - unidade diferentes: ['ADMINISTRACAO' 'VILLA']
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# AMANDA KIYOKO SOUZA KOSSAKA ==================================================
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# ANA GABRIELA GEWEHR VALE SALMEN ==================================================
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - AVALIACAO PRE ROTINA ]
# 04 - dia da semana errado: [ FDS - AVALIACAO PRE ROTINA ]
#
#
# carregou - 1 0.03
# ANA JUNG DOCKO ==================================================
# 09 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 1 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 10 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 1 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 24 - valor unico: [ 07 ... 07 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 25 - valor unico: [ 07 ... 12 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 30 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 31 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 03 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - AV.PRE ANESTESICA ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# ANDRÉ DA COSTA AGUIAR VENTURA ==================================================
# 04 - valor unico: [ 07 ... 13 - VNS - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# ANDRÉ LUIS XAVIER FRANCO ==================================================
# 15 - valor unico: [ 07 ... 19 - VNS - FDS - PLANTAO ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 16 - valor unico: [ 07 ... 13 - VNS - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.04
# ANDRÉ MORTARI PLÁ GIL ==================================================
# 09 - valor unico: [ 07 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 09 - dia da semana errado: [ ADMINISTRATIVO ]
# 16 - valor unico: [ 07 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 16 - dia da semana errado: [ ADMINISTRATIVO ]
# 18 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 23 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 10 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 24 - erro entre os horarios: [ 07:00 ... 01:00 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 25 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 10 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 26 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 27 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 30 - erro entre os horarios: [ 07:00 ... 13:00 ]
# 30 - dia da semana errado: [ ADMINISTRATIVO ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
#
#
# carregou - 1 0.04
# ANDREIA LOUREIRO MORI ==================================================
#
#
# carregou - 1 0.03
# ANNA BEATRIZ ARANHA TREVISAN ==================================================
# 08 - erro entre os horarios: [ 05:30 ... 19:00 ]
# 08 - unidade diferentes: ['ITAIM' 'MORUMBI']
# 12 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 3 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 17 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 3 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 19 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 3 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 31 - valor unico: [ 07 ... 13 - MORUMBI - SEMANA - MANHA - C.CIRURGICO ]
# 02 - valor unico: [ 07 ... 13 - MORUMBI - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# ANNA BEATRIZ LIMA DO VALLE ASTUR ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 13 - valor unico: [ 19 ... 07 - ITAIM - SEMANA - NOTURNO - PLANTAO ]
#
#
# carregou - 1 0.02
# ANTONIO ALVARO DIAS LIMA DA CUNHA NETO ==================================================
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# carregou - 1 0.03
# ARTHUR OLIVEIRA FACCHINI ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# AVELINO JOSÉ DA SILVA FREITAS JÚNIOR ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# BEATRIZ ANTIPOU DOS SANTOS ==================================================
# 07 - erro entre os horarios: [ 19:00 ... 14:30 ]
# 07 - unidade diferentes: ['AVICCENA' 'ITAIM']
# 10 - valor unico: [ 07 ... 11 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 16 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - AV.PRE ANESTESICA ]
# 04 - valor unico: [ 07 ... 13 - AVICCENA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# BIANCA PRISCILA BUNIOTTI ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - MATERNIDADE - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# BRUCE YE MAN CHOW ==================================================
# 11 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 11 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
#
#
# carregou - 1 0.6
# BRUNA DAIBERT DANESIN ==================================================
# 09 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 15 - valor unico: [ 07 ... 19 - JABAQUARA - FDS - D2 PRIMEIRO (R) ]
#
#
# carregou - 1 0.05
# BRUNO FERRAZ DE CAMPOS BARONE ==================================================
# 12 - valor unico: [ 08 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 12 - dia da semana errado: [ ADMINISTRATIVO ]
# 20 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 20 - unidade diferentes: ['ITAIM' 'VNS']
# 27 - valor unico: [ 07 ... 13 - VNS - SEMANA - MANHA - C.CIRURGICO ]
# 29 - erro entre os horarios: [ 17:30 ... 22:30 ]
# 03 - valor unico: [ 07 ... 13 - VNS - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.04
# BRUNO STORNIOLI TAGUCHI LEMOS ==================================================
# 09 - valor unico: [ 07 ... 12 - JABAQUARA - SEMANA - MANHA - C.CIRURGICO ]
# 25 - valor unico: [ 14 ... 19 - JABAQUARA - SEMANA - TARDE - C.CIRURGICO ]
# 29 - erro entre os horarios: [ 07:00 ... 12:00 ]
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# CAIO TULIO DUARTE ==================================================
#
#
# carregou - 1 0.03
# CAMILA CHIARANTANO HARRISON ==================================================
# 08 - valor unico: [ 07 ... 19 - VILLA - FDS - D2 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 30 - unidade diferentes: ['JABAQUARA' 'VILLA']
#
#
# carregou - 1 0.03
# CARLOS AUGUSTO TREVISAN ==================================================
# 08 - valor unico: [ 07 ... 19 - ANALIA - FDS - D2 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.03
# CARLOS EDUARDO CORRÊA GRILO ==================================================
# 13 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 17 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 20 - valor unico: [ 07 ... 09 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 23 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 13 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 24 - valor unico: [ 07 ... 13 - ADMINISTRACAO - PERIODO DE DESCANSO - 13 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 30 - erro entre os horarios: [ 07:00 ... 13:00 ]
# 30 - unidade diferentes: ['ADMINISTRACAO' 'ANALIA']
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 31 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# CARLOS EDUARDO GONDIM OLIVEIRA ==================================================
# 07 - unidade diferentes: ['ITAIM' 'MORUMBI']
# 11 - valor unico: [ 07 ... 10 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 15 - erro entre os horarios: [ 19:00 ... 13:00 ]
# 15 - unidade diferentes: ['MORUMBI' 'VNS']
# 16 - erro entre os horarios: [ 19:00 ... 11:00 ]
# 16 - unidade diferentes: ['ITAIM' 'MATERNIDADE']
# 19 - erro entre os horarios: [ 19:00 ... 10:30 ]
# 19 - unidade diferentes: ['ITAIM' 'VNS']
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 24 - erro entre os horarios: [ 19:00 ... 14:00 ]
# 24 - unidade diferentes: ['ITAIM' 'MATERNIDADE']
#
#
# carregou - 1 0.04
# CAROLINE FIRMINO LEMES DA SILVA ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 31 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 31 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
#
#
# carregou - 1 0.92
# CLAUDIO MUELLER KAKUDA ==================================================
# 11 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - MATERNIDADE - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# DANIEL MASUZAKI WONG ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.85
# DANIEL RODRIGUES DE OLIVEIRA ==================================================
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.03
# DANIELLEN LINS LOURENÇO ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 13 ]
# 04 - valor unico: [ 19 ... 07 - VNS - FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# carregou - 1 0.04
# DÉBORA ALVES AUDE ==================================================
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# DÉBORA PHILIPPI BRESSANE ==================================================
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# DENIO LOPES DE ALMEIDA ==================================================
# 09 - unidade diferentes: ['ITAIM' 'MATERNIDADE']
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 1.08
# DIEGO DA CUNHA TOMAZ ==================================================
#
#
# carregou - 1 0.05
# DIOGO CANDEO RODRIGUES CORDEIRO ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 09 - erro entre os horarios: [ 06:00 ... 07:00 ]
# 09 - unidade diferentes: ['ADMINISTRACAO' 'ANALIA']
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 10 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 10 - unidade diferentes: ['ADMINISTRACAO' 'ANALIA']
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# DIOGO HENRIQUE PEREIRA MATTOS ==================================================
# 11 - valor unico: [ 07 ... 07 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# EDUARDO ARBACHE BEZERRA ==================================================
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# EDUARDO DALA ROSA SOARES ==================================================
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 10 ]
#
#
# carregou - 1 0.03
# ELAINE IMAEDA DE MOURA ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# EMERSON DOMINGOS DA COSTA ==================================================
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# ERICK OLIVEIRA LIMA GOMES ==================================================
# 10 - valor unico: [ 07 ... 09 - JABAQUARA - SEMANA - MANHA - C.CIRURGICO ]
# 17 - valor unico: [ 07 ... 11 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 1.38
# ESTANRLEY BARCELOS PINTO ==================================================
# 08 - valor unico: [ 07 ... 19 - JABAQUARA - FDS - D2 PRIMEIRO (R) ]
#
#
# carregou - 1 0.03
# EVERTON SIDNEY DA CONCEIÇÃO CARVALHO ==================================================
# 09 - unidade diferentes: ['ITAIM' 'OSASCO']
# 10 - valor unico: [ 07 ... 13 - OSASCO - SEMANA - MANHA - C.CIRURGICO ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 17 - valor unico: [ 07 ... 11 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 30 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 30 - unidade diferentes: ['ADMINISTRACAO' 'OSASCO']
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
#
#
# carregou - 1 0.03
# FABIANA BARBOSA BASTOS ==================================================
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 04 - valor unico: [ 07 ... 13 - VNS - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.06
# FABIANA SOARES GAMA ==================================================
# 25 - valor unico: [ 07 ... 13 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 1.23
# FÁBIO ANTÔNIO DE SOUZA OLIVEIRA ==================================================
# 11 - erro entre os horarios: [ 19:00 ... 13:00 ]
# 25 - valor unico: [ 19 ... 07 - ITAIM - SEMANA - NOTURNO - PLANTAO ]
#
#
# carregou - 1 0.04
# FÁBIO YUJI SUGUITA ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 09 - valor unico: [ 07 ... 11 - JABAQUARA - SEMANA - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# FELIPE COELHO DE SOUZA ==================================================
# 19 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.05
# FELIPE DE OLIVEIRA NUNES ==================================================
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 29 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - SEGUNDO (B) ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# FERNANDA TELES RIBEIRO ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 22 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - SEGUNDO (B) ]
# 24 - valor unico: [ 07 ... 08 - MATERNIDADE - SEMANA - MANHA - C.CIRURGICO ]
# 26 - valor unico: [ 19 ... 07 - MATERNIDADE - SEMANA - NOTURNO - PLANTAO ]
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# FERNANDO AKIRA KOGA ==================================================
# 10 - valor unico: [ 07 ... 10 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 11 - valor unico: [ 07 ... 13 - MORUMBI - SEMANA - MANHA - C.CIRURGICO ]
# 24 - valor unico: [ 07 ... 11 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 31 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# FERNANDO NARDY BELLICIERI ==================================================
#
#
# carregou - 1 0.03
# FERNANDO RIBEIRO SÁ ==================================================
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 10 - erro entre os horarios: [ 05:30 ... 01:00 ]
# 10 - unidade diferentes: ['ADMINISTRACAO' 'VNS']
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
#
#
# carregou - 1 0.04
# FILIPE LUGON MOULIN LIMA ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 20 - valor unico: [ 07 ... 11 - JABAQUARA - SEMANA - MANHA - C.CIRURGICO ]
# 03 - valor unico: [ 13 ... 19 - MORUMBI - SEMANA - TARDE - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# FILIPE MAEDA HASHI ABDALLA MARTINS ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# FLÁVIO HIDEKI OSHIKA ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# FRANCISCO ANTONIO ALVES BONATTO ==================================================
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# FRANCISCO JOSÉ LUCENA BEZERRA ==================================================
# 21 - unidade diferentes: ['AVICCENA' 'MORUMBI']
# 29 - valor unico: [ 07 ... 19 - ANALIA - FDS - PLANTAO ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# GABRIEL DE AGUIAR SANTANA ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# GABRIEL GONDIM FONSECA ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 19 - valor unico: [ 19 ... 07 - ANALIA - SEMANA - NOTURNO - PLANTAO ]
# 20 - valor unico: [ 07 ... 10 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# GABRIELA RODRIGUES MACHADO BORJA ==================================================
#
#
# carregou - 1 0.03
# GABRIELA SOARES PIASSI ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# GABRIELLA GADELHA SARMENTO ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.03
# GRETEL OLIVEIRA NICOLAU ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 08 - valor unico: [ 07 ... 19 - MATERNIDADE - FDS - PLANTAO ]
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 24 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
#
#
# carregou - 1 0.03
# GUILHERME DE ALMEIDA COSTA ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 19 - valor unico: [ 19 ... 07 - VILLA - SEMANA - NOTURNO - PLANTAO ]
# 20 - valor unico: [ 07 ... 13 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# carregou - 1 0.03
# GUILHERME SILVEIRA LOPES ==================================================
# 15 - valor unico: [ 07 ... 19 - ANALIA - FDS - D2 ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# GUSTAVO MARQUES DA SILVA ==================================================
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# HEDICLEBER PESTANA SEVERINO ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 09 - valor unico: [ 07 ... 10 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 05 ... 07 - VILLA - SEMANA - 6HS ]
# 04 - valor unico: [ 07 ... 13 - SANTA ISABEL - FDS - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# HELENA ARAUJO DAMASCENO ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# HENRI ROGER WATANABE OLIVEIRA ==================================================
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 29 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - PRIMEIRO (R) ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# IVÃ BARBOSA SOARES ==================================================
# 08 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - SEGUNDO (B) ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 26 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
#
#
# carregou - 1 0.68
# IZABELLA GONTIJO CUNHA ==================================================
# 15 - valor unico: [ 07 ... 19 - ITAIM - FDS - D2 ]
#
#
# carregou - 1 0.04
# JÉSSICA LÍDIA DE SOUZA ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 15 - valor unico: [ 07 ... 17 - VILLA - FDS - PLANTAO ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 17:00 ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# JOÃO THEODORO DE MEDEIROS NETO ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.81
# JOSÉ CARLOS TUNA SCARPA ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 15 - valor unico: [ 07 ... 20 - AVICCENA - FDS - D1 ]
#
#
# carregou - 1 0.04
# JOSÉ MARCOS VIEIRA DA SILVA ==================================================
# 25 - valor unico: [ 07 ... 11 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# JULIANA AKEMI FUNABASHI ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# JULIANA HUSSEIN GRILO ==================================================
# 02 - erro entre os horarios: [ 07:00 ... 13:00 ]
# 02 - dia da semana errado: [ MES ANTERIOR ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 4 ]
# 25 - valor unico: [ 13 ... 19 - VILLA - SEMANA - TARDE - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# JULIANO MOISÉS TOBAL ==================================================
#
#
# carregou - 1 0.02
# KAIÊ FERNANDES ==================================================
# 19 - unidade diferentes: ['ITAIM' 'VILLA']
# 02 - erro entre os horarios: [ 19:00 ... 13:00 ]
#
#
# carregou - 1 0.04
# KAREN PEIXOTO RICCI ==================================================
# 16 - valor unico: [ 07 ... 12 - OSASCO - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# KAREN YUMI MIYASHIRO ==================================================
#
#
# carregou - 1 0.03
# KAWAN RAMIS RODRIGUES ==================================================
#
#
# carregou - 1 0.04
# LAIS RIBEIRO TEIXEIRA ==================================================
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# LARISSA MAYUMI ONO ==================================================
#
#
# carregou - 1 0.03
# LEANDRO EDUARDO FRANÇA ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - AVALIACAO PRE ROTINA ]
# 04 - dia da semana errado: [ FDS - AVALIACAO PRE ROTINA ]
#
#
# carregou - 1 0.03
# LEANDRO KENDI KANADA ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# LEANDRO OLIVEIRA MARTINS CÔRTES ==================================================
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 31 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# LEOPOLDO MUNIZ DA SILVA ==================================================
#
#
# carregou - 1 0.03
# LETÍCIA FERNANDES BORGES ==================================================
#
#
# carregou - 1 0.03
# LÍVIA SCHENKEL THURLER TRAIRI ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.04
# LUANA MARIS RODRIGUES DE SOUZA ==================================================
#
#
# carregou - 1 0.04
# LUCCAS VARELA GODOY ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:30 ]
# 30 - valor unico: [ 07 ... 13 - OSASCO - SEMANA - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.03
# LUCIANA VENTURINI ==================================================
#
#
# carregou - 1 0.03
# LUCIANO ANGELO RICHETTI ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 10 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 10 - unidade diferentes: ['ADMINISTRACAO' 'SANTA ISABEL']
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 7 ]
# carregou - 1 1.01
# LUDMYLLA GOMES NEVES ==================================================
#
#
# carregou - 1 0.03
# LUIZ ALBERTO CEPÊDA ==================================================
#
#
# carregou - 1 0.04
# LUIZ AUGUSTO XAVIER BRANDÃO ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 20 - valor unico: [ 07 ... 13 - SANTA ISABEL - SEMANA - MANHA - C.CIRURGICO ]
# 03 - valor unico: [ 07 ... 13 - SANTA ISABEL - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 1.11
# LUIZ GUILHERME THOMAZ ZACHARIAS ==================================================
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 07 ... 10 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 1.12
# MAIELY MARCOLIN ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 07 ... 09 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - D1 ]
# 04 - dia da semana errado: [ FDS - D1 ]
#
#
# carregou - 1 0.3
# MAÍRA LEITE BASILE ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 23 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 25 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 27 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 2 ]
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 3 ]
#
#
# carregou - 1 0.03
# MANOEL DE SOUZA NETO ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 08 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - PRIMEIRO (R) ]
# 03 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - AV.PRE ANESTESICA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# MARCELA APARECIDA CORREA MARTINS ==================================================
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.04
# MARCELA LEITE ROSIGNOLI ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# MARCELLA PELLICCIOTTI DE SOUZA ==================================================
#
#
# carregou - 1 0.03
# MARCELO DOS ANJOS REIS ==================================================
#
#
# carregou - 1 0.03
# MARCELO FELIPE DE SOUZA BUTO ==================================================
#
#
# carregou - 1 0.03
# MARCELO MAIA DA SILVEIRA ==================================================
# 11 - valor unico: [ 07 ... 13 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 29 - valor unico: [ 07 ... 19 - VILLA - FDS - D2 ]
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# MÁRCIO IGHOR AZEVEDO SILVA DE MENDONÇA MELÂNIA ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.03
# MARCOS ROGÉRIO PEREIRA MACHADO FILHO ==================================================
# 11 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 11 - unidade diferentes: ['ADMINISTRACAO' 'VILLA']
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 13 - erro entre os horarios: [ 04:30 ... 19:00 ]
# 13 - unidade diferentes: ['ADMINISTRACAO' 'VILLA']
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 13 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# 20 - dia da semana errado: [ PERIODO DE DESCANSO - 5 ]
# ...
# 30 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 31 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 31 - dia da semana errado: [ PERIODO DE DESCANSO - 1 ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# RODRIGO ACHUI HAGA ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# RODRIGO ANDRADE CARMELLO ==================================================
# 19 - valor unico: [ 07 ... 13 - VNS - SEMANA - MANHA - C.CIRURGICO ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 02 - valor unico: [ 07 ... 13 - VNS - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# RODRIGO ANTONIO REY GONZALEZ ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 25 - valor unico: [ 07 ... 12 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 07 ... 13 - SANTA ISABEL - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - OSASCO - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# carregou - 1 0.02
# RODRIGO DE CARVALHO SILVA ==================================================
#
#
# carregou - 1 0.02
# RODRIGO GIOVANELLI CONSTANTINO ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 06 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 10 - unidade diferentes: ['ADMINISTRACAO' 'ANALIA']
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 11 - valor unico: [ 07 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 11 - dia da semana errado: [ ADMINISTRATIVO ]
# 12 - dia da semana errado: [ ADMINISTRATIVO ]
# 12 - dia da semana errado: [ ADMINISTRATIVO ]
# 18 - valor unico: [ 07 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 18 - dia da semana errado: [ ADMINISTRATIVO ]
# 19 - dia da semana errado: [ ADMINISTRATIVO ]
# 19 - dia da semana errado: [ ADMINISTRATIVO ]
# 25 - valor unico: [ 07 ... 13 - ADMINISTRACAO - ADMINISTRATIVO ]
# 25 - dia da semana errado: [ ADMINISTRATIVO ]
# 26 - dia da semana errado: [ ADMINISTRATIVO ]
# 26 - dia da semana errado: [ ADMINISTRATIVO ]
# 30 - dia da semana errado: [ ADMINISTRATIVO ]
# 30 - dia da semana errado: [ ADMINISTRATIVO ]
# 04 - valor unico: [ 07 ... 13 - ANALIA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# RODRIGO MIYASHIRO NUNES DOS SANTOS ==================================================
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.03
# ROGÉRIO SIDNEY THON ==================================================
#
#
# carregou - 1 0.03
# ROMULO SPOLIDORIO ==================================================
# 21 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# RONALD FIGUEIREDO GOMES ==================================================
# 11 - valor unico: [ 07 ... 10 - AVICCENA - SEMANA - MANHA - C.CIRURGICO ]
# 17 - valor unico: [ 07 ... 13 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.62
# SABRINA DE SOUZA RAMOS ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.02
# SAULLO QUEIROZ SILVEIRA ==================================================
# 02 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 02 - unidade diferentes: ['ADMINISTRACAO' 'VNS']
# 02 - dia da semana errado: [ ADMINISTRATIVO ]
# 04 - dia da semana errado: [ ADMINISTRATIVO ]
# 04 - dia da semana errado: [ ADMINISTRATIVO ]
# 09 - erro entre os horarios: [ 05:30 ... 01:00 ]
# 09 - unidade diferentes: ['ADMINISTRACAO' 'VNS']
# 09 - dia da semana errado: [ ADMINISTRATIVO ]
# 11 - dia da semana errado: [ ADMINISTRATIVO ]
# 11 - dia da semana errado: [ ADMINISTRATIVO ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 16 - valor unico: [ 13 ... 19 - ADMINISTRACAO - ADMINISTRATIVO ]
# 16 - dia da semana errado: [ ADMINISTRATIVO ]
# 18 - dia da semana errado: [ ADMINISTRATIVO ]
# 18 - dia da semana errado: [ ADMINISTRATIVO ]
# 23 - erro entre os horarios: [ 06:30 ... 19:00 ]
# 23 - unidade diferentes: ['ADMINISTRACAO' 'VNS']
# 23 - dia da semana errado: [ ADMINISTRATIVO ]
# 25 - dia da semana errado: [ ADMINISTRATIVO ]
# 25 - dia da semana errado: [ ADMINISTRATIVO ]
# 27 - valor unico: [ 07 ... 11 - VNS - SEMANA - MANHA - C.CIRURGICO ]
# 30 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 30 - unidade diferentes: ['ADMINISTRACAO' 'VNS']
# 30 - dia da semana errado: [ ADMINISTRATIVO ]
#
#
# carregou - 1 0.03
# SÉRGIO ZAMITH ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 8 ]
#
#
# carregou - 1 0.34
# SHEILA ITIROCO MONTE ==================================================
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.64
# SIDNEY ORLANDO DE SOUZA ==================================================
# 25 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 30 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.03
# SILVIA ALINE DOS SANTOS ANDRADE ==================================================
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - ITAIM - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# STEFANY HÉLLEN SOUSA MARTINS ==================================================
# 24 - valor unico: [ 07 ... 12 - MORUMBI - SEMANA - MANHA - C.CIRURGICO ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.02
# THAIS CHAVES PINHEIRO ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 21 - erro entre os horarios: [ 19:00 ... 13:00 ]
# 22 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 07 ... 13 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - VNS - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# THAIS MIRANDA RAMOS ==================================================
# 10 - erro entre os horarios: [ 07:00 ... 20:30 ]
# 10 - unidade diferentes: ['MATERNIDADE' 'VILLA']
# 11 - valor unico: [ 07 ... 10 - JABAQUARA - SEMANA - MANHA - C.CIRURGICO ]
#
#
# carregou - 1 0.02
# THALES LUVISOTTO NEDER ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 15 - valor unico: [ 07 ... 19 - MORUMBI - FDS - D2 - SEGUNDO (B) ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
#
#
# carregou - 1 0.02
# THASSIO CUNHA DE SANTANA ==================================================
#
#
# carregou - 1 0.02
# THAYS FILIZZOLA BORGES ==================================================
#
#
# carregou - 1 0.81
# THIAGO BARRETO MARQUES DA SILVA ==================================================
# 15 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 30 - valor unico: [ 05 ... 07 - VILLA - SEMANA - 6HS ]
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - AVALIACAO PRE ROTINA ]
# 04 - dia da semana errado: [ FDS - AVALIACAO PRE ROTINA ]
#
#
# carregou - 1 0.02
# THIAGO FRANCISCO MARTINS ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 04 - unidade diferentes: ['ITAIM' 'MATERNIDADE']
# 04 - dia da semana errado: [ FDS - PLANTAO ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# THIAGO SILVA PINTO ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 05 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 05 - unidade diferentes: ['ADMINISTRACAO' 'SANTA ISABEL']
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 05 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 09 - erro entre os horarios: [ 07:00 ... 19:00 ]
# 09 - unidade diferentes: ['ADMINISTRACAO' 'SANTA ISABEL']
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 10 - erro entre os horarios: [ 06:00 ... 07:00 ]
# 10 - unidade diferentes: ['ADMINISTRACAO' 'SANTA ISABEL']
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 9 ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# carregou - 1 0.01
# TURÍBIO RODRIGUES FREIRE NETO ==================================================
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 02 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 03 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 04 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 09 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
# 10 - dia da semana errado: [ PERIODO DE DESCANSO - 11 ]
#
#
# carregou - 1 0.02
# VANESSA PACIULLO MAROSSI ==================================================
# 08 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
#
#
# carregou - 1 0.02
# VICTOR SAPOUNTZAKIS RIBEIRO ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - AVALIACAO PRE ROTINA ]
# 04 - dia da semana errado: [ FDS - AVALIACAO PRE ROTINA ]
#
#
# carregou - 1 0.01
# VITOR MACIEL DE SOUSA PINTO ==================================================
# 09 - erro entre os horarios: [ 17:30 ... 13:00 ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 17 - valor unico: [ 07 ... 08 - ANALIA - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.01
# VITOR OLIVEIRA ANDRÉ ==================================================
# 04 - valor unico: [ 07 ... 13 - JABAQUARA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.01
# VIVIAN CRISTINE DOS ANJOS E SILVA ==================================================
# 04 - valor unico: [ 07 ... 13 - VILLA - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.01
# VIVIANNA BOVÉRIO GALZERANI ==================================================
#
#
# carregou - 1 0.01
# WANGLES PIGNATON DE PAULA ==================================================
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - dia da semana errado: [ FDS - PLANTAO ]
# 01 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 11 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 11 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 11 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 12 - erro entre os horarios: [ 06:00 ... 07:00 ]
# 12 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 12 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 16 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 16 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 16 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 17 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 17 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 17 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 18 - erro entre os horarios: [ 06:00 ... 19:00 ]
# 18 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 18 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 19 - erro entre os horarios: [ 06:00 ... 07:00 ]
# 19 - unidade diferentes: ['ADMINISTRACAO' 'MORUMBI']
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 19 - dia da semana errado: [ PERIODO DE DESCANSO - 6 ]
# 28 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 29 - [FDS - PLANTÃO] registrado a tarde -[ 07:00 ... 19:00 ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.02
# YOKO HAYASHI ==================================================
#
#
# carregou - 1 0.02
# YURI ANDERSON PACHECO DE LIMA ==================================================
# 19 - valor unico: [ 05 ... 07 - MORUMBI - SEMANA - 6HS ]
# 26 - valor unico: [ 07 ... 09 - ITAIM - SEMANA - MANHA - C.CIRURGICO ]
# 04 - valor unico: [ 07 ... 13 - MORUMBI - FDS - C.CIRURGICO ROTINA ]
# 04 - dia da semana errado: [ FDS - C.CIRURGICO ROTINA ]
#
#
# carregou - 1 0.01
# YURI LUCAS DE SOUZA ==================================================
# 07 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 14 - [FDS - PLANTÃO] registrado a tarde -[ 13:00 ... 19:00 ]
# 16 - valor unico: [ 07 ... 13 - VILLA - SEMANA - MANHA - AMBULATORIO ]
# 17 - valor unico: [ 07 ... 12 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 19 - valor unico: [ 07 ... 11 - VILLA - SEMANA - MANHA - C.CIRURGICO ]
# 30 - valor unico: [ 07 ... 13 - VILLA - SEMANA - MANHA - AMBULATORIO ]

# %%
tabela

# %% [markdown]
# ## ==============================================================

# %%
browser.find_element_by_xpath('/html/body/div[6]/div/input').send_keys(NOMES[NOME])

# %%
browser.find_element_by_xpath('//*[@id="select2-drop"]/ul/li/div').click()

# %%
 and semana == 5

# %%
tabela

# %%
dias_fds = ['31','07','14','21','28','06','13','20','27','03']


for semana in tabela['Semana'].unique(): 
    tabela_semana = tabela[tabela['Semana'] == semana] # _isolar semana_
    #print('SEMANA', semana, '='*50)
    
    for dia in tabela_semana['Dia'].unique(): #verifique cada dia
        #print('DIA', dia, '='*40)
        tab_dia = tabela_semana[tabela_semana['Dia'] == str(dia)] #tabela dia XX # _isolar dia_
        tab_dia.reset_index(drop=True, inplace=True) #resetando index

        #ENCONTRANDO REGISTRO UNICOS, QUE NÃO SEJAM FINAL DE SEMANA COM PERIODOS MAIOR QUE 6H
        if len(tab_dia) == 1: #se contem apenas um registro
            if dia in dias_fds and int(tab_dia['Saida'][0][:2]) - int(tab_dia['Entrada'][0][:2]) <= 6:
                continue #pule 
            else: #se não for final de semana
                print('valor unico:', dia) #indique
                print(int(tab_dia['Saida'][0][:2]), int(tab_dia['Entrada'][0][:2]))
        
        #ENCONTRANDO DIAS QUE NÃO BATEM OS HORARIOS DE ENTRADA E SAIDA DOS TURNOS
        for t in range(len(tab_dia)): #para cada registro da tabela
            if t != 0: #em excessão do primeiro
                if tab_dia['Entrada'][t] != tab_dia['Saida'][t-1]: 
                    #verifique se a hora do inicio do plantão é igual a fim do plantão anterior
                    print('erro nos horarios:', dia) #se for, indique                        

        #ENCONTRANDO DIAS COM MAIS DE UMA UNIDADE REGISTRADA
        unidades_presentes = tab_dia['Unidade'].unique()
        if len(unidades_presentes) != 1:
            print('unidade diferentes:', dia)
            
        #ENCONTRANDO FINAIS DE SEMANA REGISTRADO COMO SEMANA
        if dia in dias_fds:
            for registro in range(len(tab_dia)):
                if 'FDS' not in tab_dia['Periodo'][registro]:
                    print("fim de semana errado:", tab_dia['Dia'][registro])
        if dia not in dias_fds:
            for registro in range(len(tab_dia)):
                if 'SEMANA' not in tab_dia['Periodo'][registro]:
                    print('dia da semana errado:', tab_dia['Dia'][registro])

# %% [markdown]
# # REAL:

# %%
browser.quit()
