# %%
mes = "07"

# %%
#manipulação de dados
import pandas as pd
import numpy as np

#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import unidecode #arrumar strings

import re #regex
import os


#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# # Automação

# %%
browser = webdriver.Firefox()

browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()

# %% [markdown]
# # Capturando setores:

# %%
#click criar novo plantão
browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr[1]/td[4]/button').click()

# %%
import time
from time import sleep

# %%
inicio = time.time() #iniciando o cronometro

#Setor
browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()

setor_html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML')
soup = BeautifulSoup(setor_html, 'html.parser')

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.799278736114502

# %%
inicio = time.time() #iniciando o cronometro

lista_unidade = []
lista_unidade_count = []
lista_plt = []
lista_plt_count = []

count_unidade = 1

for i in soup.find_all(class_="select2-results-dept-0 select2-result select2-result-unselectable select2-result-with-children"):
    #print('\n', i.find(class_='select2-result-label').get_text(), '====== \n')
    count_plt = 1
    for t in i.find_all(class_='select2-results-dept-1 select2-result select2-result-selectable'): 
        #print(t.get_text())
        lista_plt.append(t.get_text())
        lista_plt_count.append(count_plt)
        count_plt += 1
            
        lista_unidade.append(i.find(class_='select2-result-label').get_text())
        lista_unidade_count.append(count_unidade)
    count_unidade += 1

scrap_unidades = pd.DataFrame({'unidade':lista_unidade, 'momento':lista_plt,
                               'unidade_count':lista_unidade_count, 'plt_count':lista_plt_count})

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: x.replace('  ',' '))

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))
scrap_unidades['unidade'] = scrap_unidades['unidade'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.04015040397644043

# %% [markdown]
# # TESTANDO SETORES

# %%
df_backup = pd.read_excel('df_giov2.xlsx')

df_backup = df_backup.sort_values(['nome', 'data'])
df_backup.reset_index(drop=True, inplace=True)

df_backup['periodo'] = df_backup['periodo2']

#FATIAMENTO NO DATAFRAME
df_backup_up = df_backup.copy()

print(len(df_backup))
df_backup.sample(5)
# Out:
# 47
#                                                  chat         dia  \
# 17  [08/07/2023 09:18:03] Kaiê Fernandes: 08/07 Ja...  08/07/2023
# 41  [11/07/2023 14:21:13] Thales Luvisotto Neder: ...  11/07/2023
# 11  [01/07/2023 11:21:08] Francisco José Lucena Be...  01/07/2023
# 39  [03/07/2023 06:07:26] Thais Chaves Pinheiro: 0...  03/07/2023
# 1   [01/07/2023 11:40:45] Anna Beatriz Lima Do Val...  01/07/2023
#
#                                 nome  \
# 17                    KAIE FERNANDES
# 41            THALES LUVISOTTO NEDER
# 11     FRANCISCO JOSE LUCENA BEZERRA
# 39             THAIS CHAVES PINHEIRO
# 1   ANNA BEATRIZ LIMA DO VALLE ASTUR
#
#                                              mensagem controle        data  \
# 17  08/07 Jabaquara Kaie saída 9:10   (  deslocado...     PROB  08/07/2023
# 41  11/07 Osasco  -  Thales saída 14:20   (  deslo...     PROB  11/07/2023
# 11        01/07 SANTA ISABEL -  Lucena -  saída 11:15     PROB  01/07/2023
# 39                03/07 Itaim  -  Thaís entrada 06:00     PROB  03/07/2023
# 1   01/07 Santa Isabel  -  Astur saida 11:40   (  ...     PROB  01/07/2023
#
#          unidade  extra     tipo ENTRADA  SAIDA DURAÇÃO PERIODO  periodo2  \
# 17     JABAQUARA    NaN    SAIDA   07:00  09:30   02:30   manha       2.0
# 41        OSASCO    NaN    SAIDA   13:00  14:30   01:30   tarde       NaN
# 11  SANTA ISABEL    NaN    SAIDA   07:00  11:30   04:30   manha       2.0
# 39         ITAIM    NaN  ENTRADA   06:00  07:00   01:00      6h       1.0
# 1   SANTA ISABEL  extra    SAIDA   07:00  12:00   05:00   manha       2.0
#
#                            setor sem_ou_fds            unidade2  \
# 17                    FDS ROTINA        fds   ['JABA', 'ITAIM']
# 41  SEMANA - TARDE - C.CIRURGICO     semana  ['OSASCO', 'JABA']
# 11                   FDS - MANHA        fds               SANTA
# 39                  SEMANA - 6HS     semana               ITAIM
# 1                    FDS - MANHA        fds               SANTA
#
#       setor_inicio  periodo
# 17      FDS ROTINA      2.0
# 41  SEMANA - TARDE      NaN
# 11     FDS - MANHA      2.0
# 39    SEMANA - 6HS      1.0
# 1      FDS - MANHA      2.0

# %%
print(df_backup['setor'].unique())
df_backup['setor_inicio'] = df_backup['setor']
df_backup['setor'][df_backup['setor'] == 'SEMANA - MANHA'] = 'SEMANA - MANHA - C.CIRURGICO'
df_backup['setor'][df_backup['setor'] == 'SEMANA - TARDE'] = 'SEMANA - TARDE - C.CIRURGICO'
# Out:
# ['SEMANA - TARDE - C.CIRURGICO' 'FDS - MANHA' 'FDS ROTINA'
#  'SEMANA - MANHA - C.CIRURGICO' 'SEMANA - 6HS' 'FDS - SAIDA'
#  'SEMANA - NOTURNO - SAIDA' 'FDS - PLANTAO']

# %%
df_backup_fds = df_backup[(df_backup['sem_ou_fds'] != 'semana') | (df_backup['tipo'] != 'SAIDA')].reset_index(drop=True)
print(len(df_backup_fds))
df_backup_up = df_backup[(df_backup['sem_ou_fds'] == 'semana') & (df_backup['tipo'] == 'SAIDA')].reset_index(drop=True)
print(len(df_backup_up))

df = df_backup_up.copy()
# Out:
# 25
# 22

# %%
df_backup_up
# Out:
#                                                  chat         dia  \
# 0   [13/07/2023 05:04:20] Alexsander Takashi Hamad...  13/07/2023
# 1   [10/07/2023 09:46:18] Everton Sidney da Concei...  10/07/2023
# 2   [11/07/2023 15:51:35] Fabiana Barbosa Bastos: ...  11/07/2023
# 3   [10/07/2023 15:33:22] Felipe Coelho de Souza: ...  10/07/2023
# 4   [10/07/2023 17:10:05] Guilherme de Almeida Cos...  10/07/2023
# 5   [11/07/2023 20:27:18] Ícaro Moura: 11/07 - Ita...  11/07/2023
# 6   [11/07/2023 09:05:09] Izabela Cristina Almeida...  11/07/2023
# 7   [10/07/2023 16:11:49] Jessica Lidia de Souza: ...  10/07/2023
# 8   [10/07/2023 18:17:25] Karen Cavichini Rosseto:...  10/07/2023
# 9   [10/07/2023 14:30:03] Maíra Leite Basile: 10/0...  10/07/2023
# 10  [11/07/2023 18:21:20] Marcela Leite Rosignoli:...  11/07/2023
# 11  [11/07/2023 16:30:00] Maria Carolina Célia Sil...  11/07/2023
# 12  [12/07/2023 14:17:37] Maria Carolina Célia Sil...  12/07/2023
# 13  [10/07/2023 14:23:40] Maurício Faria Tetti: 10...  10/07/2023
# 14  [10/07/2023 15:24:51] Maxvilano Lima de Macedo...  10/07/2023
# 15  [10/07/2023 10:45:43] Nara Yamane dos Santos: ...  10/07/2023
# 16  [11/07/2023 16:29:30] Pedro Henrique Diniz Bot...  11/07/2023
# 17  [11/07/2023 16:12:10] Pedro Henrique Milhomens...  11/07/2023
# 18  [12/07/2023 16:02:15] Rafael Tadeu Marques: 12...  12/07/2023
# 19  [11/07/2023 14:21:13] Thales Luvisotto Neder: ...  11/07/2023
# 20  [10/07/2023 14:46:40] Thiago Barreto Marques d...  10/07/2023
# 21  [12/07/2023 14:18:20] Vivianna Bovério Galzera...  12/07/2023
#
#                                     nome  \
# 0              ALEXSANDER TAKASHI HAMADA
# 1   EVERTON SIDNEY DA CONCEICAO CARVALHO
# 2                 FABIANA BARBOSA BASTOS
# 3                 FELIPE COELHO DE SOUZA
# 4             GUILHERME DE ALMEIDA COSTA
# 5                            ICARO MOURA
# 6        IZABELA CRISTINA ALMEIDA DUARTE
# 7                 JESSICA LIDIA DE SOUZA
# 8                KAREN CAVICHINI ROSSETO
# 9                     MAIRA LEITE BASILE
# 10               MARCELA LEITE ROSIGNOLI
# 11         MARIA CAROLINA CELIA SILVEIRA
# 12         MARIA CAROLINA CELIA SILVEIRA
# 13                  MAURICIO FARIA TETTI
# 14              MAXVILANO LIMA DE MACEDO
# 15                NARA YAMANE DOS SANTOS
# 10     JABAQUARA   NaN  SAIDA   13:00  17:00   04:00          tarde       NaN
# 11        OSASCO   NaN  SAIDA   13:00  16:30   03:30          tarde       NaN
# 12        OSASCO   NaN  SAIDA   13:00  14:00   01:00          tarde       NaN
# 13      AVICCENA   NaN  SAIDA   13:00  14:30   01:30          tarde       NaN
# 14        OSASCO   NaN  SAIDA   13:00  15:30   02:30          tarde       NaN
# 15  SANTA ISABEL   NaN  SAIDA   07:00  11:00   04:00          manha       NaN
# 16     JABAQUARA   NaN  SAIDA   13:00  16:30   03:30          tarde       NaN
# 17        OSASCO   NaN  SAIDA   13:00  16:30   03:30          tarde       NaN
# 18           VNS   NaN  SAIDA   13:00  16:00   03:00          tarde       NaN
# 19        OSASCO   NaN  SAIDA   13:00  14:30   01:30          tarde       NaN
# 20        OSASCO   NaN  SAIDA   13:00  15:00   02:00          tarde       NaN
# 21     JABAQUARA   NaN  SAIDA   13:00  14:00   01:00          tarde       NaN
#
#                            setor sem_ou_fds                   unidade2  \
# 0   SEMANA - TARDE - C.CIRURGICO     semana                MATERNIDADE
# 1   SEMANA - MANHA - C.CIRURGICO     semana          ['JABA', 'ITAIM']
# 2   SEMANA - TARDE - C.CIRURGICO     semana         ['VNS', 'MORUMBI']
# 3   SEMANA - TARDE - C.CIRURGICO     semana                        VNS
# 4   SEMANA - TARDE - C.CIRURGICO     semana      ['MORUMBI', 'ANALIA']
# 5       SEMANA - NOTURNO - SAIDA     semana                      ITAIM
# 6   SEMANA - MANHA - C.CIRURGICO     semana                      VILLA
# 7   SEMANA - TARDE - C.CIRURGICO     semana                        VNS
# 8   SEMANA - TARDE - C.CIRURGICO     semana                      VILLA
# 9   SEMANA - TARDE - C.CIRURGICO     semana         ['MORUMBI', 'VNS']
# 10  SEMANA - TARDE - C.CIRURGICO     semana                       JABA
# 11  SEMANA - TARDE - C.CIRURGICO     semana          ['OSASCO', 'VNS']
# 12  SEMANA - TARDE - C.CIRURGICO     semana          ['OSASCO', 'VNS']
# 13  SEMANA - TARDE - C.CIRURGICO     semana     ['AVICCENA', 'ANALIA']
# 14  SEMANA - TARDE - C.CIRURGICO     semana                     OSASCO
# 15  SEMANA - MANHA - C.CIRURGICO     semana       ['SANTA', 'MORUMBI']
# 16  SEMANA - TARDE - C.CIRURGICO     semana         ['JABA', 'OSASCO']
# 17  SEMANA - TARDE - C.CIRURGICO     semana  ['OSASCO', 'MATERNIDADE']
# 18  SEMANA - TARDE - C.CIRURGICO     semana                        VNS
# 19  SEMANA - TARDE - C.CIRURGICO     semana         ['OSASCO', 'JABA']
# 20  SEMANA - TARDE - C.CIRURGICO     semana       ['OSASCO', 'ANALIA']
# 21  SEMANA - TARDE - C.CIRURGICO     semana            ['JABA', 'VNS']
#
#                     setor_inicio  periodo
# 0   SEMANA - TARDE - C.CIRURGICO      NaN
# 1   SEMANA - MANHA - C.CIRURGICO      NaN
# 2   SEMANA - TARDE - C.CIRURGICO      NaN
# 3   SEMANA - TARDE - C.CIRURGICO      NaN
# 4   SEMANA - TARDE - C.CIRURGICO      NaN
# 5       SEMANA - NOTURNO - SAIDA      NaN
# 6   SEMANA - MANHA - C.CIRURGICO      NaN
# 7   SEMANA - TARDE - C.CIRURGICO      NaN
# 8   SEMANA - TARDE - C.CIRURGICO      NaN
# 9   SEMANA - TARDE - C.CIRURGICO      NaN
# 10  SEMANA - TARDE - C.CIRURGICO      NaN
# 11  SEMANA - TARDE - C.CIRURGICO      NaN
# 12  SEMANA - TARDE - C.CIRURGICO      NaN
# 13  SEMANA - TARDE - C.CIRURGICO      NaN
# 14  SEMANA - TARDE - C.CIRURGICO      NaN
# 15  SEMANA - MANHA - C.CIRURGICO      NaN
# 16  SEMANA - TARDE - C.CIRURGICO      NaN
# 17  SEMANA - TARDE - C.CIRURGICO      NaN
# 18  SEMANA - TARDE - C.CIRURGICO      NaN
# 19  SEMANA - TARDE - C.CIRURGICO      NaN
# 20  SEMANA - TARDE - C.CIRURGICO      NaN
# 21  SEMANA - TARDE - C.CIRURGICO      NaN

# %%
for X in range(0, len(df)):
    if len(scrap_unidades.loc[(scrap_unidades.unidade == df['unidade'][X]) & 
                                 (scrap_unidades.momento == df['setor'][X])]) < 1:
        print(X)
        print(df['unidade'][X], '-', df['setor'][X])
        #print('index', ind)
        #print(scrap_unidades['unidade'][ind], '-', scrap_unidades['momento'][ind])
        #print('codigos:', unidade, setorzin)
    #else:
        #print('='*100, df['unidade'][X], '-', df['setor'][X])

print("="*20, "TUDO OK", "="*20)
# Out:
# ==================== TUDO OK ====================

# %% [markdown]
# # Função de captura dos dados

# %%
#########2
#capturando registros
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

def funcao():
    lista_tabela = []
    for i in range(1, 6): #passando por cada semana[1 a 5]
    ##print('semana:', i, "=="*20)
        for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
            reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
            content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
            content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra

            dia = content[0] #dia do registro
            del(content[0]) #deletando o dia, ja que foi coletado
            del(content[-1]) #deletando resido do wepscraping

            if len(content) != 0: #ignorando dias em branco (sem registro) ¹
                #print('dia:', t)

                ##print('dia:', dia)
                #print(content)

                count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
                lista_control = []
                for y in content: #passando um for sobre cada item da lista
                    if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                        #print('================unidade:', y)
                        unidade = y
                    elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                        count_hora += 1
                        if count_hora == 1: #capturando entrada
                            #print('hora entrada:', y)
                            lista_control.append(y)
                        elif count_hora == 2: #capturando saida
                            #print('hora saida:', y)
                            lista_control.append(y)
                            ##print('lista teste', lista_control)
                            lista_tabela.append(lista_control)
                            lista_control = []
                            count_hora = 0
                    else: #capturando dia, unidade, e periodo
                        #print('.')
                        #print('periodo:', y)
                        lista_control.append(dia)
                        lista_control.append(unidade)
                        lista_control.append(y)
                        lista_control.append(i)
                        lista_control.append(t) #dia semanal

                ##print('='*20)    

            else:
                continue #ignorando dias em branco (sem registro) ²
    
    tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Dia Semana','Entrada','Saida'])
    
    #limpeza da tabela
    #########3
    tabela['Dia'] = tabela['Dia'].apply(lambda x: int(x))

    #recolhendo os dias do mes passado que ainda aparecem na primeira semana
    dias_mes_passado = list(tabela[(tabela['Dia'] > 20) & (tabela['Semana'] == 1)].index) 
    tabela.drop(dias_mes_passado, axis=0, inplace=True) #excluindo
    tabela.reset_index(drop=True, inplace=True) #resetando index

    #Inserindo a ordem dos registros
    tabela['ordem'] = ''

    for i in tabela['Dia'].unique():
        for t in range(0, len(tabela[tabela['Dia'] == i].index)):
            tabela['ordem'][tabela[tabela['Dia'] == i].index[t]] = t+1

    #Inserindo coluna de data        
    tabela['data'] = tabela['Dia'].apply(lambda x: str(x))

    for i in range(len(tabela)):
        if len(tabela['data'][i]) == 1:
            tabela['data'][i] = "0" + tabela['data'][i]

        tabela['data'][i] = tabela['data'][i] + "/" + mes + "/2023" 

    tabela = tabela.query("Unidade != 'ADMINISTRACAO'")
    tabela = tabela[~((tabela['Semana'] >= 5) & (tabela['Dia'] < 10))]
    tabela.reset_index(drop=True, inplace=True) #resetando index
    
    tabela['PERIODO'] = np.nan
    for i in range(0, len(tabela)):
        if int(tabela['Entrada'][i][:2]) <= 6:
            tabela['PERIODO'][i] = '6h'
        elif int(tabela['Entrada'][i][:2]) >= 7 and int(tabela['Entrada'][i][:2]) <= 12:
            tabela['PERIODO'][i] = 'manha'
        elif int(tabela['Entrada'][i][:2]) >= 13 and int(tabela['Entrada'][i][:2]) <= 18:
            tabela['PERIODO'][i] = 'tarde'
        else:
            tabela['PERIODO'][i] = 'noturno saida'

    tabela['periodo'] = np.nan
    tabela['periodo'][tabela['PERIODO'] == '6h'] = 1
    tabela['periodo'][tabela['PERIODO'] == 'manha'] = 2
    tabela['periodo'][tabela['PERIODO'] == 'tarde'] = 3
    tabela['periodo'][tabela['PERIODO'] == 'noturno saida'] = 4
    
    
    
    return tabela
    
tabela = funcao()
tabela
# Out:
#     Dia      Unidade                           Periodo  Semana  Dia Semana  \
# 0     1     AVICCENA                         FDS - 6HS       1           6
# 1     1     AVICCENA          FDS - C.CIRURGICO ROTINA       1           6
# 2     3          VNS      SEMANA - MANHA - C.CIRURGICO       2           1
# 3     3          VNS      SEMANA - TARDE - C.CIRURGICO       2           1
# 4     4       ANALIA      SEMANA - MANHA - C.CIRURGICO       2           2
# 5     4       ANALIA      SEMANA - TARDE - C.CIRURGICO       2           2
# 6     4       OSASCO          SEMANA - NOTURNO - SAIDA       2           2
# 7     6       OSASCO                      SEMANA - 6HS       2           4
# 8     6       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       2           4
# 9     6       OSASCO      SEMANA - TARDE - C.CIRURGICO       2           4
# 10    7       OSASCO                      SEMANA - 6HS       2           5
# 11    7       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       2           5
# 12    7       OSASCO  SEMANA - TARDE - COBERTURA EXTRA       2           5
# 13    7       OSASCO          SEMANA - NOTURNO - SAIDA       2           5
# 14   10          VNS      SEMANA - MANHA - C.CIRURGICO       3           1
# 15   10          VNS      SEMANA - TARDE - C.CIRURGICO       3           1
# 16   10          VNS        SEMANA - NOTURNO - PLANTAO       3           1
# 17   13       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       3           4
# 18   13       OSASCO  SEMANA - TARDE - COBERTURA EXTRA       3           4
# 19   14       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       3           5
# 20   14       OSASCO  SEMANA - TARDE - COBERTURA EXTRA       3           5
# 21   15       OSASCO          FDS - C.CIRURGICO ROTINA       3           6
# 22   16       OSASCO                     FDS - PLANTAO       3           7
# 23   16       OSASCO                     FDS - PLANTAO       3           7
# 24   17      MORUMBI      SEMANA - MANHA - C.CIRURGICO       4           1
# 25   17      MORUMBI      SEMANA - TARDE - C.CIRURGICO       4           1
# 26   18        ITAIM      SEMANA - MANHA - C.CIRURGICO       4           2
# 27   18        ITAIM      SEMANA - TARDE - C.CIRURGICO       4           2
# 28   20      MORUMBI  SEMANA - MANHA - COBERTURA EXTRA       4           4
# 29   20      MORUMBI  SEMANA - TARDE - COBERTURA EXTRA       4           4
# 30   21       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       4           5
# 31   21       OSASCO  SEMANA - TARDE - COBERTURA EXTRA       4           5
# 32   22       OSASCO          FDS - C.CIRURGICO ROTINA       4           6
# 33   24  MATERNIDADE      SEMANA - MANHA - C.CIRURGICO       5           1
# 34   24  MATERNIDADE      SEMANA - TARDE - C.CIRURGICO       5           1
# 35   25        VILLA      SEMANA - MANHA - C.CIRURGICO       5           2
# 36   25        VILLA      SEMANA - TARDE - C.CIRURGICO       5           2
# 37   25        VILLA      SEMANA - NOTURNO - DISTANCIA       5           2
# 38   27    JABAQUARA      SEMANA - MANHA - C.CIRURGICO       5           4
# 39   27    JABAQUARA      SEMANA - TARDE - C.CIRURGICO       5           4
# 40   28       OSASCO  SEMANA - MANHA - COBERTURA EXTRA       5           5
# 41   28       OSASCO  SEMANA - TARDE - COBERTURA EXTRA       5           5
#
#    Entrada  Saida ordem        data        PERIODO  periodo
# 0    06:00  07:00     1  01/07/2023             6h      1.0
# 1    07:00  13:00     2  01/07/2023          manha      2.0
# 2    07:00  13:00     1  03/07/2023          manha      2.0
# 3    13:00  19:00     2  03/07/2023          tarde      3.0
# 4    07:00  13:00     1  04/07/2023          manha      2.0
# 5    13:00  19:00     2  04/07/2023          tarde      3.0
# 6    19:00  21:00     3  04/07/2023  noturno saida      4.0
# 7    05:30  07:00     1  06/07/2023             6h      1.0
# 8    07:00  13:00     2  06/07/2023          manha      2.0
# 4      JABAQUARA    NaN    SAIDA   07:00  10:00   03:00          manha
# 5            VNS    NaN    SAIDA   13:00  16:00   03:00          tarde
# 6         OSASCO    NaN  ENTRADA   06:00  07:00   01:00             6h
# 7            VNS    NaN    SAIDA   13:00  15:30   02:30          tarde
# 8            VNS    NaN  ENTRADA   06:00  07:00   01:00             6h
# 9      JABAQUARA    NaN    SAIDA   13:00  18:00   05:00          tarde
# 10     JABAQUARA    NaN  ENTRADA   05:00  07:00   02:00             6h
# 11  SANTA ISABEL    NaN    SAIDA   07:00  11:30   04:30          manha
# 12       MORUMBI    NaN    SAIDA   13:00  16:30   03:30          tarde
# 13         ITAIM    NaN    SAIDA   19:00  20:30   01:30  noturno saida
# 14       MORUMBI    NaN  ENTRADA   05:00  07:00   02:00             6h
# 15         VILLA    NaN    SAIDA   07:00  09:00   02:00          manha
# 16           VNS    NaN    SAIDA   13:00  16:30   03:30          tarde
# 17     JABAQUARA    NaN    SAIDA   07:00  09:30   02:30          manha
# 18         VILLA    NaN    SAIDA   13:00  18:30   05:30          tarde
# 19        OSASCO    NaN  ENTRADA   05:30  07:00   01:30             6h
# 20         ITAIM    NaN  ENTRADA   05:00  07:00   02:00             6h
# 21       MORUMBI    NaN    SAIDA   13:00  14:00   01:00          tarde
# 22     JABAQUARA    NaN    SAIDA   13:00  17:00   04:00          tarde
# 23        OSASCO    NaN    SAIDA   13:00  16:30   03:30          tarde
# 24        OSASCO    NaN    SAIDA   13:00  14:00   01:00          tarde
# 25   MATERNIDADE    NaN  ENTRADA   05:30  07:00   01:30             6h
# 26  SANTA ISABEL    NaN  ENTRADA   07:00  13:00   06:00          manha
# 27      AVICCENA    NaN    SAIDA   13:00  14:30   01:30          tarde
# 28        OSASCO    NaN    SAIDA   13:00  15:30   02:30          tarde
# 29  SANTA ISABEL    NaN    SAIDA   13:00  16:00   03:00          tarde
# 30  SANTA ISABEL    NaN    SAIDA   07:00  11:00   04:00          manha
# 31        ANALIA    NaN    SAIDA   07:00  11:30   04:30          manha
# 32        OSASCO    NaN  ENTRADA   06:00  07:00   01:00             6h
# 33     JABAQUARA    NaN    SAIDA   13:00  16:30   03:30          tarde
# 34        OSASCO    NaN    SAIDA   13:00  16:30   03:30          tarde
# 35           VNS    NaN    SAIDA   13:00  16:00   03:00          tarde
# 36     JABAQUARA    NaN  ENTRADA   05:00  07:00   02:00             6h
# 37       MORUMBI    NaN    SAIDA   07:00  11:00   04:00          manha
# 38        OSASCO    NaN    SAIDA   19:00  22:30   03:30  noturno saida
# 39         ITAIM    NaN  ENTRADA   06:00  07:00   01:00             6h
# 40        OSASCO    NaN  ENTRADA   05:30  07:00   01:30             6h
# 41        OSASCO    NaN    SAIDA   13:00  14:30   01:30          tarde
# 42        ANALIA    NaN    SAIDA   07:00  11:30   04:30          manha
# 43        OSASCO    NaN    SAIDA   13:00  15:00   02:00          tarde
# 44       MORUMBI    NaN  ENTRADA   05:30  07:00   01:30             6h
# 45       MORUMBI  extra  ENTRADA   05:00  07:00   02:00             6h
# 46     JABAQUARA    NaN    SAIDA   13:00  14:00   01:00          tarde
#
#     periodo2                         setor sem_ou_fds  \
# 0        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 1        2.0                   FDS - MANHA        fds
# 2        2.0                    FDS ROTINA        fds
# 3        2.0                    FDS ROTINA        fds
# 4        NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 5        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 6        1.0                  SEMANA - 6HS     semana
# 7        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 8        NaN                  SEMANA - 6HS     semana
# 9        3.0                   FDS - SAIDA        fds
# 10       1.0                  SEMANA - 6HS     semana
# 11       2.0                   FDS - MANHA        fds
# 12       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 13       NaN      SEMANA - NOTURNO - SAIDA     semana
# 14       NaN                  SEMANA - 6HS     semana
# 15       NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 16       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 17       2.0                    FDS ROTINA        fds
# 18       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 19       1.0                  SEMANA - 6HS     semana
# 20       NaN                  SEMANA - 6HS     semana
# 21       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 22       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 23       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 24       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 25       NaN                  SEMANA - 6HS     semana
# 26       2.0  SEMANA - MANHA - C.CIRURGICO     semana
# 27       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 28       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 29       3.0                   FDS - SAIDA        fds
# 30       NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 31       2.0                    FDS ROTINA        fds
# 32       1.0                  SEMANA - 6HS     semana
# 33       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 34       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 35       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 36       1.0                  SEMANA - 6HS     semana
# 37       2.0                    FDS ROTINA        fds
# 38       4.0                 FDS - PLANTAO        fds
# 39       1.0                  SEMANA - 6HS     semana
# 40       1.0                  SEMANA - 6HS     semana
# 41       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 42       2.0                    FDS ROTINA        fds
# 43       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 44       1.0                  SEMANA - 6HS     semana
# 45       NaN                  SEMANA - 6HS     semana
# 46       NaN  SEMANA - TARDE - C.CIRURGICO     semana
#
#                      unidade2                  setor_inicio  periodo
# 0                 MATERNIDADE  SEMANA - TARDE - C.CIRURGICO      NaN
# 1                       SANTA                   FDS - MANHA      2.0
# 2       ['ANALIA', 'MORUMBI']                    FDS ROTINA      2.0
# 3          ['OSASCO', 'JABA']                    FDS ROTINA      2.0
# 4           ['JABA', 'ITAIM']  SEMANA - MANHA - C.CIRURGICO      NaN
# 5          ['VNS', 'MORUMBI']  SEMANA - TARDE - C.CIRURGICO      NaN
# 6                      OSASCO                  SEMANA - 6HS      1.0
# 7                         VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 8                         VNS                  SEMANA - 6HS      NaN
# 9                        JABA                   FDS - SAIDA      3.0
# 10                       JABA                  SEMANA - 6HS      1.0
# 11                      SANTA                   FDS - MANHA      2.0
# 12      ['MORUMBI', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 13                      ITAIM      SEMANA - NOTURNO - SAIDA      NaN
# 14                    MORUMBI                  SEMANA - 6HS      NaN
# 15                      VILLA  SEMANA - MANHA - C.CIRURGICO      NaN
# 16                        VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 17          ['JABA', 'ITAIM']                    FDS ROTINA      2.0
# 18                      VILLA  SEMANA - TARDE - C.CIRURGICO      NaN
# 19                     OSASCO                  SEMANA - 6HS      1.0
# 20                      ITAIM                  SEMANA - 6HS      NaN
# 21         ['MORUMBI', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 22                       JABA  SEMANA - TARDE - C.CIRURGICO      NaN
# 23          ['OSASCO', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 24          ['OSASCO', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 25                MATERNIDADE                  SEMANA - 6HS      NaN
# 26                      SANTA  SEMANA - MANHA - C.CIRURGICO      2.0
# 27     ['AVICCENA', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 28                     OSASCO  SEMANA - TARDE - C.CIRURGICO      NaN
# 29                      SANTA                   FDS - SAIDA      3.0
# 30       ['SANTA', 'MORUMBI']  SEMANA - MANHA - C.CIRURGICO      NaN
# 31                     ANALIA                    FDS ROTINA      2.0
# 32                     OSASCO                  SEMANA - 6HS      1.0
# 33         ['JABA', 'OSASCO']  SEMANA - TARDE - C.CIRURGICO      NaN
# 34  ['OSASCO', 'MATERNIDADE']  SEMANA - TARDE - C.CIRURGICO      NaN
# 35                        VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 36                       JABA                  SEMANA - 6HS      1.0
# 37                    MORUMBI                    FDS ROTINA      2.0
# 38                     OSASCO                 FDS - PLANTAO      4.0
# 39                      ITAIM                  SEMANA - 6HS      1.0
# 40                     OSASCO                  SEMANA - 6HS      1.0
# 41         ['OSASCO', 'JABA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 42                     ANALIA                    FDS ROTINA      2.0
# 43       ['OSASCO', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 44                    MORUMBI                  SEMANA - 6HS      1.0
# 45                    MORUMBI                  SEMANA - 6HS      NaN
# 46            ['JABA', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN

# %%
len(df_backup)
# Out:
# 47

# %%
count = 0

# %%
fdzão = pd.DataFrame(columns = dia_sel.columns)
fdzão
# Out:
# Empty DataFrame
# Columns: [Dia, Unidade, Periodo, Semana, Dia Semana, Entrada, Saida, ordem, data, PERIODO, periodo]
# Index: []

# %%
from selenium.webdriver.common.action_chains import ActionChains

action_chains = ActionChains(browser)

# %%
#Para cada profissional na lista
df = df_backup[count:]

for i in df['nome'].unique():
    print("nome:", i)
    df_nome = df[df['nome'] == i]
    df_nome.reset_index(drop=True, inplace=True)
    
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    #browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/div/div[1]/div[3]/professionals/div/a/span[2]/b').click()
    sleep(2)
    
    browser.find_element("xpath", '/html/body/div[9]/div/input').send_keys(i)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()

    #esperando carregamento do site
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))

    sleep(2)
    tabela = funcao()  
    sleep(2)
    
    #Para cada registro na lista_nome
    for t in range(len(df_nome)):
        dia_sel = tabela[(tabela['data'] == df_nome['data'][t]) & (tabela['Unidade'] != df_nome['unidade'][t])]
        dia_sel.reset_index(drop=True, inplace=True)
        
        print(df_nome['chat'][t] + " - " + df_nome['data'][t] + ' - ' + df_nome['unidade'][t] + " - " + df_nome['ENTRADA'][t] + " - " + df_nome['SAIDA'][t])
        #display(dia_sel)
        if len(dia_sel) == 0:
            print(count, "-> PROB")
            df_backup['controle'][count] = "PROB"
        else:
            fd = pd.DataFrame(columns = dia_sel.columns) #df de captura para recriação
            for r in range(len(dia_sel)-1, -1, -1):
                if dia_sel['periodo'][r] <= df_nome['periodo'][t]: #capturando dados
                    print('PRINCIPAL')
                    #abrindo/selecionando periodo conforme localização
                    dia_ordem = r
                    xpath_textao = '//*[@id="shift-monthly"]/div[2]/table/tbody/tr['+str(dia_sel['Semana'][0])+']/td['+str(dia_sel['Dia Semana'][0])+']/ul['+str(dia_sel['ordem'][dia_ordem])+']/li'
                    elemento = browser.find_element("xpath", xpath_textao)
                    elemento.click()

                    #Esperar componentes carregarem
                    WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]')))

                    #Apagando
                    browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[2]/button[1]').click()
                    #Clicando em continuar
                    sleep(0.5)
                    browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[3]/button[2]').click()
                    
                    if dia_sel['periodo'][r] < df_nome['periodo'][t]:
                        fd.loc[len(fd)] = list(dia_sel.loc[r])
                    
                    #esperando carregamento do site para prosseguir
                    WebDriverWait(browser, 10).until_not(visibility_of(browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button')))

            fd = fd.sort_values(['periodo'])
            fd.reset_index(drop=True, inplace=True)
            fd['Unidade_antiga'] = fd['Unidade']
            fd['Unidade'] = df_nome['unidade'][0]
            fd['nome'] = df_nome['nome'][0]
            fdzão = pd.concat([fdzão, fd]) # juntando ao df total de captura
            fdzão = fdzão.reset_index(drop=True)
            
            tabela = funcao() #atualizando tabela de registros
            sleep(2)
            print(count, '-> OK')
            df_backup['controle'][count] = "OK"
            
        count += 1
        if count >= 10:
            break
            
        if count % 25 == 0:
            print('='*80)
            print(df_backup['controle'].value_counts())
            print('='*80)
            
    print('\n')
# Out:
# nome: IZABELA CRISTINA ALMEIDA DUARTE
# [11/07/2023 09:05:09] Izabela Cristina Almeida Duarte: 11/07 Villa Iza Duarte saída 8:45 - 11/07/2023 - VILLA - 07:00 - 09:00
# 15 -> OK
#
#
# nome: JESSICA LIDIA DE SOUZA
# [10/07/2023 16:11:49] Jessica Lidia de Souza: 10/07 VNS - Jessica saída 16:10 (deslocada HAV) - 10/07/2023 - VNS - 13:00 - 16:30
# 16 -> OK
#
#
# nome: KAIE FERNANDES
# [08/07/2023 09:18:03] Kaiê Fernandes: 08/07 Jabaquara Kaie saída 9:10 (deslocado Itaim) - 08/07/2023 - JABAQUARA - 07:00 - 09:30
# PRINCIPAL
# 17 -> OK
#
#
# nome: KAREN CAVICHINI ROSSETO
# 34  11/07 Osasco Mota saída 16:10   (  deslocado M...       OK  11/07/2023
# 35                 12/07 VNS Rafael tadeu saída 15:55     PROB  12/07/2023
# 36               03/07 Jabaquara Rômulo entrada 05:20       OK  03/07/2023
# 37                   08/07 MORUMBI Sheila saída 10:40     PROB  08/07/2023
# 38                  02/07 OSASCO  -  Bosi saída 22:20     PROB  02/07/2023
# 39                03/07 Itaim  -  Thaís entrada 06:00       OK  03/07/2023
# 40               03/07 Osasco  -  Thaís entrada 05:35       OK  03/07/2023
# 41  11/07 Osasco  -  Thales saída 14:20   (  deslo...     PROB  11/07/2023
# 42  08/07 Anália  -  Naldo  -  saída  -  11:05   (...     PROB  08/07/2023
# 43  10/07 Osasco Naldo saída 14:45 pós plantão des...       OK  10/07/2023
# 44               07/07 Morumbi Turíbio Entrada: 05:50     PROB  07/07/2023
# 45  13/07 Morumbi Vitor entrada 05:10   (  EXTRA  )       PROB  13/07/2023
# 46  12/07 Jabaquara Vivianna saída 13:50   (  desl...     PROB  12/07/2023
#
#          unidade  extra     tipo ENTRADA  SAIDA DURAÇÃO        PERIODO  \
# 0    MATERNIDADE    NaN    SAIDA   13:00  14:30   01:30          tarde
# 1   SANTA ISABEL  extra    SAIDA   07:00  12:00   05:00          manha
# 2         ANALIA    NaN    SAIDA   07:00  10:00   03:00          manha
# 3         OSASCO    NaN    SAIDA   07:00  10:30   03:30          manha
# 4      JABAQUARA    NaN    SAIDA   07:00  10:00   03:00          manha
# 5            VNS    NaN    SAIDA   13:00  16:00   03:00          tarde
# 6         OSASCO    NaN  ENTRADA   06:00  07:00   01:00             6h
# 7            VNS    NaN    SAIDA   13:00  15:30   02:30          tarde
# 8            VNS    NaN  ENTRADA   06:00  07:00   01:00             6h
# 9      JABAQUARA    NaN    SAIDA   13:00  18:00   05:00          tarde
# 10     JABAQUARA    NaN  ENTRADA   05:00  07:00   02:00             6h
# 11  SANTA ISABEL    NaN    SAIDA   07:00  11:30   04:30          manha
# 12       MORUMBI    NaN    SAIDA   13:00  16:30   03:30          tarde
# 13         ITAIM    NaN    SAIDA   19:00  20:30   01:30  noturno saida
# 14       MORUMBI    NaN  ENTRADA   05:00  07:00   02:00             6h
# 15         VILLA    NaN    SAIDA   07:00  09:00   02:00          manha
# 16           VNS    NaN    SAIDA   13:00  16:30   03:30          tarde
# 17     JABAQUARA    NaN    SAIDA   07:00  09:30   02:30          manha
# 18         VILLA    NaN    SAIDA   13:00  18:30   05:30          tarde
# 19        OSASCO    NaN  ENTRADA   05:30  07:00   01:30             6h
# 20         ITAIM    NaN  ENTRADA   05:00  07:00   02:00             6h
# 21       MORUMBI    NaN    SAIDA   13:00  14:00   01:00          tarde
# 22     JABAQUARA    NaN    SAIDA   13:00  17:00   04:00          tarde
# 23        OSASCO    NaN    SAIDA   13:00  16:30   03:30          tarde
# 24        OSASCO    NaN    SAIDA   13:00  14:00   01:00          tarde
# 25   MATERNIDADE    NaN  ENTRADA   05:30  07:00   01:30             6h
# 26  SANTA ISABEL    NaN  ENTRADA   07:00  13:00   06:00          manha
# 27      AVICCENA    NaN    SAIDA   13:00  14:30   01:30          tarde
# 28        OSASCO    NaN    SAIDA   13:00  15:30   02:30          tarde
# 29  SANTA ISABEL    NaN    SAIDA   13:00  16:00   03:00          tarde
# 30  SANTA ISABEL    NaN    SAIDA   07:00  11:00   04:00          manha
# 31        ANALIA    NaN    SAIDA   07:00  11:30   04:30          manha
# 32        OSASCO    NaN  ENTRADA   06:00  07:00   01:00             6h
# 33     JABAQUARA    NaN    SAIDA   13:00  16:30   03:30          tarde
# 34        OSASCO    NaN    SAIDA   13:00  16:30   03:30          tarde
# 35           VNS    NaN    SAIDA   13:00  16:00   03:00          tarde
# 36     JABAQUARA    NaN  ENTRADA   05:00  07:00   02:00             6h
# 37       MORUMBI    NaN    SAIDA   07:00  11:00   04:00          manha
# 38        OSASCO    NaN    SAIDA   19:00  22:30   03:30  noturno saida
# 39         ITAIM    NaN  ENTRADA   06:00  07:00   01:00             6h
# 40        OSASCO    NaN  ENTRADA   05:30  07:00   01:30             6h
# 41        OSASCO    NaN    SAIDA   13:00  14:30   01:30          tarde
# 42        ANALIA    NaN    SAIDA   07:00  11:30   04:30          manha
# 43        OSASCO    NaN    SAIDA   13:00  15:00   02:00          tarde
# 44       MORUMBI    NaN  ENTRADA   05:30  07:00   01:30             6h
# 45       MORUMBI  extra  ENTRADA   05:00  07:00   02:00             6h
# 46     JABAQUARA    NaN    SAIDA   13:00  14:00   01:00          tarde
#
#     periodo2                         setor sem_ou_fds  \
# 0        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 1        2.0                   FDS - MANHA        fds
# 2        2.0                    FDS ROTINA        fds
# 3        2.0                    FDS ROTINA        fds
# 4        NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 5        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 6        1.0                  SEMANA - 6HS     semana
# 7        NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 8        NaN                  SEMANA - 6HS     semana
# 9        3.0                   FDS - SAIDA        fds
# 10       1.0                  SEMANA - 6HS     semana
# 11       2.0                   FDS - MANHA        fds
# 12       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 13       NaN      SEMANA - NOTURNO - SAIDA     semana
# 14       NaN                  SEMANA - 6HS     semana
# 15       NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 16       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 17       2.0                    FDS ROTINA        fds
# 18       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 19       1.0                  SEMANA - 6HS     semana
# 20       NaN                  SEMANA - 6HS     semana
# 21       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 22       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 23       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 24       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 25       NaN                  SEMANA - 6HS     semana
# 26       2.0  SEMANA - MANHA - C.CIRURGICO     semana
# 27       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 28       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 29       3.0                   FDS - SAIDA        fds
# 30       NaN  SEMANA - MANHA - C.CIRURGICO     semana
# 31       2.0                    FDS ROTINA        fds
# 32       1.0                  SEMANA - 6HS     semana
# 33       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 34       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 35       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 36       1.0                  SEMANA - 6HS     semana
# 37       2.0                    FDS ROTINA        fds
# 38       4.0                 FDS - PLANTAO        fds
# 39       1.0                  SEMANA - 6HS     semana
# 40       1.0                  SEMANA - 6HS     semana
# 41       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 42       2.0                    FDS ROTINA        fds
# 43       NaN  SEMANA - TARDE - C.CIRURGICO     semana
# 44       1.0                  SEMANA - 6HS     semana
# 45       NaN                  SEMANA - 6HS     semana
# 46       NaN  SEMANA - TARDE - C.CIRURGICO     semana
#
#                      unidade2                  setor_inicio  periodo
# 0                 MATERNIDADE  SEMANA - TARDE - C.CIRURGICO      NaN
# 1                       SANTA                   FDS - MANHA      2.0
# 2       ['ANALIA', 'MORUMBI']                    FDS ROTINA      2.0
# 3          ['OSASCO', 'JABA']                    FDS ROTINA      2.0
# 4           ['JABA', 'ITAIM']  SEMANA - MANHA - C.CIRURGICO      NaN
# 5          ['VNS', 'MORUMBI']  SEMANA - TARDE - C.CIRURGICO      NaN
# 6                      OSASCO                  SEMANA - 6HS      1.0
# 7                         VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 8                         VNS                  SEMANA - 6HS      NaN
# 9                        JABA                   FDS - SAIDA      3.0
# 10                       JABA                  SEMANA - 6HS      1.0
# 11                      SANTA                   FDS - MANHA      2.0
# 12      ['MORUMBI', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 13                      ITAIM      SEMANA - NOTURNO - SAIDA      NaN
# 14                    MORUMBI                  SEMANA - 6HS      NaN
# 15                      VILLA  SEMANA - MANHA - C.CIRURGICO      NaN
# 16                        VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 17          ['JABA', 'ITAIM']                    FDS ROTINA      2.0
# 18                      VILLA  SEMANA - TARDE - C.CIRURGICO      NaN
# 19                     OSASCO                  SEMANA - 6HS      1.0
# 20                      ITAIM                  SEMANA - 6HS      NaN
# 21         ['MORUMBI', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 22                       JABA  SEMANA - TARDE - C.CIRURGICO      NaN
# 23          ['OSASCO', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 24          ['OSASCO', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN
# 25                MATERNIDADE                  SEMANA - 6HS      NaN
# 26                      SANTA  SEMANA - MANHA - C.CIRURGICO      2.0
# 27     ['AVICCENA', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 28                     OSASCO  SEMANA - TARDE - C.CIRURGICO      NaN
# 29                      SANTA                   FDS - SAIDA      3.0
# 30       ['SANTA', 'MORUMBI']  SEMANA - MANHA - C.CIRURGICO      NaN
# 31                     ANALIA                    FDS ROTINA      2.0
# 32                     OSASCO                  SEMANA - 6HS      1.0
# 33         ['JABA', 'OSASCO']  SEMANA - TARDE - C.CIRURGICO      NaN
# 34  ['OSASCO', 'MATERNIDADE']  SEMANA - TARDE - C.CIRURGICO      NaN
# 35                        VNS  SEMANA - TARDE - C.CIRURGICO      NaN
# 36                       JABA                  SEMANA - 6HS      1.0
# 37                    MORUMBI                    FDS ROTINA      2.0
# 38                     OSASCO                 FDS - PLANTAO      4.0
# 39                      ITAIM                  SEMANA - 6HS      1.0
# 40                     OSASCO                  SEMANA - 6HS      1.0
# 41         ['OSASCO', 'JABA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 42                     ANALIA                    FDS ROTINA      2.0
# 43       ['OSASCO', 'ANALIA']  SEMANA - TARDE - C.CIRURGICO      NaN
# 44                    MORUMBI                  SEMANA - 6HS      1.0
# 45                    MORUMBI                  SEMANA - 6HS      NaN
# 46            ['JABA', 'VNS']  SEMANA - TARDE - C.CIRURGICO      NaN

# %%
fdzão
#fdzão = fdzão.drop([1]).reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [Dia, Unidade, Periodo, Semana, Dia Semana, Entrada, Saida, ordem, data, PERIODO, periodo, Unidade_antiga, nome]
# Index: []

# %%
df_backup['controle'].value_counts()
# Out:
# OK      24
# PROB    23
# Name: controle, dtype: int64

# %%
for i in df_backup[df_backup['controle'] == 'OK'].index:
    print(df_backup['mensagem'][i], '-', df_backup['nome'][i])
# Out:
# 12/07 Maternidade  -  Alex saída 14:20 - ALEXSANDER TAKASHI HAMADA
# 10/07 Jabaquara Everton saída 09:40   (  Pós - plantão/deslocado Itaim  )   - EVERTON SIDNEY DA CONCEICAO CARVALHO
# 11/07 VNS  -  Fabiana saída 15:50   (  deslocada Morumbi  )   - FABIANA BARBOSA BASTOS
# 10/07 VNS  -  Coelho saída 15:30   (  pós plantão  )   - FELIPE COELHO DE SOUZA
# 11/07 VNS  -  Koga entrada 06:15 - FERNANDO AKIRA KOGA
# 01/07 SANTA ISABEL -  Lucena -  saída 11:15 - FRANCISCO JOSE LUCENA BEZERRA
# 10/07 morumbi costa saida 16:20 pos plantao deslocado analia - GUILHERME DE ALMEIDA COSTA
# 11/07 Villa Iza Duarte saída 8:45 - IZABELA CRISTINA ALMEIDA DUARTE
# 10/07 VNS  -  Jessica saída 16:10   (  deslocada HAV  )   - JESSICA LIDIA DE SOUZA
# 08/07 Jabaquara Kaie saída 9:10   (  deslocado Itaim  )   - KAIE FERNANDES
# 10/07 Villa  -  Cavichini saída 18:15 - KAREN CAVICHINI ROSSETO
# 10/07 Morumbi  -  Maíra saída 13:50   (  pós plantão deslocada VNS  )   - MAIRA LEITE BASILE
# 10/07 Jabaquara Marcela Leite saída 16:40 - MARCELA LEITE ROSIGNOLI
# 11/07 OSASCO  -  M. Carolina saída 16:20   (  deslocada VNS  )   - MARIA CAROLINA CELIA SILVEIRA
# 03/07 SANTA ISABEL Arraes entrada 07:00 - MATHEUS DE ALENCAR ARRAES
# 10/07 Aviccena Maurício saída 14:20   (  pós plantão deslocado Anália  )   - MAURICIO FARIA TETTI
# 08/07  -  Santa Isabel  -  Mirela saída 15:40 - MIRELA FARIAS FIGUEIROA
# 10/07 Osasco  -  Tavares  -  entrada 6:00 - PEDRO AUGUSTO TAVARES DALL AGLIO
# 11/07 Jabaquara  -  Diniz saída 16:20   (  deslocado Osasco  )   - PEDRO HENRIQUE DINIZ BOTELHO
# 11/07 Osasco Mota saída 16:10   (  deslocado Maternidade  )   - PEDRO HENRIQUE MILHOMENS DA MOTA
# 03/07 Jabaquara Rômulo entrada 05:20 - ROMULO SPOLIDORIO
# 03/07 Itaim  -  Thaís entrada 06:00 - THAIS CHAVES PINHEIRO
# 03/07 Osasco  -  Thaís entrada 05:35 - THAIS CHAVES PINHEIRO
# 10/07 Osasco Naldo saída 14:45 pós plantão deslocado Anália - THIAGO BARRETO MARQUES DA SILVA

# %%
len(fdzão)
# Out:
# 0

# %%
fd
# Out:
# Empty DataFrame
# Columns: [Dia, Unidade, Periodo, Semana, Dia Semana, Entrada, Saida, ordem, data, PERIODO, periodo, Unidade_antiga, nome]
# Index: []

# %% [markdown]
# # ARRUMANDO A PORRA TODA:

# %%
df = df_backup

# %%
print(len(fdzão))
fdzão.head(1)

# %%
#DURAÇÃO DO PLANTÃO
fdzão['DURAÇÃO'] = ''

for i in range(0, len(fdzão)):
    diferenca_tempo = datetime.strptime(fdzão['SAIDA'][i], '%H:%M') - datetime.strptime(fdzão['ENTRADA'][i], '%H:%M')
    
    #diferenca_tempo vem em formato estranho, tem-se que transformar em segundos antes
    diferenca_tempo_s = diferenca_tempo.seconds
    horas = '0' + str(int((diferenca_tempo_s/60)/60)) #capturando horas
    minutos = str(int((diferenca_tempo_s/60)%60))  #capturando minutos
    
    if len(minutos) == 1:
        minutos = '0' + minutos
    
    fdzão['DURAÇÃO'][i] = horas + ':' + minutos
    
fdzão['DURAÇÃO'].unique()

# %%
print(df['extra'].value_counts())
df['extra'].fillna('DESLOCADO', inplace = True)
print(df['extra'].value_counts())

# %%
fdzão = fdzão.rename({'Unidade':'unidade', 'Periodo':'setor',
                     'Entrada':'ENTRADA', 'Saida':'SAIDA'}, axis=1)

fd = fdzão[['nome','data','unidade','ENTRADA','SAIDA','DURAÇÃO','setor']]

df = pd.concat([df, fd])
df = df.reset_index(drop=True)
df

# %% [markdown]
# # MATANDO O RESTO:

# %%
H=0
print(len(df))

# %%
for h in range(H, len(df)):
    print(h)
    #click criar novo plantão
    browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr[1]/td[4]/button').click()
    
    #esta disponivel o botão de setor
    WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]')))
    #Setor====
    print('base:', df['unidade'][h], '-', df['setor'][h])
    browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()
    ind = scrap_unidades.loc[(scrap_unidades.unidade == df['unidade'][h]) & 
                             (scrap_unidades.momento == df['setor'][h])].index.values[0]
    unidade = scrap_unidades['unidade_count'][ind]
    setorzin = scrap_unidades['plt_count'][ind]
    print('scraping:', scrap_unidades['unidade'][ind], '-', scrap_unidades['momento'][ind])
    #SELECIONANDO Setor ##//*[@id="select2-drop"]/ul/li[unidade]/ul/li[momento]/div
    print('caixa:', browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/div').text, '-',
          browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/ul/li['+str(setorzin)+']/div').text)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/ul/li['+str(setorzin)+']/div').click()
    print('selecionado:', browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').text, '\n')
    
    #PROFISSIONAL
    #esta disponivel o botão de profissional
    WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]')))
    
    #listar todos
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
    
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click() #########
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click() #########
    sleep(0.5)
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionalA"]/a/span[1]').click()
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(df['nome'][h])
    #Dando enter
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(Keys.RETURN)
    #info
    print('base:', df['nome'][h])
    print('selecionado:', browser.find_element("xpath", '//*[@id="s2id_ddlProfessionalA"]/a/span[1]').text)
    print(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').text)
    
    sleep(2)
    #Data
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[2]/div[3]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').clear()
    sleep(1)
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[2]/div[3]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').send_keys(df['data'][h])
    sleep(0.5)
    print(df['data'][h])
    
    #Inicio do plantão
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').send_keys(df['ENTRADA'][h])
    sleep(1)
    print('hora de entrada:', df['ENTRADA'][h], '\nhora de saida:', df['SAIDA'][h])
    #Duração do plantão
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').send_keys(df['DURAÇÃO'][h])
    print('duração do plantão', df['DURAÇÃO'][h])
        
    ##TIPO
    '''
    //*[@id="select2-drop"]/ul/li[3]/div
    1 - Normal
    2 - DESLOCAMENTO
    3 - VOLUNTÁRIO
    4 - COBERTURA
    '''
    if df['extra'][h] == 'extra':
        print('EXTRA')
        sleep(1)
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(1)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[3]/div').click()
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(200) #Pontos
            print('duração >5 -> 200 pontos')
        else:
            pass
    elif df['extra'][h] == 'DESLOCADO':
        print('DESLOCADO')
        sleep(1)
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(1)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            print('duração >5 -> 100 pontos')
        else:
            pass
        sleep(2)
    else:
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            print('duração >5 -> 100 pontos')
        else:
            pass
        sleep(2)
        
    #salvar plantão
    sleep(1)
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    sleep(4)

    #VERIFICANDO SE HOUVE ERRO - HÁ PLANTÃO NO MESMO HORARIO
    if browser.find_element("xpath", '/html/body/div[5]/div/div[2]/div[2]/div/label').text != '':
        #browser.find_element("xpath", '//*[@id="ckb-add-service-ignore-conflict"]').click()#estou ciente
        sleep(1)
        #browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click() #salvar plantão
        #browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
        #browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
        #
        browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button').click() #FECHAR
        df.loc[int(h), 'controle'] = "PROBS"
        print("PROB")
    else:
        df.loc[int(h), 'controle'] = "NORM"
    
    #browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button').click() #fechar {X}

    #não esta disponivel o X
    
    WebDriverWait(browser, 10).until_not(visibility_of(browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button')))
    H += 1
    print('='*40, '\n')
    
    if H % 5 == 0:
        print('='*80)
        print(df['controle'].value_counts())
        print('='*80)
        #df.to_excel("df_gabs.xlsx", index=False)
        
print("="*50, 'TERMINOU', "="*50)
print('Total  ', len(df))
print(df['controle'].value_counts())

# %%
df['controle'][df['controle'] != 'NORM'] = 'NORM'

# %%
df_erros = pd.concat([df_backup_fds, df[df['controle'] != 'NORM']])
df_erros.reset_index(drop=True, inplace=True)
print("probs:", len(df_erros))

# Registros Perfeitos ja feitos
df = df[df['controle'] == 'NORM']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))

#salvando
Feitos = pd.read_excel('Feitos.xlsx')
df_corrigidos = pd.concat([Feitos, df]).reset_index(drop=True)
df_corrigidos.to_excel('Feitos.xlsx', index=False)
os.remove("df_giov2.xlsx")

df_erros.to_excel("df_giov3.xlsx", index=False)
