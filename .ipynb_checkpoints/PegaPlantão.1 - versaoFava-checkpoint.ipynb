# 124  [30/06/2023 07:10:09] Felipe de Oliveira Nunes...
# 125  [30/06/2023 07:16:34] Alexsander Takashi Hamad...
# 126  [30/06/2023 07:22:06] Mônica Robles Gonçalves:...
# 127  [30/06/2023 07:22:08] Thales Luvisotto Neder: ...
# 128  [30/06/2023 07:23:10] Arthur Rodrigues Torréli...
# 129  [30/06/2023 07:26:10] Flavio Hideki Oshika: 30...
# 130  [30/06/2023 07:42:31] Maxvilano Lima de Macedo...
# 131  [30/06/2023 08:16:41] Karen Yumi Miyashiro: 30...
# 132  [30/06/2023 08:40:01] Fabiana Barbosa Bastos: ...
# 133  [30/06/2023 10:34:38] Natan Soares Silveira: 3...
# 134  [30/06/2023 10:39:21] Gabriela Santos Menezes:...
# 135  [30/06/2023 11:54:09] Bruce Ye Man Chow: 30/06...
# 136  [30/06/2023 12:12:51] Thiago Barreto Marques d...
# 137  [30/06/2023 12:13:15] Thiago Barreto Marques d...
# 138  [30/06/2023 12:48:23] Bianca Priscila Buniotti...
# 139  [30/06/2023 12:49:20] Lais Ribeiro Teixeira: 3...

# %% [markdown]
# # CAPTURANDO INFORMAÇÕES:

# %%
#DIA QUE FOI ENVIADA A MENSAGEM
dia = []
for i in range(0, len(df['chat'])):
    dia.append(df['chat'][i][1:11]) #pegando exatamente aonde parte da data esta
df['dia'] = dia
df['dia'].unique()
# Out:
# array(['29/06/2023', '30/06/2023'], dtype=object)

# %%
#NOME DO ANESTESISTA
nome = []
count = 0
for i in range(0, len(df['chat'])):
    loc = df['chat'][i].find(']')+1 #digito data
    loc2 = df['chat'][i][loc+1:].find(':')+1 #digito nome
    nome.append(unidecode.unidecode(df['chat'][i][loc+1:loc+loc2].upper()))
    count += 1
    #print(count, "->", unidecode.unidecode(chat[i][loc+1:loc+loc2].upper()))
df['nome'] = nome
df['nome'].unique()
# Out:
# array(['MAURICIO FARIA TETTI', 'JESSICA LIDIA DE SOUZA',
#        'KAREN YUMI MIYASHIRO', 'FABIANA SOARES GAMA',
#        'BRUNO STORNIOLI TAGUCHI LEMOS', 'ELAINE IMAEDA DE MOURA',
#        'EDUARDO DALA ROSA SOARES', 'ANNA BEATRIZ LIMA DO VALLE ASTUR',
#        'GABRIELLA GADELHA SARMENTO',
#        'MARCOS ROGERIO PEREIRA MACHADO FILHO', 'LEONARDO DE PAULA SOUZA',
#        'ORLANDO DOMINGUES DE ARAUJO PONTES', 'MARIANA DARDENGO BORGES',
#        'CLAUDIO MUELLER KAKUDA', 'CAMILA CHIARANTANO HARRISON',
#        'RICARDO IVO DE LIMA', 'ALEXANDRE AMARAL LUCAS',
#        'LAYSA LAYNA RIBEIRO LIMA', 'MILTON OLAIO NETO',
#        'DIOGO HENRIQUE PEREIRA MATTOS', 'FLAVIO HIDEKI OSHIKA',
#        'BRUNA DAIBERT DANESIN', 'RODRIGO MIYASHIRO NUNES DOS SANTOS',
#        'FRANCISCO JOSE LUCENA BEZERRA', 'MARCELO FELIPE DE SOUZA BUTO',
#        'ESTANRLEY BARCELOS PINTO', 'FABIANA BARBOSA BASTOS',
#        'ERICK OLIVEIRA LIMA GOMES', 'CAIO TULIO DUARTE',
#        'ALEXSANDER TAKASHI HAMADA', 'MONICA ROBLES GONCALVES',
#        'THALES LUVISOTTO NEDER', 'ARTHUR RODRIGUES TORRELIO',
#        'NATAN SOARES SILVEIRA', 'BRUCE YE MAN CHOW',
#        'THIAGO BARRETO MARQUES DA SILVA', 'LAIS RIBEIRO TEIXEIRA'],
#       dtype=object)

# %%
#MENSAGEM ESCRITA
mensagem = []
for i in range(0, len(df)):
    digito_data = df['chat'][i].find(']') #aonde acaba a data
    digito_nome = df['chat'][i][digito_data+1:].find(':')
    mensagem_escrevida = df['chat'][i][digito_data+digito_nome+3:]
    mensagem.append(mensagem_escrevida)
    
df['mensagem'] = mensagem
df['mensagem'].unique()
# Out:
# array(['29/06 Villa Maurício entrada 5:45',
#        '29/06 VILLA - Jessica  entrada 11:00',
#        '29/06 VILLA - Yumi entrada 06:00',
#        '29/06 Villa Fabiana Gama entrada as 06:00',
#        '29/06 Morumbi Bruno Lemos entrada 06:00',
#        '29/06 Anália Elaine saída 13:20',
#        '29/06 Morumbi - Soares entrada 04:00 ( EXTRA )',
#        '29/06 Morumbi - Soares saída 13:40 ( EXTRA )',
#        '29/06 Osasco - Astur entrada 07:00 (EXTRA)',
#        '29/06 Osasco - Astur saida 13:50 (EXTRA)',
#        '29/06 VNS - Gabriella saída 14:00',
#        '29/06 Santa Marcos saída 14:10',
#        '29/06 Santa Leonardo entrada 05:45',
#        '29/06 Santa Leonardo saída 13:40',
#        '29/06 AVICCENA Orlando saida 14:35',
#        '28/06 ITAIM - M. Dardengo saída 22:00',
#        '29/06 MORUMBI - M. Dardengo entrada 06:20',
#        '29/06 Maternidade - Kakuda saida 14:45',
#        '29/06 Villa Camila Saida 14:50',
#        '29/06 - Morumbi - Ricardo Ivo Saída - 14:50h',
#        '29/06 - Osasco - alexandre Amaral - entrada 06:05',
#        '29/06 Jabaquara Laysa saída 15h (pos plantão)',
#        '29/6-Itaim Olaio entrada 6:00', '29/6-Itaim Olaio saída 14:55',
#        '29/06 ANÁLIA - Diogo saída 15:20',
#        '29/06 ANÁLIA - Flávio saída 15:40',
#        '29/06 Anália Bruna saída 15:00',
#        '29/06 MORUMBI - Miyashiro saida 16:25',
#        '29/06 ANÁLIA- Lucena- saída 16:30',
#        '29/06 Osasco - Buto saída 16:20 (deslocado Itaim)',
#        '29/06 ANÁLIA-Estanrley Saida: 16:30',
#        '29/06  VNS - Fabiana saída 16:40',
#        '29/06 ANÁLIA - Akemi saída 16:55',
#        '29/06 Anália - Diniz saída 16:50',
#        '29/06 Santa Isabel Manoel saída 17:00',
#        '29/06 ANÁLIA Paula Neves saída 15:30',
#        '29/06 Anália - Matheus saída 17:10',
#        '29/06 Itaim - Bianca saída 15:30 (pós plantão; deslocada maternidade)',
#        '29/06 Jabaquara - Silveira saída 17:10',
#        '29/06 MORUMBI - Laura entrada 05:40',
#        '29/06 ANÁLIA - Giraldelli saída 16:55',
#        '29/06 - Aviccena - Alexandre - entrada 06:00',
#        '29/06 MORUMBI - Renata Togeiro saída 14:50',
#        '29/06 Jabaquara Assunção saída 19:15',
#        '29/06 Jabaquara Débora saída 19:25',
#        '29/06 OSASCO - pereira saída 19:27',
#        '29/06 Itaim Kaie saída 19:40',
#        '29/06 Itaim Larissa - saída 19:45',
#        '29/06 OSASCO - Gomes saída 19:50',
#        '29/06-Itaim-Sidney-entrada as 05:45',
#        '29/6 Jabaquara - Maxvilano. Saída 19:40',
#        '29/06-Itaim-Sidney- saida: 19:30',
#        '29/06 Itaim Karen saída 19:40', '29/06 Osasco KRosa saida 19:35',
#        '29/06 Itaim - Nunes saída 19:15',
#        '29/06 MORUMBI - M. Dardengo saída 19:55',
#        '29/06 Villa - Renato saída 19:50',
#        '29/06 Itaim - Norival Saída 19:45',
#        '29/06 Morumbi - Pedro entrada 06:00h',
#        '29/06 Morumbi - Pedro saída 20:20h',
#        '29/06 Itaim Luciano saída 20:15',
#        '29/06 Analia Moura saída 20:35',
#        '29/06 Osasco kawaura saída 20:35',
#        '29/06 Aviccena Facchini saída 19:40',
#        '29/06 VILLA - Ighor saída 20:50', '29/06 Itaim Yoko saída 20:50',
#        '29/06 - itaim - Silvia saida 21:00', '29/06 VILLA - Livia 20:50',
#        '29/06 - Itaim José Marcos entrada 6:00',
#        '29/06 - Itaim José Marcos saída 20:15',
#        '29/06 VNS Xavier Saída 21:00',
#        '29/06 Morumbi Hedicleber saída 21:05',
#        '29/06 Itaim Rafael Tadeu saída 21:10',
#        '29/06 Osasco Juliano Tobal saída 20:35',
#        '29/06 VILLA - Yumi entrada 20:40',
#        '29/06 ITAIM Sheila saída 21:40',
#        '29/06 Itaim Andréia saída 21:45',
#        '29/06 Itaim Daniel entrada 5:20',
#        '29/06 Itaim Daniel saída 22:00',
#        '29/06 Jabaquara -Zamith saída 22:05',
#        '29/06 Jabaquara - Borja saída 21:55',
#        '29/06 Jabaquara - G.Menezes saída 21:55',
#        '29/06 Villa Leandro kanada saida 22:10',
#        '29/06 Jabaquara - Garcia saída 22:30',
#        '29/06 Jabaquara - Sapountzakis saída 22:50',
#        '29/06 VNS - Oliveira saída 23:15',
#        '29/06 Villa  - Maia saída 23:30',
#        '29/06 Morumbi Bruno Lemos saida 23:45',
#        '30/06 Villa  - Jessica saída 00:10',
#        '29/06 JABAQUARA - Côrtes saída 01:50 (distância para efeito de escala)',
#        '30/06 VNS - Koga entrada 04:20', '30/06 JBQ Duarte entrada 4:30',
#        '30/06 Morumbi - Wong entrada 04:40',
#        '30/06 Morumbi Everton entrada 04:30',
#        '30/06 Itaim Rafael Tadeu entrada 4:50',
#        '30/06 MORUMBI - Amanda entrada 04:40',
#        '30/06 Itaim Karen entrada 5:00',
#        '30/06 Morumbi - Vale entrada 4:35',
#        '30/06 Morumbi Moura entrada 04:50',
#        '30/06 Jabaquara Vitor entrada 05:15',
#        '30/06 ANÁLIA-Estanrley entrada: 05:10',
#        '30/06 ANÁLIA - Francisco entrada 05:10 (deslocamento VILLA)',
#        '30/06 Villa Juliano Tobal entrada 05:20',
#        '30/06 Jabaquara - Dênio entrada 05:20',
#        '30/06 Santa - T.Silva - entrada 05:20 (EXTRA)',
#        '30/06 Osasco entrada Kaie 5:45 (EXTRA)',
#        '30/06 Villa - Helena - entrada 05:35',
#        '30/6 Jabaquara Débora entrada 06:00',
#        '30/06 Morumbi Queiroz entrada 05:30',
#        '30/06 ANÁLIA Vivian entrada 05:45',
#        '30/06 Osasco kawaura entrada 6:00',
#        '30/06 Santa Isabel Manoel entrada 06:00',
#        '30/06 Osasco Borja entrada 6:00',
#        '30/06 Morumbi - Patrick entrada 05:40',
#        '30/06 Anália- Rômulo entrada 06:00',
#        '30/06 VNS Ribeiro entrada 06:10',
#        '30/06 Jabaquara Bruno Lemos entrada 06:00',
#        '30/06 ITAIM Ventura entrada 6:00',
#        '30/06 OSASCO - Erick entrada 05:40',
#        '30/06 Itaim Yoko (dispensa por motivo de saúde)',
#        '30/06 MORUMBI - Caio entrada 05:45',
#        '29/06 Osasco - alexandre Amaral - saída 19:20',
#        '30/06 OSASCO - Gomes entrada 06:00',
#        '30/06 Jabaquara Facchini entrada 06:00',
#        '30/06 Villa - Nunes entrada 6:00',
#        '30/06  Villa - Alex entrada 7:10',
#        '30/06 Itaim Monica entrada 05:00',
#        '30/06 Osasco - Thales entrada 07:00 (EXTRA)',
#        '30/06 MORUMBI - Torrelio entrada 04:30',
#        '30/06 MORUMBI - Flávio entrada 04:00',
#        '30/06 - Itaim - Maxvilano - Entrada 06:00',
#        '30/06 Anália - Yumi entrada 06:00',
#        '30/06 VNS - Fabiana entrada 6:30',
#        '30/06 Aviccena- Natan- entrada 11:00 (a pedido da coordenação)',
#        '30/06 Osasco - G.Menezes entrada 06:20 (deslocada Jabaquara)',
#        '30/06 morumbi - bruce saida 11:40 (EXTRA)',
#        '29/06 Osasco - Naldo saída - 16:20 (pós - plantão )',
#        '30/06 Aviccena - Naldo - entrada 05:35',
#        '30/06 Morumbi - Bianca saída 12:35 (EXTRA)',
#        '30/06 Jabaquara Lais entrada 06h00'], dtype=object)

# %%
#DATA DO PLANTÃO
df['controle'] = ''
df['data'] = ''
invalido =0 
for i in range(0, len(df)):
    lista_datas = re.findall(r'[0-9]{1,2}\/[0-9]{1,2}', df['mensagem'][i]) #regex dd/mm
    quantidade_itens = len(lista_datas)
    
    if quantidade_itens == 1: #capturar registros com uma data apenas
        df['data'][i] = lista_datas[0]
    else: #restante com nenhuma ou mais de uma data
        df['controle'][i] = 'PROB'
        invalido += 1

print('mais de uma data: '+str(invalido))

df['data'].unique()
# Out:
# mais de uma data: 0
# array(['29/06', '28/06', '29/6', '30/06', '30/6'], dtype=object)

# %% [markdown]
# # Obs registros:

# %%
df[df['controle'] == 'PROB']
# Out:
# Empty DataFrame
# Columns: [chat, dia, nome, mensagem, controle, data]
# Index: []

# %%
#CAPTURANDO UNIDADE
df['unidade'] = ''
df['Q_unidades'] = ''
unidades = []

for i in range(0, len(df)):
    mensagem = unidecode.unidecode(df['mensagem'][i].upper())
    lista_unidades = re.findall(r'HSI|ANALIA|AVICCENA|ITAIM|JABA|MATERNIDADE|MORUMBI|OSASCO|VILLA|VNS|SANTA', mensagem)
    quantidade_unidades = len(lista_unidades)
    unidades.append(lista_unidades)
    
    df['Q_unidades'][i] = quantidade_unidades
    
    if quantidade_unidades >= 1: #capturando com unidades
        df['unidade'][i] = lista_unidades[0]
    elif quantidade_unidades == 0:
        df['controle'][i] = 'PROB'
        
print(df['Q_unidades'].value_counts(),'\n')
print("prob: "+str(len(df[df['controle'] == 'PROB'])))
# Out:
# 1    135
# 2      4
# 0      1
# Name: Q_unidades, dtype: int64
#
# prob: 1

# %%
prob = df[df['controle'] == 'PROB']
prob
# Out:
#                                                  chat         dia  \
# 91  [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
#
#                                nome                       mensagem controle  \
# 91  IZABELA CRISTINA ALMEIDA DUARTE  30/06 JBQ Duarte entrada 4:30     PROB
#
#      data unidade Q_unidades
# 91  30/06                  0

# %%
#RETIRANDO REGISTROS DE DESLOCADOS, DISTANCIA E SAIDAS POR QUESTÃO DE SAUDE

#preparando para reconhecer corretamente
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('(',' ( '))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace(')',' ) '))
df['mensagem'] = df['mensagem'].apply(lambda x: x.upper())
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCADA','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCAMENTO','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSADA','DISPENSADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSA ','DISPENSADO'))
df['sit'] = ''


for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    observacoes = re.findall(r'DESLOCADO|DISPENSADO|SAUDE|DISTANCIA', mensagem)
    quantidade_observacoes = len(observacoes)
    
    if quantidade_observacoes > 0:
        df['controle'][i] = 'PROB'
        
for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    deslocado = re.findall(r'DESLOCADO', mensagem)
    dispensado = re.findall(r'DISPENSADO', mensagem)
    distancia = re.findall(r'DISTANCIA', mensagem)
    
    if len(deslocado) > 0:
        df['sit'][i] = "DESLOCADO"
    elif len(dispensado) > 0:
        df['sit'][i] = "DISPENSADO"
    elif len(distancia)  > 0:
        df['sit'][i] = "DISTANCIA"
    else:
        df['sit'][i] = ''
        
print(df['controle'].value_counts()) 
prob = df[df['controle'] == 'PROB']
# Out:
#         134
# PROB      6
# Name: controle, dtype: int64

# %%
prob
# Out:
#                                                   chat         dia  \
# 29   [29/06/2023 16:27:17] Marcelo Felipe de Souza ...  29/06/2023
# 37   [29/06/2023 17:16:59] Bianca Priscila Buniotti...  29/06/2023
# 91   [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
# 101  [30/06/2023 05:17:59] Francisco Antonio Alves ...  30/06/2023
# 119  [30/06/2023 06:27:50] Yoko Hayashi: 30/06 Itai...  30/06/2023
# 134  [30/06/2023 10:39:21] Gabriela Santos Menezes:...  30/06/2023
#
#                                 nome  \
# 29      MARCELO FELIPE DE SOUZA BUTO
# 37          BIANCA PRISCILA BUNIOTTI
# 91   IZABELA CRISTINA ALMEIDA DUARTE
# 101  FRANCISCO ANTONIO ALVES BONATTO
# 119                     YOKO HAYASHI
# 134          GABRIELA SANTOS MENEZES
#
#                                               mensagem controle   data  \
# 29   29/06 OSASCO - BUTO SAÍDA 16:20  ( DESLOCADO I...     PROB  29/06
# 37   29/06 ITAIM - BIANCA SAÍDA 15:30  ( PÓS PLANTÃ...     PROB  29/06
# 91                       30/06 JBQ DUARTE ENTRADA 4:30     PROB  30/06
# 101  30/06 ANÁLIA - FRANCISCO ENTRADA 05:10  ( DESL...     PROB  30/06
# 119  30/06 ITAIM YOKO  ( DISPENSADOPOR MOTIVO DE SA...     PROB  30/06
# 134  30/06 OSASCO - G.MENEZES ENTRADA 06:20  ( DESL...     PROB  30/06
#
#     unidade Q_unidades         sit
# 29   OSASCO          2   DESLOCADO
# 37    ITAIM          2   DESLOCADO
# 91                   0
# 101  ANALIA          2   DESLOCADO
# 119   ITAIM          1  DISPENSADO
# 134  OSASCO          2   DESLOCADO

# %%
#VERIFICANDO SE É EXTRA
df["extra"] = ''

for i in range(0, len(df)):
    if 'EXTRA' in df['mensagem'][i].upper(): #se contiver a palavra "extra"
        df['extra'][i] = 'extra' #marque na coluna extra como extra
        
print(df['extra'].value_counts()        )
# Out:
#          131
# extra      9
# Name: extra, dtype: int64

# %% [markdown]
# # Tipo entrada e saida:

# %%
#Indentificando se é um registro de entrada ou saida
df['tipo'] = ''
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('SAÍDA','SAIDA'))
invalido = 0
for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    entradas_saidas = re.findall(r'ENTRADA|SAIDA', mensagem)
    quantidade_entradas_saidas = len(entradas_saidas)
    
    if quantidade_entradas_saidas != 1: #capturando apenas com uma informação escrita
        df['controle'][i] = 'PROB'
        invalido += 1
    else: #restante com mais de uma informação
        df['tipo'][i] = entradas_saidas[0]
        
print(df['tipo'].value_counts())        
print(df['controle'].value_counts())
print('entrada e saída junto: '+str(invalido))

prob = df[df['controle'] == 'PROB']
# Out:
# SAIDA      75
# ENTRADA    63
#             2
# Name: tipo, dtype: int64
#         133
# PROB      7
# Name: controle, dtype: int64
# entrada e saída junto: 2

# %%
prob
# Out:
#                                                   chat         dia  \
# 29   [29/06/2023 16:27:17] Marcelo Felipe de Souza ...  29/06/2023
# 37   [29/06/2023 17:16:59] Bianca Priscila Buniotti...  29/06/2023
# 67   [29/06/2023 21:02:49] Lívia Schenkel Thurler T...  29/06/2023
# 91   [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
# 101  [30/06/2023 05:17:59] Francisco Antonio Alves ...  30/06/2023
# 119  [30/06/2023 06:27:50] Yoko Hayashi: 30/06 Itai...  30/06/2023
# 4        MORUMBI          1                     ENTRADA
# 5         ANALIA          1                       SAIDA
# 6        MORUMBI          1              extra  ENTRADA
# 7        MORUMBI          1              extra    SAIDA
# 8         OSASCO          1              extra  ENTRADA
# 9         OSASCO          1              extra    SAIDA
# 10           VNS          1                       SAIDA
# 11         SANTA          1                       SAIDA
# 12         SANTA          1                     ENTRADA
# 13         SANTA          1                       SAIDA
# 14      AVICCENA          1                       SAIDA
# 15         ITAIM          1                       SAIDA
# 16       MORUMBI          1                     ENTRADA
# 17   MATERNIDADE          1                       SAIDA
# 18         VILLA          1                       SAIDA
# 19       MORUMBI          1                       SAIDA
# 20        OSASCO          1                     ENTRADA
# 21          JABA          1                       SAIDA
# 22         ITAIM          1                     ENTRADA
# 23         ITAIM          1                       SAIDA
# 24        ANALIA          1                       SAIDA
# 25        ANALIA          1                       SAIDA
# 26        ANALIA          1                       SAIDA
# 27       MORUMBI          1                       SAIDA
# 28        ANALIA          1                       SAIDA
# 29        OSASCO          2   DESLOCADO           SAIDA
# 30        ANALIA          1                       SAIDA
# 31           VNS          1                       SAIDA
# 32        ANALIA          1                       SAIDA
# 33        ANALIA          1                       SAIDA
# 34         SANTA          1                       SAIDA
# 35        ANALIA          1                       SAIDA
# 36        ANALIA          1                       SAIDA
# 37         ITAIM          2   DESLOCADO           SAIDA
# 38          JABA          1                       SAIDA
# 39       MORUMBI          1                     ENTRADA
# 40        ANALIA          1                       SAIDA
# 41      AVICCENA          1                     ENTRADA
# 42       MORUMBI          1                       SAIDA
# 43          JABA          1                       SAIDA
# 44          JABA          1                       SAIDA
# 45        OSASCO          1                       SAIDA
# 46         ITAIM          1                       SAIDA
# 47         ITAIM          1                       SAIDA
# 48        OSASCO          1                       SAIDA
# 49         ITAIM          1                     ENTRADA
# 50          JABA          1                       SAIDA
# 51         ITAIM          1                       SAIDA
# 52         ITAIM          1                       SAIDA
# 53        OSASCO          1                       SAIDA
# 54         ITAIM          1                       SAIDA
# 55       MORUMBI          1                       SAIDA
# 56         VILLA          1                       SAIDA
# 57         ITAIM          1                       SAIDA
# 58       MORUMBI          1                     ENTRADA
# 59       MORUMBI          1                       SAIDA
# 60         ITAIM          1                       SAIDA
# 61        ANALIA          1                       SAIDA
# 62        OSASCO          1                       SAIDA
# 63      AVICCENA          1                       SAIDA
# 64         VILLA          1                       SAIDA
# 65         ITAIM          1                       SAIDA
# 66         ITAIM          1                       SAIDA
# 67         VILLA          1
# 68         ITAIM          1                     ENTRADA
# 69         ITAIM          1                       SAIDA
# 70           VNS          1                       SAIDA
# 71       MORUMBI          1                       SAIDA
# 72         ITAIM          1                       SAIDA
# 73        OSASCO          1                       SAIDA
# 74         VILLA          1                     ENTRADA
# 75         ITAIM          1                       SAIDA
# 76         ITAIM          1                       SAIDA
# 77         ITAIM          1                     ENTRADA
# 78         ITAIM          1                       SAIDA
# 79          JABA          1                       SAIDA
# 80          JABA          1                       SAIDA
# 81          JABA          1                       SAIDA
# 82         VILLA          1                       SAIDA
# 83          JABA          1                       SAIDA
# 84          JABA          1                       SAIDA
# 85           VNS          1                       SAIDA
# 86         VILLA          1                       SAIDA
# 87       MORUMBI          1                       SAIDA
# 88         VILLA          1                       SAIDA
# 89          JABA          1                       SAIDA
# 90           VNS          1                     ENTRADA
# 91                        0                     ENTRADA
# 92       MORUMBI          1                     ENTRADA
# 93       MORUMBI          1                     ENTRADA
# 94         ITAIM          1                     ENTRADA
# 95       MORUMBI          1                     ENTRADA
# 96         ITAIM          1                     ENTRADA
# 97       MORUMBI          1                     ENTRADA
# 98       MORUMBI          1                     ENTRADA
# 99          JABA          1                     ENTRADA
# 100       ANALIA          1                     ENTRADA
# 101       ANALIA          2   DESLOCADO         ENTRADA
# 102        VILLA          1                     ENTRADA
# 103         JABA          1                     ENTRADA
# 104        SANTA          1              extra  ENTRADA
# 105       OSASCO          1              extra  ENTRADA
# 106        VILLA          1                     ENTRADA
# 107         JABA          1                     ENTRADA
# 108      MORUMBI          1                     ENTRADA
# 109       ANALIA          1                     ENTRADA
# 110       OSASCO          1                     ENTRADA
# 111        SANTA          1                     ENTRADA
# 112       OSASCO          1                     ENTRADA
# 113      MORUMBI          1                     ENTRADA
# 114       ANALIA          1                     ENTRADA
# 115          VNS          1                     ENTRADA
# 116         JABA          1                     ENTRADA
# 117        ITAIM          1                     ENTRADA
# 118       OSASCO          1                     ENTRADA
# 119        ITAIM          1  DISPENSADO
# 120      MORUMBI          1                     ENTRADA
# 121       OSASCO          1                       SAIDA
# 122       OSASCO          1                     ENTRADA
# 123         JABA          1                     ENTRADA
# 124        VILLA          1                     ENTRADA
# 125        VILLA          1                     ENTRADA
# 126        ITAIM          1                     ENTRADA
# 127       OSASCO          1              extra  ENTRADA
# 128      MORUMBI          1                     ENTRADA
# 129      MORUMBI          1                     ENTRADA
# 130        ITAIM          1                     ENTRADA
# 131       ANALIA          1                     ENTRADA
# 132          VNS          1                     ENTRADA
# 133     AVICCENA          1                     ENTRADA
# 134       OSASCO          2   DESLOCADO         ENTRADA
# 135      MORUMBI          1              extra    SAIDA
# 136       OSASCO          1                       SAIDA
# 137     AVICCENA          1                     ENTRADA
# 138      MORUMBI          1              extra    SAIDA
# 139         JABA          1                     ENTRADA
#
#                                                   hora
# 0                          VILLA MAURÍCIO ENTRADA 5:45
# 1                       VILLA - JESSICA  ENTRADA 11:00
# 2                           VILLA - YUMI ENTRADA 06:00
# 3                  VILLA FABIANA GAMA ENTRADA AS 06:00
# 4                    MORUMBI BRUNO LEMOS ENTRADA 06:00
# 5                            ANÁLIA ELAINE SAIDA 13:20
# 6          MORUMBI - SOARES ENTRADA 04:00  (  EXTRA  )
# 7            MORUMBI - SOARES SAIDA 13:40  (  EXTRA  )
# 8              OSASCO - ASTUR ENTRADA 07:00  ( EXTRA )
# 9                OSASCO - ASTUR SAIDA 13:50  ( EXTRA )
# 10                         VNS - GABRIELLA SAIDA 14:00
# 11                            SANTA MARCOS SAIDA 14:10
# 12                        SANTA LEONARDO ENTRADA 05:45
# 13                          SANTA LEONARDO SAIDA 13:40
# 120                       MORUMBI - CAIO ENTRADA 05:45
# 121            OSASCO - ALEXANDRE AMARAL - SAIDA 19:20
# 122                       OSASCO - GOMES ENTRADA 06:00
# 123                   JABAQUARA FACCHINI ENTRADA 06:00
# 124                         VILLA - NUNES ENTRADA 6:00
# 125                          VILLA - ALEX ENTRADA 7:10
# 126                         ITAIM MONICA ENTRADA 05:00
# 127           OSASCO - THALES ENTRADA 07:00  ( EXTRA )
# 128                   MORUMBI - TORRELIO ENTRADA 04:30
# 129                     MORUMBI - FLÁVIO ENTRADA 04:00
# 130                - ITAIM - MAXVILANO - ENTRADA 06:00
# 131                        ANÁLIA - YUMI ENTRADA 06:00
# 132                         VNS - FABIANA ENTRADA 6:30
# 133  AVICCENA- NATAN- ENTRADA 11:00  ( A PEDIDO DA ...
# 134  OSASCO - G.MENEZES ENTRADA 06:20  ( DESLOCADO ...
# 135             MORUMBI - BRUCE SAIDA 11:40  ( EXTRA )
# 136   OSASCO - NALDO SAIDA - 16:20  ( PÓS - PLANTÃO  )
# 137                   AVICCENA - NALDO - ENTRADA 05:35
# 138            MORUMBI - BIANCA SAIDA 12:35  ( EXTRA )
# 139                       JABAQUARA LAIS ENTRADA 06H00

# %%
#arrumando data d/mm (6/10, não 06/10)
for i in range(0, len(df)):
    if df['data'][i] != "" and df['data'][i][1] == '/':
        df['data'][i] = '0'+df['data'][i]
df['data'].unique()
# Out:
# array(['29/06', '28/06', '29/6', '30/06', '30/6'], dtype=object)

# %%
#somando informações restantes na data: dd/MM/yyyy
for i in range(0, len(df)):
    df['data'][i] = df['data'][i][0:2] + "/"+ mes +"/2023" 
    
print(df['data'].unique())
# Out:
# ['29/06/2023' '28/06/2023' '30/06/2023']

# %%
df['sem_ou_fds'] = 'semana'

df.loc[(df['data'] == sabado) | (df['data'] == domingo), 'sem_ou_fds'] = 'fds'

df['sem_ou_fds'].value_counts()
# Out:
# semana    140
# Name: sem_ou_fds, dtype: int64

# %%
df
# Out:
#                                                   chat         dia  \
# 0    [29/06/2023 09:41:33] Maurício Faria Tetti: 29...  29/06/2023
# 1    [29/06/2023 10:59:23] Jessica Lidia de Souza: ...  29/06/2023
# 2    [29/06/2023 12:53:23] Karen Yumi Miyashiro: 29...  29/06/2023
# 3    [29/06/2023 13:01:31] Fabiana Soares Gama: 29/...  29/06/2023
# 4    [29/06/2023 13:02:24] Bruno Stornioli Taguchi ...  29/06/2023
# 5    [29/06/2023 13:20:21] Elaine Imaeda de Moura: ...  29/06/2023
# 6    [29/06/2023 13:43:26] Eduardo Dala Rosa Soares...  29/06/2023
# 7    [29/06/2023 13:43:54] Eduardo Dala Rosa Soares...  29/06/2023
# 8    [29/06/2023 13:49:58] Anna Beatriz Lima Do Val...  29/06/2023
# 9    [29/06/2023 13:50:29] Anna Beatriz Lima Do Val...  29/06/2023
# 10   [29/06/2023 14:00:54] Gabriella Gadelha Sarmen...  29/06/2023
# 11   [29/06/2023 14:10:10] Marcos Rogério Pereira M...  29/06/2023
# 12   [29/06/2023 14:24:44] Leonardo de Paula Souza:...  29/06/2023
# 129               30/06 MORUMBI - FLÁVIO ENTRADA 04:00           30/06/2023
# 130          30/06 - ITAIM - MAXVILANO - ENTRADA 06:00           30/06/2023
# 131                  30/06 ANÁLIA - YUMI ENTRADA 06:00           30/06/2023
# 132                   30/06 VNS - FABIANA ENTRADA 6:30           30/06/2023
# 133  30/06 AVICCENA- NATAN- ENTRADA 11:00  ( A PEDI...           30/06/2023
# 134  30/06 OSASCO - G.MENEZES ENTRADA 06:20  ( DESL...     PROB  30/06/2023
# 135      30/06 MORUMBI - BRUCE SAIDA 11:40  ( EXTRA )            30/06/2023
# 136  29/06 OSASCO - NALDO SAIDA - 16:20  ( PÓS - PL...           29/06/2023
# 137             30/06 AVICCENA - NALDO - ENTRADA 05:35           30/06/2023
# 138     30/06 MORUMBI - BIANCA SAIDA 12:35  ( EXTRA )            30/06/2023
# 139                 30/06 JABAQUARA LAIS ENTRADA 06H00           30/06/2023
#
#          unidade Q_unidades         sit  extra     tipo  \
# 0          VILLA          1                     ENTRADA
# 1          VILLA          1                     ENTRADA
# 2          VILLA          1                     ENTRADA
# 3          VILLA          1                     ENTRADA
# 4        MORUMBI          1                     ENTRADA
# 5         ANALIA          1                       SAIDA
# 6        MORUMBI          1              extra  ENTRADA
# 7        MORUMBI          1              extra    SAIDA
# 8         OSASCO          1              extra  ENTRADA
# 9         OSASCO          1              extra    SAIDA
# 10           VNS          1                       SAIDA
# 11         SANTA          1                       SAIDA
# 12         SANTA          1                     ENTRADA
# 13         SANTA          1                       SAIDA
# 14      AVICCENA          1                       SAIDA
# 15         ITAIM          1                       SAIDA
# 16       MORUMBI          1                     ENTRADA
# 17   MATERNIDADE          1                       SAIDA
# 18         VILLA          1                       SAIDA
# 19       MORUMBI          1                       SAIDA
# 20        OSASCO          1                     ENTRADA
# 21          JABA          1                       SAIDA
# 22         ITAIM          1                     ENTRADA
# 23         ITAIM          1                       SAIDA
# 24        ANALIA          1                       SAIDA
# 25        ANALIA          1                       SAIDA
# 26        ANALIA          1                       SAIDA
# 27       MORUMBI          1                       SAIDA
# 28        ANALIA          1                       SAIDA
# 29        OSASCO          2   DESLOCADO           SAIDA
# 30        ANALIA          1                       SAIDA
# 31           VNS          1                       SAIDA
# 32        ANALIA          1                       SAIDA
# 33        ANALIA          1                       SAIDA
# 34         SANTA          1                       SAIDA
# 35        ANALIA          1                       SAIDA
# 36        ANALIA          1                       SAIDA
# 37         ITAIM          2   DESLOCADO           SAIDA
# 38          JABA          1                       SAIDA
# 39       MORUMBI          1                     ENTRADA
# 40        ANALIA          1                       SAIDA
# 41      AVICCENA          1                     ENTRADA
# 42       MORUMBI          1                       SAIDA
# 43          JABA          1                       SAIDA
# 44          JABA          1                       SAIDA
# 45        OSASCO          1                       SAIDA
# 46         ITAIM          1                       SAIDA
# 47         ITAIM          1                       SAIDA
# 48        OSASCO          1                       SAIDA
# 49         ITAIM          1                     ENTRADA
# 50          JABA          1                       SAIDA
# 51         ITAIM          1                       SAIDA
# 52         ITAIM          1                       SAIDA
# 53        OSASCO          1                       SAIDA
# 54         ITAIM          1                       SAIDA
# 55       MORUMBI          1                       SAIDA
# 56         VILLA          1                       SAIDA
# 57         ITAIM          1                       SAIDA
# 58       MORUMBI          1                     ENTRADA
# 59       MORUMBI          1                       SAIDA
# 60         ITAIM          1                       SAIDA
# 61        ANALIA          1                       SAIDA
# 62        OSASCO          1                       SAIDA
# 63      AVICCENA          1                       SAIDA
# 64         VILLA          1                       SAIDA
# 65         ITAIM          1                       SAIDA
# 66         ITAIM          1                       SAIDA
# 67         VILLA          1
# 68         ITAIM          1                     ENTRADA
# 69         ITAIM          1                       SAIDA
# 70           VNS          1                       SAIDA
# 71       MORUMBI          1                       SAIDA
# 72         ITAIM          1                       SAIDA
# 73        OSASCO          1                       SAIDA
# 74         VILLA          1                     ENTRADA
# 75         ITAIM          1                       SAIDA
# 76         ITAIM          1                       SAIDA
# 77         ITAIM          1                     ENTRADA
# 78         ITAIM          1                       SAIDA
# 79          JABA          1                       SAIDA
# 80          JABA          1                       SAIDA
# 81          JABA          1                       SAIDA
# 82         VILLA          1                       SAIDA
# 83          JABA          1                       SAIDA
# 84          JABA          1                       SAIDA
# 85           VNS          1                       SAIDA
# 86         VILLA          1                       SAIDA
# 87       MORUMBI          1                       SAIDA
# 88         VILLA          1                       SAIDA
# 89          JABA          1                       SAIDA
# 90           VNS          1                     ENTRADA
# 91                        0                     ENTRADA
# 92       MORUMBI          1                     ENTRADA
# 93       MORUMBI          1                     ENTRADA
# 94         ITAIM          1                     ENTRADA
# 95       MORUMBI          1                     ENTRADA
# 96         ITAIM          1                     ENTRADA
# 97       MORUMBI          1                     ENTRADA
# 98       MORUMBI          1                     ENTRADA
# 99          JABA          1                     ENTRADA
# 100       ANALIA          1                     ENTRADA
# 101       ANALIA          2   DESLOCADO         ENTRADA
# 102        VILLA          1                     ENTRADA
# 103         JABA          1                     ENTRADA
# 104        SANTA          1              extra  ENTRADA
# 105       OSASCO          1              extra  ENTRADA
# 106        VILLA          1                     ENTRADA
# 107         JABA          1                     ENTRADA
# 108      MORUMBI          1                     ENTRADA
# 109       ANALIA          1                     ENTRADA
# 110       OSASCO          1                     ENTRADA
# 111        SANTA          1                     ENTRADA
# 112       OSASCO          1                     ENTRADA
# 113      MORUMBI          1                     ENTRADA
# 114       ANALIA          1                     ENTRADA
# 115          VNS          1                     ENTRADA
# 116         JABA          1                     ENTRADA
# 117        ITAIM          1                     ENTRADA
# 118       OSASCO          1                     ENTRADA
# 119        ITAIM          1  DISPENSADO
# 120      MORUMBI          1                     ENTRADA
# 121       OSASCO          1                       SAIDA
# 122       OSASCO          1                     ENTRADA
# 123         JABA          1                     ENTRADA
# 124        VILLA          1                     ENTRADA
# 125        VILLA          1                     ENTRADA
# 126        ITAIM          1                     ENTRADA
# 127       OSASCO          1              extra  ENTRADA
# 128      MORUMBI          1                     ENTRADA
# 129      MORUMBI          1                     ENTRADA
# 130        ITAIM          1                     ENTRADA
# 131       ANALIA          1                     ENTRADA
# 132          VNS          1                     ENTRADA
# 133     AVICCENA          1                     ENTRADA
# 134       OSASCO          2   DESLOCADO         ENTRADA
# 135      MORUMBI          1              extra    SAIDA
# 136       OSASCO          1                       SAIDA
# 137     AVICCENA          1                     ENTRADA
# 138      MORUMBI          1              extra    SAIDA
# 139         JABA          1                     ENTRADA
#
#                                                   hora sem_ou_fds
# 0                          VILLA MAURÍCIO ENTRADA 5:45     semana
# 1                       VILLA - JESSICA  ENTRADA 11:00     semana
# 2                           VILLA - YUMI ENTRADA 06:00     semana
# 3                  VILLA FABIANA GAMA ENTRADA AS 06:00     semana
# 4                    MORUMBI BRUNO LEMOS ENTRADA 06:00     semana
# 5                            ANÁLIA ELAINE SAIDA 13:20     semana
# 6          MORUMBI - SOARES ENTRADA 04:00  (  EXTRA  )     semana
# 7            MORUMBI - SOARES SAIDA 13:40  (  EXTRA  )     semana
# 8              OSASCO - ASTUR ENTRADA 07:00  ( EXTRA )     semana
# 9                OSASCO - ASTUR SAIDA 13:50  ( EXTRA )     semana
# 10                         VNS - GABRIELLA SAIDA 14:00     semana
# 11                            SANTA MARCOS SAIDA 14:10     semana
# 12                        SANTA LEONARDO ENTRADA 05:45     semana
# 13                          SANTA LEONARDO SAIDA 13:40     semana
# 14                        AVICCENA ORLANDO SAIDA 14:35     semana
# 15                     ITAIM - M. DARDENGO SAIDA 22:00     semana
# 16                 MORUMBI - M. DARDENGO ENTRADA 06:20     semana
# 17                    MATERNIDADE - KAKUDA SAIDA 14:45     semana
# 18                            VILLA CAMILA SAIDA 14:50     semana
# 19              - MORUMBI - RICARDO IVO SAIDA - 14:50H     semana
# 20         - OSASCO - ALEXANDRE AMARAL - ENTRADA 06:05     semana
# 21          JABAQUARA LAYSA SAIDA 15H  ( POS PLANTÃO )     semana
# 22                           -ITAIM OLAIO ENTRADA 6:00     semana
# 23                            -ITAIM OLAIO SAIDA 14:55     semana
# 24                          ANÁLIA - DIOGO SAIDA 15:20     semana
# 25                         ANÁLIA - FLÁVIO SAIDA 15:40     semana
# 26                            ANÁLIA BRUNA SAIDA 15:00     semana
# 27                     MORUMBI - MIYASHIRO SAIDA 16:25     semana
# 28                         ANÁLIA- LUCENA- SAIDA 16:30     semana
# 29      OSASCO - BUTO SAIDA 16:20  ( DESLOCADO ITAIM )     semana
# 30                       ANÁLIA-ESTANRLEY SAIDA: 16:30     semana
# 31                           VNS - FABIANA SAIDA 16:40     semana
# 32                          ANÁLIA - AKEMI SAIDA 16:55     semana
# 33                          ANÁLIA - DINIZ SAIDA 16:50     semana
# 34                     SANTA ISABEL MANOEL SAIDA 17:00     semana
# 35                      ANÁLIA PAULA NEVES SAIDA 15:30     semana
# 36                        ANÁLIA - MATHEUS SAIDA 17:10     semana
# 37   ITAIM - BIANCA SAIDA 15:30  ( PÓS PLANTÃO; DES...     semana
# 38                    JABAQUARA - SILVEIRA SAIDA 17:10     semana
# 39                       MORUMBI - LAURA ENTRADA 05:40     semana
# 40                     ANÁLIA - GIRALDELLI SAIDA 16:55     semana
# 91                             JBQ DUARTE ENTRADA 4:30     semana
# 92                        MORUMBI - WONG ENTRADA 04:40     semana
# 93                       MORUMBI EVERTON ENTRADA 04:30     semana
# 94                     ITAIM RAFAEL TADEU ENTRADA 4:50     semana
# 95                      MORUMBI - AMANDA ENTRADA 04:40     semana
# 96                            ITAIM KAREN ENTRADA 5:00     semana
# 97                         MORUMBI - VALE ENTRADA 4:35     semana
# 98                         MORUMBI MOURA ENTRADA 04:50     semana
# 99                       JABAQUARA VITOR ENTRADA 05:15     semana
# 100                    ANÁLIA-ESTANRLEY ENTRADA: 05:10     semana
# 101  ANÁLIA - FRANCISCO ENTRADA 05:10  ( DESLOCADO ...     semana
# 102                  VILLA JULIANO TOBAL ENTRADA 05:20     semana
# 103                    JABAQUARA - DÊNIO ENTRADA 05:20     semana
# 104         SANTA - T.SILVA - ENTRADA 05:20  ( EXTRA )     semana
# 105                OSASCO ENTRADA KAIE 5:45  ( EXTRA )     semana
# 106                     VILLA - HELENA - ENTRADA 05:35     semana
# 107                     JABAQUARA DÉBORA ENTRADA 06:00     semana
# 108                      MORUMBI QUEIROZ ENTRADA 05:30     semana
# 109                        ANÁLIA VIVIAN ENTRADA 05:45     semana
# 110                        OSASCO KAWAURA ENTRADA 6:00     semana
# 111                  SANTA ISABEL MANOEL ENTRADA 06:00     semana
# 112                          OSASCO BORJA ENTRADA 6:00     semana
# 113                    MORUMBI - PATRICK ENTRADA 05:40     semana
# 114                       ANÁLIA- RÔMULO ENTRADA 06:00     semana
# 115                          VNS RIBEIRO ENTRADA 06:10     semana
# 116                JABAQUARA BRUNO LEMOS ENTRADA 06:00     semana
# 117                         ITAIM VENTURA ENTRADA 6:00     semana
# 118                       OSASCO - ERICK ENTRADA 05:40     semana
# 119      ITAIM YOKO  ( DISPENSADOPOR MOTIVO DE SAÚDE )     semana
# 120                       MORUMBI - CAIO ENTRADA 05:45     semana
# 121            OSASCO - ALEXANDRE AMARAL - SAIDA 19:20     semana
# 122                       OSASCO - GOMES ENTRADA 06:00     semana
# 123                   JABAQUARA FACCHINI ENTRADA 06:00     semana
# 124                         VILLA - NUNES ENTRADA 6:00     semana
# 125                          VILLA - ALEX ENTRADA 7:10     semana
# 126                         ITAIM MONICA ENTRADA 05:00     semana
# 127           OSASCO - THALES ENTRADA 07:00  ( EXTRA )     semana
# 128                   MORUMBI - TORRELIO ENTRADA 04:30     semana
# 129                     MORUMBI - FLÁVIO ENTRADA 04:00     semana
# 130                - ITAIM - MAXVILANO - ENTRADA 06:00     semana
# 131                        ANÁLIA - YUMI ENTRADA 06:00     semana
# 132                         VNS - FABIANA ENTRADA 6:30     semana
# 133  AVICCENA- NATAN- ENTRADA 11:00  ( A PEDIDO DA ...     semana
# 134  OSASCO - G.MENEZES ENTRADA 06:20  ( DESLOCADO ...     semana
# 135             MORUMBI - BRUCE SAIDA 11:40  ( EXTRA )     semana
# 136   OSASCO - NALDO SAIDA - 16:20  ( PÓS - PLANTÃO  )     semana
# 137                   AVICCENA - NALDO - ENTRADA 05:35     semana
# 138            MORUMBI - BIANCA SAIDA 12:35  ( EXTRA )     semana
# 139                       JABAQUARA LAIS ENTRADA 06H00     semana

# %% [markdown]
# # Hora:

# %%
#substituindo "h" por ":" para capturar horarios 11h22
df['hora'] = df['hora'].apply(lambda x: x.upper().replace("H", ":"))

# %%
invalido = 0
for i in range(0, len(df)):
    mensagem = df['hora'][i]
    horas = re.findall(r'[0-9]{1,2}:[0-9]{1,2}', mensagem) #capturando horas HH:mm
    quantidade_horas = len(horas)

    if quantidade_horas == 1: #capturando apenas com uma horas escrita
        df['hora'][i] = horas[0]
    else: #restante com nenhuma ou mais horas (geralmente pq digitou a hora de entrada e saida {informação inutil})
        df['hora'][i] = ''
        df['controle'][i] = 'PROB'
        invalido += 1
        
print(df['controle'].value_counts())
print('mais de uma hora ou nenhuma hora: '+str(invalido))
prob = df[df['controle'] == "PROB"]
# Out:
#         132
# PROB      8
# Name: controle, dtype: int64
# mais de uma hora ou nenhuma hora: 2

# %%
len(prob)
# Out:
# 8

# %%
len(df[df['hora'] == ""])
# Out:
# 2

# %%
#adicionando 0 no primeiro algorismo dos valores h:mm
for i in range(0, len(df)):
    if df['hora'][i] != "" and df['hora'][i][1] == ":":
        df['hora'][i] = "0"+df['hora'][i]
        
df['hora'].unique()
# Out:
# array(['05:45', '11:00', '06:00', '13:20', '04:00', '13:40', '07:00',
#        '13:50', '14:00', '14:10', '14:35', '22:00', '06:20', '14:45',
#        '14:50', '06:05', '', '14:55', '15:20', '15:40', '15:00', '16:25',
#        '16:30', '16:20', '16:40', '16:55', '16:50', '17:00', '15:30',
#        '17:10', '05:40', '19:15', '19:25', '19:27', '19:40', '19:45',
#        '19:50', '19:30', '19:35', '19:55', '20:20', '20:15', '20:35',
#        '20:50', '21:00', '21:05', '21:10', '20:40', '21:40', '21:45',
#        '05:20', '22:05', '21:55', '22:10', '22:30', '22:50', '23:15',
#        '23:30', '23:45', '00:10', '01:50', '04:20', '04:30', '04:40',
#        '04:50', '05:00', '04:35', '05:15', '05:10', '05:35', '05:30',
#        '06:10', '19:20', '07:10', '06:30', '11:40', '12:35'], dtype=object)

# %% [markdown]
# # Hora final:

# %%
#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %%
len(df)
# Out:
# 140

# %%
prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
prob_hora = df[df['hora'] == ""] #zero ou mais de uma hora
prob_hora.reset_index(drop=True, inplace=True)
df = df[df['hora'] != ""] #df passa a ter ainda os prob, mas sem incluir os prob de hora
df.reset_index(drop=True, inplace=True)
print("prob: "+str(len(prob)))
print("prob_hora: "+str(len(prob_hora)))
print("df: "+str(len(df)))
# Out:
# prob: 8
# prob_hora: 2
# df: 138

# %%
#criando uma coluna datetime para fazer calculos de horas e minutos
df['hora2'] = df['hora'].apply(lambda x: datetime.strptime(x, '%H:%M'))

#verificando se esta tudo certo
print(df['hora2'].dt.year.unique())
print(df['hora2'].dt.month.unique())
print(df['hora2'].dt.day.unique())
print(df['hora2'].dt.hour.unique())

for i in range(0, len(df)):
    minuto = int(df['hora'][i][3:])
    
    if minuto != 0 and minuto != 30:
        if minuto < 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (0) subtraindo quantos minutos tem entre o momento e HH:00
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-minuto))[11:-3]
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (30) acrecentando quantos minutos faltam para HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(30-minuto)))[11:-3]
            else:
                df['controle'][i] = 'PROB'
                
        elif minuto > 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (30) subtraindo quando minutos tem entre o momento e HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-(minuto-30)))[11:-3]   
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (60) acrecentando quantos minutos faltam para HH:60
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(60-minuto)))[11:-3]            
            else:
                df['controle'][i] = 'PROB'
        else:
            df['controle'][i] = 'PROB'
            
    elif minuto == 0 or minuto == 30:
        df['hora'][i] = str(df['hora2'][i])[11:-3] 
        
    else:
        df['controle'][i] = 'PROB'
        
df['hora'].unique()
# Out:
# [1900]
# [1]
# [1]
# [ 5 11  6 13  4  7 14 22 15 16 17 19 20 21 23  0  1 12]
# array(['05:30', '11:00', '06:00', '13:30', '04:00', '14:00', '07:00',
#        '14:30', '15:00', '22:00', '15:30', '16:00', '16:30', '17:00',
#        '17:30', '19:30', '20:00', '20:30', '21:00', '20:50', '21:30',
#        '05:00', '22:30', '23:00', '23:30', '00:00', '00:30', '02:00',
#        '04:30', '06:30', '12:00', '13:00'], dtype=object)

# %% [markdown]
# # Setor:

# %%
#reconhendo em qual periodo do dia aconteceu o plantão
df['ENTRADA'] = ''
df['SAIDA'] = ''
df['PERIODO'] = ''

for i in range(0, len(df)):
    minuto = int(df['hora'][i][:2])
    
    if df['tipo'][i] == 'ENTRADA':
        df['ENTRADA'][i] = df['hora'][i]
        if minuto < 7: #periodo 6h
            df['PERIODO'][i] = '6h'
            df['SAIDA'][i] = '07:00'
        elif minuto >= 7 and minuto < 13: #periodo manha
            df['PERIODO'][i] = 'manha'
            df['SAIDA'][i] = '13:00'
        elif minuto >= 13 and minuto < 19: #periodo tarde
            df['PERIODO'][i] = 'tarde'
            df['SAIDA'][i] = '19:00'
        else:
            df['controle'][i] = 'PROB'
    elif df['tipo'][i] == 'SAIDA':
        df['SAIDA'][i] = df['hora'][i]
        if minuto >= 7 and minuto < 13: #periodo manha
            df['ENTRADA'][i] = '07:00'
            df['PERIODO'][i] = 'manha'
        elif minuto >= 13 and minuto < 19: #periodo tarde
            df['ENTRADA'][i] = '13:00'
            df['PERIODO'][i] = 'tarde'
        elif minuto >= 19: #periodo noturno
            df['ENTRADA'][i] = '19:00'
            df['PERIODO'][i] = 'noturno saida'
        elif minuto <= 2: #periodo noturno
            df['ENTRADA'][i] = '19:00'
            df['PERIODO'][i] = 'noturno saida'
        else:
            df['controle'][i] = 'PROB'
    else:
        df['controle'][i] = 'PROB'
        
df['PERIODO'].value_counts()

print(df['controle'].value_counts())

prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
print("probs:", len(prob))
# Out:
#         131
# PROB      7
# Name: controle, dtype: int64
# probs: 7

# %%
prob
# Out:
#                                                 chat         dia  \
# 0  [29/06/2023 16:27:17] Marcelo Felipe de Souza ...  29/06/2023
# 1  [29/06/2023 17:16:59] Bianca Priscila Buniotti...  29/06/2023
# 2  [29/06/2023 21:02:49] Lívia Schenkel Thurler T...  29/06/2023
# 3  [29/06/2023 21:38:50] Karen Yumi Miyashiro: 29...  29/06/2023
# 4  [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
# 5  [30/06/2023 05:17:59] Francisco Antonio Alves ...  30/06/2023
# 6  [30/06/2023 10:39:21] Gabriela Santos Menezes:...  30/06/2023
#
#                               nome  \
# 0     MARCELO FELIPE DE SOUZA BUTO
# 1         BIANCA PRISCILA BUNIOTTI
# 2    LIVIA SCHENKEL THURLER TRAIRI
# 3             KAREN YUMI MIYASHIRO
# 4  IZABELA CRISTINA ALMEIDA DUARTE
# 5  FRANCISCO ANTONIO ALVES BONATTO
# 6          GABRIELA SANTOS MENEZES
#
#                                             mensagem controle        data  \
# 0  29/06 OSASCO - BUTO SAIDA 16:20  ( DESLOCADO I...     PROB  29/06/2023
# 1  29/06 ITAIM - BIANCA SAIDA 15:30  ( PÓS PLANTÃ...     PROB  29/06/2023
# 2                          29/06 VILLA - LIVIA 20:50     PROB  29/06/2023
# 3                   29/06 VILLA - YUMI ENTRADA 20:40     PROB  29/06/2023
# 4                      30/06 JBQ DUARTE ENTRADA 4:30     PROB  30/06/2023
# 5  30/06 ANÁLIA - FRANCISCO ENTRADA 05:10  ( DESL...     PROB  30/06/2023
# 6  30/06 OSASCO - G.MENEZES ENTRADA 06:20  ( DESL...     PROB  30/06/2023
#
#   unidade Q_unidades        sit extra     tipo   hora sem_ou_fds  \
# 0  OSASCO          2  DESLOCADO          SAIDA  16:30     semana
# 1   ITAIM          2  DESLOCADO          SAIDA  15:30     semana
# 2   VILLA          1                            20:50     semana
# 3   VILLA          1                   ENTRADA  20:30     semana
# 4                  0                   ENTRADA  04:30     semana
# 5  ANALIA          2  DESLOCADO        ENTRADA  05:00     semana
# 6  OSASCO          2  DESLOCADO        ENTRADA  06:00     semana
#
#                 hora2 ENTRADA  SAIDA PERIODO
# 0 1900-01-01 16:20:00   13:00  16:30   tarde
# 1 1900-01-01 15:30:00   13:00  15:30   tarde
# 2 1900-01-01 20:50:00
# 3 1900-01-01 20:40:00   20:30
# 4 1900-01-01 04:30:00   04:30  07:00      6h
# 5 1900-01-01 05:10:00   05:00  07:00      6h
# 6 1900-01-01 06:20:00   06:00  07:00      6h

# %%
prob.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)
print("prob: "+str(len(prob)))
print("prob_hora: "+str(len(prob_hora)))
print("df: "+str(len(df)))
# Out:
# prob: 7
# prob_hora: 2
# df: 138

# %%
prob_dura = df[(df['SAIDA'] == "" )|  (df['ENTRADA'] == "")] #prob_dura: sem entrada ou saída
df = df[df['ENTRADA'] != ""]
df = df[df['SAIDA'] != ""]  ## retiro sem ENTRADA OU SEM SAÍDA
df.reset_index(drop=True, inplace=True)
prob_dura.reset_index(drop=True, inplace=True)

# %%
print(len(df))
print(len(prob_dura))
# Out:
# 136
# 2

# %%
problemao = pd.concat([prob_hora, prob_dura]) #problemao = prob mais de uma hora, nenhuma hora , nenhuma entrada ou saída
problemao.reset_index(drop=True, inplace=True) #todo problemao já não faz parte de df
problemao
# Out:
#                                                 chat         dia  \
# 0  [29/06/2023 15:06:29] Laysa Layna Ribeiro Lima...  29/06/2023
# 1  [30/06/2023 06:27:50] Yoko Hayashi: 30/06 Itai...  30/06/2023
# 2  [29/06/2023 21:02:49] Lívia Schenkel Thurler T...  29/06/2023
# 3  [29/06/2023 21:38:50] Karen Yumi Miyashiro: 29...  29/06/2023
#
#                             nome  \
# 0       LAYSA LAYNA RIBEIRO LIMA
# 1                   YOKO HAYASHI
# 2  LIVIA SCHENKEL THURLER TRAIRI
# 3           KAREN YUMI MIYASHIRO
#
#                                             mensagem controle        data  \
# 0  29/06 JABAQUARA LAYSA SAIDA 15H  ( POS PLANTÃO )      PROB  29/06/2023
# 1  30/06 ITAIM YOKO  ( DISPENSADOPOR MOTIVO DE SA...     PROB  30/06/2023
# 2                          29/06 VILLA - LIVIA 20:50     PROB  29/06/2023
# 3                   29/06 VILLA - YUMI ENTRADA 20:40     PROB  29/06/2023
#
#   unidade Q_unidades         sit extra     tipo   hora sem_ou_fds  \
# 0    JABA          1                      SAIDA            semana
# 1   ITAIM          1  DISPENSADO                           semana
# 2   VILLA          1                             20:50     semana
# 3   VILLA          1                    ENTRADA  20:30     semana
#
#                 hora2 ENTRADA SAIDA PERIODO
# 0                 NaT     NaN   NaN     NaN
# 1                 NaT     NaN   NaN     NaN
# 2 1900-01-01 20:50:00
# 3 1900-01-01 20:40:00   20:30

# %%
### PROB CONTINUA DENTRO DO DF
### PROBLEMAO É SOMA DE PROBLEMAS QUE SAÍRAM DO DF: NÃO TINHAM HORA + ERRO ENTRADA OU SAÍDA

# %%
#DURAÇÃO DO PLANTÃO
df['DURAÇÃO'] = ''

for i in range(0, len(df)):
    diferenca_tempo = datetime.strptime(df['SAIDA'][i], '%H:%M') - datetime.strptime(df['ENTRADA'][i], '%H:%M')
    
    #diferenca_tempo vem em formato estranho, tem-se que transformar em segundos antes
    diferenca_tempo_s = diferenca_tempo.seconds
    horas = '0' + str(int((diferenca_tempo_s/60)/60)) #capturando horas
    minutos = str(int((diferenca_tempo_s/60)%60))  #capturando minutos
    
    if len(minutos) == 1:
        minutos = '0' + minutos
    
    df['DURAÇÃO'][i] = horas + ':' + minutos
    
df['DURAÇÃO'].unique()
# Out:
# array(['01:30', '02:00', '01:00', '00:30', '03:00', '06:00', '02:30',
#        '03:30', '04:00', '04:30', '05:00', '05:30', '07:00', '00:00'],
#       dtype=object)

# %%
df['setor'] = ''

for i in range(0, len(df)):
    if df['sem_ou_fds'][i] == 'semana':
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'SEMANA - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'SEMANA - MANHA - C.CIRURGICO'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'SEMANA - TARDE - C.CIRURGICO'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'SEMANA - NOTURNO - SAIDA'
        else:
            df['setor'][i] = 'VERIFICAR'

    elif df['sem_ou_fds'][i] == 'fds': 
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'FDS - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'FDS - C.CIRURGICO ROTINA'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'FDS - SAIDA'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'FDS - PLANTAO'
        else:
            df['setor'][i] = 'VERIFICAR'  

    else:
        df['setor'][i] = 'VERIFICAR'
        
df['setor'].value_counts()
# Out:
# SEMANA - 6HS                    57
# SEMANA - NOTURNO - SAIDA        43
# SEMANA - TARDE - C.CIRURGICO    30
# SEMANA - MANHA - C.CIRURGICO     6
# Name: setor, dtype: int64

# %%
print("prob:", len(prob)) #ainda dentro de df
print("problemao:", len(problemao)) #fora de df
print("df:", len(df)) #todo df
# Out:
# prob: 7
# problemao: 4
# df: 136

# %%
df[df['SAIDA'] == "00:30"]
# Out:
#                                                  chat         dia  \
# 85  [30/06/2023 00:10:27] Jessica Lidia de Souza: ...  30/06/2023
#
#                       nome                            mensagem controle  \
# 85  JESSICA LIDIA DE SOUZA  30/06 VILLA  - JESSICA SAIDA 00:10
#
#           data unidade Q_unidades sit extra   tipo   hora sem_ou_fds  \
# 85  30/06/2023   VILLA          1            SAIDA  00:30     semana
#
#                  hora2 ENTRADA  SAIDA        PERIODO DURAÇÃO  \
# 85 1900-01-01 00:10:00   19:00  00:30  noturno saida   05:30
#
#                        setor
# 85  SEMANA - NOTURNO - SAIDA

# %% [markdown]
# # Ultimos ajustes:

# %%
# Distancias
for i in range(0, len(df)):
    mensagem = df['mensagem'][i].upper()
    regex_D = re.findall('D[0-9]', mensagem)
    
    if len(regex_D) == 0:
        continue
    else:
        df['controle'][i] == 'PROB'

# %%
for i in range(0, len(df)):
    if df['DURAÇÃO'][i] == "00:00" :
        df['controle'][i] = "PROB"
        
print(df['controle'].value_counts())
# Out:
#         130
# PROB      6
# Name: controle, dtype: int64

# %%
df['setor'] = df['setor'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))
df['unidade'] = df['unidade'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))

df['unidade'] = df['unidade'].apply(lambda x: x.replace('JABA','JABAQUARA'))

df['unidade'] = df['unidade'].apply(lambda x: x.replace('SANTA','SANTA ISABEL'))

df['unidade'].unique()

#problemas com santa isabel 
#df['setor'][(df['unidade'] == "SANTA ISABEL") & (df['setor'] == "FDS - SAIDA")] = "FDS - NOTURNO - SAIDA"
df['setor'][(df['unidade'] == "SANTA ISABEL") & (df['setor'] == "FDS - C.CIRURGICO ROTINA")] = "FDS - MANHA - C.CIRURGICO"

# %%
#df['UNIDADE'] = df['UNIDADE'].apply(lambda x: x.replace('JABA','JABAQUARA'))
df['nome'] = df['nome'].apply(lambda x: x.replace('  ',' '))

#df['UNIDADE'] = df['UNIDADE'].apply(lambda x: x.replace('JABAQUARAQUARA','JABAQUARA'))
#df['UNIDADE'].unique()

# %%
#problemao - erro hora (mais de 1 ou nenhum), entrada saída
#prob: inclui deslocado, possível dispensa (maioria dentro de problemao) e duração 00h
#df ainda inclui prob

# %%
desloc = df[df['sit'] == 'DESLOCADO']
dispen = problemao[problemao['sit'] == 'DISPENSADO']
desloc.reset_index(inplace=True, drop=True)
dispen.reset_index(inplace=True, drop=True)

# %%
len(df)
# Out:
# 136

# %%
len(desloc)
# Out:
# 4

# %%
problemao = problemao[problemao['sit'] != 'DISPENSADO']
df = df[df['sit'] != 'DESLOCADO']
prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)
problemao.reset_index(drop=True, inplace=True)

# %%
len(df)
# Out:
# 132

# %%
problemao
# Out:
#                                                 chat         dia  \
# 0  [29/06/2023 15:06:29] Laysa Layna Ribeiro Lima...  29/06/2023
# 1  [29/06/2023 21:02:49] Lívia Schenkel Thurler T...  29/06/2023
# 2  [29/06/2023 21:38:50] Karen Yumi Miyashiro: 29...  29/06/2023
#
#                             nome  \
# 0       LAYSA LAYNA RIBEIRO LIMA
# 1  LIVIA SCHENKEL THURLER TRAIRI
# 2           KAREN YUMI MIYASHIRO
#
#                                             mensagem controle        data  \
# 0  29/06 JABAQUARA LAYSA SAIDA 15H  ( POS PLANTÃO )      PROB  29/06/2023
# 1                          29/06 VILLA - LIVIA 20:50     PROB  29/06/2023
# 2                   29/06 VILLA - YUMI ENTRADA 20:40     PROB  29/06/2023
#
#   unidade Q_unidades sit extra     tipo   hora sem_ou_fds               hora2  \
# 0    JABA          1              SAIDA            semana                 NaT
# 1   VILLA          1                     20:50     semana 1900-01-01 20:50:00
# 2   VILLA          1            ENTRADA  20:30     semana 1900-01-01 20:40:00
#
#   ENTRADA SAIDA PERIODO
# 0     NaN   NaN     NaN
# 1
# 2   20:30

# %%
prob ##inclúido ainda no df
# Out:
#                                                 chat         dia  \
# 0  [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
# 1  [30/06/2023 12:48:23] Bianca Priscila Buniotti...  30/06/2023
#
#                               nome  \
# 0  IZABELA CRISTINA ALMEIDA DUARTE
# 1         BIANCA PRISCILA BUNIOTTI
#
#                                          mensagem controle        data  \
# 0                   30/06 JBQ DUARTE ENTRADA 4:30     PROB  30/06/2023
# 1  30/06 MORUMBI - BIANCA SAIDA 12:35  ( EXTRA )      PROB  30/06/2023
#
#    unidade Q_unidades sit  extra     tipo   hora sem_ou_fds  \
# 0                   0             ENTRADA  04:30     semana
# 1  MORUMBI          1      extra    SAIDA  13:00     semana
#
#                 hora2 ENTRADA  SAIDA PERIODO DURAÇÃO  \
# 0 1900-01-01 04:30:00   04:30  07:00      6h   02:30
# 1 1900-01-01 12:35:00   13:00  13:00   tarde   00:00
#
#                           setor
# 0                  SEMANA - 6HS
# 1  SEMANA - TARDE - C.CIRURGICO

# %%
desloc
# Out:
#                                                 chat         dia  \
# 0  [29/06/2023 16:27:17] Marcelo Felipe de Souza ...  29/06/2023
# 1  [29/06/2023 17:16:59] Bianca Priscila Buniotti...  29/06/2023
# 2  [30/06/2023 05:17:59] Francisco Antonio Alves ...  30/06/2023
# 3  [30/06/2023 10:39:21] Gabriela Santos Menezes:...  30/06/2023
#
#                               nome  \
# 0     MARCELO FELIPE DE SOUZA BUTO
# 1         BIANCA PRISCILA BUNIOTTI
# 2  FRANCISCO ANTONIO ALVES BONATTO
# 3          GABRIELA SANTOS MENEZES
#
#                                             mensagem controle        data  \
# 0  29/06 OSASCO - BUTO SAIDA 16:20  ( DESLOCADO I...     PROB  29/06/2023
# 1  29/06 ITAIM - BIANCA SAIDA 15:30  ( PÓS PLANTÃ...     PROB  29/06/2023
# 2  30/06 ANÁLIA - FRANCISCO ENTRADA 05:10  ( DESL...     PROB  30/06/2023
# 3  30/06 OSASCO - G.MENEZES ENTRADA 06:20  ( DESL...     PROB  30/06/2023
#
#   unidade Q_unidades        sit extra     tipo   hora sem_ou_fds  \
# 0  OSASCO          2  DESLOCADO          SAIDA  16:30     semana
# 1   ITAIM          2  DESLOCADO          SAIDA  15:30     semana
# 2  ANALIA          2  DESLOCADO        ENTRADA  05:00     semana
# 3  OSASCO          2  DESLOCADO        ENTRADA  06:00     semana
#
#                 hora2 ENTRADA  SAIDA PERIODO DURAÇÃO  \
# 0 1900-01-01 16:20:00   13:00  16:30   tarde   03:30
# 1 1900-01-01 15:30:00   13:00  15:30   tarde   02:30
# 2 1900-01-01 05:10:00   05:00  07:00      6h   02:00
# 3 1900-01-01 06:20:00   06:00  07:00      6h   01:00
#
#                           setor
# 0  SEMANA - TARDE - C.CIRURGICO
# 1  SEMANA - TARDE - C.CIRURGICO
# 2                  SEMANA - 6HS
# 3                  SEMANA - 6HS

# %%
dispen
# Out:
#                                                 chat         dia  \
# 0  [30/06/2023 06:27:50] Yoko Hayashi: 30/06 Itai...  30/06/2023
#
#            nome                                           mensagem controle  \
# 0  YOKO HAYASHI  30/06 ITAIM YOKO  ( DISPENSADOPOR MOTIVO DE SA...     PROB
#
#          data unidade Q_unidades         sit extra tipo hora sem_ou_fds hora2  \
# 0  30/06/2023   ITAIM          1  DISPENSADO                     semana   NaT
#
#   ENTRADA SAIDA PERIODO
# 0     NaN   NaN     NaN

# %%
df = df[df['controle'] != "PROB"]
df.reset_index(drop=True, inplace=True)

# %%
len(df)
# Out:
# 130

# %%
len(prob)
# Out:
# 2

# %%
problemas_final = pd.concat([problemao, prob])
problemas_final.reset_index(drop=True, inplace=True)

# %%
len(problemas_final)
# Out:
# 5

# %%
problemas_final
# Out:
#                                                 chat         dia  \
# 0  [29/06/2023 15:06:29] Laysa Layna Ribeiro Lima...  29/06/2023
# 1  [29/06/2023 21:02:49] Lívia Schenkel Thurler T...  29/06/2023
# 2  [29/06/2023 21:38:50] Karen Yumi Miyashiro: 29...  29/06/2023
# 3  [30/06/2023 04:41:52] Izabela Cristina Almeida...  30/06/2023
# 4  [30/06/2023 12:48:23] Bianca Priscila Buniotti...  30/06/2023
#
#                               nome  \
# 0         LAYSA LAYNA RIBEIRO LIMA
# 1    LIVIA SCHENKEL THURLER TRAIRI
# 2             KAREN YUMI MIYASHIRO
# 3  IZABELA CRISTINA ALMEIDA DUARTE
# 4         BIANCA PRISCILA BUNIOTTI
#
#                                             mensagem controle        data  \
# 0  29/06 JABAQUARA LAYSA SAIDA 15H  ( POS PLANTÃO )      PROB  29/06/2023
# 1                          29/06 VILLA - LIVIA 20:50     PROB  29/06/2023
# 2                   29/06 VILLA - YUMI ENTRADA 20:40     PROB  29/06/2023
# 3                      30/06 JBQ DUARTE ENTRADA 4:30     PROB  30/06/2023
# 4     30/06 MORUMBI - BIANCA SAIDA 12:35  ( EXTRA )      PROB  30/06/2023
#
#    unidade Q_unidades sit  extra     tipo   hora sem_ou_fds  \
# 0     JABA          1               SAIDA            semana
# 1    VILLA          1                      20:50     semana
# 2    VILLA          1             ENTRADA  20:30     semana
# 3                   0             ENTRADA  04:30     semana
# 4  MORUMBI          1      extra    SAIDA  13:00     semana
#
#                 hora2 ENTRADA  SAIDA PERIODO DURAÇÃO  \
# 0                 NaT     NaN    NaN     NaN     NaN
# 1 1900-01-01 20:50:00                            NaN
# 2 1900-01-01 20:40:00   20:30                    NaN
# 3 1900-01-01 04:30:00   04:30  07:00      6h   02:30
# 4 1900-01-01 12:35:00   13:00  13:00   tarde   00:00
#
#                           setor
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                  SEMANA - 6HS
# 4  SEMANA - TARDE - C.CIRURGICO

# %% [markdown]
# ### PESQUISANDO PERÍODOS A EXCLUIR PÓS 13H

# %%
df['dt'] = pd.to_datetime(df['SAIDA'], format="%H:%M")

# %%
df['conferir'] = ""

# %%
for i in range(0, len(df)):
    if df['dt'][i].hour < 13 and df['dt'][i].hour !=0 and df['tipo'][i] == "SAIDA":
        df['conferir'][i] = "SIM"
    elif df['dt'][i].hour == 13 and df['dt'][i].minute == 0 and  df['tipo'][i] == "SAIDA":
        df['conferir'][i] = "SIM"
    else:
        pass

# %%
conferir = df[df['conferir'] == 'SIM']

# %%
conferir.reset_index(inplace=True, drop=True)
conferir
# Out:
#                                                 chat         dia  \
# 0  [30/06/2023 01:54:26] Leandro Oliveira Martins...  30/06/2023
# 1  [30/06/2023 11:54:09] Bruce Ye Man Chow: 30/06...  30/06/2023
#
#                               nome  \
# 0  LEANDRO OLIVEIRA MARTINS CORTES
# 1                BRUCE YE MAN CHOW
#
#                                             mensagem controle        data  \
# 0  29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂN...           29/06/2023
# 1      30/06 MORUMBI - BRUCE SAIDA 11:40  ( EXTRA )            30/06/2023
#
#      unidade Q_unidades sit  extra   tipo   hora sem_ou_fds  \
# 0  JABAQUARA          1             SAIDA  02:00     semana
# 1    MORUMBI          1      extra  SAIDA  12:00     semana
#
#                 hora2 ENTRADA  SAIDA        PERIODO DURAÇÃO  \
# 0 1900-01-01 01:50:00   19:00  02:00  noturno saida   07:00
# 1 1900-01-01 11:40:00   07:00  12:00          manha   05:00
#
#                           setor                  dt conferir
# 0      SEMANA - NOTURNO - SAIDA 1900-01-01 02:00:00      SIM
# 1  SEMANA - MANHA - C.CIRURGICO 1900-01-01 12:00:00      SIM

# %%
escala = pd.read_excel('Junho.xlsx')
escala.columns = ['nome','data','inicio','duracao']
escala = escala.replace("-",None, regex=True)
escala = escala.dropna()
escala['data'] = escala['data'].dt.strftime('%d/%m')
escala['nome'] = escala['nome'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
escala.reset_index(inplace=True, drop=True)

# %%
atencao = pd.DataFrame(columns=['nome','data'])

# %%
for i in range(0,len(escala)):
    for j in range(0,len(conferir)):
        if escala['nome'][i] == conferir['nome'][j] and escala['data'][i]+"/2023" == conferir['data'][j] and\
        escala['inicio'][i].hour == 13:
            atencao.loc[j] = [conferir['nome'][j], conferir['data'][j]]

# %%
atencao.reset_index(inplace=True, drop=True)
atencao

# %% [markdown]
# # Salvando:

# %%
df.to_excel("df_ok1.xlsx", index=False) #tudo que está certo
problemas_final.to_excel('df_giovarever1.xlsx', index=False) #tudo que é problema (inclui principalmente duração 00h do prob + oq sobrou problemao)

# %%
desloc.to_excel("desloc.xlsx", index=False) #todos deslocados
dispen.to_excel("dispen.xlsx", index=False) #todos dispensados

# %%
atencao.to_excel("apagar13.xlsx", index=False) #todos para apagar a tarde

# %%
conferir
# Out:
#                                                 chat         dia  \
# 0  [30/06/2023 01:54:26] Leandro Oliveira Martins...  30/06/2023
# 1  [30/06/2023 11:54:09] Bruce Ye Man Chow: 30/06...  30/06/2023
#
#                               nome  \
# 0  LEANDRO OLIVEIRA MARTINS CORTES
# 1                BRUCE YE MAN CHOW
#
#                                             mensagem controle        data  \
# 0  29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂN...           29/06/2023
# 1      30/06 MORUMBI - BRUCE SAIDA 11:40  ( EXTRA )            30/06/2023
#
#      unidade Q_unidades sit  extra   tipo   hora sem_ou_fds  \
# 0  JABAQUARA          1             SAIDA  02:00     semana
# 1    MORUMBI          1      extra  SAIDA  12:00     semana
#
#                 hora2 ENTRADA  SAIDA        PERIODO DURAÇÃO  \
# 0 1900-01-01 01:50:00   19:00  02:00  noturno saida   07:00
# 1 1900-01-01 11:40:00   07:00  12:00          manha   05:00
#
#                           setor                  dt conferir
# 0      SEMANA - NOTURNO - SAIDA 1900-01-01 02:00:00      SIM
# 1  SEMANA - MANHA - C.CIRURGICO 1900-01-01 12:00:00      SIM
