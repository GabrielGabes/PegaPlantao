# %%
#Definindo finais de semana
mes = "06"
sabado = "03/"+mes+"/2023"
domingo = "04/"+mes+"/2023"

# %%
#PACOTES
import pandas as pd #manipulação de dados
import numpy as np #matematica

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import unidecode #arrumar strings

import re #regex

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#lendo arquivo txt e transformando em dataframe cada mensagem
def read_file(file):
    '''Reads Whatsapp text file into a list of strings'''
    x = open(file, 'r', encoding = 'utf-8')
    y = x.read()
    content = y.splitlines()
    return content

chat = read_file('_chat.txt')
df = pd.DataFrame({'chat':chat})
df
# Out:
#                                                   chat
# 0    [01/06/2023 05:07:21] Sergio Zamith: 01/06 Jab...
# 1    [01/06/2023 05:12:07] Renata Togeiro Bastos Go...
# 2    [01/06/2023 05:19:30] Sheila Itiroco Monte: 01...
# 3    [01/06/2023 05:22:11] Alexandre Amaral Lucas: ...
# 4    [01/06/2023 05:30:07] Gretel Oliveira Nicolau:...
# ..                                                 ...
# 685  [07/06/2023 22:13:40] Rodrigo Andrade Carmello...
# 686  [07/06/2023 22:14:50] Thassio Cunha de Santana...
# 687  [07/06/2023 22:15:25] Thassio Cunha de Santana...
# 688  [07/06/2023 22:32:23] Marcelo Felipe de Souza ...
# 689  [07/06/2023 23:17:10] Carlos Augusto Trevisan:...
#
# [690 rows x 1 columns]

# %% [markdown]
# # CAPTURANDO INFORMAÇÕES:

# %%
#DIA QUE FOI ENVIADA A MENSAGEM
dia = []
for i in range(0, len(df['chat'])):
    dia.append(df['chat'][i][1:11]) #pegando exatamente aonde parte da data esta
df['dia'] = dia
df['dia'].unique()
# Out:
# array(['01/06/2023', '02/06/2023', '03/06/2023', '04/06/2023',
#        '05/06/2023', '06/06/2023', '07/06/2023'], dtype=object)

# %%
#NOME DO ANESTESISTA
nome = []
count = 0
for i in range(0, len(df['chat'])):
    loc = df['chat'][i].find(']')+1 #digito data
    loc2 = df['chat'][i][loc+1:].find(':')+1 #digito nome
    nome.append(unidecode.unidecode(df['chat'][i][loc+1:loc+loc2].upper()))
    count += 1
    #print(count, "->", unidecode.unidecode(chat[i][loc+1:loc+loc2].upper()))
df['nome'] = nome
df['nome'].unique()
# Out:
# array(['SERGIO ZAMITH', 'RENATA TOGEIRO BASTOS GODOY DE FARIA',
#        'SHEILA ITIROCO MONTE', 'ALEXANDRE AMARAL LUCAS',
#        'GRETEL OLIVEIRA NICOLAU', 'MARCELO FELIPE DE SOUZA BUTO',
#        'GABRIELA RODRIGUES MACHADO BORJA', 'DEBORA ALVES AUDE',
#        'LARISSA MAYUMI ONO', 'NATHALIA FANUCCI OLIVEIRA DI JORGE',
#        'LUDMYLLA GOMES NEVES',
#        'MARCIO IGHOR AZEVEDO SILVA DE MENDONCA MELANIA',
#        'RICARDO KAWAURA', 'LUCCAS VARELA GODOY',
#        'LAYSA LAYNA RIBEIRO LIMA', 'ARTHUR RODRIGUES TORRELIO',
#        'FABIO YUJI SUGUITA', 'KAIE FERNANDES',
#        'SILVIA ALINE DOS SANTOS ANDRADE', 'ARTHUR OLIVEIRA FACCHINI',
#        'EDUARDO DALA ROSA SOARES', 'ALESSANDRE LUIZ BRAGA JUNIOR',
#        'GABRIEL DE AGUIAR SANTANA', 'MARIANA GASPARELLI DE SOUZA',
#        'JESSICA LIDIA DE SOUZA', 'EMERSON DOMINGOS DA COSTA',
#        'ERICK OLIVEIRA OLIVEIRA LIMA GOMES', 'PAULA ANGELICA PINHA NEVES',
#        'RENATA PINHEIRO MODOLO', 'FABIANA SOARES GAMA',
#        'GABRIEL ELIAS GEWEHR SALMEN RAFFOUL', 'CARLOS AUGUSTO TREVISAN',
#        'HENRI ROGER WATANABE OLIVEIRA', 'ANA GABRIELA GEWEHR VALE SALMEN',
#        'EDUARDO ARBACHE BEZERRA', 'MARCELA LEITE ROSIGNOLI',
#        'LAURA SILVA ASSUNCAO MAPA', 'NORIVAL SCANDELAI JUNIOR',
#        'FILIPE LUGON MOULIN LIMA', 'FABIANA BARBOSA BASTOS',
#        'VIVIANNA BOVERIO GALZERANI', 'VITOR MACIEL DE SOUSA PINTO',
#        'JAIME ANDRES ARIAS CRIOLLO', 'RICARDO BARBOSA VIANA FILHO',
#        'PAOLA RODRIGUES OSHIRO', 'NATALIA MAIA QUEIROZ',
#        'MARIANA DARDENGO BORGES', 'ROGERIO SIDNEY THON',
#        'GABRIELLA GADELHA SARMENTO', 'THAIS BOSI NONATO',
#        'GUILHERME SILVEIRA COSTA', 'STEFANY HELLEN SOUSA MARTINS'],
#       dtype=object)

# %%
#MENSAGEM ESCRITA
mensagem = []
for i in range(0, len(df)):
    digito_data = df['chat'][i].find(']') #aonde acaba a data
    digito_nome = df['chat'][i][digito_data+1:].find(':')
    mensagem_escrevida = df['chat'][i][digito_data+digito_nome+3:]
    mensagem.append(mensagem_escrevida)
    
df['mensagem'] = mensagem
df['mensagem'].unique()
# Out:
# array(['01/06 Jabaquara- Zamith entrada 05:05.',
#        '01/06 MORUMBI - Renata Togeiro entrada 5:00',
#        '01/06 ITAIM Sheila entrada 05:15',
#        '01/06 Osasco - alexandre Amaral entrada 05:20',
#        '01/06 Analia- Gretel entrada 4: 40',
#        '01/06 VILLA - Buto entrada 5:20 (deslocado Itaim)',
#        '01/06 osasco - Borja entrada 05:30',
#        '01/06 Itaim Débora entrada 05:30',
#        '01/06 Osasco Larissa - entrada 05:30 (deslocada Itaim)',
#        '01/06 MORUMBI Nathália entrada 05:40',
#        '01/06 Analia- Ludmylla entrada 5:20',
#        '01/06 VILLA - Ighor entrada 05:30',
#        '01/06 Osasco kawaura entrada 6:00',
#        '01/06 Osasco Luccas entrada 6:00',
#        '31/05 Jabaquara Laysa saída 19:55',
#        '01/06 Morumbi Laysa entrada 6:00',
#        '01/06 OSASCO - Torrelio entrada 05:50',
#        '01/06 jabaquara yuji entrada 06:10',
#        '01/06 Itaim Kaie entrada 6:00',
#        '01/06 - Morumbi - Silvia entrada 06:00 (deslocada Itaim)',
#        '01/06 Aviccena Facchini entrada 06:20',
#        '01/06 Osasco - Coelho entrada 6:15',
#        '01/06 Jabaquara - Gomes entrada 05:50',
#        '01/06 Jabaquara Garcia entrada 6:00',
#        '01/06 itaim - bruce entrada 06:10',
#        '01/06 Jabaquara - Assunção entrada 06:00',
#        '01/06 Santa Isabel - T.Silva - entrada 06:00',
#        '01/06 Anália José Carlos Entrada 05:30',
#        '01/06 Osasco - G.Menezes entrada 06:00',
#        '01/06 Anália - Cadu entrada 06:00',
#        '01/06 VILLA - J. Hussein entrada 6:00',
#        '01/06 Morumbi - Yuri entrada 06:00 (deslocado VNS)',
#        '01/06 Itaim Daniel entrada 6:00',
#        '01/05 jabaquara Valverde entrada 5:40',
#        '01/05 Morumbi - Darlan entrada 05:50',
#        '01/05 Jabaquara - Kawan entrada 05:40',
#        '01/06 VILLA - França entrada 11:00',
#        '01/06 Aviccena Orlando saida 07:30 (motivo de saude)',
#        '01/06-Itaim-Sidney-entrada:06:00',
#        '01/06 Osasco Larissa - saída 12:45 (deslocada Itaim)',
#        '01/06 itaim bruce - saida 13:24',
#        '01/06 Santa Marcos saída 13:50',
#        '01/06- Jabaquara- Antipou- entrada 04:30 (deslocada Maternidade)',
#        '01/06- Jabaquara- Antipou- saída 14:20 (deslocada maternidade)',
#        '01/06 Jabaquara - Silveira saída 13:50',
#        '01/06 Santa Isabel - T. Silva saída 14:10',
#        '01/06 Villa - Buto saída 13:40 (deslocado Itaim)',
#        '01/06 OSASCO - Borja saída 14:25',
#        '01/06 Jabaquara - Kawan saída 14:41',
#        '01/06 Santa Isabel Manoel Saída 14:40',
#        '01/06 jabaquara yuji saída 14:50',
#        '01/06 Jabaquara -Zamith saída 14:50.',
#        '01/06 jabaquara Garcia saída 14:50',
#        '01/06 Jabaquara - Valverde saída 14:50',
#        '01/06 Maternidade - Kakuda saída 15:25',
#        '01/06 Osasco Luccas saída 15:20', '01/06 Analia Ana saída 15:30',
#        '01/06 VILLA - Ighor saída 15:35',
#        '01/06 Jabaquara - Gomes saída 15:35',
#        '01/06 Osasco - alexandre Amaral saída 15:10',
#        '01/06 Morumbi - Bianca saída 16:20 (pós plantão maternidade - deslocada Jabaquara)',
#        '01/06 Anália José Carlos Saída 16:45',
#        '01/06 VNS Barone saida 17:08',
#        '01/06 - Itaim - Ricardo Ivo Entrada - 06:00h (Deslocado Morumbi)',
#        '01/06 Morumbi - Yuri saída 17:00 (deslocado VNS)',
#        '01/06 - Itaim - Ricardo Ivo Saída - 17:00h (Deslocado Morumbi)',
#        '01/06 Osasco - G.Menezes saída 17:10',
#        '01/06 Santa Diego saida 17:10',
#        '01/06 Osasco - Torrelio saída 17:10',
#        '01/06 Anália Ludmylla Saída 16:05',
#        '01/06 Anália Diniz entrada 5:40',
#        '01/06 Anália Diniz saída 17:15',
#        '01/06 Itaim Rafael tadeu entrada: 6:00',
#        '01/06 - Morumbi - Silvia saída 17:45 (deslocada do Itaim)',
#        '01/06 - Analia- Gretel saida 16:10',
#        '01/06 Itaim Débora saída 19:15', '01/06 VNS Xavier saída 19:20',
#        '01/06 VNS - Oliveira saída 19:45',
#        '01/06 Jabaquara Sabrina saída 19:50',
#        '01/06 Jabaquara Viana saída 19:50',
#        '07/06 OSASCO - Miranda saída às 19h45',
#        '07/6-Itaim Olaio entrada 5:20', '07/6-Itaim Olaio saída 19:50',
#        '07/06 Analia Laysa saída 19h35',
#        '07/06 Osasco Larissa - saída 20:00',
#        '07/06 MORUMBI Nathália saída 20:10',
#        '07/06 Osasco Sapountzakis saída 20:21',
#        '07/06 MORUMBI - Anna Beatriz saída 18:10',
#        '07/06 Itaim - Gabriel saída 20:30',
#        '07/06 Analia - Garcia saída 17:50',
#        '07/06 Santa Marcos saída 20:50',
#        '07/06 Morumbi - Pedro saida 20:50h',
#        '07/06 Jabaquara - Helena Saída 20:55',
#        '07/06 - Villa - Alexandre - saída 21:05',
#        '07/06 - Itaim José Marcos saída 21:20',
#        '07/06 Itaim Zamith saída 21:15.',
#        '07/06 Osasco Lemes saída 21:20',
#        '07/06 Anália - Candeo saída 21:15',
#        '07/06 Morumbi - Carmello saída 22:10',
#        '07/06 Jabaquara - Thassio entrada 11:00',
#        '07/06 Jabaquara - Thassio saída 22:15',
#        '07/06 Jabaquara - Buto saída 22:25',
#        '07/06 ITAIM Carlos saída 21:05'], dtype=object)

# %%
#DATA DO PLANTÃO
df['controle'] = ''
df['data'] = ''
invalido =0 
for i in range(0, len(df)):
    lista_datas = re.findall(r'[0-9]{1,2}\/[0-9]{1,2}', df['mensagem'][i]) #regex dd/mm
    quantidade_itens = len(lista_datas)
    
    if quantidade_itens == 1: #capturar registros com uma data apenas
        df['data'][i] = lista_datas[0]
    else: #restante com nenhuma ou mais de uma data
        df['controle'][i] = 'PROB'
        invalido += 1
        
print(df['controle'].value_counts())
#print('mais de uma data: '+str(invalido))

df['data'].unique()
# Out:
#         688
# PROB      2
# Name: controle, dtype: int64
# mais de uma data: 2
# array(['01/06', '31/05', '01/05', '01/6', '02/06', '02/05', '02/6', '2/6',
#        '03/06', '03/6', '03/05', '04/06', '05/06', '', '5/6', '05/6',
#        '06/06', '06/6', '06/05', '6/6', '07/06', '07/05', '07/6'],
#       dtype=object)

# %% [markdown]
# # Obs registros:

# %%
df[df['controle'] == 'PROB']
# Out:
#                                                   chat         dia  \
# 361  [05/06/2023 05:53:16] Wangles Pignaton de Paul...  05/06/2023
# 536  [06/06/2023 18:00:45] Jaime Andres Arias Criol...  06/06/2023
#
#                            nome                                  mensagem  \
# 361   WANGLES PIGNATON DE PAULA       Deslocado Villa (cirurgia a pedido)
# 536  JAIME ANDRES ARIAS CRIOLLO  ‎Você removeu Jaime Andres Arias Criollo
#
#     controle data
# 361     PROB
# 536     PROB

# %%
#CAPTURANDO UNIDADE
df['unidade'] = ''
df['Q_unidades'] = ''
unidades = []

for i in range(0, len(df)):
    mensagem = unidecode.unidecode(df['mensagem'][i].upper())
    lista_unidades = re.findall(r'HSI|ANALIA|AVICCENA|ITAIM|JABA|MATERNIDADE|MORUMBI|OSASCO|VILLA|VNS|SANTA', mensagem)
    quantidade_unidades = len(lista_unidades)
    unidades.append(lista_unidades)
    
    df['Q_unidades'][i] = quantidade_unidades
    
    if quantidade_unidades >= 1: #capturando com unidades
        df['unidade'][i] = lista_unidades[0]
    elif quantidade_unidades == 0:
        df['controle'][i] = 'PROB'
        
print(df['Q_unidades'].value_counts(),'\n')
print("prob: "+str(len(df[df['controle'] == 'PROB'])))
# Out:
# 1    637
# 2     50
# 0      2
# 3      1
# Name: Q_unidades, dtype: int64
#
# prob: 3

# %%
prob = df[df['controle'] == 'PROB']
prob
# Out:
#                                                   chat         dia  \
# 361  [05/06/2023 05:53:16] Wangles Pignaton de Paul...  05/06/2023
# 528  [06/06/2023 17:03:21] Pedro Augusto Tavares Da...  06/06/2023
# 536  [06/06/2023 18:00:45] Jaime Andres Arias Criol...  06/06/2023
#
#                                  nome  \
# 361         WANGLES PIGNATON DE PAULA
# 528  PEDRO AUGUSTO TAVARES DALL AGLIO
# 536        JAIME ANDRES ARIAS CRIOLLO
#
#                                      mensagem controle   data unidade  \
# 361       Deslocado Villa (cirurgia a pedido)     PROB          VILLA
# 528    06/06 avicenna - Tavares - saída 16:40     PROB  06/06
# 536  ‎Você removeu Jaime Andres Arias Criollo     PROB
#
#     Q_unidades
# 361          1
# 528          0
# 536          0

# %%
#RETIRANDO REGISTROS DE DESLOCADOS, DISTANCIA E SAIDAS POR QUESTÃO DE SAUDE

#preparando para reconhecer corretamente
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('(',' ( '))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace(')',' ) '))
df['mensagem'] = df['mensagem'].apply(lambda x: x.upper())
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCADA','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCAMENTO','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSADA','DISPENSADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSA ','DISPENSADO'))
df['sit'] = ''


for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    observacoes = re.findall(r'DESLOCADO|DISPENSADO|SAUDE|DISTANCIA', mensagem)
    quantidade_observacoes = len(observacoes)
    
    if quantidade_observacoes > 0:
        df['controle'][i] = 'PROB'
        
for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    deslocado = re.findall(r'DESLOCADO', mensagem)
    dispensado = re.findall(r'DISPENSADO', mensagem)
    distancia = re.findall(r'DISTANCIA', mensagem)
    
    if len(deslocado) > 0:
        df['sit'][i] = "DESLOCADO"
    elif len(dispensado) > 0:
        df['sit'][i] = "DISPENSADO"
    elif len(distancia)  > 0:
        df['sit'][i] = "DISTANCIA"
    else:
        df['sit'][i] = ''
        
print(df['controle'].value_counts()) 
prob = df[df['controle'] == 'PROB']
# Out:
#         628
# PROB     62
# Name: controle, dtype: int64

# %%
prob
# Out:
#                                                   chat         dia  \
# 5    [01/06/2023 05:32:48] Marcelo Felipe de Souza ...  01/06/2023
# 8    [01/06/2023 05:41:18] Larissa Mayumi Ono: 01/0...  01/06/2023
# 19   [01/06/2023 06:20:00] Silvia Aline dos Santos ...  01/06/2023
# 503     VILLA          1  DISPENSADO
# 507     ITAIM          1  DISPENSADO
# 522     ITAIM          2   DESLOCADO
# 528                    0
# 536                    0
# 558     SANTA          2   DESLOCADO
# 559     SANTA          2   DESLOCADO
# 584      JABA          2   DESLOCADO
# 594    OSASCO          2   DESLOCADO
# 600      JABA          2   DESLOCADO
# 623      JABA          2   DESLOCADO
# 628    OSASCO          2   DESLOCADO
# 629    ANALIA          2   DESLOCADO
# 630      JABA          1  DISPENSADO
# 631    ANALIA          1  DISPENSADO
# 633    ANALIA          1  DISPENSADO
# 637      JABA          2   DESLOCADO
# 644     SANTA          2   DESLOCADO
# 658    ANALIA          2   DESLOCADO

# %%
#VERIFICANDO SE É EXTRA
df["extra"] = ''

for i in range(0, len(df)):
    if 'EXTRA' in df['mensagem'][i].upper(): #se contiver a palavra "extra"
        df['extra'][i] = 'extra' #marque na coluna extra como extra
        
print(df['extra'].value_counts()        )
# Out:
#          680
# extra     10
# Name: extra, dtype: int64

# %% [markdown]
# # Tipo entrada e saida:

# %%
#Indentificando se é um registro de entrada ou saida
df['tipo'] = ''
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('SAÍDA','SAIDA'))
invalido = 0
for i in range(0, len(df)):
    mensagem = df['mensagem'][i]
    entradas_saidas = re.findall(r'ENTRADA|SAIDA', mensagem)
    quantidade_entradas_saidas = len(entradas_saidas)
    
    if quantidade_entradas_saidas != 1: #capturando apenas com uma informação escrita
        df['controle'][i] = 'PROB'
        invalido += 1
    else: #restante com mais de uma informação
        df['tipo'][i] = entradas_saidas[0]
        
print(df['tipo'].value_counts())        
print(df['controle'].value_counts())
print('entrada e saída junto: '+str(invalido))

prob = df[df['controle'] == 'PROB']
# Out:
# SAIDA      419
# ENTRADA    253
#             18
# Name: tipo, dtype: int64
#         622
# PROB     68
# Name: controle, dtype: int64
# entrada e saída junto: 18

# %%
prob

# %% [markdown]
# # Data:

# %%
#retirando a data da mensagem para não atrapalhar no reconhecimento de hora
df['hora'] = ''

for i in range(0, len(df)):
    df['hora'][i] = df['mensagem'][i].replace(df['data'][i], '').strip() #substituindo a data por vazio

# %%
#arrumando data d/mm (6/10, não 06/10)
for i in range(0, len(df)):
    if df['data'][i] != "" and df['data'][i][1] == '/':
        df['data'][i] = '0'+df['data'][i]
df['data'].unique()
# Out:
# array(['01/06', '31/05', '01/05', '01/6', '02/06', '02/05', '02/6',
#        '03/06', '03/6', '03/05', '04/06', '05/06', '', '05/6', '06/06',
#        '06/6', '06/05', '07/06', '07/05', '07/6'], dtype=object)

# %%
#somando informações restantes na data: dd/MM/yyyy
for i in range(0, len(df)):
    df['data'][i] = df['data'][i][0:2] + "/"+ mes +"/2023" 
    
print(df['data'].unique())
# Out:
# ['01/06/2023' '31/06/2023' '02/06/2023' '03/06/2023' '04/06/2023'
#  '05/06/2023' '/06/2023' '06/06/2023' '07/06/2023']

# %%
df['sem_ou_fds'] = 'semana'

df.loc[(df['data'] == sabado) | (df['data'] == domingo), 'sem_ou_fds'] = 'fds'

df['sem_ou_fds'].value_counts()
# Out:
# semana    566
# fds       124
# Name: sem_ou_fds, dtype: int64

# %%
df

# %% [markdown]
# # Hora:

# %%
#substituindo "h" por ":" para capturar horarios 11h22
df['hora'] = df['hora'].apply(lambda x: x.upper().replace("H", ":"))

# %%
invalido = 0
for i in range(0, len(df)):
    mensagem = df['hora'][i]
    horas = re.findall(r'[0-9]{1,2}:[0-9]{1,2}', mensagem) #capturando horas HH:mm
    quantidade_horas = len(horas)

    if quantidade_horas == 1: #capturando apenas com uma horas escrita
        df['hora'][i] = horas[0]
    else: #restante com nenhuma ou mais horas (geralmente pq digitou a hora de entrada e saida {informação inutil})
        df['hora'][i] = ''
        df['controle'][i] = 'PROB'
        invalido += 1
        
print(df['controle'].value_counts())
print('mais de uma hora ou nenhuma hora: '+str(invalido))
prob = df[df['controle'] == "PROB"]
# Out:
#         617
# PROB     73
# Name: controle, dtype: int64
# mais de uma hora ou nenhuma hora: 19

# %%
len(prob)
# Out:
# 73

# %%
len(df[df['hora'] == ""])
# Out:
# 19

# %%
#adicionando 0 no primeiro algorismo dos valores h:mm
for i in range(0, len(df)):
    if df['hora'][i] != "" and df['hora'][i][1] == ":":
        df['hora'][i] = "0"+df['hora'][i]
        
df['hora'].unique()
# Out:
# array(['05:05', '05:00', '05:15', '05:20', '', '05:30', '05:40', '06:00',
#        '19:55', '05:50', '06:10', '06:20', '06:15', '11:00', '07:30',
#        '12:45', '13:24', '13:50', '04:30', '14:20', '14:10', '13:40',
#        '14:25', '14:41', '14:40', '14:50', '15:25', '15:20', '15:30',
#        '15:35', '15:10', '16:20', '16:45', '17:08', '17:00', '17:10',
#        '16:05', '17:15', '17:45', '16:10', '19:15', '19:20', '19:45',
#        '19:50', '19:35', '19:40', '20:08', '20:10', '20:15', '20:35',
#        '20:41', '20:05', '20:45', '20:50', '21:00', '20:40', '21:15',
#        '21:10', '21:20', '21:40', '21:35', '21:50', '21:55', '22:25',
#        '22:40', '22:50', '04:20', '04:40', '05:25', '05:35', '05:45',
#        '07:00', '08:50', '10:50', '13:30', '14:45', '15:15', '15:40',
#        '08:25', '15:45', '16:25', '16:40', '16:50', '16:55', '17:05',
#        '17:25', '17:40', '19:10', '19:30', '20:00', '20:20', '20:30',
#        '17:13', '21:30', '21:36', '22:00', '22:10', '22:37', '23:00',
#        '23:05', '06:05', '08:20', '10:15', '10:17', '10:20', '10:45',
#        '11:10', '11:20', '11:40', '11:30', '11:50', '12:00', '12:05',
#        '12:10', '12:25', '12:40', '13:15', '13:25', '13:20', '13:35',
#        '13:00', '13:55', '14:52', '15:00', '14:35', '16:15', '16:30',
#        '13:45', '17:20', '17:30', '18:18', '18:00', '18:32', '18:40',
#        '18:43', '19:25', '13:10', '18:35', '08:00', '04:15', '04:45',
#        '09:45', '09:50', '10:10', '10:25', '10:40', '12:55', '14:05',
#        '14:30', '16:24', '16:00', '17:55', '19:38', '18:20', '20:04',
#        '20:13', '21:45', '23:10', '23:31', '06:30', '08:30', '10:21',
#        '10:55', '11:55', '15:42', '16:54', '06:40', '14:15', '14:55',
#        '17:50', '20:21', '18:10', '20:55', '21:05', '22:15'], dtype=object)

# %% [markdown]
# # Hora final:

# %%
#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %%
len(df)
# Out:
# 690

# %%
prob_hora['chat'][18]
# Out:
# '[07/06/2023 14:16:51] Natan Soares Silveira: 05/06 Anália - Natan - dispensado'

# %%
prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
prob_hora = df[df['hora'] == ""] #zero ou mais de uma hora
prob_hora.reset_index(drop=True, inplace=True)
df = df[df['hora'] != ""] #df passa a ter ainda os prob, mas sem incluir os prob de hora
df.reset_index(drop=True, inplace=True)
print("prob: "+str(len(prob)))
print("prob_hora: "+str(len(prob_hora)))
print("df: "+str(len(df)))
# Out:
# prob: 73
# prob_hora: 19
# df: 671

# %%
#criando uma coluna datetime para fazer calculos de horas e minutos
df['hora2'] = df['hora'].apply(lambda x: datetime.strptime(x, '%H:%M'))

#verificando se esta tudo certo
print(df['hora2'].dt.year.unique())
print(df['hora2'].dt.month.unique())
print(df['hora2'].dt.day.unique())
print(df['hora2'].dt.hour.unique())

for i in range(0, len(df)):
    minuto = int(df['hora'][i][3:])
    
    if minuto != 0 and minuto != 30:
        if minuto < 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (0) subtraindo quantos minutos tem entre o momento e HH:00
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-minuto))[11:-3]
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (30) acrecentando quantos minutos faltam para HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(30-minuto)))[11:-3]
            else:
                df['controle'][i] = 'PROB'
                
        elif minuto > 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (30) subtraindo quando minutos tem entre o momento e HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-(minuto-30)))[11:-3]   
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (60) acrecentando quantos minutos faltam para HH:60
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(60-minuto)))[11:-3]            
            else:
                df['controle'][i] = 'PROB'
        else:
            df['controle'][i] = 'PROB'
            
    elif minuto == 0 or minuto == 30:
        df['hora'][i] = str(df['hora2'][i])[11:-3] 
        
    else:
        df['controle'][i] = 'PROB'
        
df['hora'].unique()
# Out:
# [1900]
# [1]
# [1]
# [ 5  6 19 11  7 12 13  4 14 15 16 17 20 21 22  8 10 23 18  9]
# array(['05:00', '05:30', '06:00', '20:00', '11:00', '07:30', '13:00',
#        '13:30', '14:00', '04:30', '14:30', '15:00', '15:30', '16:00',
#        '16:30', '17:00', '17:30', '18:00', '19:30', '20:30', '21:00',
#        '21:30', '21:10', '22:00', '22:30', '23:00', '04:00', '07:00',
#        '09:00', '08:30', '23:30', '10:30', '11:30', '12:00', '12:30',
#        '18:30', '19:00', '08:00', '10:00', '19:38', '00:00', '06:30',
#        '14:15'], dtype=object)

# %% [markdown]
# # Setor:

# %%
df['hora'][i][:2]
# Out:
# '21'

# %%
#reconhendo em qual periodo do dia aconteceu o plantão
df['ENTRADA'] = ''
df['SAIDA'] = ''
df['PERIODO'] = ''

for i in range(0, len(df)):
    minuto = int(df['hora'][i][:2])
    
    if df['tipo'][i] == 'ENTRADA':
        df['ENTRADA'][i] = df['hora'][i]
        if minuto < 7: #periodo 6h
            df['PERIODO'][i] = '6h'
            df['SAIDA'][i] = '07:00'
        elif minuto >= 7 and minuto < 13: #periodo manha
            df['PERIODO'][i] = 'manha'
            df['SAIDA'][i] = '13:00'
        elif minuto >= 13 and minuto < 19: #periodo tarde
            df['PERIODO'][i] = 'tarde'
            df['SAIDA'][i] = '19:00'
        else:
            df['controle'][i] = 'PROB'
    elif df['tipo'][i] == 'SAIDA':
        df['SAIDA'][i] = df['hora'][i]
        if minuto >= 7 and minuto <= 13: #periodo manha
            df['ENTRADA'][i] = '07:00'
            df['PERIODO'][i] = 'manha'
        elif minuto > 13 and minuto <= 19: #periodo tarde
            df['ENTRADA'][i] = '13:00'
            df['PERIODO'][i] = 'tarde'
        elif minuto > 19: #periodo noturno
            df['ENTRADA'][i] = '19:00'
            df['PERIODO'][i] = 'noturno saida'
        elif minuto <= 2: #periodo noturno
            df['ENTRADA'][i] = '19:00'
            df['PERIODO'][i] = 'noturno saida'
        else:
            df['controle'][i] = 'PROB'
    else:
        df['controle'][i] = 'PROB'
        
df['PERIODO'].value_counts()

print(df['controle'].value_counts())

prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
print("probs:", len(prob))
# Out:
#         617
# PROB     54
# Name: controle, dtype: int64
# probs: 54

# %%
prob

# %%
prob.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)
print("prob: "+str(len(prob)))
print("prob_hora: "+str(len(prob_hora)))
print("df: "+str(len(df)))
# Out:
# prob: 54
# prob_hora: 19
# df: 671

# %%
prob_dura = df[(df['SAIDA'] == "" )|  (df['ENTRADA'] == "")] #prob_dura: sem entrada ou saída
df = df[df['ENTRADA'] != ""]
df = df[df['SAIDA'] != ""]  ## retiro sem ENTRADA OU SEM SAÍDA
df.reset_index(drop=True, inplace=True)
prob_dura.reset_index(drop=True, inplace=True)

# %%
print(len(df))
print(len(prob_dura))
# Out:
# 667
# 4

# %%
problemao = pd.concat([prob_hora, prob_dura]) #problemao = prob mais de uma hora, nenhuma hora , nenhuma entrada ou saída
problemao.reset_index(drop=True, inplace=True) #todo problemao já não faz parte de df
problemao
# Out:
#                                                  chat         dia  \
# 0   [01/06/2023 05:30:07] Gretel Oliveira Nicolau:...  01/06/2023
# 1   [01/06/2023 20:25:49] Lívia Schenkel Thurler T...  01/06/2023
# 2   [02/06/2023 05:14:39] Andréia Loureiro Mori: 0...  02/06/2023
# 3   [02/06/2023 06:03:29] Thaís Miranda Ramos: 02/...  02/06/2023
# 4   [02/06/2023 12:17:22] Francisco José Lucena Be...  02/06/2023
# 5   [02/06/2023 17:09:16] Thaís Miranda Ramos: 02/...  02/06/2023
# 6             DESLOCADO VILLA  ( CIRURGIA A PEDIDO )      PROB    /06/2023
# 7   05/06 VILLA/OSASCO- CAVICHINI DISPENSADO  ( PÓ...     PROB  05/06/2023
# 8   05/06 VILLA - RENATA BUENO ENTRADA 11:00 SAIDA...     PROB  05/06/2023
# 9   05/06 - OSASCO - TAVARES  (  DISPENSADO PÓS PL...     PROB  05/06/2023
# 10                06/06 JABAQUARA - THALES DISPENSADO     PROB  06/06/2023
# 11                 06/06 MORUMBI - FABIANA DISPENSADO     PROB  06/06/2023
# 12                      06/06 VILLA CAMILA DISPENSADO     PROB  06/06/2023
# 13                    06/06 ITAIM VIVIANNA DISPENSADO     PROB  06/06/2023
# 14                      06/06 ITAIM FABIO ENTRADA 6HS     PROB  06/06/2023
# 15           ‎VOCÊ REMOVEU JAIME ANDRES ARIAS CRIOLLO     PROB    /06/2023
# 16          07/06 JABAQUARA - FILIPE LUGON DISPENSADO     PROB  07/06/2023
# 17         07/06 ANÁLIA - VALE DISPENSADO  ( SAÚDE )      PROB  07/06/2023
# 18                  05/06 ANÁLIA - NATAN - DISPENSADO     PROB  05/06/2023
# 19                        01/06 OSASCO - COELHO 21:10     PROB  01/06/2023
# 20          05/06 VNS FÁBIO ENTRADA 6HS E SAIDA 19:38     PROB  05/06/2023
# 21                     07/06 - OSASCO - PEREIRA 06:00     PROB  07/06/2023
# 22  07/06 ITAIM FABIO ENTRADA 7HS E SAIDA 14:15  (...     PROB  07/06/2023
#
#     unidade Q_unidades         sit extra     tipo   hora sem_ou_fds  \
# 0    ANALIA          1                    ENTRADA            semana
# 1     VILLA          1                                       semana
# 2      JABA          1                    ENTRADA            semana
# 3    OSASCO          1                    ENTRADA            semana
# 4     SANTA          1  DISPENSADO                           semana
# 5    OSASCO          1                      SAIDA            semana
# 6     VILLA          1   DESLOCADO                           semana
# 7     VILLA          2  DISPENSADO                           semana
# 8     VILLA          1                                       semana
# 9    OSASCO          2  DISPENSADO                           semana
# 10     JABA          1  DISPENSADO                           semana
# 11  MORUMBI          1  DISPENSADO                           semana
# 12    VILLA          1  DISPENSADO                           semana
# 13    ITAIM          1  DISPENSADO                           semana
# 14    ITAIM          1                    ENTRADA            semana
# 15                   0                                       semana
# 16     JABA          1  DISPENSADO                           semana
# 17   ANALIA          1  DISPENSADO                           semana
# 18   ANALIA          1  DISPENSADO                           semana
# 19   OSASCO          1                             21:10     semana
# 20      VNS          1                             19:38     semana
# 21   OSASCO          1                             06:00     semana
# 22    ITAIM          1                             14:15     semana
#
#                  hora2 ENTRADA SAIDA PERIODO
# 0                  NaT     NaN   NaN     NaN
# 1                  NaT     NaN   NaN     NaN
# 2                  NaT     NaN   NaN     NaN
# 3                  NaT     NaN   NaN     NaN
# 4                  NaT     NaN   NaN     NaN
# 5                  NaT     NaN   NaN     NaN
# 6                  NaT     NaN   NaN     NaN
# 7                  NaT     NaN   NaN     NaN
# 8                  NaT     NaN   NaN     NaN
# 9                  NaT     NaN   NaN     NaN
# 10                 NaT     NaN   NaN     NaN
# 11                 NaT     NaN   NaN     NaN
# 12                 NaT     NaN   NaN     NaN
# 13                 NaT     NaN   NaN     NaN
# 14                 NaT     NaN   NaN     NaN
# 15                 NaT     NaN   NaN     NaN
# 16                 NaT     NaN   NaN     NaN
# 17                 NaT     NaN   NaN     NaN
# 18                 NaT     NaN   NaN     NaN
# 19 1900-01-01 21:10:00
# 20 1900-01-01 19:38:00
# 21 1900-01-01 06:00:00
# 22 1900-01-01 14:15:00

# %%
### PROB CONTINUA DENTRO DO DF
### PROBLEMAO É SOMA DE PROBLEMAS QUE SAÍRAM DO DF: NÃO TINHAM HORA + ERRO ENTRADA OU SAÍDA

# %%
#DURAÇÃO DO PLANTÃO
df['DURAÇÃO'] = ''

for i in range(0, len(df)):
    diferenca_tempo = datetime.strptime(df['SAIDA'][i], '%H:%M') - datetime.strptime(df['ENTRADA'][i], '%H:%M')
    
    #diferenca_tempo vem em formato estranho, tem-se que transformar em segundos antes
    diferenca_tempo_s = diferenca_tempo.seconds
    horas = '0' + str(int((diferenca_tempo_s/60)/60)) #capturando horas
    minutos = str(int((diferenca_tempo_s/60)%60))  #capturando minutos
    
    if len(minutos) == 1:
        minutos = '0' + minutos
    
    df['DURAÇÃO'][i] = horas + ':' + minutos
    
df['DURAÇÃO'].unique()
# Out:
# array(['02:00', '01:30', '01:00', '00:30', '06:00', '06:30', '02:30',
#        '03:00', '03:30', '04:00', '04:30', '05:00', '05:30'], dtype=object)

# %%
df['setor'] = ''

for i in range(0, len(df)):
    if df['sem_ou_fds'][i] == 'semana':
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'SEMANA - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'SEMANA - MANHA - C.CIRURGICO'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'SEMANA - TARDE - C.CIRURGICO'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'SEMANA - NOTURNO - SAIDA'
        else:
            df['setor'][i] = 'VERIFICAR'

    elif df['sem_ou_fds'][i] == 'fds': 
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'FDS - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'FDS - C.CIRURGICO ROTINA'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'FDS - SAIDA'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'FDS - PLANTAO'
        else:
            df['setor'][i] = 'VERIFICAR'  

    else:
        df['setor'][i] = 'VERIFICAR'
        
df['setor'].value_counts()
# Out:
# SEMANA - 6HS                    198
# SEMANA - TARDE - C.CIRURGICO    167
# SEMANA - NOTURNO - SAIDA        141
# FDS - SAIDA                      44
# FDS - 6HS                        40
# SEMANA - MANHA - C.CIRURGICO     37
# FDS - C.CIRURGICO ROTINA         36
# FDS - PLANTAO                     4
# Name: setor, dtype: int64

# %%
print("prob:", len(prob)) #ainda dentro de df
print("problemao:", len(problemao)) #fora de df
print("df:", len(df)) #todo df
# Out:
# prob: 54
# problemao: 23
# df: 667

# %%
df[df['SAIDA'] == "00:30"]
# Out:
# Empty DataFrame
# Columns: [chat, dia, nome, mensagem, controle, data, unidade, Q_unidades, sit, extra, tipo, hora, sem_ou_fds, hora2, ENTRADA, SAIDA, PERIODO, DURAÇÃO, setor]
# Index: []

# %% [markdown]
# # Ultimos ajustes:

# %%
# Distancias
for i in range(0, len(df)):
    mensagem = df['mensagem'][i].upper()
    regex_D = re.findall('D[0-9]', mensagem)
    
    if len(regex_D) == 0:
        continue
    else:
        df['controle'][i] == 'PROB'

# %%
for i in range(0, len(df)):
    if df['DURAÇÃO'][i] == "00:00" :
        df['controle'][i] = "PROB"
        
print(df['controle'].value_counts())
# Out:
#         617
# PROB     50
# Name: controle, dtype: int64

# %%
df['setor'] = df['setor'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))
df['unidade'] = df['unidade'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))

df['unidade'] = df['unidade'].apply(lambda x: x.replace('JABA','JABAQUARA'))

df['unidade'] = df['unidade'].apply(lambda x: x.replace('SANTA','SANTA ISABEL'))

df['unidade'].unique()

#problemas com santa isabel 
#df['setor'][(df['unidade'] == "SANTA ISABEL") & (df['setor'] == "FDS - SAIDA")] = "FDS - NOTURNO - SAIDA"
df['setor'][(df['unidade'] == "SANTA ISABEL") & (df['setor'] == "FDS - C.CIRURGICO ROTINA")] = "FDS - MANHA - C.CIRURGICO"

# %%
#df['UNIDADE'] = df['UNIDADE'].apply(lambda x: x.replace('JABA','JABAQUARA'))
df['nome'] = df['nome'].apply(lambda x: x.replace('  ',' '))

#df['UNIDADE'] = df['UNIDADE'].apply(lambda x: x.replace('JABAQUARAQUARA','JABAQUARA'))
#df['UNIDADE'].unique()

# %%
#problemao - erro hora (mais de 1 ou nenhum), entrada saída
#prob: inclui deslocado, possível dispensa (maioria dentro de problemao) e duração 00h
#df ainda inclui prob

# %%
desloc = df[df['sit'] == 'DESLOCADO']
dispen = problemao[problemao['sit'] == 'DISPENSADO']
desloc.reset_index(inplace=True, drop=True)
dispen.reset_index(inplace=True, drop=True)

# %%
len(df)
# Out:
# 667

# %%
len(desloc)
# Out:
# 48

# %%
problemao = problemao[problemao['sit'] != 'DISPENSADO']
df = df[df['sit'] != 'DESLOCADO']
prob = df[df['controle'] == "PROB"]
prob.reset_index(drop=True, inplace=True)
df.reset_index(drop=True, inplace=True)
problemao.reset_index(drop=True, inplace=True)

# %%
len(df)

# %%
problemao

# %%
prob ##inclúido ainda no df

# %%
desloc

# %%
dispen

# %%
df = df[df['controle'] != "PROB"]
df.reset_index(drop=True, inplace=True)

# %%
len(df)
# Out:
# 617

# %%
len(prob)
# Out:
# 2

# %%
problemas_final = pd.concat([problemao, prob])
problemas_final.reset_index(drop=True, inplace=True)

# %%
len(problemas_final)

# %%
problemas_final

# %% [markdown]
# ### PESQUISANDO PERÍODOS A EXCLUIR PÓS 13H

# %%
df['dt'] = pd.to_datetime(df['SAIDA'], format="%H:%M")

# %%
df['conferir'] = ""

# %%
# 21      FDS - C.CIRURGICO ROTINA 1900-01-01 13:00:00      SIM
# 22      FDS - C.CIRURGICO ROTINA 1900-01-01 08:00:00      SIM
# 23      FDS - C.CIRURGICO ROTINA 1900-01-01 12:30:00      SIM
# 24  SEMANA - MANHA - C.CIRURGICO 1900-01-01 10:30:00      SIM
# 25  SEMANA - MANHA - C.CIRURGICO 1900-01-01 10:00:00      SIM
# 26  SEMANA - MANHA - C.CIRURGICO 1900-01-01 10:30:00      SIM
# 27  SEMANA - MANHA - C.CIRURGICO 1900-01-01 10:30:00      SIM
# 28  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:00:00      SIM
# 29  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:00:00      SIM
# 30  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:30:00      SIM
# 31  SEMANA - MANHA - C.CIRURGICO 1900-01-01 13:00:00      SIM
# 32  SEMANA - MANHA - C.CIRURGICO 1900-01-01 13:00:00      SIM
# 33  SEMANA - MANHA - C.CIRURGICO 1900-01-01 10:30:00      SIM
# 34  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:00:00      SIM
# 35  SEMANA - MANHA - C.CIRURGICO 1900-01-01 12:00:00      SIM
# 36  SEMANA - MANHA - C.CIRURGICO 1900-01-01 12:00:00      SIM
# 37  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:00:00      SIM
# 38  SEMANA - MANHA - C.CIRURGICO 1900-01-01 11:00:00      SIM
# 39  SEMANA - MANHA - C.CIRURGICO 1900-01-01 12:30:00      SIM

# %%
escala = pd.read_excel('Junho.xlsx')
escala.columns = ['nome','data','inicio','duracao']
escala = escala.replace("-",None, regex=True)
escala = escala.dropna()
escala['data'] = escala['data'].dt.strftime('%d/%m')
escala['nome'] = escala['nome'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
escala.reset_index(inplace=True, drop=True)

# %%
atencao = pd.DataFrame(columns=['nome','data'])

# %%
for i in range(0,len(escala)):
    for j in range(0,len(conferir)):
        if escala['nome'][i] == conferir['nome'][j] and escala['data'][i]+"/2023" == conferir['data'][j] and\
        escala['inicio'][i].hour == 13:
            atencao.loc[j] = [conferir['nome'][j], conferir['data'][j]]

# %%
atencao.reset_index(inplace=True, drop=True)
atencao

# %% [markdown]
# # Salvando:

# %%
df.to_excel("df_ok1.xlsx", index=False) #tudo que está certo

# %%
df.to_excel("df_ok1.xlsx", index=False) #tudo que está certo
problemas_final.to_excel('df_giovarever1.xlsx', index=False) #tudo que é problema (inclui principalmente duração 00h do prob + oq sobrou problemao)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13472\4008440242.py in <module>
#       1 df.to_excel("df_ok1.xlsx", index=False) #tudo que está certo
# ----> 2 problemas_final.to_excel('df_giovarever1.xlsx', index=False) #tudo que é problema (inclui principalmente duração 00h do prob + oq sobrou problemao)
#
# NameError: name 'problemas_final' is not defined

# %%
desloc.to_excel("desloc.xlsx", index=False) #todos deslocados
dispen.to_excel("dispen.xlsx", index=False) #todos dispensados

# %%
atencao.to_excel("apagar13.xlsx", index=False) #todos para apagar a tarde

# %%
conferir
