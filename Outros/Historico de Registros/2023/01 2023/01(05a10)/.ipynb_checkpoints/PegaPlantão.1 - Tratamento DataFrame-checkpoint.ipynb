# %%
#Definindo finais de semana
sabado = "07/01/2023"
domingo = "08/01/2023"
mes = "01"

# %%
#PACOTES
import pandas as pd #manipulação de dados
import numpy as np #matematica

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import unidecode #arrumar strings

import re #regex

# %%
#lendo arquivo txt e transformando em dataframe cada mensagem
def read_file(file):
    '''Reads Whatsapp text file into a list of strings'''
    x = open(file,'r', encoding = 'utf-8')
    y = x.read()
    content = y.splitlines()
    return content

chat = read_file('_chat.txt')
df = pd.DataFrame({'chat':chat})
df
# Out:
#                                                   chat
# 0    [05/01/2023 15:06:00] Thiago Silva Pinto: 05/0...
# 1    [05/01/2023 15:18:34] Yoko Hayashi: 05/01 Osas...
# 2    [05/01/2023 15:22:44] Marcio Ighor Azevedo Sil...
# 3    [05/01/2023 15:47:38] Manoel de Souza Neto: 05...
# 4    [05/01/2023 15:52:32] Nathalia Fanucci Oliveir...
# ..                                                 ...
# 392  [10/01/2023 08:44:24] Mariana Gasparelli de So...
# 393  [10/01/2023 08:50:48] Ronald Figueiredo Gomes:...
# 394  [10/01/2023 09:35:38] Rodrigo Miyashiro Nunes ...
# 395  [10/01/2023 09:42:26] Fernando Akira Koga: 10/...
# 396  [10/01/2023 09:51:47] Filipe Maeda Hashi Abdal...
#
# [397 rows x 1 columns]

# %% [markdown]
# # CAPTURANDO INFORMAÇÕES:

# %%
#DIA QUE FOI ENVIADA A MENSAGEM
dia = []
for i in range(0, len(df['chat'])):
    dia.append(df['chat'][i][1:11]) #pegando exatamente aonde parte da data esta
df['dia'] = dia
df['dia'].unique()
# Out:
# array(['05/01/2023', '06/01/2023', '07/01/2023', '08/01/2023',
#        '09/01/2023', '10/01/2023'], dtype=object)

# %%
#NOME DO ANESTESISTA
nome = []
count = 0
for i in range(0, len(df['chat'])):
    loc = df['chat'][i].find(']')+1 #digito data
    loc2 = df['chat'][i][loc+1:].find(':')+1 #digito nome
    nome.append(unidecode.unidecode(df['chat'][i][loc+1:loc+loc2].upper()))
    count += 1
    #print(count, "->", unidecode.unidecode(chat[i][loc+1:loc+loc2].upper()))
df['nome'] = nome
df['nome'].unique()
# Out:
# array(['THIAGO SILVA PINTO', 'YOKO HAYASHI',
#        'MARCIO IGHOR AZEVEDO SILVA DE MENDONCA MELANIA',
#        'MANOEL DE SOUZA NETO', 'NATHALIA FANUCCI OLIVEIRA DI JORGE',
#        'ALESSANDRE LUIZ BRAGA JUNIOR', 'KAREN YUMI MIYASHIRO',
#        'NATAN SOARES SILVEIRA', 'SIDNEY ORLANDO DE SOUZA',
#        'MARCELO FELIPE DE SOUZA BUTO', 'ANDRE MORTARI PLA GIL',
#        'FLAVIO HIDEKI OSHIKA', 'DIEGO DA CUNHA TOMAZ',
#        'KAREN PEIXOTO RICCI', 'KAIE FERNANDES', 'RONALD FIGUEIREDO GOMES',
#        'ANNA BEATRIZ ARANHA TREVISAN', 'JOAO THEODORO DE MEDEIROS NETO',
#        'MARCOS ROGERIO PEREIRA MACHADO FILHO', 'LARISSA MAYUMI ONO',
#        'SILVIA ALINE DOS SANTOS ANDRADE', 'ESTANRLEY BARCELOS PINTO',
#        'RICARDO GIRALDELLI CARVALHO LIMA', 'HEDICLEBER PESTANA SEVERINO',
#        'RENATA PINHEIRO MODOLO', 'ANNA BEATRIZ LIMA DO VALLE ASTUR',
#        'MAURICIO FARIA TETTI', 'MARINA PONTES MOURA NASCIMENTO E SILVA',
#        'CAMILA CHIARANTANO HARRISON', 'FABIANA SOARES GAMA',
#        'GRETEL OLIVEIRA NICOLAU', 'PEDRO TIAGO BONFITTO',
#        'RICARDO BARBOSA VIANA FILHO', 'LUDMYLLA GOMES NEVES',
#        'ALVARO LAZARO RAO REGONATO', 'VITOR MACIEL DE SOUSA PINTO',
#        'VICTOR SAPOUNTZAKIS RIBEIRO', 'BRUNA DAIBERT DANESIN',
#        'PAULA ANGELICA PINHA NEVES', 'SABRINA DE SOUZA RAMOS',
#        'MATHEUS VIANA LEMO', 'JOSE CARLOS TUNA SCARPA',
#        'DIOGO HENRIQUE PEREIRA MATTOS', 'DEBORA ALVES AUDE',
#        'PAOLA RODRIGUES OSHIRO', 'VITOR OLIVEIRA ANDRE',
#        'YURI ANDERSON PACHECO DE LIMA',
#        'RODRIGO MIYASHIRO NUNES DOS SANTOS', 'ROBERTO VOTTO MELKAN',
#        'STEFANY HELLEN SOUSA MARTINS', 'BEATRIZ ANTIPOU DOS SANTOS',
#        'MARIA CECILIA DOMINGUES DA SILVA SOARES',
#        'MONICA ROBLES GONCALVES', 'ARTHUR OLIVEIRA FACCHINI',
#        'PEDRO HENRIQUE MILHOMENS DA MOTA', 'LUCIANO ANGELO RICHETTI',
#        'BRUCE YE MAN CHOW', 'PEDRO PAULO SILVA FARAH',
#        'WANGLES PIGNATON DE PAULA', 'AMANDA KIYOKO SOUZA KOSSAKA',
#        'ROGERIO SIDNEY THON', 'LUIZ GUILHERME THOMAZ ZACHARIAS',
#        'CLAUDIO MUELLER KAKUDA', 'JOSE MARCOS VIEIRA DA SILVA',
#        'FERNANDA TELES RIBEIRO', 'THALES LUVISOTTO NEDER',
#        'MARIA CAROLINA CELIA SILVEIRA', 'MIRELA FARIAS FIGUEIROA',
#        'CARLOS EDUARDO CORREA GRILO', 'BIANCA PRISCILA BUNIOTTI',
#        'ROMULO SPOLIDORIO', 'ALEXSANDER TAKASHI HAMADA',
#        'AVELINO JOSE DA SILVA FREITAS JUNIOR',
#        'BRUNO FERRAZ DE CAMPOS BARONE', 'PAULA LOPES AGAPITO DE FREITAS',
#        'ANDRE DA COSTA AGUIAR VENTURA', 'ALEXANDRE BERNARDINO',
#        'GUILHERME SILVEIRA LOPES', 'FABIO YUJI SUGUITA',
#        'RICARDO KAWAURA', 'IVA BARBOSA SOARES', 'ELAINE IMAEDA DE MOURA',
#        'ALBERTO DE AZEVEDO ALVES MOREIRA', 'JULIANA AKEMI FUNABASHI',
#        'VANESSA PACIULLO MAROSSI', 'ORLANDO DOMINGUES DE ARAUJO PONTES',
#        'YURI LUCAS DE SOUZA', 'RODRIGO ANDRADE CARMELLO',
#        'GABRIEL GONDIM FONSECA', 'SHEILA ITIROCO MONTE',
#        'MAIELY MARCOLIN', 'DIOGO CANDEO RODRIGUES CORDEIRO',
#        'ANDREIA LOUREIRO MORI', 'FELIPE COELHO DE SOUZA',
#        'CARLOS EDUARDO GONDIM OLIVEIRA', 'LUIZ AUGUSTO XAVIER BRANDAO',
#        'THAIS CHAVES PINHEIRO', 'LETICIA FERNANDES BORGES',
#        'DANIELLEN LINS LOURENCO', 'NELIANE GUEDES PRETTI',
#        'PEDRO ULYSSES VIEIRA DE MATOS', 'RENATA TORRES BUENO',
#        'LEANDRO KENDI KANADA', 'DEBORA PHILIPPI BRESSANE',
#        'HENRI ROGER WATANABE OLIVEIRA', 'RODRIGO ACHUI HAGA',
#        'EDUARDO DALA ROSA SOARES', 'FERNANDO AKIRA KOGA',
#        'PEDRO AUGUSTO TAVARES DALL AGLIO', 'GABRIELA SOARES PIASSI',
#        'RODRIGO GIOVANELLI CONSTANTINO',
#        'THIAGO BARRETO MARQUES DA SILVA', 'ERICK OLIVEIRA LIMA GOMES',
#        'JESSICA LIDIA DE SOUZA', 'RODRIGO ANTONIO REY GONZALEZ',
#        'MARCELLA PELLICCIOTTI DE SOUZA BUTO',
#        'BRUNO STORNIOLI TAGUCHI LEMOS', 'MARCELA LEITE ROSIGNOLI',
#        'MATHEUS DE ALENCAR ARRAES', 'GUSTAVO MARQUES DA SILVA',
#        'CAROLINE FIRMINO LEMES DA SILVA',
#        'ANTONIO ALVARO DIAS LIMA DA CUNHA NETO',
#        'SAULLO QUEIROZ SILVEIRA', 'RAFAEL TADEU MARQUES',
#        'DENIO LOPES DE ALMEIDA', 'GABRIEL DE AGUIAR SANTANA',
#        'EDUARDO ARBACHE BEZERRA', 'RENATA TOGEIRO BASTOS GODOY DE FARIA',
#        'LUCCAS VARELA GODOY', 'EMERSON DOMINGOS DA COSTA',
#        'EVERTON SIDNEY DA CONCEICAO CARVALHO',
#        'MARCELA APARECIDA CORREA MARTINS', 'LEANDRO EDUARDO FRANCA',
#        'MARIANA DARDENGO BORGES', 'CARLOS AUGUSTO TREVISAN',
#        'DANIEL MASUZAKI WONG', 'MILTON OLAIO NETO',
#        'THIAGO FRANCISCO MARTINS', 'MAIRA LEITE BASILE',
#        'LEANDRO OLIVEIRA MARTINS CORTES', 'HELENA ARAUJO DAMASCENO',
#        'MARCELO MAIA DA SILVEIRA', 'VIVIAN CRISTINE DOS ANJOS E SILVA',
#        'JULIANO MOISES TOBAL', 'ALINE FRANCHINI GOULART LIMA',
#        'DANIEL RODRIGUES DE OLIVEIRA', 'MARIANA GASPARELLI DE SOUZA',
#        'FILIPE MAEDA HASHI ABDALLA MARTINS', 'VIVIANNA BOVERIO GALZERANI',
#        'IZABELLA GONTIJO CUNHA', 'FERNANDO RIBEIRO SA',
#        'NORIVAL SCANDELAI JUNIOR'], dtype=object)

# %%
#MENSAGEM ESCREVIDA
mensagem = []
for i in range(0, len(df)):
    digito_data = df['chat'][i].find(']') #aonde acaba a data
    digito_nome = df['chat'][i][digito_data+1:].find(':')
    mensagem_escrevida = df['chat'][i][digito_data+digito_nome+3:]
    mensagem.append(mensagem_escrevida)
    
df['mensagem'] = mensagem
df['mensagem'].unique()
# Out:
# array(['05/01 Santa Isabel - T. Silva - Saída 14:10 (EXTRA)',
#        '05/01 Osasco Yoko saída 15:10',
#        '05/01 Osasco - Ighor saída 15:00', '05/01 VNS Manoel saída 15:45',
#        '05/01 ANÁLIA Nathália saída 15:40',
#        '05/01 Analia Franco - Alessandre saída 15:50',
#        '05/01 Jabaquara - Yumi saída 15:30',
#        '05/01 Anália - Natan - Saída- 15:40',
#        '05/01-Itaim- Sidney-saida: 15:45',
#        '05/01 Santa - Buto entrada 7:00 (extra)',
#        '05/01 Santa - Buto saída 16:10 (extra)',
#        '05/01 itaim André saída 16:00h',
#        '05/01 ANÁLIA - Flávio saida 16:23',
#        '05/01 Santa Diego saida 16:20', '05/01 Itaim Karen saída 16:45',
#        '05/01 Itaim Kaie saída 16:45',
#        '05/01 VILLA - Ronald Entrada 05:40 (EXTRA)',
#        '05/01 VILLA - Ronald saida 16:50 (EXTRA)',
#        '05/12 MORUMBI - Anna Beatriz entrada 06:00',
#        '05/12 MORUMBI - Anna Beatriz saída 16:25',
#        '04/01 Osasco - João dispensado (saúde)',
#        '05/12 Villa - Marcos entrada 6:00 (EXTRA)',
#        '05/12 Villa - Marcos saída 17:10 (EXTRA)',
#        '05/01 Itaim Larissa - saída 17:10',
#        '05/01 - Morumbi - Silvia entrada 06:00',
#        '05/01 - Morumbi - Silvia saída 17:00',
#        '05/01 SANTA ISABEL-Estanrley Saida: 17:10',
#        '05/01 OSASCO - Giraldelli saída 17:30',
#        '05/01 Villa Hedicleber saída 18:00(extra)',
#        '05/01 VILLA R. Modolo saída 18:30 (deslocada Itaim)',
#        '05/01 Villa Astur saida 19:10',
#        '05/01 Villa Maurício saída 19:15',
#        '05/01 Analia Marina pontes saída 19:10',
#        '05/01 Villa Camila Saida 19:15',
#        '05/01 Villa Fabiana Gama saída as 19:40',
#        '05/01 Analia Gretel saida 19:48',
#        '05/01 Santa Bonfitto saída 19:50',
#        '05/01 Anália - Barbosa Saída 16:50',
#        '05/01 Jabaquara - Ludmylla saída 20:00',
#        '05/01 Villa Ráo saída 20:05', '05/01 VILLA Maciel saída 20:15',
#        '05/01 Anália - Sapountzakis saída 20:05',
#        '05/01 Analia Bruna saída 20:25',
#        '05/01 ANÁLIA Paula Neves saída 20:25',
#        '05/01 Jabaquara Sabrina saída 22:15',
#        '05/01 Jabaquara Viana saída 22:15',
#        '05/01 Jabaquara José Carlos Saída 22:15',
#        '05/01 ANÁLIA - Diogo saída 21:34',
#        '06/01 Itaim Débora entrada 05:10',
#        '06/01 VILLA-Paola entrada 05:20',
#        '06/01 Itaim Larissa - entrada 05:20',
#        '06/01 Jabaquara Vitor entrada 05:10',
#        '06/01 Morumbi - Yuri entrada 05:30',
#        '06/01 OSASCO - Miyashiro entrada 05:40 (deslocamento ITAIM)',
#        '10/01 Jabaquara - bruce entrada 06:00',
#        '10/01 OSASCO - M. Carolina entrada 05:20 (deslocada VNS)',
#        '10/01 MORUMBI - Wangles entrada 5:20',
#        '10/01 ITAIM Arraes entrada 07:40',
#        '10/01 Jabaquara - Erick entrada 7:00 ( EXTRA )',
#        '10/01 Anália - Candeo entrada às 06:00 (EXTRA)',
#        '10/01 sino Viana entrada 07:00 (EXTRA)',
#        '10/01 MORUMBI - Renata Togeiro entrada 6:00',
#        '10/01 Morumbi - Mariana Gasparelli entrada 05:10 ( EXTRA)',
#        '10/01 VILLA - Ronald entrada 07:00 (EXTRA)',
#        '10/01 JABAQUARA - Miyashiro saida 09:35 (EXTRA)',
#        '10/01 Itaim - Koga saída 09:40',
#        '10/01 Jabaquara Maeda saída 9:50'], dtype=object)

# %%
#DATA DO PLANTÃO
df['controle'] = ''
df['data'] = ''

for i in range(0, len(df)):
    lista_datas = re.findall(r'[0-9]{1,2}\/[0-9]{1,2}', df['mensagem'][i]) #regex dd/mm
    quantidade_itens = len(lista_datas)
    
    if quantidade_itens == 1: #capturar apenas registros com uma data apenas
        df['data'][i] = lista_datas[0]
    else: #restante com nenhuma ou mais de uma data
        df['controle'][i] = 'PROB'

#salvando
df_prob = df[df['controle'] == 'PROB']
df_prob.reset_index(drop=True, inplace=True)
print("data probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("datas ok:", len(df)) 

df['data'].unique()
# Out:
# data probs: 0
# datas ok: 397
# array(['05/01', '05/12', '04/01', '06/01', '06/10', '07/01', '02/01',
#        '07/10', '08/01', '09/01', '9/1', '09/10', '10/01'], dtype=object)

# %% [markdown]
# # Obs registros:

# %%
#CAPTURANDO UNIDADE
df['unidade'] = ''
df['Q_unidades'] = ''

for i in range(0, len(df)):
    mensagem = unidecode.unidecode(df['mensagem'][i].upper())
    lista_unidades = re.findall(r'ALPHA|ANALIA|AVICCENA|ITAIM|JABA|MATERNIDADE|MORUMBI|OSASCO|VILLA|VNS|SANTA', mensagem)
    quantidade_unidades = len(lista_unidades)
    
    df['Q_unidades'][i] = quantidade_unidades
    
    if quantidade_unidades == 1: #capturando apenas com uma unidade
        df['unidade'][i] = lista_unidades[0]
    else: #restante com nenhuma ou mais de uma unidade
        df['controle'][i] = 'PROB'
        
print(df['Q_unidades'].value_counts(),'\n')

#salvando
df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("unidades probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("unidade ok:", len(df))
# Out:
# 1    364
# 2     32
# 0      1
# Name: Q_unidades, dtype: int64
#
# unidades probs: 33
# unidade ok: 364

# %%
#RETIRANDO REGISTROS DE DESLOCADOS, DISTANCIA E SAIDAS POR QUESTÃO DE SAUDE

#preparando para reconhecer corretamente
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('(',' ( '))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace(')',' ) '))

df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCADA','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DESLOCAMENTO','DESLOCADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSADA','DISPENSADO'))
df['mensagem'] = df['mensagem'].apply(lambda x: x.replace('DISPENSA ','DISPENSADO'))

df['obs'] = ''

for i in range(0, len(df)):
    mensagem = unidecode.unidecode(df['mensagem'][i].upper())
    observacoes = re.findall(r'DESLOCADO|DISPENSADO|SAUDE|DESLOCADO|DISTANCIA', mensagem)
    quantidade_observacoes = len(observacoes)
    
    if quantidade_observacoes > 0:
        df['controle'][i] = 'PROB'
        
df['controle'].value_counts() 

#salvando
df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("unidades probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("unidade ok:", len(df))
# Out:
# unidades probs: 37
# unidade ok: 360

# %%
#VERIFICANDO SE É EXTRA
df["extra"] = ''

for i in range(0, len(df)):
    if 'EXTRA' in df['mensagem'][i].upper(): #se conter a palavra "extra"
        df['extra'][i] = 'extra' #marque na coluna extra como extra
        
df['extra'].value_counts()
# Out:
#          292
# extra     68
# Name: extra, dtype: int64

# %% [markdown]
# # Tipo entrada e saida:

# %%
#Indentificando se é um registro de entrada ou saida
df['tipo'] = ''

for i in range(0, len(df)):
    mensagem = unidecode.unidecode(df['mensagem'][i].upper())
    entradas_saidas = re.findall(r'ENTRADA|SAIDA', mensagem)
    quantidade_entradas_saidas = len(entradas_saidas)
    
    if quantidade_entradas_saidas != 1: #capturando apenas com uma informação escrita
        df['controle'][i] = 'PROB'
    else: #restante com mais de uma informação
        df['controle'][i] = ''
        df['tipo'][i] = entradas_saidas[0]
        
print(df['tipo'].value_counts())        
print(df['controle'].value_counts())

df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))
# Out:
# SAIDA      226
# ENTRADA    132
#              2
# Name: tipo, dtype: int64
#         358
# PROB      2
# Name: controle, dtype: int64
# probs: 39
# ok: 358

# %% [markdown]
# # Data:

# %%
#retirando a data da mensagem para não atrapalhar no reconhecimento de hora
df['hora'] = ''

for i in range(0, len(df)):
    df['hora'][i] = df['mensagem'][i].replace(df['data'][i], '').strip() #substituindo a data por vazio

# %%
#arrumando data d/mm (6/10, não 06/10)
for i in range(0, len(df)):
    if df['data'][i][1] == '/':
        df['data'][i] = '0'+df['data'][i]
df['data'].unique()
# Out:
# array(['05/01', '05/12', '06/01', '06/10', '07/01', '07/10', '08/01',
#        '09/01', '09/1', '09/10', '10/01'], dtype=object)

# %%
#somando informações restantes na data: dd/MM/yyyy
for i in range(0, len(df)):
    df['data'][i] = df['data'][i][0:2] + "/"+ mes +"/2023" 
    
print(df['data'].unique())
# Out:
# ['05/01/2023' '06/01/2023' '07/01/2023' '08/01/2023' '09/01/2023'
#  '10/01/2023']

# %%
df['sem_ou_fds'] = 'semana'

df.loc[(df['data'] == sabado) | (df['data'] == domingo), 'sem_ou_fds'] = 'fds'

df['sem_ou_fds'].value_counts()
# Out:
# semana    258
# fds       100
# Name: sem_ou_fds, dtype: int64

# %%
#df['data'].iloc[180] = '26/09/2022'

# %% [markdown]
# # Hora:

# %%
#substituindo "h" por ":" para capturar horarios 11h22
df['hora'] = df['hora'].apply(lambda x: x.upper().replace("H", ":"))

# %%
for i in range(0, len(df)):
    mensagem = df['hora'][i]
    horas = re.findall(r'[0-9]{1,2}:[0-9]{1,2}', mensagem) #capturando horas HH:mm
    quantidade_horas = len(horas)
    
    if quantidade_horas == 1: #capturando apenas com uma horas escrita
        df['hora'][i] = horas[0]
    else: #restante com nenhuma ou mais horas (geralmente pq digitou a hora de entrada e saida {informação inutil})
        df['hora'][i] = ''
        df['controle'][i] = 'PROB'
        
print(df['controle'].value_counts())

#salvando
df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))
# Out:
#     358
# Name: controle, dtype: int64
# probs: 39
# ok: 358

# %%
#adicionando 0 no primeiro algorismo dos valores h:mm
for i in range(0, len(df)):
    if df['hora'][i][1] == ":":
        df['hora'][i] = "0"+df['hora'][i]
        
df['hora'].unique()
# Out:
# array(['14:10', '15:10', '15:00', '15:45', '15:40', '15:50', '15:30',
#        '07:00', '16:10', '16:00', '16:23', '16:20', '16:45', '05:40',
#        '16:50', '06:00', '16:25', '17:10', '17:00', '17:30', '18:00',
#        '19:10', '19:15', '19:40', '19:48', '19:50', '20:00', '20:05',
#        '20:15', '20:25', '22:15', '21:34', '05:10', '05:20', '05:30',
#        '05:50', '04:50', '05:45', '06:10', '06:30', '08:15', '06:40',
#        '08:45', '09:20', '09:30', '09:50', '10:15', '10:38', '10:40',
#        '10:45', '12:20', '12:45', '13:45', '13:40', '14:25', '14:40',
#        '15:25', '16:15', '16:35', '16:55', '16:40', '17:20', '17:05',
#        '19:20', '20:10', '20:40', '21:20', '21:10', '04:20', '05:15',
#        '05:35', '09:15', '10:00', '10:10', '11:10', '11:15', '10:50',
#        '11:00', '11:50', '12:00', '12:15', '12:28', '12:40', '12:30',
#        '13:00', '13:10', '13:30', '13:50', '14:15', '06:45', '14:35',
#        '14:30', '14:45', '14:50', '15:20', '16:30', '17:15', '17:40',
#        '18:40', '18:20', '19:00', '19:45', '11:40', '07:50', '05:00',
#        '04:45', '12:50', '14:00', '15:55', '18:45', '17:50', '19:25',
#        '19:35', '19:30', '20:30', '20:35', '20:45', '21:00', '21:15',
#        '21:40', '21:55', '22:44', '23:10', '07:40', '09:35', '09:40'],
#       dtype=object)

# %% [markdown]
# # Hora final:

# %%
#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %%
df['hora'].unique()
# Out:
# array(['14:10', '15:10', '15:00', '15:45', '15:40', '15:50', '15:30',
#        '07:00', '16:10', '16:00', '16:23', '16:20', '16:45', '05:40',
#        '16:50', '06:00', '16:25', '17:10', '17:00', '17:30', '18:00',
#        '19:10', '19:15', '19:40', '19:48', '19:50', '20:00', '20:05',
#        '20:15', '20:25', '22:15', '21:34', '05:10', '05:20', '05:30',
#        '05:50', '04:50', '05:45', '06:10', '06:30', '08:15', '06:40',
#        '08:45', '09:20', '09:30', '09:50', '10:15', '10:38', '10:40',
#        '10:45', '12:20', '12:45', '13:45', '13:40', '14:25', '14:40',
#        '15:25', '16:15', '16:35', '16:55', '16:40', '17:20', '17:05',
#        '19:20', '20:10', '20:40', '21:20', '21:10', '04:20', '05:15',
#        '05:35', '09:15', '10:00', '10:10', '11:10', '11:15', '10:50',
#        '11:00', '11:50', '12:00', '12:15', '12:28', '12:40', '12:30',
#        '13:00', '13:10', '13:30', '13:50', '14:15', '06:45', '14:35',
#        '14:30', '14:45', '14:50', '15:20', '16:30', '17:15', '17:40',
#        '18:40', '18:20', '19:00', '19:45', '11:40', '07:50', '05:00',
#        '04:45', '12:50', '14:00', '15:55', '18:45', '17:50', '19:25',
#        '19:35', '19:30', '20:30', '20:35', '20:45', '21:00', '21:15',
#        '21:40', '21:55', '22:44', '23:10', '07:40', '09:35', '09:40'],
#       dtype=object)

# %%
#criando uma coluna datetime para fazer calculos de horas e minutos
df['hora2'] = df['hora'].apply(lambda x: datetime.strptime(x, '%H:%M'))

#verificando se esta tudo certo
print(df['hora2'].dt.year.unique())
print(df['hora2'].dt.month.unique())
print(df['hora2'].dt.day.unique())
print(df['hora2'].dt.hour.unique())

for i in range(0, len(df)):
    minuto = int(df['hora'][i][3:])
    
    if minuto != 0 and minuto != 30:
        if minuto < 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (0) subtraindo quantos minutos tem entre o momento e HH:00
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-minuto))[11:-3]
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (30) acrecentando quantos minutos faltam para HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(30-minuto)))[11:-3]
            else:
                df['controle'][i] = 'PROB'
                
        elif minuto > 30:
            if df['tipo'][i] == "ENTRADA": #arredondando para baixo (30) subtraindo quando minutos tem entre o momento e HH:30
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=-(minuto-30)))[11:-3]   
            elif df['tipo'][i] == "SAIDA": #arredondando para cima (60) acrecentando quantos minutos faltam para HH:60
                df['hora'][i] = str(df['hora2'][i] + timedelta(minutes=+(60-minuto)))[11:-3]            
            else:
                df['controle'][i] = 'PROB'
        else:
            df['controle'][i] = 'PROB'
            
    elif minuto == 0 or minuto == 30:
        df['hora'][i] = str(df['hora2'][i])[11:-3] 
        
    else:
        df['controle'][i] = 'PROB'
        
df['hora'].unique()
# Out:
# [1900]
# [1]
# [1]
# [14 15  7 16  5  6 17 18 19 20 22 21  4  8  9 10 12 13 11 23]
# array(['14:30', '15:30', '15:00', '16:00', '07:00', '16:30', '17:00',
#        '05:30', '06:00', '17:30', '18:00', '19:30', '20:00', '20:30',
#        '22:30', '22:00', '05:00', '04:30', '06:30', '08:30', '09:00',
#        '09:30', '10:00', '10:30', '11:00', '12:30', '13:00', '14:00',
#        '21:00', '21:30', '04:00', '11:30', '12:00', '13:30', '19:00',
#        '18:30', '07:30', '23:00', '23:30'], dtype=object)

# %% [markdown]
# # Setor:

# %%
#reconhendo em qual periodo do dia aconteceu o plantão
df['ENTRADA'] = ''
df['SAIDA'] = ''

df['PERIODO'] = ''

for i in range(0, len(df)):
    minuto = int(df['hora'][i][:2])
    
    if df['tipo'][i] == 'ENTRADA':
        df['ENTRADA'][i] = df['hora'][i]
        if minuto < 7: #periodo 6h
            df['PERIODO'][i] = '6h'
            df['SAIDA'][i] = '07:00'
        elif minuto >= 7 and minuto < 13: #periodo manha
            df['PERIODO'][i] = 'manha'
            df['SAIDA'][i] = '13:00'
        elif minuto >= 13 and minuto < 19: #periodo tarde
            df['PERIODO'][i] = 'tarde'
            df['SAIDA'][i] = '19:00'
        else:
            df['controle'][i] = 'PROB'
    elif df['tipo'][i] == 'SAIDA':
        df['SAIDA'][i] = df['hora'][i]
        if minuto >= 7 and minuto < 13: #periodo manha
            df['ENTRADA'][i] = '07:00'
            df['PERIODO'][i] = 'manha'
        elif minuto >= 13 and minuto < 19: #periodo tarde
            df['ENTRADA'][i] = '13:00'
            df['PERIODO'][i] = 'tarde'
        elif minuto >= 19: #periodo noturno
            df['ENTRADA'][i] = '19:00'
            df['PERIODO'][i] = 'noturno saida'
        else:
            df['controle'][i] = 'PROB'
    else:
        df['controle'][i] = 'PROB'
        
df['PERIODO'].value_counts()

print(df['controle'].value_counts())

#salvando restante
df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))
# Out:
#     358
# Name: controle, dtype: int64
# probs: 39
# ok: 358

# %%
#DURAÇÃO DO PLANTÃO
df['DURAÇÃO'] = ''

for i in range(0, len(df)):
    diferenca_tempo = datetime.strptime(df['SAIDA'][i], '%H:%M') - datetime.strptime(df['ENTRADA'][i], '%H:%M')
    
    #diferenca_tempo vem em formato estranho, tem-se que transformar em segundos antes
    diferenca_tempo_s = diferenca_tempo.seconds
    horas = '0' + str(int((diferenca_tempo_s/60)/60)) #capturando horas
    minutos = str(int((diferenca_tempo_s/60)%60))  #capturando minutos
    
    if len(minutos) == 1:
        minutos = '0' + minutos
    
    df['DURAÇÃO'][i] = horas + ':' + minutos
    
df['DURAÇÃO'].unique()
# Out:
# array(['01:30', '02:30', '02:00', '03:00', '06:00', '03:30', '04:00',
#        '01:00', '04:30', '05:00', '00:30', '05:30', '00:00'], dtype=object)

# %%
df['setor'] = ''

for i in range(0, len(df)):
    if df['sem_ou_fds'][i] == 'semana':
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'SEMANA - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'SEMANA - MANHA - C.CIRURGICO'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'SEMANA - TARDE - C.CIRURGICO'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'SEMANA - NOTURNO - SAIDA'
        else:
            df['setor'][i] = 'VERIFICAR'

    elif df['sem_ou_fds'][i] == 'fds': 
        if df['PERIODO'][i] == '6h':
            df['setor'][i] = 'FDS - 6HS'
        elif df['PERIODO'][i] == 'manha':
            df['setor'][i] = 'FDS - C.CIRURGICO ROTINA'
        elif df['PERIODO'][i] == 'tarde':
            df['setor'][i] = 'FDS - SAIDA'
        elif df['PERIODO'][i] == 'noturno saida':
            df['setor'][i] = 'FDS - PLANTAO'
        else:
            df['setor'][i] = 'VERIFICAR'  

    else:
        df['setor'][i] = 'VERIFICAR'
        
df['setor'].value_counts()
# Out:
# SEMANA - 6HS                    87
# SEMANA - TARDE - C.CIRURGICO    70
# SEMANA - NOTURNO - SAIDA        69
# FDS - SAIDA                     48
# SEMANA - MANHA - C.CIRURGICO    32
# FDS - 6HS                       28
# FDS - C.CIRURGICO ROTINA        21
# FDS - PLANTAO                    3
# Name: setor, dtype: int64

# %%
print("probs:", len(df_prob))
print("ok:", len(df))

porcentagem = round((len(df)/(len(df)+len(df_prob)))*100, 2)
print('Porcentagem de registros corrigidas pelo o algoritmo:', porcentagem)
# Out:
# probs: 39
# ok: 358
# Porcentagem de registros corrigidas pelo o algoritmo: 90.18

# %% [markdown]
# # Ultimos ajustes:

# %%
for i in range(0, len(df)):
    if df['DURAÇÃO'][i] == "00:00":
        df['controle'][i] = "PROB"
        
print(df['controle'].value_counts())

#salvando restante
df_prob = pd.concat([df_prob, df[df['controle'] == 'PROB']])
df_prob.reset_index(drop=True, inplace=True)
print("probs:", len(df_prob))

df = df[df['controle'] != 'PROB']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))
# Out:
#         349
# PROB      9
# Name: controle, dtype: int64
# probs: 48
# ok: 349

# %% [markdown]
# # Salvando:

# %%
df = df[['chat', 'dia', 'nome', 'mensagem', 'controle', 'data', 'unidade',
       'extra', 'ENTRADA', 'SAIDA', 'DURAÇÃO', 'PERIODO', 'setor', 'sem_ou_fds']]

# %%
df.to_excel("df.xlsx", index=False)
df_prob.to_excel('df_prob.xlsx', index=False)

# %%
df
# Out:
#                                                   chat         dia  \
# 0    [05/01/2023 15:06:00] Thiago Silva Pinto: 05/0...  05/01/2023
# 1    [05/01/2023 15:18:34] Yoko Hayashi: 05/01 Osas...  05/01/2023
# 2    [05/01/2023 15:22:44] Marcio Ighor Azevedo Sil...  05/01/2023
# 3    [05/01/2023 15:47:38] Manoel de Souza Neto: 05...  05/01/2023
# 4    [05/01/2023 15:52:32] Nathalia Fanucci Oliveir...  05/01/2023
# ..                                                 ...         ...
# 344  [10/01/2023 08:44:24] Mariana Gasparelli de So...  10/01/2023
# 345  [10/01/2023 08:50:48] Ronald Figueiredo Gomes:...  10/01/2023
# 346  [10/01/2023 09:35:38] Rodrigo Miyashiro Nunes ...  10/01/2023
# 347  [10/01/2023 09:42:26] Fernando Akira Koga: 10/...  10/01/2023
# 348  [10/01/2023 09:51:47] Filipe Maeda Hashi Abdal...  10/01/2023
#
#                                                nome  \
# 0                                THIAGO SILVA PINTO
# 1                                      YOKO HAYASHI
# 2    MARCIO IGHOR AZEVEDO SILVA DE MENDONCA MELANIA
# 3                              MANOEL DE SOUZA NETO
# 4                NATHALIA FANUCCI OLIVEIRA DI JORGE
# ..                                              ...
# 344                     MARIANA GASPARELLI DE SOUZA
# 345                         RONALD FIGUEIREDO GOMES
# 346              RODRIGO MIYASHIRO NUNES DOS SANTOS
# 347                             FERNANDO AKIRA KOGA
# 348              FILIPE MAEDA HASHI ABDALLA MARTINS
#
#                                               mensagem controle        data  \
# 0    05/01 Santa Isabel - T. Silva - Saída 14:10  (...           05/01/2023
# 1                        05/01 Osasco Yoko saída 15:10           05/01/2023
# 2                     05/01 Osasco - Ighor saída 15:00           05/01/2023
# 3                         05/01 VNS Manoel saída 15:45           05/01/2023
# 4                    05/01 ANÁLIA Nathália saída 15:40           05/01/2023
# ..                                                 ...      ...         ...
# 344  10/01 Morumbi - Mariana Gasparelli entrada 05:...           10/01/2023
# 345     10/01 VILLA - Ronald entrada 07:00  ( EXTRA )            10/01/2023
# 346  10/01 JABAQUARA - Miyashiro saida 09:35  ( EXT...           10/01/2023
# 347                     10/01 Itaim - Koga saída 09:40           10/01/2023
# 348                   10/01 Jabaquara Maeda saída 9:50           10/01/2023
#
#      unidade  extra ENTRADA  SAIDA DURAÇÃO PERIODO  \
# 0      SANTA  extra   13:00  14:30   01:30   tarde
# 1     OSASCO          13:00  15:30   02:30   tarde
# 2     OSASCO          13:00  15:00   02:00   tarde
# 3        VNS          13:00  16:00   03:00   tarde
# 4     ANALIA          13:00  16:00   03:00   tarde
# ..       ...    ...     ...    ...     ...     ...
# 344  MORUMBI  extra   05:00  07:00   02:00      6h
# 345    VILLA  extra   07:00  13:00   06:00   manha
# 346     JABA  extra   07:00  10:00   03:00   manha
# 347    ITAIM          07:00  10:00   03:00   manha
# 348     JABA          07:00  10:00   03:00   manha
#
#                             setor sem_ou_fds
# 0    SEMANA - TARDE - C.CIRURGICO     semana
# 1    SEMANA - TARDE - C.CIRURGICO     semana
# 2    SEMANA - TARDE - C.CIRURGICO     semana
# 3    SEMANA - TARDE - C.CIRURGICO     semana
# 4    SEMANA - TARDE - C.CIRURGICO     semana
# ..                            ...        ...
# 344                  SEMANA - 6HS     semana
# 345  SEMANA - MANHA - C.CIRURGICO     semana
# 346  SEMANA - MANHA - C.CIRURGICO     semana
# 347  SEMANA - MANHA - C.CIRURGICO     semana
# 348  SEMANA - MANHA - C.CIRURGICO     semana
#
# [349 rows x 14 columns]
