# %%
mes = "10"

# %%
#manipulação de dados
import pandas as pd
import numpy as np

#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)

import os


import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import unidecode #arrumar strings

import re #regex
import os


#pacotes para manipular data
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta

# %%
browser = webdriver.Firefox()

# %%
browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()

# %% [markdown]
# # Capturando setores:

# %%
#click criar novo plantão
browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr[1]/td[4]/button').click()

# %%
inicio = time.time() #iniciando o cronometro

#Setor
browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()

setor_html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML')
soup = BeautifulSoup(setor_html, 'html.parser')

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.7948951721191406

# %%
inicio = time.time() #iniciando o cronometro

lista_unidade = []
lista_unidade_count = []
lista_plt = []
lista_plt_count = []

count_unidade = 1

for i in soup.find_all(class_="select2-results-dept-0 select2-result select2-result-unselectable select2-result-with-children"):
    #print('\n', i.find(class_='select2-result-label').get_text(), '====== \n')
    count_plt = 1
    for t in i.find_all(class_='select2-results-dept-1 select2-result select2-result-selectable'): 
        #print(t.get_text())
        lista_plt.append(t.get_text())
        lista_plt_count.append(count_plt)
        count_plt += 1
            
        lista_unidade.append(i.find(class_='select2-result-label').get_text())
        lista_unidade_count.append(count_unidade)
    count_unidade += 1

scrap_unidades = pd.DataFrame({'unidade':lista_unidade, 'momento':lista_plt,
                               'unidade_count':lista_unidade_count, 'plt_count':lista_plt_count})

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: x.replace('  ',' '))

scrap_unidades['momento'] = scrap_unidades['momento'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))
scrap_unidades['unidade'] = scrap_unidades['unidade'].apply(lambda x: unidecode.unidecode(x.replace('  ',' ').upper().strip()))

fim = time.time() #encerrando cronometro
print('\nTempo que demorou o codigo:', fim - inicio)
# Out:
# Tempo que demorou o codigo: 0.016393423080444336

# %%
#scrap_unidades.to_excel("setores.xlsx", index=False)
scrap_unidades.sample(20)
# Out:
#            unidade                             momento  unidade_count  \
# 159   SANTA ISABEL        SEMANA - MANHA - C.CIRURGICO             11
# 150         OSASCO            SEMANA - NOTURNO - SAIDA             10
# 158   SANTA ISABEL  SEMANA - MANHA - AV.PRE ANESTESICA             11
# 101    MATERNIDADE                            FDS - D1              8
# 63           ITAIM          FDS - AVALIACAO PRE ROTINA              6
# 100    MATERNIDADE            FDS - C.CIRURGICO ROTINA              8
# 73           ITAIM        SEMANA - MANHA - C.CIRURGICO              6
# 93       JABAQUARA  SEMANA - TARDE - AV.PRE ANESTESICA              7
# 45          ANALIA        SEMANA - NOTURNO - DISTANCIA              3
# 121        MORUMBI                        SEMANA - 6HS              9
# 88       JABAQUARA                         FDS - SAIDA              7
# 78           ITAIM        SEMANA - NOTURNO - DISTANCIA              6
# 108    MATERNIDADE    SEMANA - TARDE - COBERTURA EXTRA              8
# 11   ADMINISTRACAO            PERIODO DE DESCANSO - 11              1
# 74           ITAIM    SEMANA - MANHA - COBERTURA EXTRA              6
# 111    MATERNIDADE            SEMANA - NOTURNO - SAIDA              8
# 165   SANTA ISABEL            SEMANA - NOTURNO - SAIDA             11
# 22           ALPHA                         FDS - SAIDA              2
# 49        AVICCENA            FDS - C.CIRURGICO ROTINA              4
# 48        AVICCENA                           FDS - 6HS              4
#
#      plt_count
# 159          9
# 150         17
# 158          8
# 101          3
# 63           2
# 100          2
# 73          12
# 93          13
# 45          18
# 121         10
# 88           8
# 78          17
# 108         10
# 11          12
# 74          13
# 111         13
# 165         15
# 22           4
# 49           2
# 48           1

# %%
scrap_unidades[scrap_unidades['unidade'] == 'SANTA ISABEL']
# Out:
#           unidade                             momento  unidade_count  \
# 151  SANTA ISABEL                           FDS - 6HS             11
# 152  SANTA ISABEL     FDS - MANHA - AV.PRE ANESTESICA             11
# 153  SANTA ISABEL           FDS - MANHA - C.CIRURGICO             11
# 154  SANTA ISABEL                            FDS - D1             11
# 155  SANTA ISABEL                       FDS - PLANTAO             11
# 156  SANTA ISABEL                         FDS - SAIDA             11
# 157  SANTA ISABEL                        SEMANA - 6HS             11
# 158  SANTA ISABEL  SEMANA - MANHA - AV.PRE ANESTESICA             11
# 159  SANTA ISABEL        SEMANA - MANHA - C.CIRURGICO             11
# 160  SANTA ISABEL    SEMANA - MANHA - COBERTURA EXTRA             11
# 161  SANTA ISABEL        SEMANA - TARDE - C.CIRURGICO             11
# 162  SANTA ISABEL    SEMANA - TARDE - COBERTURA EXTRA             11
# 163  SANTA ISABEL        SEMANA - NOTURNO - DISTANCIA             11
# 164  SANTA ISABEL          SEMANA - NOTURNO - PLANTAO             11
# 165  SANTA ISABEL            SEMANA - NOTURNO - SAIDA             11
#
#      plt_count
# 151          1
# 152          2
# 153          3
# 154          4
# 155          5
# 156          6
# 157          7
# 158          8
# 159          9
# 160         10
# 161         11
# 162         12
# 163         13
# 164         14
# 165         15

# %% [raw]
# for i in scrap_unidades.columns:
#     print(scrap_unidades[i].unique(),'\n')

# %% [markdown]
# # TESTANDO SETORES

# %%
# df_gabs
# df_continuar
# df_gabs_desl

df = pd.read_excel('df_gabs.xlsx')
print(len(df))
df.sample(3)
# Out:
# 349
#                                                   chat         dia  \
# 2    [05/10/2023 11:05:17] Diego da Cunha Tomaz: 05...  05/10/2023
# 142  [06/10/2023 16:40:37] Ana Jung Docko: 06/10 An...  06/10/2023
# 129  [06/10/2023 15:42:34] Juliano Moisés Tobal: 06...  06/10/2023
#
#                      nome                                           mensagem  \
# 2    DIEGO DA CUNHA TOMAZ                  05/10 Santa  -  Diego saida 10:50
# 142        ANA JUNG DOCKO                       06/10 Analia Ana saída 16:40
# 129  JULIANO MOISES TOBAL  06/10 Central Juliano Tobal saída 15:40   (   ...
#
#       controle        data       unidade extra   tipo ENTRADA  SAIDA DURAÇÃO  \
# 2          NaN  05/10/2023  SANTA ISABEL   NaN  SAIDA   07:00  11:00   04:00
# 142        NaN  06/10/2023        ANALIA   NaN  SAIDA   13:00  17:00   04:00
# 129  DESLOCADO  06/10/2023      AVICCENA   NaN  SAIDA   13:00  16:00   03:00
#
#     PERIODO  periodo                         setor sem_ou_fds  \
# 2     manha        2  SEMANA - MANHA - C.CIRURGICO     semana
# 142   tarde        3  SEMANA - TARDE - C.CIRURGICO     semana
# 129   tarde        3  SEMANA - TARDE - C.CIRURGICO     semana
#
#                   unidade2
# 2                    SANTA
# 142                 ANALIA
# 129  ['AVICCENA', 'VILLA']

# %%
df['setor'][(df['setor'] == 'FDS - C.CIRURGICO ROTINA') & (df['unidade'] == 'SANTA ISABEL')] = 'FDS - MANHA - C.CIRURGICO'
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16552\4212879801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['setor'][(df['setor'] == 'FDS - C.CIRURGICO ROTINA') & (df['unidade'] == 'SANTA ISABEL')] = 'FDS - MANHA - C.CIRURGICO'

# %%
for X in range(0, len(df)):
    if len(scrap_unidades.loc[(scrap_unidades.unidade == df['unidade'][X]) & 
                                 (scrap_unidades.momento == df['setor'][X])]) < 1:
        print(X)
        print(df['unidade'][X], '-', df['setor'][X])
        #print('index', ind)
        #print(scrap_unidades['unidade'][ind], '-', scrap_unidades['momento'][ind])
        #print('codigos:', unidade, setorzin)
        

print("="*20, "TUDO OK", "="*20)
# Out:
# ==================== TUDO OK ====================

# %%
print(df['unidade'][X])
print(df['setor'][X])
# Out:
# VNS
# SEMANA - MANHA - C.CIRURGICO

# %%
df['nome'][df['nome'] == 'ICARO MOURA DE SOUSA'] = 'ICARO DE MOURA SOUSA'

# %% [markdown]
# # RODANDO NO PEGA

# %%
len(df)
# Out:
# 349

# %%
H=0

# %%
for h in range(H, len(df)):
    print(h)
    print('nome:', df['nome'][h])
    print('mensagem:', df['mensagem'][h])
    print('dia:', df['data'][h])
    
    #click criar novo plantão
    browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr[1]/td[4]/button').click()
    
    #esta disponivel o botão de setor
    WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]')))
    #Setor====
    #print('base:', df['unidade'][h], '-', df['setor'][h])
    browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').click()
    ind = scrap_unidades.loc[(scrap_unidades.unidade == df['unidade'][h]) & 
                             (scrap_unidades.momento == df['setor'][h])].index.values[0]
    unidade = scrap_unidades['unidade_count'][ind]
    setorzin = scrap_unidades['plt_count'][ind]
    #print('scraping:', scrap_unidades['unidade'][ind], '-', scrap_unidades['momento'][ind])
    #SELECIONANDO Setor ##//*[@id="select2-drop"]/ul/li[unidade]/ul/li[momento]/div
    #print('caixa:', browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/div').text, '-',
          #browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/ul/li['+str(setorzin)+']/div').text)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li['+str(unidade)+']/ul/li['+str(setorzin)+']/div').click()
    #print('selecionado:', browser.find_element("xpath", '//*[@id="s2id_ddlServiceSector"]/a/span[1]').text, '\n')
    
    #PROFISSIONAL
    #esta disponivel o botão de profissional
    WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]')))
    
    #listar todos
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click()
    
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click() #########
    browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').click() #########
    sleep(1)
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionalA"]/a/span[1]').click()
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(df['nome'][h])
    #Dando enter
    browser.find_element("xpath", '//*[@id="select2-drop"]/div/input').send_keys(Keys.RETURN)
    #info
    #print('base:', df['nome'][h])
    #print('selecionado:', browser.find_element("xpath", '//*[@id="s2id_ddlProfessionalA"]/a/span[1]').text)
    #print(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]').text)
    
    sleep(1)
    #Data
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[2]/div[3]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').clear()
    sleep(1)
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[2]/div[3]/div[5]/div[1]/div[2]/div/div[2]/div[1]/div[2]/input[1]').send_keys(df['data'][h])
    sleep(1)
    #print(df['data'][h])
    
    #Inicio do plantão
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').send_keys(df['ENTRADA'][h])
    sleep(1)
    print('hora de entrada:', df['ENTRADA'][h], '\nhora de saida:', df['SAIDA'][h])
    #Duração do plantão
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').clear()
    browser.find_element("xpath", '//*[@id="txtServiceDuration"]').send_keys(df['DURAÇÃO'][h])
    print('duração do plantão', df['DURAÇÃO'][h])
        
    ##TIPO
    '''
    //*[@id="select2-drop"]/ul/li[3]/div
    1 - Normal
    2 - DESLOCAMENTO
    3 - VOLUNTÁRIO
    4 - COBERTURA
    '''
    if df['extra'][h] == 'extra':
        print('EXTRA')
        sleep(1)
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(1)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[3]/div').click()
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(200) #Pontos
            print('duração >5 -> 200 pontos')
        else:
            pass
    elif df['extra'][h] == 'DESLOCADO':
        print('DESLOCADO')
        sleep(5)
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        browser.find_element("xpath", '//*[@id="s2id_add-service-service-types"]/a/span[1]').click()
        sleep(5)
        #selecionando o tipo voluntario:
        browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            print('duração >5 -> 100 pontos')
        else:
            pass
        sleep(2)
    else:
        if int(df['DURAÇÃO'][h][:2]) >= 5 and df['sem_ou_fds'][h] == "semana":
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            print('duração >5 -> 100 pontos')
            
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
            
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceValue"]').send_keys(100) #Pontos
        else:
            pass
        sleep(2)
        
    #salvar plantão
    sleep(1)
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
    sleep(2)

    #VERIFICANDO SE HOUVE ERRO - HÁ PLANTÃO NO MESMO HORARIO
    #if browser.find_element("xpath", '/html/body/div[6]/div/div[2]/div[2]/div/label').text != "":
    if browser.find_element("xpath", '/html/body/div[5]/div/div[2]/div[2]/div/label').text != '':
    #if browser.find_element("xpath", '/html/body/div[4]/div/div[2]/div[2]/div/label').text != "":
        if df['PERIODO'][h] == '6h':
            browser.find_element("xpath", '//*[@id="ckb-add-service-ignore-conflict"]').click()#estou ciente
            sleep(1)
            browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click() #salvar plantão
            browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()
            browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/div[2]/button[4]').click()        
            df.loc[int(h), 'controle'] = "NORM DUPLI"
        else:
            browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button').click() #FECHAR
            df.loc[int(h), 'controle'] = "PROBS"
            print("PROB")
    else:
        df.loc[int(h), 'controle'] = "NORM"
    
    #browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button').click() #fechar {X}

    #não esta disponivel o X
    
    WebDriverWait(browser, 10).until_not(visibility_of(browser.find_element("xpath", '//*[@id="modal-add-service"]/div/div[1]/button')))
    H += 1
    print('='*40, '\n')
    
    if H % 25 == 0:
        print('='*80)
        print(df['controle'].value_counts())
        print('='*80)
        df.to_excel("df_gabs.xlsx", index=False)
        
print("="*50, 'TERMINOU', "="*50)
print('Total  ', len(df))
print(df['controle'].value_counts())
df.to_excel("df_gabs.xlsx", index=False)
# Out:
# 243
# nome: ANDRE DA COSTA AGUIAR VENTURA
# mensagem: 07/10 VNS Ventura saida 12:56
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 244
# nome: VIVIANNA BOVERIO GALZERANI
# mensagem: 07/10 Itaim Vivianna saída 13:00
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 245
# nome: RODRIGO GOMES MINAS NOVAS
# mensagem: 07/10 SANTA ISABEL Gomes saída 13:25
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 13:30
# duração do plantão 00:30
# ========================================
#
# 246
# nome: SABRINA DE SOUZA RAMOS
# mensagem: 07/10 Itaim Sabrina saída 13:35
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 247
# nome: PAULA ANGELICA PINHA NEVES
# mensagem: 07/10 ANÁLIA Paula Neves saída 12:50
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 248
# nome: RONALD FIGUEIREDO GOMES
# mensagem: 07/10 VILLA  -  Ronald saida 13:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 249
# nome: MIRELA FARIAS FIGUEIROA
# mensagem: 07/10 Anália  -  Mirela saída 13:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# ================================================================================
# NORM            173
# PROBS            74
# DESLOCADO 6H      5
# DESLOCADO         4
# NORM DUPLI        3
# Name: controle, dtype: int64
# ================================================================================
# 250
# nome: NARA YAMANE DOS SANTOS
# mensagem: 07/10 -  jabaquara  -  nara saida 13:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 251
# nome: DEBORA ALVES AUDE
# mensagem: 07/10 jabaquara Débora saída 13:30
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 13:30
# duração do plantão 00:30
# ========================================
#
# 252
# nome: ANNA BEATRIZ LIMA DO VALLE ASTUR
# mensagem: 07/10 Itaim  -  Astur saída 13:55
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 253
# nome: DANIEL RODRIGUES DE OLIVEIRA
# mensagem: 07/10 Itaim Daniel entrada 6:00
# dia: 07/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 254
# nome: DANIEL RODRIGUES DE OLIVEIRA
# mensagem: 07/10 Itaim Daniel saída 13:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 255
# nome: CAIO TULIO DUARTE
# mensagem: 07/10 ANÁLIA  -  Caio saída 12:40   (  pós - plantão Anália  )
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 256
# nome: ALEXSANDER TAKASHI HAMADA
# mensagem: 07/10 Villa  -  Alex saída 13:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:00
# duração do plantão 01:00
# ========================================
#
# 257
# nome: GABRIEL GONDIM FONSECA
# mensagem: 07/10 Itaim Gondim saída 14:15   (  cirurgia a pedido  )
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 258
# nome: LUCCAS VARELA GODOY
# mensagem: 07/10 Alpha Luccas saída 14:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 259
# nome: KAIE FERNANDES
# mensagem: 07/10 Osasco kaie saída 14:20   (  deslocado Alpha  )
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 260
# nome: THALES LUVISOTTO NEDER
# mensagem: 07/10 Osasco  -  Thales saída 14:25   (  deslocado Analia  )
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 261
# nome: ELAINE IMAEDA DE MOURA
# mensagem: 07/10 Itaim Elaine saída 14:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 262
# nome: CLAUDIO MUELLER KAKUDA
# mensagem: 07/10 Maternidade  -  Kakuda saida 10:15
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 10:30
# duração do plantão 03:30
# PROB
# ========================================
#
# 263
# nome: GABRIELA SANTOS MENEZES
# mensagem: 07/10 Jabaquara  -  G.Menezes saída 14:30
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 264
# nome: RENATA TORRES BUENO
# mensagem: 07/10 Anália  -  Renata Bueno entrada 6:00
# dia: 07/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 265
# nome: RENATA TORRES BUENO
# mensagem: 07/10 Anália  -  Renata Bueno saída 14:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 266
# nome: JESSICA LIDIA DE SOUZA
# mensagem: 07/10 VNS Jessica saida 14:30
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 267
# nome: THASSIO CUNHA DE SANTANA
# mensagem: 07/10 Jabaquara Thassio saída 14:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:00
# duração do plantão 02:00
# ========================================
#
# 268
# nome: RODRIGO MARTINS PEREIRA
# mensagem: 07/10 VILLA  -  pereira saída 14:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:00
# duração do plantão 02:00
# ========================================
#
# 269
# nome: JOSE MARCOS VIEIRA DA SILVA
# mensagem: 07/10  -  Itaim José Marcos saída 14:25
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 270
# nome: PEDRO AUGUSTO TAVARES DALL AGLIO
# mensagem: 07/10  -  Anália  -  Tavares  -  saída :15:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 271
# nome: FILIPE MAEDA HASHI ABDALLA MARTINS
# mensagem: 07/10 Osasco  -  Maeda saída 15:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 272
# nome: ANTONIO ALVARO DIAS LIMA DA CUNHA NETO
# mensagem: 07/10 VILLA  -  Álvaro saída 15:00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:00
# duração do plantão 02:00
# ========================================
#
# 273
# nome: ANA JUNG DOCKO
# mensagem: 07/10 Itaim Ana saida 15:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 274
# nome: KAREN CAVICHINI ROSSETO
# mensagem: 07/10 Villa  -  Cavichini saída 15:15
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# ================================================================================
# NORM            196
# PROBS            76
# DESLOCADO 6H      5
# NORM DUPLI        3
# DESLOCADO         1
# Name: controle, dtype: int64
# ================================================================================
# 275
# nome: IVA BARBOSA SOARES
# mensagem: 07/10 Osasco Ivã Saída 15:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 276
# nome: MARIANA DARDENGO BORGES
# mensagem: 07/10 MORUMBI  -  M. Dardengo saída 15:25
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 277
# nome: BRIAN SOSSAI PACHECO
# mensagem: 07/10 JABAQUARA  -  Brian saída 15:15
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 15:30
# duração do plantão 02:30
# ========================================
#
# 278
# nome: SAULLO QUEIROZ SILVEIRA
# mensagem: 07/10 VNS Saullo entrada 05:30   (  deslocamento de osasco  )
# dia: 07/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# ========================================
#
# 279
# nome: SAULLO QUEIROZ SILVEIRA
# mensagem: 07/10 VNS Saullo saída 16:00   (  deslocamento de osasco  )   ‎<Mensagem editada>
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 280
# nome: MARIA CECILIA DOMINGUES DA SILVA SOARES
# mensagem: 07/10 VILLA  -  M. Cecília saída 15:50
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 281
# nome: SILVIA ALINE DOS SANTOS ANDRADE
# mensagem: 07/10  -  Itaim  -  Silvia saída 15:50
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 282
# nome: LEANDRO KENDI KANADA
# mensagem: 07/10 -  Villa Leandro kanada saida 15:55
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 283
# nome: DARLAN JUNIOR SCHNEIDER
# mensagem: 07/10 Jabaquara  -  Darlan saida 15:45
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 284
# nome: RENATO DOS SANTOS BOREGA
# mensagem: 07/10 Analia  -  Renato saída 16:00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 285
# nome: FELIPE DE OLIVEIRA NUNES
# mensagem: 07/10 Osasco  -  Nunes saída 16:00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 286
# nome: IZABELA CARDOSO GARCIA
# mensagem: 07/10 Jabaquara  -  Garcia saída 16:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:30
# duração do plantão 03:30
# ========================================
#
# 287
# nome: RICARDO BARBOSA VIANA FILHO
# mensagem: 07/10 Osasco  -  Barbosa Saída 15:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:00
# duração do plantão 03:00
# ========================================
#
# 288
# nome: IZABELLA GONTIJO CUNHA
# mensagem: 07/10 ITAIM  -  Izabella saída 14:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 14:30
# duração do plantão 01:30
# ========================================
#
# 289
# nome: ANNA BEATRIZ ARANHA TREVISAN
# mensagem: 07/10 MORUMBI  -  Anna Beatriz entrada 06:00
# dia: 07/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 290
# nome: ANNA BEATRIZ ARANHA TREVISAN
# mensagem: 07/10 MORUMBI  -  Anna Beatriz saída 17:00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:00
# duração do plantão 04:00
# ========================================
#
# 291
# nome: MARIA CAROLINA CELIA SILVEIRA
# mensagem: 07/10 VNS  -  M. Carolina saída 12:40
# dia: 07/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 292
# nome: VANESSA PACIULLO MAROSSI
# mensagem: 07/10 ANÁLIA Vanessa saída 16:55
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:00
# duração do plantão 04:00
# ========================================
#
# 293
# nome: ANDRE AUGUSTO BELLINI
# mensagem: 07/10 OSASCO  -  Bellini saída 17h00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:00
# duração do plantão 04:00
# ========================================
#
# 294
# nome: AMANDA KIYOKO SOUZA KOSSAKA
# mensagem: 07/10 ITAIM  -  Amanda saída 17:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:30
# duração do plantão 04:30
# ========================================
#
# 295
# nome: GABRIELA SOARES PIASSI
# mensagem: 07/10 OSASCO  -  Piassi saída 17:00
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:00
# duração do plantão 04:00
# ========================================
#
# 296
# nome: MATHEUS ACQUESTA GAUBEUR
# mensagem: 07/10 Villa  -  Matheus saída 17:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:30
# duração do plantão 04:30
# ========================================
#
# 297
# nome: ANDRE LUIS XAVIER FRANCO
# mensagem: 07/10 Analia  -  Xavier saída 17:20
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:30
# duração do plantão 04:30
# ========================================
#
# 298
# nome: BRUNO STORNIOLI TAGUCHI LEMOS
# mensagem: 07/10 Morumbi Bruno Lemos saída 16:40
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:00
# duração do plantão 04:00
# ========================================
#
# 299
# nome: WANGLES PIGNATON DE PAULA
# mensagem: 07/10 ANÁLIA  -  Wangles: saída 17:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 17:30
# duração do plantão 04:30
# ========================================
#
# ================================================================================
# NORM            220
# PROBS            77
# DESLOCADO 6H      4
# NORM DUPLI        3
# Name: controle, dtype: int64
# ================================================================================
# 300
# nome: MAURICIO FARIA TETTI
# mensagem: 07/10 Aviccena  -  Maurício saída 18:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 18:30
# duração do plantão 05:30
# ========================================
#
# 301
# nome: DANIEL MASUZAKI WONG
# mensagem: 07/10 Morumbi  -  Wong saída 18:15
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 18:30
# duração do plantão 05:30
# ========================================
#
# 302
# nome: MILTON OLAIO NETO
# mensagem: 07/10 - Itaim Olaio saída 18:38
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 19:00
# duração do plantão 06:00
# ========================================
#
# 303
# nome: KAREN PEIXOTO RICCI
# mensagem: 07/10 Itaim Karen saída 18:30
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 18:30
# duração do plantão 05:30
# ========================================
#
# 304
# nome: MAIRA LEITE BASILE
# mensagem: 07/10 Morumbi Maíra saída 19:15
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 19:30
# duração do plantão 00:30
# ========================================
#
# 305
# nome: NORIVAL SCANDELAI JUNIOR
# mensagem: 07/10 Morumbi  -  Norival Saída 18:45
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 19:00
# duração do plantão 06:00
# ========================================
#
# 306
# nome: JULIANO MOISES TOBAL
# mensagem: 07/10 Anália Juliano Tobal saída 19:10
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 19:30
# duração do plantão 00:30
# ========================================
#
# 307
# nome: GABRIEL ELIAS GEWEHR SALMEN RAFFOUL
# mensagem: 07/10 Morumbi Salmen saída 20:55
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 21:00
# duração do plantão 02:00
# ========================================
#
# 308
# nome: YURI ANDERSON PACHECO DE LIMA
# mensagem: 07/10 Morumbi  -  Yuri saída 21:10
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 21:30
# duração do plantão 02:30
# ========================================
#
# 309
# nome: ANA GABRIELA GEWEHR VALE SALMEN
# mensagem: 07/10 Morumbi  -  Vale saída 19:50
# dia: 07/10/2023
# hora de entrada: 19:00
# hora de saida: 20:00
# duração do plantão 01:00
# ========================================
#
# 310
# nome: JULIANA HUSSEIN GRILO
# mensagem: 07/10 ANALIA  -  J. Hussein saída 16:10
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 16:30
# duração do plantão 03:30
# ========================================
#
# 311
# nome: LUIZ GUILHERME THOMAZ ZACHARIAS
# mensagem: 07/10 ITAIM  -  Guilherme saída 18:15
# dia: 07/10/2023
# hora de entrada: 13:00
# hora de saida: 18:30
# duração do plantão 05:30
# ========================================
#
# 312
# nome: AMANDA KIYOKO SOUZA KOSSAKA
# mensagem: 08/10 CENTRAL  -  Amanda entrada 06:00
# dia: 08/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 313
# nome: DANIEL MASUZAKI WONG
# mensagem: 08/10 Jabaquara  -  Wong entrada 06:30
# dia: 08/10/2023
# hora de entrada: 06:30
# hora de saida: 07:00
# duração do plantão 00:30
# ========================================
#
# 314
# nome: THIAGO BARRETO MARQUES DA SILVA
# mensagem: 08/10 Osasco  -  Naldo entrada 06:45
# dia: 08/10/2023
# hora de entrada: 06:30
# hora de saida: 07:00
# duração do plantão 00:30
# ========================================
#
# 315
# nome: KAREN CAVICHINI ROSSETO
# mensagem: 08/10 Villa  -  Cavichini entrada 05:45
# dia: 08/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# ========================================
#
# 316
# nome: FILIPE MAEDA HASHI ABDALLA MARTINS
# mensagem: 08/10 Santa Maeda entrada 9:40
# dia: 08/10/2023
# hora de entrada: 09:30
# hora de saida: 13:00
# duração do plantão 03:30
# PROB
# ========================================
#
# 317
# nome: FILIPE MAEDA HASHI ABDALLA MARTINS
# mensagem: 08/10 Santa Maeda saída 11:00
# dia: 08/10/2023
# hora de entrada: 07:00
# hora de saida: 11:00
# duração do plantão 04:00
# PROB
# ========================================
#
# 318
# nome: MATHEUS DE ALENCAR ARRAES
# mensagem: 08/10 JABAQUARA entrada 07:50
# dia: 08/10/2023
# hora de entrada: 07:30
# hora de saida: 13:00
# duração do plantão 05:30
# PROB
# ========================================
#
# 319
# nome: MATHEUS DE ALENCAR ARRAES
# mensagem: 08/10 JABAQUARA Arraes saida 11:17
# dia: 08/10/2023
# hora de entrada: 07:00
# hora de saida: 11:30
# duração do plantão 04:30
# PROB
# ========================================
#
# 320
# nome: ANA JUNG DOCKO
# mensagem: 08/10 Itaim Ana entrada 07:20
# dia: 08/10/2023
# hora de entrada: 07:00
# hora de saida: 13:00
# duração do plantão 06:00
# PROB
# ========================================
#
# 321
# nome: GABRIELLA GADELHA SARMENTO
# mensagem: 09/10 Itaim  -  Gabriella entrada 04:50
# dia: 09/10/2023
# hora de entrada: 04:30
# hora de saida: 07:00
# duração do plantão 02:30
# ========================================
#
# 322
# nome: VICTOR SAPOUNTZAKIS RIBEIRO
# mensagem: 09/10 Jabaquara  -  Sapountzakis entrada 5:00
# dia: 09/10/2023
# hora de entrada: 05:00
# hora de saida: 07:00
# duração do plantão 02:00
# ========================================
#
# 323
# nome: NATHALIA FANUCCI OLIVEIRA DI JORGE
# mensagem: 09/10 MORUMBI Nathália entrada 05:15   (  EXTRA  )
# dia: 09/10/2023
# hora de entrada: 05:00
# hora de saida: 07:00
# duração do plantão 02:00
# EXTRA
# ========================================
#
# 324
# nome: RICARDO BARBOSA VIANA FILHO
# mensagem: 09/10 Anália  -  Barbosa Entrada 05:35   (   EXTRA  )
# dia: 09/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# EXTRA
# ========================================
#
# ================================================================================
# NORM            239
# PROBS            82
# NORM DUPLI        4
# DESLOCADO 6H      4
# Name: controle, dtype: int64
# ================================================================================
# 325
# nome: NATAN SOARES SILVEIRA
# mensagem: 09/10 Jabaquara  -  Natan  -  entrada 05:35   (  deslocado Anália  )
# dia: 09/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# ========================================
#
# 326
# nome: VITOR OLIVEIRA ANDRE
# mensagem: 09/10 Jabaquara Vitor entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 327
# nome: DIOGO HENRIQUE PEREIRA MATTOS
# mensagem: 09/10 SANTA  -  Diogo entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 328
# nome: ALINE FRANCHINI GOULART LIMA
# mensagem: 09/10 Villa Aline entrada 05:35   (  deslocada ANÁLIA  )
# dia: 09/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# ========================================
#
# 329
# nome: FABIANA SOARES GAMA
# mensagem: 09/10 Anália Fabiana Gama entrada as 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 330
# nome: IZABELA CARDOSO GARCIA
# mensagem: 09/10 Itaim  -  Garcia entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 331
# nome: FILIPE MAEDA HASHI ABDALLA MARTINS
# mensagem: 09/10 Jabaquara Maeda entrada 6:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 332
# nome: RICARDO GIRALDELLI CARVALHO LIMA
# mensagem: 09/10 OSASCO  -  Giraldelli entrada 06:00   (  deslocado HAF  )
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 333
# nome: LUCIANO ANGELO RICHETTI
# mensagem: 9/10 ITAIM Luciano entrada 6:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 334
# nome: CARLOS EDUARDO CORREA GRILO
# mensagem: 09/10 Anália  -  Cadu entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 335
# nome: KAREN PEIXOTO RICCI
# mensagem: 09/10 Osasco Karen entrada 6:00   (  Extra  )
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# EXTRA
# ========================================
#
# 336
# nome: MARCIO IGHOR AZEVEDO SILVA DE MENDONCA MELANIA
# mensagem: 09/10 CENTRAL  -  Ighor entrada 05:40   (  deslocado Anália  )
# dia: 09/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# ========================================
#
# 337
# nome: IVA BARBOSA SOARES
# mensagem: 09/10 Osasco Ivã entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 338
# nome: NATALIA MAIA QUEIROZ
# mensagem: 09/10 Osasco Queiroz entrada 05:30   (   EXTRA  )
# dia: 09/10/2023
# hora de entrada: 05:30
# hora de saida: 07:00
# duração do plantão 01:30
# EXTRA
# ========================================
#
# 339
# nome: HENRI ROGER WATANABE OLIVEIRA
# mensagem: 09/10 Itaim  -  Henri entrada as 05:00
# dia: 09/10/2023
# hora de entrada: 05:00
# hora de saida: 07:00
# duração do plantão 02:00
# ========================================
#
# 340
# nome: RAFAEL SOUZA FAVA NERSESSIAN
# mensagem: 09/10 Itaim Rafael Fava entrada 6:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 341
# nome: GABRIELA SOARES PIASSI
# mensagem: 09/10 Osasco  -  Piassi entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 342
# nome: LAYSA LAYNA RIBEIRO LIMA
# mensagem: 09/10 Villa Laysa entrada 6:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 343
# nome: RODRIGO ANTONIO REY GONZALEZ
# mensagem: 09/10 OSASCO  -  Rey entrada 04:50
# dia: 09/10/2023
# hora de entrada: 04:30
# hora de saida: 07:00
# duração do plantão 02:30
# ========================================
#
# 344
# nome: NARA YAMANE DOS SANTOS
# mensagem: 09/10 -  morumbi Nara entrada as 6:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 345
# nome: DARLAN JUNIOR SCHNEIDER
# mensagem: 09/10 Morumbi  -  Darlan entrada 6:15
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 346
# nome: BRUCE YE MAN CHOW
# mensagem: 09/10 Morumbi  -  bruce entrada 06:00
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 347
# nome: MARCELO MAIA DA SILVEIRA
# mensagem: 09/10 VILLA   -  Maia Entrada 06:10
# dia: 09/10/2023
# hora de entrada: 06:00
# hora de saida: 07:00
# duração do plantão 01:00
# ========================================
#
# 348
# nome: EDUARDO DALA ROSA SOARES
# mensagem: 09/10 VNS  -  Soares entrada 09:00   (   a pedido da coordenação   )
# dia: 09/10/2023
# hora de entrada: 09:00
# hora de saida: 13:00
# duração do plantão 04:00
# PROB
# ========================================
#
# ================================================== TERMINOU ==================================================
# Total   349
# NORM          260
# PROBS          83
# NORM DUPLI      6
# Name: controle, dtype: int64

# %%
df.loc[int(H), 'controle'] = "NORM"
H += 1
print(H)

# %%
df['controle'][h] = 'OK'
H += 1

# %% [markdown]
# # Testes:

# %%
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

# %% [markdown]
# # Salvando restante:

# %%
browser.quit()

# %%
print(df['controle'].value_counts())
print(df['controle'].value_counts(normalize=True)*100)
# Out:
# NORM          260
# PROBS          83
# NORM DUPLI      6
# Name: controle, dtype: int64
# NORM          74.498567
# PROBS         23.782235
# NORM DUPLI     1.719198
# Name: controle, dtype: float64

# %%
# Registros com Problemas Corrigiveis ou Não
df_gabs = df[df['controle'] != 'NORM']
df_gabs.reset_index(drop=True, inplace=True)
print("probs:", len(df_gabs))

# Registros Perfeitos ja feitos
df = df[df['controle'] == 'NORM']
df.reset_index(drop=True, inplace=True)
print("ok:", len(df))
# Out:
# probs: 89
# ok: 260

# %%
def salvando_nome_arquivo(nome_arquivo, dataframe):
    if os.path.exists(nome_arquivo): #O nome_arquivo existe
        df1 = pd.read_excel(nome_arquivo)
        dataframe = pd.concat([df1, dataframe]).reset_index(drop=True)
        dataframe.to_excel(nome_arquivo, index=False)
        print("+=", len(df1), '; len =', len(dataframe)) 

    else: #O nome_arquivo não existe
        dataframe.to_excel(nome_arquivo, index=False)
        print("len =", len(dataframe)) 
        
os.remove("df_gabs.xlsx")
salvando_nome_arquivo('Feitos.xlsx', df)
print('.')
salvando_nome_arquivo('df_gabs2.xlsx', df_gabs)
# Out:
# += 416 ; len = 676
# .
# len = 89

# %% [markdown]
# # Função de Captura ==============================================

# %%
df_backup = df_gabs
print(len(df_backup))
df_backup.sample(5)
# Out:
# 89
#                                                  chat         dia  \
# 38  [06/10/2023 13:11:10] André da Costa Aguiar Ve...  06/10/2023
# 73  [07/10/2023 12:14:11] Sheila Itiroco Monte: 07...  07/10/2023
# 51  [06/10/2023 16:23:24] Larissa Mayumi Ono: 06/1...  06/10/2023
# 70  [07/10/2023 11:31:01] Thiago Barreto Marques d...  07/10/2023
# 61  [07/10/2023 05:47:04] Ronald Figueiredo Gomes:...  07/10/2023
#
#                                nome  \
# 38    ANDRE DA COSTA AGUIAR VENTURA
# 73             SHEILA ITIROCO MONTE
# 51               LARISSA MAYUMI ONO
# 70  THIAGO BARRETO MARQUES DA SILVA
# 61          RONALD FIGUEIREDO GOMES
#
#                                              mensagem controle        data  \
# 38  06/10 MORUMBI Ventura saida 13:10  (   desloca...    PROBS  06/10/2023
# 73              07/10 SANTA ISABEL Sheila saída 12:14    PROBS  07/10/2023
# 51                06/10 Itaim Larissa  -  saída 16:15    PROBS  06/10/2023
# 70                      07/10 santa Naldo saída 11:30    PROBS  07/10/2023
# 61             06/10 JABAQUARA  -  Ronald saida 17:10    PROBS  06/10/2023
#
#          unidade extra   tipo ENTRADA  SAIDA DURAÇÃO PERIODO  periodo  \
# 38       MORUMBI   NaN  SAIDA   13:00  13:30   00:30   tarde        3
# 73  SANTA ISABEL   NaN  SAIDA   07:00  12:30   05:30   manha        2
# 51         ITAIM   NaN  SAIDA   13:00  16:30   03:30   tarde        3
# 70  SANTA ISABEL   NaN  SAIDA   07:00  11:30   04:30   manha        2
# 61     JABAQUARA   NaN  SAIDA   13:00  17:30   04:30   tarde        3
#
#                            setor sem_ou_fds              unidade2
# 38  SEMANA - TARDE - C.CIRURGICO     semana  ['MORUMBI', 'ITAIM']
# 73     FDS - MANHA - C.CIRURGICO        fds                 SANTA
# 51  SEMANA - TARDE - C.CIRURGICO     semana                 ITAIM
# 70     FDS - MANHA - C.CIRURGICO        fds                 SANTA
# 61  SEMANA - TARDE - C.CIRURGICO     semana                  JABA

# %%
#########2
#capturando registros
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

def funcao():
    lista_tabela = []
    for i in range(1, 6): #passando por cada semana[1 a 5]
    ##print('semana:', i, "=="*20)
        for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
            reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
            content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
            content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra
            
            dia = content[0] #dia do registro
            del(content[0]) #deletando o dia, ja que foi coletado
            del(content[-1]) #deletando resido do wepscraping

            if len(content) != 0: #ignorando dias em branco (sem registro) ¹
                #print('dia:', t)

                ##print('dia:', dia)
                #print(content)

                count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
                lista_control = []
                for y in content: #passando um for sobre cada item da lista
                    if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                        #print('================unidade:', y)
                        unidade = y
                    elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                        count_hora += 1
                        if count_hora == 1: #capturando entrada
                            #print('hora entrada:', y)
                            lista_control.append(y)
                        elif count_hora == 2: #capturando saida
                            #print('hora saida:', y)
                            lista_control.append(y)
                            ##print('lista teste', lista_control)
                            lista_tabela.append(lista_control)
                            lista_control = []
                            count_hora = 0
                    else: #capturando dia, unidade, e periodo
                        #print('.')
                        #print('periodo:', y)
                        lista_control.append(dia)
                        lista_control.append(unidade)
                        lista_control.append(y)
                        lista_control.append(i)
                        lista_control.append(t) #dia semanal

                ##print('='*20)    

            else:
                continue #ignorando dias em branco (sem registro) ²

    tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Dia Semana','Entrada','Saida'])
    
    #limpeza da tabela
    #########3
    tabela['Dia'] = tabela['Dia'].apply(lambda x: int(x))

    #recolhendo os dias do mes passado que ainda aparecem na primeira semana
    dias_mes_passado = list(tabela[(tabela['Dia'] > 20) & (tabela['Semana'] == 1)].index) 
    tabela.drop(dias_mes_passado, axis=0, inplace=True) #excluindo
    tabela.reset_index(drop=True, inplace=True) #resetando index

    #Inserindo a ordem dos registros
    tabela['ordem'] = ''

    for i in tabela['Dia'].unique():
        for t in range(0, len(tabela[tabela['Dia'] == i].index)):
            tabela['ordem'][tabela[tabela['Dia'] == i].index[t]] = t+1

    #Inserindo coluna de data        
    tabela['data'] = tabela['Dia'].apply(lambda x: str(x))

    for i in range(len(tabela)):
        if len(tabela['data'][i]) == 1:
            tabela['data'][i] = "0" + tabela['data'][i]

        tabela['data'][i] = tabela['data'][i] + "/" + mes + "/2023" 

    tabela = tabela.query("Unidade != 'ADMINISTRACAO'")
    tabela = tabela[~((tabela['Semana'] >= 5) & (tabela['Dia'] < 10))]
    tabela.reset_index(drop=True, inplace=True) #resetando index
    
    return tabela
    
tabela = funcao()
tabela
# Out:
#     Dia       Unidade                       Periodo  Semana  Dia Semana  \
# 0     3  SANTA ISABEL  SEMANA - MANHA - C.CIRURGICO       2           2
# 1     3  SANTA ISABEL  SEMANA - TARDE - C.CIRURGICO       2           2
# 2     3  SANTA ISABEL    SEMANA - NOTURNO - PLANTAO       2           2
# 3     4         VILLA  SEMANA - MANHA - C.CIRURGICO       2           3
# 4     4         VILLA  SEMANA - TARDE - C.CIRURGICO       2           3
# 5     4         VILLA      SEMANA - NOTURNO - SAIDA       2           3
# 6     5      AVICCENA  SEMANA - MANHA - C.CIRURGICO       2           4
# 7     5      AVICCENA  SEMANA - TARDE - C.CIRURGICO       2           4
# 8     6         ITAIM                  SEMANA - 6HS       2           5
# 9     6         ITAIM  SEMANA - MANHA - C.CIRURGICO       2           5
# 10    6         ITAIM  SEMANA - TARDE - C.CIRURGICO       2           5
# 11    7  SANTA ISABEL     FDS - MANHA - C.CIRURGICO       2           6
# 12    7  SANTA ISABEL                      FDS - D1       2           6
# 13    7  SANTA ISABEL                      FDS - D1       2           6
# 14   10  SANTA ISABEL  SEMANA - MANHA - C.CIRURGICO       3           2
# 15   10  SANTA ISABEL  SEMANA - TARDE - C.CIRURGICO       3           2
# 16   10  SANTA ISABEL    SEMANA - NOTURNO - PLANTAO       3           2
# 17   11         VILLA  SEMANA - MANHA - C.CIRURGICO       3           3
# 18   11         VILLA  SEMANA - TARDE - C.CIRURGICO       3           3
# 19   14         VILLA      FDS - C.CIRURGICO ROTINA       3           6
# 20   18         VILLA  SEMANA - MANHA - C.CIRURGICO       4           3
# 21   18         VILLA  SEMANA - TARDE - C.CIRURGICO       4           3
# 22   20         ITAIM  SEMANA - MANHA - C.CIRURGICO       4           5
# 23   20         ITAIM  SEMANA - TARDE - C.CIRURGICO       4           5
# 24   25         VILLA  SEMANA - MANHA - C.CIRURGICO       5           3
# 25   25         VILLA  SEMANA - TARDE - C.CIRURGICO       5           3
#
#    Entrada  Saida ordem        data
# 0    07:00  13:00     1  03/10/2023
# 1    13:00  19:00     2  03/10/2023
# 2    19:00  07:00     3  03/10/2023
# 3    11:00  13:00     1  04/10/2023
# 4    13:00  19:00     2  04/10/2023
# 5    19:00  23:30     3  04/10/2023
# 6    07:00  13:00     1  05/10/2023
# 7    13:00  19:00     2  05/10/2023
# 8    05:00  07:00     1  06/10/2023
# 9    07:00  13:00     2  06/10/2023
# 10   13:00  19:00     3  06/10/2023
# 11   07:00  13:00     1  07/10/2023
# 12   13:00  19:00     2  07/10/2023
# 13   19:00  07:00     3  07/10/2023
# 14   07:00  13:00     1  10/10/2023
# 15   13:00  19:00     2  10/10/2023
# 16   19:00  07:00     3  10/10/2023
# 17   11:00  13:00     1  11/10/2023
# 18   13:00  19:00     2  11/10/2023
# 19   07:00  13:00     1  14/10/2023
# 20   11:00  13:00     1  18/10/2023
# 21   13:00  19:00     2  18/10/2023
# 22   07:00  13:00     1  20/10/2023
# 23   13:00  19:00     2  20/10/2023
# 24   11:00  13:00     1  25/10/2023
# 25   13:00  19:00     2  25/10/2023

# %% [markdown]
# # Diminuindo Tempos dos Registros ===============================================

# %%
from selenium.webdriver.common.action_chains import ActionChains

action_chains = ActionChains(browser)

# %%
len(df_backup)
# Out:
# 89

# %%
count = 0

# %%
#Para cada profissional na lista
df = df_backup[count:]

for i in df['nome'].unique():
    print("nome:", i)
    df_nome = df[df['nome'] == i]
    df_nome.reset_index(drop=True, inplace=True)
    
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    #browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/div/div[1]/div[3]/professionals/div/a/span[2]/b').click()
    sleep(2)
    
    browser.find_element("xpath", '/html/body/div[6]/div/input').send_keys(i)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()

    #esperando carregamento do site
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))

    
    tabela = funcao()    
    display(tabela)
    break
# Out:
# nome: PEDRO HENRIQUE DINIZ BOTELHO
#     Dia    Unidade                             Periodo  Semana  Dia Semana  \
# 0     2  JABAQUARA        SEMANA - TARDE - C.CIRURGICO       2           1
# 1     2     OSASCO        SEMANA - MANHA - C.CIRURGICO       2           1
# 2     2     OSASCO            SEMANA - NOTURNO - SAIDA       2           1
# 3     3     OSASCO        SEMANA - MANHA - C.CIRURGICO       2           2
# 4     3     OSASCO        SEMANA - TARDE - C.CIRURGICO       2           2
# 5     3     OSASCO          SEMANA - NOTURNO - PLANTAO       2           2
# 6     5     OSASCO        SEMANA - MANHA - C.CIRURGICO       2           4
# 7     5     OSASCO          SEMANA - NOTURNO - PLANTAO       2           4
# 8     6      ALPHA        SEMANA - MANHA - C.CIRURGICO       2           5
# 9     6      ALPHA        SEMANA - TARDE - C.CIRURGICO       2           5
# 10   10      ITAIM        SEMANA - MANHA - C.CIRURGICO       3           2
# 11   10      ITAIM        SEMANA - TARDE - C.CIRURGICO       3           2
# 12   11     ANALIA  SEMANA - MANHA - AV.PRE ANESTESICA       3           3
# 13   11     ANALIA        SEMANA - TARDE - C.CIRURGICO       3           3
# 14   20     OSASCO    SEMANA - MANHA - COBERTURA EXTRA       4           5
# 15   20     OSASCO    SEMANA - TARDE - COBERTURA EXTRA       4           5
# 16   21  JABAQUARA            FDS - C.CIRURGICO ROTINA       4           6
# 17   24     OSASCO    SEMANA - MANHA - COBERTURA EXTRA       5           2
# 18   24     OSASCO    SEMANA - TARDE - COBERTURA EXTRA       5           2
# 19   25     OSASCO    SEMANA - MANHA - COBERTURA EXTRA       5           3
# 20   25     OSASCO    SEMANA - TARDE - COBERTURA EXTRA       5           3
# 21   26     OSASCO        SEMANA - MANHA - C.CIRURGICO       5           4
# 22   26     OSASCO        SEMANA - TARDE - C.CIRURGICO       5           4
# 23   27   AVICCENA        SEMANA - MANHA - C.CIRURGICO       5           5
# 24   27   AVICCENA        SEMANA - TARDE - C.CIRURGICO       5           5
# 25   28      VILLA          FDS - AVALIACAO PRE ROTINA       5           6
# 26   29      ITAIM                       FDS - PLANTAO       5           7
# 27   29      ITAIM                       FDS - PLANTAO       5           7
#
#    Entrada  Saida ordem        data
# 0    13:00  19:00     1  02/10/2023
# 1    07:00  13:00     2  02/10/2023
# 2    19:00  22:30     3  02/10/2023
# 3    07:00  13:00     1  03/10/2023
# 4    13:00  19:00     2  03/10/2023
# 5    19:00  07:00     3  03/10/2023
# 6    07:00  13:00     1  05/10/2023
# 7    19:00  07:00     2  05/10/2023
# 8    07:00  13:00     1  06/10/2023
# 9    13:00  19:00     2  06/10/2023
# 10   07:00  13:00     1  10/10/2023
# 11   13:00  19:00     2  10/10/2023
# 12   07:00  13:00     1  11/10/2023
# 13   13:00  19:00     2  11/10/2023
# 14   07:00  13:00     1  20/10/2023
# 15   13:00  19:00     2  20/10/2023
# 16   07:00  13:00     1  21/10/2023
# 17   07:00  13:00     1  24/10/2023
# 18   13:00  19:00     2  24/10/2023
# 19   07:00  13:00     1  25/10/2023
# 20   13:00  19:00     2  25/10/2023
# 21   11:00  13:00     1  26/10/2023
# 22   13:00  19:00     2  26/10/2023
# 23   07:00  13:00     1  27/10/2023
# 24   13:00  19:00     2  27/10/2023
# 25   07:00  13:00     1  28/10/2023
# 26   07:00  19:00     1  29/10/2023
# 27   19:00  07:00     2  29/10/2023
