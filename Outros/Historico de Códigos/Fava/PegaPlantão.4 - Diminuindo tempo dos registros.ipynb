# %%
mes = "06"

# %%
#manipulação de dados
import pandas as pd
import numpy as np

#automação
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#web scraping
import requests
from bs4 import BeautifulSoup

#string e data
import unidecode

#tempo
import time
from time import sleep
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import (visibility_of, 
                                                           staleness_of, 
                                                           invisibility_of_element)

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager

browser = webdriver.Firefox(executable_path=GeckoDriverManager().install())
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_2632\3429260821.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Firefox(executable_path=GeckoDriverManager().install())

# %%
browser.get('https://www.pegaplantao.com.br/login')
sleep(1)
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_UserName"]').send_keys('gabriel_s_anjos@yahoo.com') #e-mail
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_Password"]').send_keys('Gabriel2022!') #senha
browser.find_element("xpath", '//*[@id="MainContent_LoginUser_btnLogin"]').click() #login

# %%
browser.get('https://www.pegaplantao.com.br/EscalaMensal')

# %%
#click setor/profissional
browser.find_element("xpath", '//*[@id="s2id_autogen1"]/a/span[1]').click()
#click [profissional]
browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li[2]/div').click()

# %%
df_backup = pd.read_excel('df_rodar4.xlsx')

df_backup = df_backup.sort_values(['nome', 'data'])
df_backup.reset_index(drop=True, inplace=True)

df = df_backup.copy()

df
# Out:
#                                                  chat         dia  \
# 0   [30/06/2023 07:16:34] Alexsander Takashi Hamad...  30/06/2023
# 1   [29/06/2023 16:12:38] Bruna Daibert Danesin: 2...  29/06/2023
# 2   [29/06/2023 14:51:55] Camila Chiarantano Harri...  29/06/2023
# 3   [29/06/2023 14:47:27] Cláudio Mueller Kakuda: ...  29/06/2023
# 4   [29/06/2023 15:27:25] Diogo Henrique Pereira M...  29/06/2023
# 5   [29/06/2023 13:43:26] Eduardo Dala Rosa Soares...  29/06/2023
# 6   [29/06/2023 16:32:33] Estanrley Barcelos Pinto...  29/06/2023
# 7   [29/06/2023 16:44:16] Fabiana Barbosa Bastos: ...  29/06/2023
# 8   [30/06/2023 04:20:54] Fernando Akira Koga: 30/...  30/06/2023
# 9   [30/06/2023 06:19:13] Fernando Ribeiro Sá: 30/...  30/06/2023
# 10  [29/06/2023 16:00:35] Flavio Hideki Oshika: 29...  29/06/2023
# 11  [29/06/2023 16:27:14] Francisco José Lucena Be...  29/06/2023
# 12  [29/06/2023 10:59:23] Jessica Lidia de Souza: ...  29/06/2023
# 13  [29/06/2023 16:57:34] Juliana Akemi Funabashi:...  29/06/2023
# 14  [30/06/2023 01:54:26] Leandro Oliveira Martins...  30/06/2023
# 15  [29/06/2023 14:25:24] Leonardo de Paula Souza:...  29/06/2023
# 16  [29/06/2023 17:03:49] Manoel de Souza Neto: 29...  29/06/2023
# 17  [29/06/2023 14:10:10] Marcos Rogério Pereira M...  29/06/2023
# 18  [29/06/2023 17:11:33] Matheus Acquesta Gaubeur...  29/06/2023
# 19  [29/06/2023 15:10:18] Milton Olaio Neto: 29/6-...  29/06/2023
# 20  [30/06/2023 10:34:38] Natan Soares Silveira: 3...  30/06/2023
# 21  [29/06/2023 14:35:35] Orlando Domingues de Ara...  29/06/2023
# 22  [29/06/2023 17:07:27] Paula Angélica Pinha Nev...  29/06/2023
# 23  [29/06/2023 17:01:46] Pedro Henrique Diniz Bot...  29/06/2023
# 24  [29/06/2023 19:09:27] Renata Togeiro Bastos Go...  29/06/2023
# 25  [29/06/2023 18:15:46] Ricardo Giraldelli Carva...  29/06/2023
# 26  [29/06/2023 14:55:46] Ricardo Ivo de Lima: 29/...  29/06/2023
# 27  [29/06/2023 16:25:55] Rodrigo Miyashiro Nunes ...  29/06/2023
# 28  [30/06/2023 07:22:08] Thales Luvisotto Neder: ...  30/06/2023
#
#                                     nome  \
# 0              ALEXSANDER TAKASHI HAMADA
# 1                  BRUNA DAIBERT DANESIN
# 2            CAMILA CHIARANTANO HARRISON
# 3                 CLAUDIO MUELLER KAKUDA
# 4          DIOGO HENRIQUE PEREIRA MATTOS
# 5               EDUARDO DALA ROSA SOARES
# 6               ESTANRLEY BARCELOS PINTO
# 7                 FABIANA BARBOSA BASTOS
# 8                    FERNANDO AKIRA KOGA
# 9                    FERNANDO RIBEIRO SA
# 10                  FLAVIO HIDEKI OSHIKA
# 11         FRANCISCO JOSE LUCENA BEZERRA
# 12                JESSICA LIDIA DE SOUZA
# 13               JULIANA AKEMI FUNABASHI
# 14       LEANDRO OLIVEIRA MARTINS CORTES
# 15               LEONARDO DE PAULA SOUZA
# 16                  MANOEL DE SOUZA NETO
# 17  MARCOS ROGERIO PEREIRA MACHADO FILHO
# 18              MATHEUS ACQUESTA GAUBEUR
# 19                     MILTON OLAIO NETO
# 20                 NATAN SOARES SILVEIRA
# 21    ORLANDO DOMINGUES DE ARAUJO PONTES
# 22            PAULA ANGELICA PINHA NEVES
# 23          PEDRO HENRIQUE DINIZ BOTELHO
# 24  RENATA TOGEIRO BASTOS GODOY DE FARIA
# 25      RICARDO GIRALDELLI CARVALHO LIMA
# 26                   RICARDO IVO DE LIMA
# 27    RODRIGO MIYASHIRO NUNES DOS SANTOS
# 28                THALES LUVISOTTO NEDER
#
#                                              mensagem controle        data  \
# 0                    30/06  VILLA - ALEX ENTRADA 7:10    PROBS  30/06/2023
# 1                      29/06 ANÁLIA BRUNA SAIDA 15:00    PROBS  29/06/2023
# 2                      29/06 VILLA CAMILA SAIDA 14:50    PROBS  29/06/2023
# 3              29/06 MATERNIDADE - KAKUDA SAIDA 14:45    PROBS  29/06/2023
# 4                    29/06 ANÁLIA - DIOGO SAIDA 15:20    PROBS  29/06/2023
# 5   29/06 MORUMBI - SOARES ENTRADA 04:00  (  EXTRA...    PROBS  29/06/2023
# 6                 29/06 ANÁLIA-ESTANRLEY SAIDA: 16:30    PROBS  29/06/2023
# 7                    29/06  VNS - FABIANA SAIDA 16:40    PROBS  29/06/2023
# 8                      30/06 VNS - KOGA ENTRADA 04:20    PROBS  30/06/2023
# 9                     30/06 VNS RIBEIRO ENTRADA 06:10    PROBS  30/06/2023
# 10                  29/06 ANÁLIA - FLÁVIO SAIDA 15:40    PROBS  29/06/2023
# 11                  29/06 ANÁLIA- LUCENA- SAIDA 16:30    PROBS  29/06/2023
# 12               29/06 VILLA - JESSICA  ENTRADA 11:00    PROBS  29/06/2023
# 13                   29/06 ANÁLIA - AKEMI SAIDA 16:55    PROBS  29/06/2023
# 14  29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂN...    PROBS  29/06/2023
# 15                   29/06 SANTA LEONARDO SAIDA 13:40    PROBS  29/06/2023
# 16              29/06 SANTA ISABEL MANOEL SAIDA 17:00    PROBS  29/06/2023
# 17                     29/06 SANTA MARCOS SAIDA 14:10    PROBS  29/06/2023
# 18                 29/06 ANÁLIA - MATHEUS SAIDA 17:10    PROBS  29/06/2023
# 19                       29/6-ITAIM OLAIO SAIDA 14:55    PROBS  29/06/2023
# 20  30/06 AVICCENA- NATAN- ENTRADA 11:00  ( A PEDI...    PROBS  30/06/2023
# 21                 29/06 AVICCENA ORLANDO SAIDA 14:35    PROBS  29/06/2023
# 22               29/06 ANÁLIA PAULA NEVES SAIDA 15:30    PROBS  29/06/2023
# 23                   29/06 ANÁLIA - DINIZ SAIDA 16:50    PROBS  29/06/2023
# 24         29/06 MORUMBI - RENATA TOGEIRO SAIDA 14:50    PROBS  29/06/2023
# 25              29/06 ANÁLIA - GIRALDELLI SAIDA 16:55    PROBS  29/06/2023
# 26       29/06 - MORUMBI - RICARDO IVO SAIDA - 14:50H    PROBS  29/06/2023
# 27              29/06 MORUMBI - MIYASHIRO SAIDA 16:25    PROBS  29/06/2023
# 28    30/06 OSASCO - THALES ENTRADA 07:00  ( EXTRA )     PROBS  30/06/2023
#
#          unidade  Q_unidades  sit  extra  ...   hora sem_ou_fds     hora2  \
# 0          VILLA           1  NaN    NaN  ...  07:00     semana  07:10:00
# 1         ANALIA           1  NaN    NaN  ...  15:00     semana  15:00:00
# 2          VILLA           1  NaN    NaN  ...  15:00     semana  14:50:00
# 3    MATERNIDADE           1  NaN    NaN  ...  15:00     semana  14:45:00
# 4         ANALIA           1  NaN    NaN  ...  15:30     semana  15:20:00
# 5        MORUMBI           1  NaN  extra  ...  04:00     semana  04:00:00
# 6         ANALIA           1  NaN    NaN  ...  16:30     semana  16:30:00
# 7            VNS           1  NaN    NaN  ...  17:00     semana  16:40:00
# 8            VNS           1  NaN    NaN  ...  04:00     semana  04:20:00
# 9            VNS           1  NaN    NaN  ...  06:00     semana  06:10:00
# 10        ANALIA           1  NaN    NaN  ...  16:00     semana  15:40:00
# 11        ANALIA           1  NaN    NaN  ...  16:30     semana  16:30:00
# 12         VILLA           1  NaN    NaN  ...  11:00     semana  11:00:00
# 13        ANALIA           1  NaN    NaN  ...  17:00     semana  16:55:00
# 14     JABAQUARA           1  NaN    NaN  ...  02:00     semana  01:50:00
# 15  SANTA ISABEL           1  NaN    NaN  ...  14:00     semana  13:40:00
# 16  SANTA ISABEL           1  NaN    NaN  ...  17:00     semana  17:00:00
# 17  SANTA ISABEL           1  NaN    NaN  ...  14:30     semana  14:10:00
# 18        ANALIA           1  NaN    NaN  ...  17:30     semana  17:10:00
# 19         ITAIM           1  NaN    NaN  ...  15:00     semana  14:55:00
# 20      AVICCENA           1  NaN    NaN  ...  11:00     semana  11:00:00
# 21      AVICCENA           1  NaN    NaN  ...  15:00     semana  14:35:00
# 22        ANALIA           1  NaN    NaN  ...  15:30     semana  15:30:00
# 23        ANALIA           1  NaN    NaN  ...  17:00     semana  16:50:00
# 24       MORUMBI           1  NaN    NaN  ...  15:00     semana  14:50:00
# 25        ANALIA           1  NaN    NaN  ...  17:00     semana  16:55:00
# 26       MORUMBI           1  NaN    NaN  ...  15:00     semana  14:50:00
# 27       MORUMBI           1  NaN    NaN  ...  16:30     semana  16:25:00
# 28        OSASCO           1  NaN  extra  ...  07:00     semana  07:00:00
#
#    ENTRADA  SAIDA        PERIODO DURAÇÃO                         setor  \
# 0    07:00  13:00          manha   06:00  SEMANA - MANHA - C.CIRURGICO
# 1    13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 2    13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 3    13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 4    13:00  15:30          tarde   02:30  SEMANA - TARDE - C.CIRURGICO
# 5    04:00  07:00             6h   03:00                  SEMANA - 6HS
# 6    13:00  16:30          tarde   03:30  SEMANA - TARDE - C.CIRURGICO
# 7    13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
# 8    04:00  07:00             6h   03:00                  SEMANA - 6HS
# 9    06:00  07:00             6h   01:00                  SEMANA - 6HS
# 10   13:00  16:00          tarde   03:00  SEMANA - TARDE - C.CIRURGICO
# 11   13:00  16:30          tarde   03:30  SEMANA - TARDE - C.CIRURGICO
# 12   11:00  13:00          manha   02:00  SEMANA - MANHA - C.CIRURGICO
# 13   13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
# 14   19:00  02:00  noturno saida   07:00      SEMANA - NOTURNO - SAIDA
# 15   13:00  14:00          tarde   01:00  SEMANA - TARDE - C.CIRURGICO
# 16   13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
# 17   13:00  14:30          tarde   01:30  SEMANA - TARDE - C.CIRURGICO
# 18   13:00  17:30          tarde   04:30  SEMANA - TARDE - C.CIRURGICO
# 19   13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 20   11:00  13:00          manha   02:00  SEMANA - MANHA - C.CIRURGICO
# 21   13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 22   13:00  15:30          tarde   02:30  SEMANA - TARDE - C.CIRURGICO
# 23   13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
# 24   13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 25   13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
# 26   13:00  15:00          tarde   02:00  SEMANA - TARDE - C.CIRURGICO
# 27   13:00  16:30          tarde   03:30  SEMANA - TARDE - C.CIRURGICO
# 28   07:00  13:00          manha   06:00  SEMANA - MANHA - C.CIRURGICO
#
#           dt conferir
# 0   13:00:00      NaN
# 1   15:00:00      NaN
# 2   15:00:00      NaN
# 3   15:00:00      NaN
# 4   15:30:00      NaN
# 5   07:00:00      NaN
# 6   16:30:00      NaN
# 7   17:00:00      NaN
# 8   07:00:00      NaN
# 9   07:00:00      NaN
# 10  16:00:00      NaN
# 11  16:30:00      NaN
# 12  13:00:00      NaN
# 13  17:00:00      NaN
# 14  02:00:00      SIM
# 15  14:00:00      NaN
# 16  17:00:00      NaN
# 17  14:30:00      NaN
# 18  17:30:00      NaN
# 19  15:00:00      NaN
# 20  13:00:00      NaN
# 21  15:00:00      NaN
# 22  15:30:00      NaN
# 23  17:00:00      NaN
# 24  15:00:00      NaN
# 25  17:00:00      NaN
# 26  15:00:00      NaN
# 27  16:30:00      NaN
# 28  13:00:00      NaN
#
# [29 rows x 21 columns]

# %%
len(df)
# Out:
# 29

# %% [markdown]
# # web scraping e limpeza

# %%
#########2
#capturando registros
unidades = ['ADMINISTRACAO','ALPHA','ANALIA','AVICCENA',
            'ITAIM','JABAQUARA','MATERNIDADE','MORUMBI',
            'OSASCO','VILLA','VNS','SANTA ISABEL']

def funcao():
    lista_tabela = []
    for i in range(1, 6): #passando por cada semana[1 a 5]
    ##print('semana:', i, "=="*20)
        for t in range(1, 8): #passando por cada dia[1 a 7] dentro da semana
            reg = browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/table/tbody/tr['+str(i)+']/td['+str(t)+']').text
            content = reg.splitlines() #deixando as palavras em um item dentro de uma lista
            content = [unidecode.unidecode(i.strip().upper()) for i in content] #tratando cada palavra

            dia = content[0] #dia do registro
            del(content[0]) #deletando o dia, ja que foi coletado
            del(content[-1]) #deletando resido do wepscraping

            if len(content) != 0: #ignorando dias em branco (sem registro) ¹
                #print('dia:', t)

                ##print('dia:', dia)
                #print(content)

                count_hora = 0 #count para capturar a hora de entrada e saida, count=1(entrada) | count=2(saida)
                lista_control = []
                for y in content: #passando um for sobre cada item da lista
                    if y in unidades: # capturando a unidade e dando inicio a novo registro novo
                        #print('================unidade:', y)
                        unidade = y
                    elif y[2] == ':': #reconhecendo se o item é hora (HH*:*mm)
                        count_hora += 1
                        if count_hora == 1: #capturando entrada
                            #print('hora entrada:', y)
                            lista_control.append(y)
                        elif count_hora == 2: #capturando saida
                            #print('hora saida:', y)
                            lista_control.append(y)
                            ##print('lista teste', lista_control)
                            lista_tabela.append(lista_control)
                            lista_control = []
                            count_hora = 0
                    else: #capturando dia, unidade, e periodo
                        #print('.')
                        #print('periodo:', y)
                        lista_control.append(dia)
                        lista_control.append(unidade)
                        lista_control.append(y)
                        lista_control.append(i)
                        lista_control.append(t) #dia semanal

                ##print('='*20)    

            else:
                continue #ignorando dias em branco (sem registro) ²

    tabela = pd.DataFrame(lista_tabela, columns = ['Dia','Unidade','Periodo','Semana','Dia Semana','Entrada','Saida'])
    
    #limpeza da tabela
    #########3
    tabela['Dia'] = tabela['Dia'].apply(lambda x: int(x))

    #recolhendo os dias do mes passado que ainda aparecem na primeira semana
    dias_mes_passado = list(tabela[(tabela['Dia'] > 20) & (tabela['Semana'] == 1)].index) 
    tabela.drop(dias_mes_passado, axis=0, inplace=True) #excluindo
    tabela.reset_index(drop=True, inplace=True) #resetando index

    #Inserindo a ordem dos registros
    tabela['ordem'] = ''

    for i in tabela['Dia'].unique():
        for t in range(0, len(tabela[tabela['Dia'] == i].index)):
            tabela['ordem'][tabela[tabela['Dia'] == i].index[t]] = t+1

    #Inserindo coluna de data        
    tabela['data'] = tabela['Dia'].apply(lambda x: str(x))

    for i in range(len(tabela)):
        if len(tabela['data'][i]) == 1:
            tabela['data'][i] = "0" + tabela['data'][i]

        tabela['data'][i] = tabela['data'][i] + "/" + mes + "/2023" 

    tabela = tabela.query("Unidade != 'ADMINISTRACAO'")
    tabela.reset_index(drop=True, inplace=True) #resetando index
    
    return tabela
    
tabela = funcao()
tabela
# Out:
# Empty DataFrame
# Columns: [Dia, Unidade, Periodo, Semana, Dia Semana, Entrada, Saida, ordem, data]
# Index: []

# %% [markdown]
# # alterando horario

# %%
len(df_backup)
# Out:
# 29

# %%
count = 0

# %%
from selenium.webdriver.common.action_chains import ActionChains

action_chains = ActionChains(browser)

# %%
#Para cada profissional na lista
df = df_backup[count:]

for i in df['nome'].unique():
    print("nome:", i)
    df_nome = df[df['nome'] == i]
    df_nome.reset_index(drop=True, inplace=True)
    
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    #browser.find_element("xpath", '/html/body/form/main/div[2]/div[2]/div/div[1]/div[3]/professionals/div/a/span[2]/b').click()
    sleep(2)
    ###SEMPRE DA PROBLEMA
    browser.find_element("xpath", '/html/body/div[8]/div/input').send_keys(i)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()

    #esperando carregamento do site
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))
    
    tabela = funcao()    
    sleep(2)
    
    #Para cada registro na lista_nome
    for t in range(len(df_nome)):
        print(df_nome['mensagem'][t])
        
        dia_sel = tabela[(tabela['Unidade'] == df_nome['unidade'][t]) & 
                 (tabela['data'] == df_nome['data'][t]) & 
                 (tabela['Periodo'] == df_nome["setor"][t])]
        dia_sel.reset_index(drop=True, inplace=True)
        dia_sel
        
        if len(dia_sel) == 0:
            print(count, "-> PROB")
            df_backup['controle'][count] = "PROB"
        else:
            #abrindo/selecionando periodo conforme localização
            elemento = browser.find_element("xpath", '//*[@id="shift-monthly"]/div[2]/table/tbody/tr['+str(dia_sel['Semana'][0])+']/td['+str(dia_sel['Dia Semana'][0])+']/ul['+str(dia_sel['ordem'][0])+']/li')
            elemento.click()
            
            #Esperar componentes carregarem
            WebDriverWait(browser, 10).until(visibility_of(browser.find_element("xpath", '//*[@id="service-ckb-list-all-owner"]')))
            
            #Inicio do plantão
            browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceStartTime"]').send_keys(df_nome['ENTRADA'][t])
            sleep(1)
            #print('hora de entrada:', df_nome['ENTRADA'][t], '\nhora de saida:', df_nome['SAIDA'][t])
            #Duração do plantão
            browser.find_element("xpath", '//*[@id="txtServiceDuration"]').clear()
            browser.find_element("xpath", '//*[@id="txtServiceDuration"]').send_keys(df_nome['DURAÇÃO'][t])
            #print('duração do plantão', df_nome['DURAÇÃO'][t])
            
            #salvar plantão
            sleep(1)
            browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[2]/button[5]').click()
            browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[2]/button[5]').click()
            browser.find_element("xpath", '/html/body/div[5]/div/div[1]/div[2]/button[5]').click()
            sleep(4)
            print(count, "-> OK")
            df_backup['controle'][count] = "OK"
        
        count += 1 
    print("\n")
# Out:
# nome: BRUNA DAIBERT DANESIN
# 29/06 ANÁLIA BRUNA SAIDA 15:00
# 1 -> OK
#
#
# nome: CAMILA CHIARANTANO HARRISON
# 29/06 VILLA CAMILA SAIDA 14:50
# 2 -> OK
#
#
# nome: CLAUDIO MUELLER KAKUDA
# 29/06 MATERNIDADE - KAKUDA SAIDA 14:45
# 3 -> OK
#
#
# nome: DIOGO HENRIQUE PEREIRA MATTOS
# 29/06 ANÁLIA - DIOGO SAIDA 15:20
# 4 -> OK
#
#
# nome: EDUARDO DALA ROSA SOARES
# 29/06 MORUMBI - SOARES ENTRADA 04:00  (  EXTRA  )
# 5 -> PROB
#
#
# nome: ESTANRLEY BARCELOS PINTO
# 29/06 ANÁLIA-ESTANRLEY SAIDA: 16:30
# 6 -> OK
#
#
# nome: FABIANA BARBOSA BASTOS
# 29/06  VNS - FABIANA SAIDA 16:40
# 7 -> OK
#
#
# nome: FERNANDO AKIRA KOGA
# 30/06 VNS - KOGA ENTRADA 04:20
# 8 -> PROB
#
#
# nome: FERNANDO RIBEIRO SA
# 30/06 VNS RIBEIRO ENTRADA 06:10
# 9 -> PROB
#
#
# nome: FLAVIO HIDEKI OSHIKA
# 29/06 ANÁLIA - FLÁVIO SAIDA 15:40
# 10 -> OK
#
#
# nome: FRANCISCO JOSE LUCENA BEZERRA
# 29/06 ANÁLIA- LUCENA- SAIDA 16:30
# 11 -> OK
#
#
# nome: JESSICA LIDIA DE SOUZA
# 29/06 VILLA - JESSICA  ENTRADA 11:00
# 12 -> OK
#
#
# nome: JULIANA AKEMI FUNABASHI
# 29/06 ANÁLIA - AKEMI SAIDA 16:55
# 13 -> OK
#
#
# nome: LEANDRO OLIVEIRA MARTINS CORTES
# 29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂNCIA PARA EFEITO DE ESCALA )
# 14 -> PROB
#
#
# nome: LEONARDO DE PAULA SOUZA
# 29/06 SANTA LEONARDO SAIDA 13:40
# 15 -> OK
#
#
# nome: MANOEL DE SOUZA NETO
# 29/06 SANTA ISABEL MANOEL SAIDA 17:00
# 16 -> OK
#
#
# nome: MARCOS ROGERIO PEREIRA MACHADO FILHO
# 29/06 SANTA MARCOS SAIDA 14:10
# 17 -> OK
#
#
# nome: MATHEUS ACQUESTA GAUBEUR
# 29/06 ANÁLIA - MATHEUS SAIDA 17:10
# 18 -> OK
#
#
# nome: MILTON OLAIO NETO
# 29/6-ITAIM OLAIO SAIDA 14:55
# 19 -> OK
#
#
# nome: NATAN SOARES SILVEIRA
# 30/06 AVICCENA- NATAN- ENTRADA 11:00  ( A PEDIDO DA COORDENAÇÃO )
# 20 -> OK
#
#
# nome: ORLANDO DOMINGUES DE ARAUJO PONTES
# 29/06 AVICCENA ORLANDO SAIDA 14:35
# 21 -> OK
#
#
# nome: PAULA ANGELICA PINHA NEVES
# 29/06 ANÁLIA PAULA NEVES SAIDA 15:30
# 22 -> OK
#
#
# nome: PEDRO HENRIQUE DINIZ BOTELHO
# 29/06 ANÁLIA - DINIZ SAIDA 16:50
# 23 -> OK
#
#
# nome: RENATA TOGEIRO BASTOS GODOY DE FARIA
# 29/06 MORUMBI - RENATA TOGEIRO SAIDA 14:50
# 24 -> OK
#
#
# nome: RICARDO GIRALDELLI CARVALHO LIMA
# 29/06 ANÁLIA - GIRALDELLI SAIDA 16:55
# 25 -> PROB
#
#
# nome: RICARDO IVO DE LIMA
# 29/06 - MORUMBI - RICARDO IVO SAIDA - 14:50H
# 26 -> OK
#
#
# nome: RODRIGO MIYASHIRO NUNES DOS SANTOS
# 29/06 MORUMBI - MIYASHIRO SAIDA 16:25
# 27 -> OK
#
#
# nome: THALES LUVISOTTO NEDER
# 30/06 OSASCO - THALES ENTRADA 07:00  ( EXTRA )
# 28 -> OK

# %%
##### não rodar
#count += 1
#df_backup['controle'][count] = "OK"

# %% [markdown]
# # Salvando dataframe

# %%
df_corrigidos = df_backup[df_backup['controle'] == "OK"]
print("probs ok:", len(df_corrigidos))
df_corrigidos.reset_index(drop=True, inplace=True)

df_prob = df_backup[df_backup['controle'] != "OK"]
print("probs:", len(df_prob))
# Out:
# probs ok: 24
# probs: 5

# %%
df_corrigidos.to_excel("df_final4ok.xlsx", index=False)
df_prob.to_excel("df_finalgiova.xlsx", index=False)

# %% [markdown]
# ###Fim Periodo

# %%
df[df_backup['controle'] != "OK"]
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_2632\1901850781.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_backup['controle'] != "OK"]
#                                                  chat         dia  \
# 5   [29/06/2023 13:43:26] Eduardo Dala Rosa Soares...  29/06/2023
# 8   [30/06/2023 04:20:54] Fernando Akira Koga: 30/...  30/06/2023
# 9   [30/06/2023 06:19:13] Fernando Ribeiro Sá: 30/...  30/06/2023
# 14  [30/06/2023 01:54:26] Leandro Oliveira Martins...  30/06/2023
# 25  [29/06/2023 18:15:46] Ricardo Giraldelli Carva...  29/06/2023
#
#                                 nome  \
# 5           EDUARDO DALA ROSA SOARES
# 8                FERNANDO AKIRA KOGA
# 9                FERNANDO RIBEIRO SA
# 14   LEANDRO OLIVEIRA MARTINS CORTES
# 25  RICARDO GIRALDELLI CARVALHO LIMA
#
#                                              mensagem controle        data  \
# 5   29/06 MORUMBI - SOARES ENTRADA 04:00  (  EXTRA...     PROB  29/06/2023
# 8                      30/06 VNS - KOGA ENTRADA 04:20     PROB  30/06/2023
# 9                     30/06 VNS RIBEIRO ENTRADA 06:10     PROB  30/06/2023
# 14  29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂN...     PROB  29/06/2023
# 25              29/06 ANÁLIA - GIRALDELLI SAIDA 16:55     PROB  29/06/2023
#
#       unidade  Q_unidades  sit  extra  ...   hora sem_ou_fds     hora2  \
# 5     MORUMBI           1  NaN  extra  ...  04:00     semana  04:00:00
# 8         VNS           1  NaN    NaN  ...  04:00     semana  04:20:00
# 9         VNS           1  NaN    NaN  ...  06:00     semana  06:10:00
# 14  JABAQUARA           1  NaN    NaN  ...  02:00     semana  01:50:00
# 25     ANALIA           1  NaN    NaN  ...  17:00     semana  16:55:00
#
#    ENTRADA  SAIDA        PERIODO DURAÇÃO                         setor  \
# 5    04:00  07:00             6h   03:00                  SEMANA - 6HS
# 8    04:00  07:00             6h   03:00                  SEMANA - 6HS
# 9    06:00  07:00             6h   01:00                  SEMANA - 6HS
# 14   19:00  02:00  noturno saida   07:00      SEMANA - NOTURNO - SAIDA
# 25   13:00  17:00          tarde   04:00  SEMANA - TARDE - C.CIRURGICO
#
#           dt conferir
# 5   07:00:00      NaN
# 8   07:00:00      NaN
# 9   07:00:00      NaN
# 14  02:00:00      SIM
# 25  17:00:00      NaN
#
# [5 rows x 21 columns]

# %%
browser.quit()

# %%
print("Registros dos dias:", sorted(list(df_prob["dia"].unique())))
print("quantidade de registros:", len(df_prob), "=",
      str(round((len(df_prob)/len(df_backup))*100, 2)) + "% de todos os registros feitos")
print("#"*30, "\n")

for nome in sorted(list(df_prob['nome'].unique())):
    print(nome, "="*10)
    selecao = df_prob.loc[df_prob['nome']==nome]
    selecao.reset_index(drop=True, inplace=True)
    
    for i in range(len(selecao)):
        print(selecao["mensagem"][i])
    
    print("\n")
# Out:
# Registros dos dias: ['29/06/2023', '30/06/2023']
# quantidade de registros: 5 = 17.24% de todos os registros feitos
# ##############################
#
# EDUARDO DALA ROSA SOARES ==========
# 29/06 MORUMBI - SOARES ENTRADA 04:00  (  EXTRA  )
#
#
# FERNANDO AKIRA KOGA ==========
# 30/06 VNS - KOGA ENTRADA 04:20
#
#
# FERNANDO RIBEIRO SA ==========
# 30/06 VNS RIBEIRO ENTRADA 06:10
#
#
# LEANDRO OLIVEIRA MARTINS CORTES ==========
# 29/06 JABAQUARA - CÔRTES SAIDA 01:50  ( DISTÂNCIA PARA EFEITO DE ESCALA )
#
#
# RICARDO GIRALDELLI CARVALHO LIMA ==========
# 29/06 ANÁLIA - GIRALDELLI SAIDA 16:55

# %%
#CAPTURANDO NOME DE TODOS PROFISSIONAIS ========================================================
browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a').click() #barra de nome

html = browser.find_element("xpath", '//*[@id="select2-drop"]/ul').get_attribute('outerHTML') #
soup_nome = BeautifulSoup(html, 'html.parser')
#soup_nome

NOMES = []
for i in soup_nome.find_all(class_ ="select2-results-dept-0 select2-result select2-result-selectable"):
    #print(i.get_text())
    NOMES.append(i.get_text())
#del(NOME[0])

NOMES

# %% [markdown]
# # detecção problemas de inserção de registros

# %%
dias_fds = ['07','08','14','15','21','22']

for semana in tabela['Semana'].unique(): 
    tabela_semana = tabela[tabela['Semana'] == semana] # _isolar semana_
    #print('SEMANA', semana, '='*50)

    for dia in tabela_semana['Dia'].unique(): #verifique cada dia
        #print('DIA', dia, '='*40)
        tab_dia = tabela_semana[tabela_semana['Dia'] == str(dia)] #tabela dia XX # _isolar dia_
        tab_dia.reset_index(drop=True, inplace=True) #resetando index

        #ENCONTRANDO REGISTRO UNICOS, QUE NÃO SEJAM FINAL DE SEMANA COM PERIODOS MAIOR QUE 6H
        if len(tab_dia) == 1: #se contem apenas um registro
            if dia in dias_fds and int(tab_dia['Saida'][0][:2]) - int(tab_dia['Entrada'][0][:2]) <= 6:
                continue #pule 
            elif (int(tab_dia['Dia'][0]) <= 25 and semana == 1) or (int(tab_dia['Dia'][0]) == 1 and semana == 5):
                continue #pule 
            else: #se não for final de semana
                print(dia, '- valor unico:', '[', 
                      tab_dia['Entrada'][0][:2],'...',tab_dia['Saida'][0][:2],
                      '-',tab_dia['Unidade'][0],'-',tab_dia['Periodo'][0],']') #indique
                #print(int(tab_dia['Saida'][0][:2]), int(tab_dia['Entrada'][0][:2]))

        #ENCONTRANDO DIAS QUE NÃO BATEM OS HORARIOS DE ENTRADA E SAIDA DOS TURNOS
        for t in range(len(tab_dia)): #para cada registro da tabela
            if t != 0: #em excessão do primeiro
                if tab_dia['Entrada'][t] != tab_dia['Saida'][t-1]: 
                    #verifique se a hora do inicio do plantão é igual a fim do plantão anterior
                    print(dia, '- erro entre os horarios:', 
                          '[', tab_dia['Entrada'][t], '...',tab_dia['Saida'][t-1],']') #se for, indique                        

        #ENCONTRANDO DIAS COM MAIS DE UMA UNIDADE REGISTRADA
        unidades_presentes = tab_dia['Unidade'].unique()
        if len(unidades_presentes) != 1:
            print(dia, '- unidade diferentes:', unidades_presentes)

        #ENCONTRANDO FINAIS DE SEMANA REGISTRADO COMO SEMANA
        if dia in dias_fds:
            for registro in range(len(tab_dia)):
                if 'FDS' not in tab_dia['Periodo'][registro]:
                    if (int(tab_dia['Dia'][registro]) == 31 and semana == 1) or (int(tab_dia['Dia'][registro]) <= 3 and semana == 5):
                        continue
                    else:
                        print(tab_dia['Dia'][registro], "- fim de semana errado:",
                              '[', tab_dia['Periodo'][registro], ']')

        if dia not in dias_fds:
            for registro in range(len(tab_dia)):
                if 'SEMANA' not in tab_dia['Periodo'][registro]:
                    if (int(tab_dia['Dia'][registro]) == 31 and semana == 1) or (int(tab_dia['Dia'][registro]) <= 3 and semana == 5):
                        continue
                    else:
                        print(tab_dia['Dia'][registro], '- dia da semana errado:',
                              '[', tab_dia['Periodo'][registro], ']')

        for j in range(len(tab_dia)):
            if tab_dia['Periodo'][j] == 'FDS - PLANTAO':
                if int(tab_dia['Entrada'][j][0:2]) < 18:
                    print(tab_dia['Dia'][j], '- [FDS - PLANTÃO] registrado a tarde -'
                          '[', tab_dia['Entrada'][j], '...',tab_dia['Saida'][j],']')
            if tab_dia['Periodo'][j] == 'FDS - SAIDA':
                if int(tab_dia['Entrada'][j][0:2]) > 18:
                    print(tab_dia['Dia'][j], '- [FDS - SAIDA] registrado a noite -'
                          '[', tab_dia['Entrada'][j], '...',tab_dia['Saida'][j],']')

# %%
#Para cada profissional na lista
df = df_backup[count:]

for i in df['nome'].unique():
    print("nome:", i)
    df_nome = df[df['nome'] == i]
    df_nome.reset_index(drop=True, inplace=True)
    
    browser.find_element("xpath", '//*[@id="s2id_ddlProfessionals"]/a/span[1]').click()
    sleep(2)
    browser.find_element("xpath", '/html/body/div[7]/div/input').send_keys(i)
    browser.find_element("xpath", '//*[@id="select2-drop"]/ul/li/div').click()

    #esperando carregamento do site
    WebDriverWait(browser, 30).until_not(visibility_of(browser.find_element("xpath", '//*[@id="loader"]')))
    
    tabela = funcao()
    tabela
    
    sleep(2)
    
    #Para cada registro na lista_nome
    for t in range(len(df_nome)):
        print(count)
        print(df_nome['mensagem'][t])
        
        dia_sel = tabela[(tabela['Unidade'] == df_nome['unidade'][t]) & 
                 (tabela['data'] == df_nome['data'][t]) & 
                 (tabela['Periodo'] == df_nome["setor"][t])]
        dia_sel.reset_index(drop=True, inplace=True)
        dia_sel
        
        if len(dia_sel) == 0:
            print("PROB")
            df_backup['controle'][count] = "PROB"
        else:
            print("OK")
            df_backup['controle'][count] = "OK"
        count += 1
